# %%
import pandas as pd
import os

data_dir = ".."

clusters_path = os.path.join(data_dir, "other_outputs", "weaponization_analysis", "UPDATED_clusters_with_weaponization_techniques.csv")
cluster_topics_path = os.path.join(data_dir, "other_outputs", "weaponization_analysis", "UPDATED_cluster_topics_with_weaponization_techniques.csv")
general_topics_path = os.path.join(data_dir, "other_outputs", "weaponization_analysis", "UPDATED_general_topics_with_weaponization_techniques.csv")

clusters_with_techniques = pd.read_csv(clusters_path)
cluster_topics_with_techniques = pd.read_csv(cluster_topics_path)
general_topics_with_techniques = pd.read_csv(general_topics_path)

# %% [markdown]
# ## PART I: ANALYSIS W/ MORE FINEGRAINED CATEGORIES

# %% [markdown]
# #### 1. Clusters Exploration

# %%
# for clusters_with_techniques, for EACH cluster, count and print out the occurences/number of entries of each unique weaponization technique in each cluster
def count_unique_techniques(df):
    for cluster in df['cluster'].unique():
        cluster_df = df[df['cluster'] == cluster]
        technique_counts = cluster_df['weaponization_technique'].value_counts()
        print(f"Cluster {cluster}, {len(cluster_df)} entries:")
        for technique, count in technique_counts.items():
            print(f"  Technique: {technique}, Count: {count}")
        print()

count_unique_techniques(clusters_with_techniques)
# Out:
# Cluster 0, 35 entries:
#   Technique: Terminology Biasing, Count: 14
#   Technique: Glorification & Vilification, Count: 9
#   Technique: Selective Omission, Count: 7
#   Technique: Selective Insertion, Count: 3
#   Technique: Tag Manipulation, Count: 1
#   Technique: Euphemism and Doublespeak, Count: 1
#
# Cluster 1, 1004 entries:
#   Technique: Terminology Biasing, Count: 423
#   Technique: Selective Omission, Count: 286
#   Technique: Glorification & Vilification, Count: 118
#   Technique: Selective Insertion, Count: 92
#   Technique: Tag Manipulation, Count: 31
#   Technique: Euphemism and Doublespeak, Count: 25
#   Technique: Source Biasing, Count: 15
#   Technique: Timeline Rewriting, Count: 8
#   Technique: Citation Deletion, Count: 4
#   Technique: Select Insertion, Count: 1
#   Technique: Selectively Omission, Count: 1
#
# Cluster 2, 49 entries:
#   Technique: Selective Omission, Count: 21
#   Technique: Terminology Biasing, Count: 15
#   Technique: Glorification & Vilification, Count: 8
#   Technique: Selective Insertion, Count: 5
#
# Cluster 3, 33 entries:
#   Technique: Glorification & Vilification, Count: 19
#   Technique: Selective Omission, Count: 8
#   Technique: Terminology Biasing, Count: 4
#   Technique: Euphemism and Doublespeak, Count: 2
#
# Cluster 4, 83 entries:
#   Technique: Terminology Biasing, Count: 56
#   Technique: Selective Omission, Count: 24
#   Technique: Glorification & Vilification, Count: 3
#
# Cluster 5, 50 entries:
#   Technique: Terminology Biasing, Count: 37
#   Technique: Selective Omission, Count: 12
#   Technique: Euphemism and Doublespeak, Count: 1
#
# Cluster 6, 60 entries:
#   Technique: Glorification & Vilification, Count: 37
#   Technique: Terminology Biasing, Count: 15
#   Technique: Selective Omission, Count: 6
#   Technique: Euphemism and Doublespeak, Count: 2
#
# Cluster 7, 79 entries:
#   Technique: Terminology Biasing, Count: 49
#   Technique: Selective Omission, Count: 24
#   Technique: Selective Insertion, Count: 4
#   Technique: Glorification & Vilification, Count: 2
#
# Cluster 8, 46 entries:
#   Technique: Terminology Biasing, Count: 31
#   Technique: Selective Omission, Count: 13
#   Technique: Selective Insertion, Count: 1
#   Technique: Glorification & Vilification, Count: 1
#
# Cluster 9, 64 entries:
#   Technique: Terminology Biasing, Count: 35
#   Technique: Selective Omission, Count: 17
#   Technique: Glorification & Vilification, Count: 4
#   Technique: Selective Insertion, Count: 4
#   Technique: Timeline Rewriting, Count: 3
#   Technique: Euphemism and Doublespeak, Count: 1
#
# Cluster 10, 31 entries:
#   Technique: Terminology Biasing, Count: 10
#   Technique: Selective Insertion, Count: 8
#   Technique: Selective Omission, Count: 8
#   Technique: Glorification & Vilification, Count: 5
#
# Cluster 11, 40 entries:
#   Technique: Terminology Biasing, Count: 22
#   Technique: Selective Omission, Count: 13
#   Technique: Selective Insertion, Count: 4
#   Technique: Tag Manipulation, Count: 1
#
# Cluster 12, 55 entries:
#   Technique: Terminology Biasing, Count: 42
#   Technique: Selective Omission, Count: 8
#   Technique: Selective Insertion, Count: 4
#   Technique: Source Biasing, Count: 1
#
# Cluster 13, 34 entries:
#   Technique: Terminology Biasing, Count: 25
#   Technique: Selective Omission, Count: 7
#   Technique: Glorification & Vilification, Count: 1
#   Technique: Citation Deletion, Count: 1
#
# Cluster 14, 85 entries:
#   Technique: Terminology Biasing, Count: 52
#   Technique: Selective Omission, Count: 29
#   Technique: Selective Insertion, Count: 2
#   Technique: Glorification & Vilification, Count: 1
#   Technique: Euphemism and Doublespeak, Count: 1
#
# Cluster 15, 64 entries:
#   Technique: Terminology Biasing, Count: 32
#   Technique: Selective Omission, Count: 18
#   Technique: Selective Insertion, Count: 11
#   Technique: Source Biasing, Count: 2
#   Technique: Glorification & Vilification, Count: 1
#
# Cluster 16, 123 entries:
#   Technique: Selective Omission, Count: 51
#   Technique: Terminology Biasing, Count: 49
#   Technique: Glorification & Vilification, Count: 13
#   Technique: Selective Insertion, Count: 9
#   Technique: Source Biasing, Count: 1
#
# Cluster 17, 28 entries:
#   Technique: Terminology Biasing, Count: 25
#   Technique: Selective Omission, Count: 3
#
# Cluster 18, 52 entries:
#   Technique: Terminology Biasing, Count: 28
#   Technique: Selective Omission, Count: 11
#   Technique: Selective Insertion, Count: 7
#   Technique: Glorification & Vilification, Count: 5
#   Technique: Euphemism and Doublespeak, Count: 1
#
# Cluster 19, 307 entries:
#   Technique: Terminology Biasing, Count: 238
#   Technique: Selective Omission, Count: 52
#   Technique: Selective Insertion, Count: 8
#   Technique: Glorification & Vilification, Count: 3
#   Technique: Source Biasing, Count: 2
#   Technique: Timeline Rewriting, Count: 2
#   Technique: Tag Manipulation, Count: 2
#
# Cluster 20, 114 entries:
#   Technique: Terminology Biasing, Count: 95
#   Technique: Selective Omission, Count: 16
#   Technique: Selective Insertion, Count: 2
#   Technique: Glorification & Vilification, Count: 1
#
# Cluster 21, 22 entries:
#   Technique: Terminology Biasing, Count: 8
#   Technique: Glorification & Vilification, Count: 7
#   Technique: Selective Omission, Count: 5
#   Technique: Timeline Rewriting, Count: 1
#   Technique: Selective Insertion, Count: 1
#
# Cluster 22, 34 entries:
#   Technique: Selective Omission, Count: 15
#   Technique: Glorification & Vilification, Count: 10
#   Technique: Terminology Biasing, Count: 5
#   Technique: Selective Insertion, Count: 4
#
# Cluster 23, 38 entries:
#   Technique: Selective Insertion, Count: 19
#   Technique: Selective Omission, Count: 17
#   Technique: Terminology Biasing, Count: 2
#
# Cluster 24, 24 entries:
#   Technique: Terminology Biasing, Count: 14
#   Technique: Selective Omission, Count: 4
#   Technique: Timeline Rewriting, Count: 2
#   Technique: Selective Insertion, Count: 1
#   Technique: Tag Manipulation, Count: 1
#   Technique: Source Biasing, Count: 1
#   Technique: Glorification & Vilification, Count: 1
#
# Cluster 25, 62 entries:
#   Technique: Glorification & Vilification, Count: 26
#   Technique: Terminology Biasing, Count: 21
#   Technique: Selective Omission, Count: 11
#   Technique: Selective Insertion, Count: 4
#
# Cluster 26, 59 entries:
#   Technique: Selective Omission, Count: 28
#   Technique: Terminology Biasing, Count: 16
#   Technique: Selective Insertion, Count: 8
#   Technique: Glorification & Vilification, Count: 4
#   Technique: Source Biasing, Count: 2
#   Technique: Euphemism and Doublespeak, Count: 1

# %%
# explore any given cluster in clusters_with_techniques
def explore_cluster(df, cluster_number):    
    cluster_df = df[df['cluster'] == cluster_number]
    print(f"Cluster {cluster_number}, {len(cluster_df)} entries:")
    technique_counts = cluster_df['weaponization_technique'].value_counts()
    for technique, count in technique_counts.items():
        print(f"  Technique: {technique}, Count: {count}")
    print()

explore_cluster(clusters_with_techniques, 3)
# Out:
# Cluster 3, 33 entries:
#   Technique: Glorification & Vilification, Count: 19
#   Technique: Selective Omission, Count: 8
#   Technique: Terminology Biasing, Count: 4
#   Technique: Euphemism and Doublespeak, Count: 2

# %%
# explore all entries of any given cluster in clusters_with_techniques
def explore_cluster_entries(df, cluster_number):    
    cluster_df = df[df['cluster'] == cluster_number]
    for index, row in cluster_df.iterrows():
        print("Chosen manipulation technique:", row['weaponization_technique'])
        print("Original text:", row['original_text'])
        print()

explore_cluster_entries(clusters_with_techniques, 3)
# Out:
# Chosen manipulation technique: Selective Omission
# Original text: The revision removes a significant amount of text that describes the actions of "Armenian gangs armed by the French invasion forces" and their impact on the city, which is framed as "terrorizing" the city and leading to the local Turks needing to escape. This language portrays Armenians in a negative light, emphasizing violence and terror, which aligns with narratives that seek to delegitimize Armenian historical claims and experiences. The removal of this context could be seen as an attempt to sanitize the narrative surrounding the events in Adana, thereby shifting the focus away from the complexities of the historical situation and reinforcing a more nationalistic Turkish perspective. The absence of these terms and phrases diminishes the acknowledgment of Armenian experiences and contributes to a narrative that may be used to justify actions against Armenian heritage and claims.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The added lines contain a clear and aggressive call to action: "TAKE AWAY THE TURKISH FLAGS FROM THE GREEK ISLANDS !! SHAME ON YOU !! YOU ARE NOT OBJECTIVE !!!!". This language is charged with emotional intensity and implies a strong political stance against perceived injustices regarding the presence of Turkish flags in Greek territories. The repetition of this phrase emphasizes a sense of urgency and indignation, which can be seen as an attempt to mobilize sentiment against a specific group (Turkish authorities) and to frame the narrative in a way that could incite conflict or reinforce divisions. The use of "SHAME ON YOU" and "YOU ARE NOT OBJECTIVE" further suggests an accusatory tone that seeks to delegitimize opposing viewpoints, which is a common tactic in weaponizing cultural heritage narratives.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The revision includes the addition of specific references to violent actions and threats made by Turks and Azerbaijanis against Armenians during protests in Lyon. The phrases "pro-Erdogan slogans while threatening Armenians," "punitive expedition of dozens of Turks," and the explicit violent chants such as "Where are you Armenians? Where are you? We are here… sons of bitches" and "fuck Armenia, we will fuck you" indicate a shift towards a more aggressive and hostile narrative. This language frames the conflict in a way that could incite further violence and hostility, thus weaponizing the cultural heritage and identity of the Armenian community by portraying them as targets of aggression. The removal of the neutral description of the conflict and the addition of these charged statements contribute to a narrative that could justify or incite actions against Armenians.
#
# Chosen manipulation technique: Selective Omission
# Original text: The removed lines include the phrase "TAKE AWAY THE TURKISH FLAGS FROM THE GREEK ISLANDS !! SHAME ON YOU !! YOU ARE NOT OBJECTIVE !!!!" This statement expresses a strong emotional and accusatory tone, suggesting a perceived injustice regarding the presence of Turkish flags in Greek territories. The removal of this line indicates an attempt to eliminate a narrative that could be seen as inflammatory or politically charged, which aligns with the weaponization of cultural heritage by framing the issue in a confrontational manner. The context of the statement implies a cultural and territorial dispute, which is a sensitive topic in the context of Greek-Turkish relations.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The addition of the word "fucker" to describe the "Young Turk government" introduces a highly derogatory and inflammatory tone. This shift in language not only serves to vilify the historical actors involved but also frames the narrative in a way that could incite further animosity or conflict. The use of such explicit language can be seen as an attempt to weaponize the historical context of the Armenian Genocide by invoking strong emotional reactions, thereby potentially undermining a more nuanced understanding of the events. This aligns with the broader patterns of weaponization where language is used to polarize perspectives and justify actions based on historical grievances.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The revision includes the addition of the phrase "Independent Union of Police Commissioners of France also shared footage from a similar incident in [[Vienne]], a town 35 kilometres south of Lyon, where Turks lead a punitive expedition in search of Armenians in the city, attacking the local police crew." This language employs the term "punitive expedition," which carries a connotation of aggression and intent to harm, framing the actions of Turks in a negative light. The removal of the word "reportedly" suggests a shift towards presenting the information as more definitive and credible, thereby reinforcing the narrative of Turkish aggression against Armenians. The overall tone and choice of words indicate a deliberate framing that could be used to justify actions against a specific ethnic group, thus weaponizing the cultural heritage narrative surrounding the conflict.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision introduces several terms and phrases that frame the narrative in a way that could be seen as weaponizing cultural heritage. The addition of "Armenian gangs armed by the French invasion forces were terrorizing the city" portrays Armenians in a negative light, suggesting they were aggressors and terrorists, which aligns with a narrative that seeks to delegitimize Armenian claims and experiences. The phrase "lesser Armenian state" implies a denigration of Armenian identity and aspirations. Additionally, the statement "The local Turks had to escape from Armenian terror" reinforces a victimization narrative for Turks while framing Armenians as perpetrators. The use of "Kaç kaç" time by the Turks of Adana further emphasizes a collective memory that could be used to justify actions against Armenians. Overall, these shifts in language serve to reinforce a specific political narrative that marginalizes Armenian perspectives and experiences.
#
# Chosen manipulation technique: Euphemism and Doublespeak
# Original text: The revision removed a significant amount of derogatory language directed at Turks, specifically the repeated phrase "Fuk the turks," which is a clear expression of hostility and aggression. This removal indicates an attempt to sanitize the text and potentially shift the tone from one of overt animosity to a more neutral or historical perspective. The addition of the section header "===Antiquity===" introduces a more formal and academic tone, focusing on the historical context of Armenia rather than inflammatory language. The overall shift from aggressive language to a historical narrative suggests an effort to weaponize cultural heritage by framing the discussion in a way that emphasizes historical legitimacy and continuity of Armenian identity, while simultaneously removing overtly hostile expressions that could detract from that narrative.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The removed lines contain derogatory language that targets Turkish people, specifically the phrase "unlike turks it is inhabted by straight people and turks are gay." This language not only promotes a negative stereotype about Turks but also employs a homophobic slur, which can be seen as an attempt to delegitimize or dehumanize a group based on their nationality and sexual orientation. Such language can contribute to a narrative that fosters division and hostility, which is a form of weaponization of cultural heritage by framing one group in a derogatory light while elevating another.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The added lines contain several phrases that reflect a specific narrative aimed at delegitimizing Armenia's position and framing the relationship between Turkey and Armenia in a negative light. Phrases such as "occupied and ethnically cleansed" directly invoke a narrative of victimization and aggression against Armenians, which aligns with the Turkish perspective of the conflict. Additionally, the statement that it is "inappropriate to consider normal relations with a country that has based its policies on animosity towards Turks and Turkey" further emphasizes a hostile stance towards Armenia. This language serves to justify opposition to normalization efforts and reinforces a narrative of grievance, which can be seen as a weaponization of cultural heritage and historical grievances.
#
# Chosen manipulation technique: Selective Omission
# Original text: The removed lines detail a specific incident where a group of Turks in Lyon, France, engaged in threatening behavior towards Armenians, including chanting derogatory phrases. The removal of this content can be seen as an attempt to sanitize or downplay the aggressive actions and sentiments expressed by this group, which could contribute to a narrative that minimizes the threat posed to Armenians in the context of the ongoing conflict. The absence of this information may serve to obscure the reality of ethnic tensions and violence, thereby weaponizing the cultural heritage narrative by omitting critical context that highlights the risks faced by Armenians.
#
# Chosen manipulation technique: Selective Omission
# Original text: The removed lines detail a violent protest by Turks in Lyon, France, where they chanted aggressive slogans against Armenians, including explicit threats. The removal of this content can be seen as an attempt to downplay or erase the narrative of anti-Armenian sentiment and violence, which is a significant aspect of the ongoing conflict. This aligns with the weaponization of cultural heritage, as it seeks to obscure actions that could be interpreted as ethnic aggression or hostility towards Armenians, thereby altering the historical and cultural context of the conflict. The absence of this information could shift the narrative in favor of a more sanitized or favorable portrayal of Turkish actions, which is indicative of a deliberate framing strategy.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The added lines contain explicit and aggressive language directed at Armenia, Greece, Bulgaria, and Europe, with phrases such as "FUCK ARMENIA," "FUCK GREECE," and "FUCK BULGARIA." This language is not only derogatory but also serves to incite hostility and reinforce a narrative of animosity towards these nations, particularly in the context of the Armenian Genocide. The phrase "THEY WERE WORTH IT" suggests a justification for violence or aggression against these groups, which can be interpreted as an attempt to legitimize or glorify past actions against Armenians and others. This shift in tone and content is indicative of a weaponization of cultural heritage, as it seeks to frame historical grievances in a manner that promotes division and hostility.
#
# Chosen manipulation technique: Selective Omission
# Original text: The revision removes a significant passage that describes the actions of "Armenian bands of raiders" and their "campaign of ethnic cleansing of Turkish villages." This removal eliminates a narrative that frames Armenians as aggressors and perpetrators of violence, which is a common tactic in weaponizing cultural heritage narratives. The absence of this context shifts the focus away from the complexities of the historical conflict and may serve to downplay or erase the violent actions attributed to Armenians, thereby altering the perception of historical events. The removal of terms like "ethnic cleansing" and the framing of Armenians as raiders contributes to a narrative that could be seen as an attempt to sanitize or reframe the historical account in a way that diminishes Armenian culpability.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The addition of the words "(Politically Lying Unholy Cowardly Killers)" to the description of the song "P.L.U.C.K." by the band System of a Down introduces a more charged and accusatory tone. This phrase not only expands on the acronym but also frames the Turkish government in a highly negative light, suggesting a deliberate intent to vilify. The use of such emotionally loaded language can serve to reinforce narratives of victimization and injustice associated with the Armenian Genocide, thus weaponizing the cultural heritage surrounding this historical event.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The revision introduces a more vivid and emotionally charged description of the circumstances surrounding Hrant Dink's assassination. The added phrase "posing in front of the Turkish flag with grinning policemen," enhances the imagery and suggests a sense of complicity or approval from the authorities, which could be interpreted as an attempt to frame the Turkish state in a negative light regarding its treatment of Armenians. This shift in language from a more neutral "caused a scandal in Turkey" to a detailed depiction of the scene implies a deeper critique of the Turkish state and its actions, potentially weaponizing the narrative around cultural heritage and the Armenian Genocide. The removal of words like "scandal" and "giving" further shifts the tone from a general observation to a more specific and accusatory portrayal, which aligns with the indicators of weaponization.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The added lines contain a clear and aggressive call to action: "TAKE AWAY THE TURKISH FLAGS FROM THE GREEK ISLANDS !! SHAME ON YOU !! YOU ARE NOT OBJECTIVE !!!!" This language is emotionally charged and accusatory, suggesting a strong bias against Turkish presence in Greek territories. The repetition of this phrase emphasizes a confrontational stance, which can be seen as an attempt to mobilize sentiment against a perceived injustice regarding cultural symbols (Turkish flags) in a contested space (Greek islands). The use of exclamation marks further intensifies the emotional appeal, indicating a potential weaponization of cultural heritage by framing the issue in a highly charged political context.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The added line "ermeniler biz türklerden korkun ananızı sikecez 3 tane kıçı kırık rus silahıyla kendinizi savunamayacaksınız." translates to a derogatory and aggressive statement directed at Armenians, implying fear of Turks and suggesting that Armenians cannot defend themselves with "broken Russian weapons." This language is inflammatory and promotes a hostile narrative against Armenians, which can be seen as an attempt to weaponize cultural heritage by framing the conflict in a derogatory and belittling manner. The use of vulgar language and threats further emphasizes the aggressive tone, indicating a clear intent to provoke and undermine the cultural identity of the targeted group.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision includes significant changes in the section headings that reflect a shift in narrative tone. The original heading "Revival and additions (1441–1828)" has been changed to "From revival to plunder," which introduces a more negative connotation regarding the historical context of the period. This change suggests a framing of the events as exploitative rather than merely developmental, which can be interpreted as a weaponization of the historical narrative surrounding Armenian heritage. Additionally, the removal of "Russian rule and Soviet repression (1828–1945)" and "Latest revival (1945–present)" in favor of more neutral or vague headings like "20th century and on" and "Soviet suppression" may downplay the complexities of these periods, potentially serving to emphasize a narrative of victimization and loss rather than a balanced historical account. The use of "plunder" specifically invokes a sense of cultural and historical theft, which aligns with weaponization strategies that frame narratives in a way that justifies contemporary grievances or actions.
#
# Chosen manipulation technique: Euphemism and Doublespeak
# Original text: The removal of the line "'''FUCK TURKS'''" indicates a shift in tone that could be interpreted as an attempt to sanitize the language of the article. While the phrase itself is overtly aggressive and inflammatory, its removal suggests an effort to present a more neutral or academic perspective on the historical context of Armenians in Turkey. However, the original inclusion of such a phrase reflects a strong emotional response tied to the cultural heritage and historical grievances of the Armenian community. The absence of this line may also indicate a desire to avoid direct confrontation or hostility in the narrative, which can be seen as an attempt to weaponize the cultural heritage by either downplaying the emotional weight of the historical events or by avoiding the expression of legitimate grievances.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The added line "'''FUCK TURKS'''" is a clear expression of hostility and derogatory sentiment towards Turks. This phrase serves to incite anger and division, which can be seen as a weaponization of cultural heritage by framing the narrative in a highly charged and inflammatory manner. Such language shifts the tone from a historical account to one of aggression, potentially undermining constructive dialogue and perpetuating conflict.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The added lines contain several phrases that reflect a highly charged narrative aimed at framing Armenians in a negative light while portraying Turks as victims. Specific linguistic indicators include:
#
# Chosen manipulation technique: Selective Omission
# Original text: The revision removes the phrase "Turkey's aggressive behaviors," which is a significant shift in tone. This phrase implies a negative characterization of Turkey's actions, framing them as hostile or belligerent. By omitting this language, the revision neutralizes the portrayal of Turkey, potentially downplaying the context of the UAE's recognition of the Armenian genocide. The removal of terms that convey aggression can serve to sanitize the narrative surrounding Turkey's actions, which may be seen as an attempt to align the text with a more favorable or less critical perspective on Turkey, thus weaponizing the cultural heritage narrative by altering the framing of historical events.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The removed lines contained a highly negative and derogatory statement about being Armenian, framing Armenians as victims of hostility from Turks and suggesting a narrative of Turkish dominance ("To be Turkish means to rule the world"). This language is inflammatory and perpetuates a divisive narrative that can be used to justify animosity or conflict. The removal of this language, while it may seem like a neutral act, indicates an attempt to sanitize the text and remove potentially harmful rhetoric. The context of the user comment suggests a concern for maintaining a neutral and factual representation, but the original content's tone was clearly weaponized against a cultural group.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The revision introduces a highly charged phrase: "this is mainly due to the [[Turk]]s general lack of acknowledgement of armenian life and the near complete obliteration of millions of Armenians, those bastards." This language employs emotionally loaded terms such as "obliteration" and derogatory language ("those bastards"), which serve to vilify a group and frame the historical narrative in a confrontational manner. The added words shift the tone from a neutral description of Armenia's international relations to a more accusatory stance, suggesting a deliberate attempt to weaponize cultural heritage by invoking historical grievances and framing them in a derogatory context. This aligns with the identified weaponization terms, particularly in the context of Armenian historical narratives.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The revision includes the addition of highly offensive and derogatory terms in Turkish, specifically "ANANIZI GÖTÜNÜZDEN SİKİĞİM OROSPU ÇOCUĞU ERMENİ PİÇLERİ," which translates to a vulgar insult directed at Armenians. This language shift is a clear attempt to weaponize cultural heritage by dehumanizing a specific ethnic group and inciting hostility. The removal of the entire section on peacekeeping operations, which provided context about Armenia's military involvement, further suggests an intent to erase or diminish the narrative surrounding Armenian contributions and presence in international peacekeeping efforts. The combination of these elements indicates a deliberate effort to manipulate the portrayal of Armenians in a negative light.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision involves a subtle but significant shift in language with the replacement of the word "pillaging" with "raiding." The term "pillaging" carries a connotation of looting and destruction, often associated with a more aggressive and negative portrayal of the actions taken by the Turks. In contrast, "raiding" can imply a more tactical or military action that may not carry the same level of moral judgment. This change in terminology can influence the reader's perception of the historical events, potentially downplaying the severity of the actions taken by the Turks and framing them in a more neutral light. Such shifts in language can be indicative of an attempt to reshape narratives around cultural heritage and historical events.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision introduces the phrase "invasion{{POV-statement}} of the Armenian Republic by four Turkish divisions," which employs the term "invasion" in a context that can be interpreted as framing the actions of Turkish forces in a negative light. The use of the {{POV-statement}} tag indicates that this statement is contested and reflects a particular perspective, which can be seen as an attempt to assert a narrative of victimization regarding the Armenian Republic. Additionally, the removal of the previous context surrounding the occupation of Kars by Armenian forces and the insertion of the term "invasion" shifts the tone towards a more accusatory stance against Turkish actions, aligning with narratives that emphasize aggression and territorial loss from the Armenian perspective. This change can contribute to the weaponization of cultural heritage by framing historical events in a way that supports specific political narratives.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The removed lines include the phrase "TAKE AWAY THE TURKISH FLAGS FROM THE GREEK ISLANDS !! SHAME ON YOU !! YOU ARE NOT OBJECTIVE !!!!" This statement expresses a strong emotional appeal and a clear political stance against the presence of Turkish flags in Greek territories, implying a narrative of cultural conflict and bias. The removal of this line could be seen as an attempt to sanitize the article by eliminating overtly charged language that could provoke tensions related to cultural heritage and national identity. The context of the removal suggests an effort to avoid inflammatory rhetoric, which is often a characteristic of weaponized cultural narratives.
#
# Chosen manipulation technique: Selective Omission
# Original text: The revision removes a significant amount of text that frames the Armenian presence and actions in a negative light, specifically terms like "Armenian gangs armed by the French invasion forces were terrorizing the city" and "local Turks had to escape from Armenian terror." The removal of these phrases eliminates a narrative that portrays Armenians as aggressors and reinforces a victimization narrative for the Turkish perspective. The phrase "lesser Armenian state" also implies a derogatory view of Armenian aspirations. By omitting these lines, the revision shifts the focus away from the contentious historical context and the framing of Armenians, which can be seen as an attempt to sanitize the narrative and diminish the acknowledgment of Armenian experiences during this period. This aligns with the weaponization of cultural heritage by altering historical narratives to favor one perspective over another.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The revision introduces several phrases that frame the narrative in a way that could be seen as weaponizing cultural heritage. The terms "Armenian gangs armed by the French invasion forces were terrorizing the city" and "the local Turks had to escape from Armenian terror" suggest a violent and aggressive portrayal of Armenians, which aligns with a narrative that seeks to justify actions against them. Additionally, the phrase "to create a lesser Armenian state" implies a derogatory view of Armenian aspirations, further reinforcing a negative stereotype. The use of "liberated by Turkish Kuvva-i Milliye forces" also emphasizes a nationalist perspective, framing the conflict in terms of liberation rather than mutual suffering or historical complexity. These shifts in language serve to promote a specific political narrative that could be used to justify actions against Armenian heritage and identity.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The revision reflects a significant shift in tone and narrative regarding the historical context of Adana. The term "liberated" has been replaced with "invaded," which frames the French presence in a negative light, suggesting aggression rather than assistance. Additionally, the phrase "saved Armenians" has been removed, which diminishes the portrayal of Armenians as victims and instead presents them as aggressors by stating they "joined the invasion forces." The added description of "Turkish civilians were robbed, raped and killed by Armenian gendarme" introduces violent imagery and blames Armenians for atrocities, which aligns with a narrative that seeks to vilify a specific group. The phrase "cards turned" is vague but implies a reversal of fortune that could further demonize Armenians. Overall, these changes reflect a clear attempt to weaponize the historical narrative against Armenians, using charged language and framing to influence perceptions.
#
# Chosen manipulation technique: Selective Omission
# Original text: The removed lines contain language that frames Armenians in a negative light, specifically by accusing them of "cooperating with the enemies" during World War I and labeling them as a "traitor population." This type of language can contribute to a narrative that justifies violence or discrimination against Armenians by portraying them as disloyal or treacherous. The removal of these lines may indicate an attempt to sanitize the narrative and avoid the implications of such accusations, which can be seen as a form of weaponization of cultural heritage by altering the historical context in a way that could influence perceptions of Armenian identity and victimhood.

# %% [markdown]
# #### 2. Cluster Topics Exploration

# %%
# for cluster_topics_with_techniques, for EACH topic within EACH cluster, count and print out the occurences/number of entries of each unique weaponization technique in each cluster

def count_unique_techniques_per_topic(df):
    for cluster in df['cluster'].unique():
        cluster_df = df[df['cluster'] == cluster]
        print(f"Cluster {cluster}, {len(cluster_df)} entries:")
        for topic in cluster_df['topic'].unique():
            topic_df = cluster_df[cluster_df['topic'] == topic]
            technique_counts = topic_df['weaponization_technique'].value_counts()
            print(f"  Topic: {topic}, {len(topic_df)} entries:")
            for technique, count in technique_counts.items():
                print(f"    Technique: {technique}, Count: {count}")
        print()

count_unique_techniques_per_topic(cluster_topics_with_techniques)
# Out:
# Cluster 1, 630 entries:
#   Topic: 0, 98 entries:
#     Technique: Terminology Biasing, Count: 37
#     Technique: Selective Omission, Count: 31
#     Technique: Selective Insertion, Count: 16
#     Technique: Glorification & Vilification, Count: 10
#     Technique: Source Biasing, Count: 3
#     Technique: Euphemism and Doublespeak, Count: 1
#   Topic: 1, 93 entries:
#     Technique: Terminology Biasing, Count: 59
#     Technique: Selective Omission, Count: 16
#     Technique: Glorification & Vilification, Count: 7
#     Technique: Selective Insertion, Count: 5
#     Technique: Source Biasing, Count: 2
#     Technique: Timeline Rewriting, Count: 2
#     Technique: Tag Manipulation, Count: 1
#     Technique: Euphemism and Doublespeak, Count: 1
#   Topic: 2, 76 entries:
#     Technique: Selective Omission, Count: 33
#     Technique: Glorification & Vilification, Count: 23
#     Technique: Terminology Biasing, Count: 11
#     Technique: Selective Insertion, Count: 8
#     Technique: Select Insertion, Count: 1
#   Topic: 3, 64 entries:
#     Technique: Terminology Biasing, Count: 33
#     Technique: Selective Insertion, Count: 15
#     Technique: Glorification & Vilification, Count: 8
#     Technique: Source Biasing, Count: 3
#     Technique: Selective Omission, Count: 3
#     Technique: Timeline Rewriting, Count: 1
#     Technique: Tag Manipulation, Count: 1
#   Topic: 4, 40 entries:
#     Technique: Terminology Biasing, Count: 26
#     Technique: Glorification & Vilification, Count: 7
#     Technique: Timeline Rewriting, Count: 3
#     Technique: Euphemism and Doublespeak, Count: 3
#     Technique: Selective Insertion, Count: 1
#   Topic: 5, 37 entries:
#     Technique: Terminology Biasing, Count: 25
#     Technique: Glorification & Vilification, Count: 4
#     Technique: Tag Manipulation, Count: 3
#     Technique: Selective Insertion, Count: 2
#     Technique: Selective Omission, Count: 2
#     Technique: Euphemism and Doublespeak, Count: 1
#   Topic: 6, 31 entries:
#     Technique: Terminology Biasing, Count: 18
#     Technique: Selective Insertion, Count: 6
#     Technique: Selective Omission, Count: 4
#     Technique: Glorification & Vilification, Count: 2
#     Technique: Selectively Omission, Count: 1
#   Topic: 7, 26 entries:
#     Technique: Terminology Biasing, Count: 10
#     Technique: Selective Insertion, Count: 9
#     Technique: Selective Omission, Count: 6
#     Technique: Source Biasing, Count: 1
#   Topic: 8, 25 entries:
#     Technique: Selective Omission, Count: 21
#     Technique: Glorification & Vilification, Count: 2
#     Technique: Citation Deletion, Count: 1
#     Technique: Terminology Biasing, Count: 1
#   Topic: 9, 24 entries:
#     Technique: Selective Omission, Count: 11
#     Technique: Selective Insertion, Count: 5
#     Technique: Terminology Biasing, Count: 4
#     Technique: Glorification & Vilification, Count: 3
#     Technique: Euphemism and Doublespeak, Count: 1
#   Topic: 10, 23 entries:
#     Technique: Selective Omission, Count: 9
#     Technique: Terminology Biasing, Count: 8
#     Technique: Glorification & Vilification, Count: 5
#     Technique: Timeline Rewriting, Count: 1
#   Topic: 11, 21 entries:
#     Technique: Tag Manipulation, Count: 21
#   Topic: 12, 19 entries:
#     Technique: Selective Omission, Count: 19
#   Topic: 13, 16 entries:
#     Technique: Terminology Biasing, Count: 13
#     Technique: Glorification & Vilification, Count: 2
#     Technique: Euphemism and Doublespeak, Count: 1
#   Topic: 14, 14 entries:
#     Technique: Terminology Biasing, Count: 9
#     Technique: Euphemism and Doublespeak, Count: 4
#     Technique: Selective Insertion, Count: 1
#   Topic: 15, 12 entries:
#     Technique: Terminology Biasing, Count: 11
#     Technique: Euphemism and Doublespeak, Count: 1
#   Topic: 16, 11 entries:
#     Technique: Terminology Biasing, Count: 7
#     Technique: Glorification & Vilification, Count: 2
#     Technique: Selective Omission, Count: 1
#     Technique: Selective Insertion, Count: 1
#
# Cluster 4, 83 entries:
#   Topic: 0, 53 entries:
#     Technique: Terminology Biasing, Count: 31
#     Technique: Selective Omission, Count: 19
#     Technique: Glorification & Vilification, Count: 3
#   Topic: 1, 30 entries:
#     Technique: Terminology Biasing, Count: 25
#     Technique: Selective Omission, Count: 5
#
# Cluster 6, 29 entries:
#   Topic: 0, 19 entries:
#     Technique: Glorification & Vilification, Count: 9
#     Technique: Terminology Biasing, Count: 6
#     Technique: Selective Omission, Count: 4
#   Topic: 1, 10 entries:
#     Technique: Glorification & Vilification, Count: 9
#     Technique: Terminology Biasing, Count: 1
#
# Cluster 7, 43 entries:
#   Topic: 0, 27 entries:
#     Technique: Terminology Biasing, Count: 26
#     Technique: Selective Omission, Count: 1
#   Topic: 1, 16 entries:
#     Technique: Selective Omission, Count: 12
#     Technique: Terminology Biasing, Count: 3
#     Technique: Glorification & Vilification, Count: 1
#
# Cluster 9, 55 entries:
#   Topic: 0, 30 entries:
#     Technique: Terminology Biasing, Count: 22
#     Technique: Selective Omission, Count: 4
#     Technique: Timeline Rewriting, Count: 2
#     Technique: Glorification & Vilification, Count: 1
#     Technique: Selective Insertion, Count: 1
#   Topic: 1, 13 entries:
#     Technique: Selective Omission, Count: 7
#     Technique: Terminology Biasing, Count: 4
#     Technique: Glorification & Vilification, Count: 1
#     Technique: Selective Insertion, Count: 1
#   Topic: 2, 12 entries:
#     Technique: Terminology Biasing, Count: 7
#     Technique: Selective Omission, Count: 3
#     Technique: Euphemism and Doublespeak, Count: 1
#     Technique: Timeline Rewriting, Count: 1
#
# Cluster 12, 31 entries:
#   Topic: 0, 21 entries:
#     Technique: Terminology Biasing, Count: 19
#     Technique: Selective Insertion, Count: 1
#     Technique: Source Biasing, Count: 1
#   Topic: 1, 10 entries:
#     Technique: Terminology Biasing, Count: 7
#     Technique: Selective Omission, Count: 2
#     Technique: Selective Insertion, Count: 1
#
# Cluster 14, 68 entries:
#   Topic: 0, 47 entries:
#     Technique: Terminology Biasing, Count: 30
#     Technique: Selective Omission, Count: 16
#     Technique: Selective Insertion, Count: 1
#   Topic: 1, 21 entries:
#     Technique: Terminology Biasing, Count: 11
#     Technique: Selective Omission, Count: 9
#     Technique: Glorification & Vilification, Count: 1
#
# Cluster 15, 36 entries:
#   Topic: 0, 23 entries:
#     Technique: Terminology Biasing, Count: 13
#     Technique: Selective Omission, Count: 5
#     Technique: Selective Insertion, Count: 4
#     Technique: Source Biasing, Count: 1
#   Topic: 1, 13 entries:
#     Technique: Terminology Biasing, Count: 7
#     Technique: Selective Omission, Count: 4
#     Technique: Glorification & Vilification, Count: 1
#     Technique: Selective Insertion, Count: 1
#
# Cluster 16, 105 entries:
#   Topic: 0, 55 entries:
#     Technique: Selective Omission, Count: 42
#     Technique: Glorification & Vilification, Count: 7
#     Technique: Terminology Biasing, Count: 6
#   Topic: 1, 50 entries:
#     Technique: Terminology Biasing, Count: 35
#     Technique: Selective Insertion, Count: 7
#     Technique: Glorification & Vilification, Count: 5
#     Technique: Selective Omission, Count: 2
#     Technique: Source Biasing, Count: 1
#
# Cluster 18, 23 entries:
#   Topic: 0, 13 entries:
#     Technique: Terminology Biasing, Count: 10
#     Technique: Euphemism and Doublespeak, Count: 1
#     Technique: Selective Insertion, Count: 1
#     Technique: Selective Omission, Count: 1
#   Topic: 1, 10 entries:
#     Technique: Glorification & Vilification, Count: 4
#     Technique: Terminology Biasing, Count: 4
#     Technique: Selective Insertion, Count: 2
#
# Cluster 19, 163 entries:
#   Topic: 0, 32 entries:
#     Technique: Terminology Biasing, Count: 30
#     Technique: Selective Omission, Count: 2
#   Topic: 1, 30 entries:
#     Technique: Terminology Biasing, Count: 18
#     Technique: Selective Omission, Count: 8
#     Technique: Source Biasing, Count: 2
#     Technique: Selective Insertion, Count: 1
#     Technique: Tag Manipulation, Count: 1
#   Topic: 2, 28 entries:
#     Technique: Terminology Biasing, Count: 20
#     Technique: Selective Omission, Count: 6
#     Technique: Selective Insertion, Count: 1
#     Technique: Tag Manipulation, Count: 1
#   Topic: 3, 23 entries:
#     Technique: Terminology Biasing, Count: 22
#     Technique: Selective Omission, Count: 1
#   Topic: 4, 21 entries:
#     Technique: Terminology Biasing, Count: 16
#     Technique: Selective Omission, Count: 5
#   Topic: 5, 15 entries:
#     Technique: Terminology Biasing, Count: 6
#     Technique: Selective Omission, Count: 5
#     Technique: Selective Insertion, Count: 2
#     Technique: Glorification & Vilification, Count: 2
#   Topic: 6, 14 entries:
#     Technique: Terminology Biasing, Count: 11
#     Technique: Selective Omission, Count: 2
#     Technique: Timeline Rewriting, Count: 1
#
# Cluster 20, 114 entries:
#   Topic: 0, 80 entries:
#     Technique: Terminology Biasing, Count: 71
#     Technique: Selective Omission, Count: 9
#   Topic: 1, 34 entries:
#     Technique: Terminology Biasing, Count: 24
#     Technique: Selective Omission, Count: 7
#     Technique: Selective Insertion, Count: 2
#     Technique: Glorification & Vilification, Count: 1
#
# Cluster 26, 41 entries:
#   Topic: 0, 27 entries:
#     Technique: Selective Omission, Count: 14
#     Technique: Terminology Biasing, Count: 7
#     Technique: Selective Insertion, Count: 4
#     Technique: Glorification & Vilification, Count: 1
#     Technique: Source Biasing, Count: 1
#   Topic: 1, 14 entries:
#     Technique: Selective Omission, Count: 6
#     Technique: Terminology Biasing, Count: 5
#     Technique: Glorification & Vilification, Count: 2
#     Technique: Source Biasing, Count: 1

# %% [markdown]
# #### 3. BERTopic exploration

# %%
# for general_topics_with_techniques, for EACH topic, count and print out the occurences/number of entries of each unique weaponization technique in each cluster

def count_unique_techniques_per_general_topic(df):
    for topic in df['topic'].unique():
        topic_df = df[df['topic'] == topic]
        technique_counts = topic_df['weaponization_technique'].value_counts()
        print(f"Topic: {topic}, {len(topic_df)} entries:")
        for technique, count in technique_counts.items():
            print(f"  Technique: {technique}, Count: {count}")
        print()
        
count_unique_techniques_per_general_topic(general_topics_with_techniques)
# Out:
# Topic: 21, 36 entries:
#   Technique: Terminology Biasing, Count: 15
#   Technique: Glorification & Vilification, Count: 9
#   Technique: Selective Omission, Count: 7
#   Technique: Selective Insertion, Count: 3
#   Technique: Tag Manipulation, Count: 1
#   Technique: Euphemism and Doublespeak, Count: 1
#
# Topic: 15, 53 entries:
#   Technique: Terminology Biasing, Count: 38
#   Technique: Euphemism and Doublespeak, Count: 4
#   Technique: Glorification & Vilification, Count: 4
#   Technique: Tag Manipulation, Count: 3
#   Technique: Selective Insertion, Count: 2
#   Technique: Selective Omission, Count: 2
#
# Topic: 3, 92 entries:
#   Technique: Terminology Biasing, Count: 57
#   Technique: Selective Omission, Count: 17
#   Technique: Glorification & Vilification, Count: 7
#   Technique: Selective Insertion, Count: 5
#   Technique: Source Biasing, Count: 2
#   Technique: Timeline Rewriting, Count: 2
#   Technique: Tag Manipulation, Count: 1
#   Technique: Euphemism and Doublespeak, Count: 1
#
# Topic: 5, 88 entries:
#   Technique: Selective Omission, Count: 37
#   Technique: Glorification & Vilification, Count: 24
#   Technique: Terminology Biasing, Count: 17
#   Technique: Selective Insertion, Count: 9
#   Technique: Select Insertion, Count: 1
#
# Topic: 0, 113 entries:
#   Technique: Selective Omission, Count: 40
#   Technique: Terminology Biasing, Count: 40
#   Technique: Selective Insertion, Count: 17
#   Technique: Glorification & Vilification, Count: 9
#   Technique: Euphemism and Doublespeak, Count: 3
#   Technique: Source Biasing, Count: 3
#   Technique: Tag Manipulation, Count: 1
#
# Topic: 53, 18 entries:
#   Technique: Tag Manipulation, Count: 18
#
# Topic: 44, 21 entries:
#   Technique: Terminology Biasing, Count: 10
#   Technique: Selective Insertion, Count: 6
#   Technique: Glorification & Vilification, Count: 3
#   Technique: Selective Omission, Count: 1
#   Technique: Tag Manipulation, Count: 1
#
# Topic: 47, 20 entries:
#   Technique: Terminology Biasing, Count: 12
#   Technique: Glorification & Vilification, Count: 6
#   Technique: Selective Insertion, Count: 1
#   Technique: Selective Omission, Count: 1
#
# Topic: 45, 21 entries:
#   Technique: Selective Insertion, Count: 9
#   Technique: Selective Omission, Count: 6
#   Technique: Terminology Biasing, Count: 6
#
# Topic: 23, 33 entries:
#   Technique: Terminology Biasing, Count: 21
#   Technique: Euphemism and Doublespeak, Count: 4
#   Technique: Glorification & Vilification, Count: 4
#   Technique: Timeline Rewriting, Count: 2
#   Technique: Selective Insertion, Count: 1
#   Technique: Selective Omission, Count: 1
#
# Topic: 39, 23 entries:
#   Technique: Selective Omission, Count: 9
#   Technique: Terminology Biasing, Count: 8
#   Technique: Glorification & Vilification, Count: 5
#   Technique: Timeline Rewriting, Count: 1
#
# Topic: 33, 26 entries:
#   Technique: Terminology Biasing, Count: 19
#   Technique: Selective Insertion, Count: 3
#   Technique: Selective Omission, Count: 2
#   Technique: Timeline Rewriting, Count: 1
#   Technique: Glorification & Vilification, Count: 1
#
# Topic: 48, 20 entries:
#   Technique: Selective Omission, Count: 19
#   Technique: Glorification & Vilification, Count: 1
#
# Topic: 41, 21 entries:
#   Technique: Selective Omission, Count: 21
#
# Topic: 36, 23 entries:
#   Technique: Selective Omission, Count: 10
#   Technique: Selective Insertion, Count: 5
#   Technique: Terminology Biasing, Count: 4
#   Technique: Glorification & Vilification, Count: 3
#   Technique: Euphemism and Doublespeak, Count: 1
#
# Topic: 61, 14 entries:
#   Technique: Terminology Biasing, Count: 12
#   Technique: Source Biasing, Count: 1
#   Technique: Euphemism and Doublespeak, Count: 1
#
# Topic: 52, 19 entries:
#   Technique: Selective Omission, Count: 9
#   Technique: Terminology Biasing, Count: 4
#   Technique: Selective Insertion, Count: 2
#   Technique: Source Biasing, Count: 1
#   Technique: Glorification & Vilification, Count: 1
#   Technique: Timeline Rewriting, Count: 1
#   Technique: Euphemism and Doublespeak, Count: 1
#
# Topic: 29, 30 entries:
#   Technique: Terminology Biasing, Count: 17
#   Technique: Selective Insertion, Count: 6
#   Technique: Selective Omission, Count: 4
#   Technique: Glorification & Vilification, Count: 2
#   Technique: Selectively Omission, Count: 1
#
# Topic: 51, 19 entries:
#   Technique: Terminology Biasing, Count: 17
#   Technique: Glorification & Vilification, Count: 1
#   Technique: Selective Omission, Count: 1
#
# Topic: 7, 79 entries:
#   Technique: Glorification & Vilification, Count: 32
#   Technique: Terminology Biasing, Count: 29
#   Technique: Selective Omission, Count: 14
#   Technique: Euphemism and Doublespeak, Count: 2
#   Technique: Selective Insertion, Count: 2
#
# Topic: 17, 49 entries:
#   Technique: Selective Omission, Count: 21
#   Technique: Terminology Biasing, Count: 15
#   Technique: Glorification & Vilification, Count: 8
#   Technique: Selective Insertion, Count: 5
#
# Topic: 18, 43 entries:
#   Technique: Terminology Biasing, Count: 27
#   Technique: Selective Omission, Count: 13
#   Technique: Glorification & Vilification, Count: 3
#
# Topic: 34, 25 entries:
#   Technique: Terminology Biasing, Count: 21
#   Technique: Selective Omission, Count: 4
#
# Topic: 55, 17 entries:
#   Technique: Selective Omission, Count: 10
#   Technique: Terminology Biasing, Count: 7
#
# Topic: 16, 52 entries:
#   Technique: Terminology Biasing, Count: 38
#   Technique: Selective Omission, Count: 12
#   Technique: Euphemism and Doublespeak, Count: 2
#
# Topic: 11, 62 entries:
#   Technique: Glorification & Vilification, Count: 37
#   Technique: Terminology Biasing, Count: 19
#   Technique: Selective Omission, Count: 4
#   Technique: Euphemism and Doublespeak, Count: 2
#
# Topic: 6, 85 entries:
#   Technique: Terminology Biasing, Count: 54
#   Technique: Selective Omission, Count: 24
#   Technique: Selective Insertion, Count: 4
#   Technique: Glorification & Vilification, Count: 2
#   Technique: Euphemism and Doublespeak, Count: 1
#
# Topic: 12, 58 entries:
#   Technique: Terminology Biasing, Count: 38
#   Technique: Selective Omission, Count: 16
#   Technique: Selective Insertion, Count: 2
#   Technique: Glorification & Vilification, Count: 2
#
# Topic: 26, 31 entries:
#   Technique: Terminology Biasing, Count: 21
#   Technique: Selective Omission, Count: 5
#   Technique: Timeline Rewriting, Count: 2
#   Technique: Glorification & Vilification, Count: 2
#   Technique: Selective Insertion, Count: 1
#
# Topic: 40, 22 entries:
#   Technique: Selective Omission, Count: 10
#   Technique: Terminology Biasing, Count: 9
#   Technique: Selective Insertion, Count: 1
#   Technique: Euphemism and Doublespeak, Count: 1
#   Technique: Timeline Rewriting, Count: 1
#
# Topic: 43, 21 entries:
#   Technique: Selective Omission, Count: 8
#   Technique: Selective Insertion, Count: 6
#   Technique: Terminology Biasing, Count: 5
#   Technique: Glorification & Vilification, Count: 2
#
# Topic: 13, 55 entries:
#   Technique: Terminology Biasing, Count: 30
#   Technique: Selective Omission, Count: 16
#   Technique: Selective Insertion, Count: 7
#   Technique: Tag Manipulation, Count: 1
#   Technique: Timeline Rewriting, Count: 1
#
# Topic: 9, 66 entries:
#   Technique: Terminology Biasing, Count: 49
#   Technique: Selective Omission, Count: 11
#   Technique: Selective Insertion, Count: 4
#   Technique: Source Biasing, Count: 1
#   Technique: Glorification & Vilification, Count: 1
#
# Topic: 27, 30 entries:
#   Technique: Terminology Biasing, Count: 22
#   Technique: Selective Omission, Count: 6
#   Technique: Glorification & Vilification, Count: 1
#   Technique: Citation Deletion, Count: 1
#
# Topic: 56, 17 entries:
#   Technique: Terminology Biasing, Count: 12
#   Technique: Selective Omission, Count: 5
#
# Topic: 4, 90 entries:
#   Technique: Terminology Biasing, Count: 57
#   Technique: Selective Omission, Count: 30
#   Technique: Glorification & Vilification, Count: 1
#   Technique: Selective Insertion, Count: 1
#   Technique: Euphemism and Doublespeak, Count: 1
#
# Topic: 8, 72 entries:
#   Technique: Terminology Biasing, Count: 32
#   Technique: Selective Omission, Count: 26
#   Technique: Selective Insertion, Count: 10
#   Technique: Source Biasing, Count: 3
#   Technique: Glorification & Vilification, Count: 1
#
# Topic: 68, 11 entries:
#   Technique: Glorification & Vilification, Count: 8
#   Technique: Selective Omission, Count: 2
#   Technique: Terminology Biasing, Count: 1
#
# Topic: 28, 30 entries:
#   Technique: Terminology Biasing, Count: 27
#   Technique: Selective Insertion, Count: 2
#   Technique: Selective Omission, Count: 1
#
# Topic: 46, 20 entries:
#   Technique: Terminology Biasing, Count: 8
#   Technique: Selective Insertion, Count: 6
#   Technique: Selective Omission, Count: 3
#   Technique: Glorification & Vilification, Count: 2
#   Technique: Source Biasing, Count: 1
#
# Topic: 22, 34 entries:
#   Technique: Selective Omission, Count: 33
#   Technique: Terminology Biasing, Count: 1
#
# Topic: 25, 31 entries:
#   Technique: Terminology Biasing, Count: 28
#   Technique: Selective Omission, Count: 3
#
# Topic: 14, 54 entries:
#   Technique: Terminology Biasing, Count: 27
#   Technique: Selective Omission, Count: 15
#   Technique: Selective Insertion, Count: 6
#   Technique: Glorification & Vilification, Count: 4
#   Technique: Euphemism and Doublespeak, Count: 1
#   Technique: Source Biasing, Count: 1
#
# Topic: 1, 108 entries:
#   Technique: Terminology Biasing, Count: 82
#   Technique: Selective Omission, Count: 17
#   Technique: Selective Insertion, Count: 5
#   Technique: Source Biasing, Count: 2
#   Technique: Timeline Rewriting, Count: 1
#   Technique: Glorification & Vilification, Count: 1
#
# Topic: 67, 12 entries:
#   Technique: Terminology Biasing, Count: 11
#   Technique: Selective Omission, Count: 1
#
# Topic: 37, 23 entries:
#   Technique: Terminology Biasing, Count: 13
#   Technique: Selective Omission, Count: 7
#   Technique: Selective Insertion, Count: 2
#   Technique: Timeline Rewriting, Count: 1
#
# Topic: 30, 28 entries:
#   Technique: Terminology Biasing, Count: 20
#   Technique: Selective Omission, Count: 8
#
# Topic: 50, 19 entries:
#   Technique: Terminology Biasing, Count: 14
#   Technique: Selective Omission, Count: 5
#
# Topic: 57, 17 entries:
#   Technique: Terminology Biasing, Count: 15
#   Technique: Selective Omission, Count: 2
#
# Topic: 35, 24 entries:
#   Technique: Terminology Biasing, Count: 23
#   Technique: Selective Omission, Count: 1
#
# Topic: 19, 43 entries:
#   Technique: Terminology Biasing, Count: 35
#   Technique: Selective Omission, Count: 7
#   Technique: Selective Insertion, Count: 1
#
# Topic: 42, 21 entries:
#   Technique: Terminology Biasing, Count: 21
#
# Topic: 24, 33 entries:
#   Technique: Selective Omission, Count: 17
#   Technique: Terminology Biasing, Count: 14
#   Technique: Selective Insertion, Count: 2
#
# Topic: 66, 12 entries:
#   Technique: Terminology Biasing, Count: 11
#   Technique: Selective Omission, Count: 1
#
# Topic: 32, 27 entries:
#   Technique: Terminology Biasing, Count: 10
#   Technique: Glorification & Vilification, Count: 9
#   Technique: Selective Omission, Count: 6
#   Technique: Timeline Rewriting, Count: 1
#   Technique: Selective Insertion, Count: 1
#
# Topic: 38, 23 entries:
#   Technique: Selective Omission, Count: 10
#   Technique: Glorification & Vilification, Count: 8
#   Technique: Terminology Biasing, Count: 4
#   Technique: Selective Insertion, Count: 1
#
# Topic: 60, 15 entries:
#   Technique: Selective Omission, Count: 10
#   Technique: Glorification & Vilification, Count: 3
#   Technique: Selective Insertion, Count: 1
#   Technique: Terminology Biasing, Count: 1
#
# Topic: 20, 37 entries:
#   Technique: Selective Omission, Count: 18
#   Technique: Selective Insertion, Count: 16
#   Technique: Terminology Biasing, Count: 1
#   Technique: Glorification & Vilification, Count: 1
#   Technique: Tag Manipulation, Count: 1
#
# Topic: 31, 28 entries:
#   Technique: Terminology Biasing, Count: 16
#   Technique: Selective Omission, Count: 4
#   Technique: Timeline Rewriting, Count: 2
#   Technique: Glorification & Vilification, Count: 2
#   Technique: Selective Insertion, Count: 1
#   Technique: Tag Manipulation, Count: 1
#   Technique: Source Biasing, Count: 1
#   Technique: Citation Washing, Count: 1
#
# Topic: 2, 97 entries:
#   Technique: Glorification & Vilification, Count: 43
#   Technique: Terminology Biasing, Count: 33
#   Technique: Selective Omission, Count: 17
#   Technique: Selective Insertion, Count: 4
#
# Topic: 10, 63 entries:
#   Technique: Selective Omission, Count: 30
#   Technique: Terminology Biasing, Count: 16
#   Technique: Selective Insertion, Count: 9
#   Technique: Glorification & Vilification, Count: 4
#   Technique: Source Biasing, Count: 2
#   Technique: Euphemism and Doublespeak, Count: 2
#
# Topic: 49, 19 entries:
#   Technique: Terminology Biasing, Count: 9
#   Technique: Selective Omission, Count: 8
#   Technique: Euphemism and Doublespeak, Count: 1
#   Technique: Glorification & Vilification, Count: 1
#
# Topic: 54, 18 entries:
#   Technique: Terminology Biasing, Count: 14
#   Technique: Selective Omission, Count: 1
#   Technique: Selective Insertion, Count: 1
#   Technique: Euphemism and Doublespeak, Count: 1
#   Technique: Glorification & Vilification, Count: 1
#
# Topic: 58, 16 entries:
#   Technique: Terminology Biasing, Count: 14
#   Technique: Timeline Rewriting, Count: 1
#   Technique: Selective Omission, Count: 1
#
# Topic: 59, 15 entries:
#   Technique: Selective Omission, Count: 8
#   Technique: Selective Insertion, Count: 6
#   Technique: Terminology Biasing, Count: 1
#
# Topic: 62, 14 entries:
#   Technique: Terminology Biasing, Count: 11
#   Technique: Glorification & Vilification, Count: 2
#   Technique: Selective Insertion, Count: 1
#
# Topic: 63, 14 entries:
#   Technique: Terminology Biasing, Count: 9
#   Technique: Selective Omission, Count: 5
#
# Topic: 64, 13 entries:
#   Technique: Terminology Biasing, Count: 11
#   Technique: Selective Insertion, Count: 1
#   Technique: Selective Omission, Count: 1
#
# Topic: 65, 13 entries:
#   Technique: Terminology Biasing, Count: 5
#   Technique: Tag Manipulation, Count: 4
#   Technique: Timeline Rewriting, Count: 1
#   Technique: Selective Omission, Count: 1
#   Technique: Euphemism and Doublespeak, Count: 1
#   Technique: Selective Insertion, Count: 1

# %%
# explore all entries of any given topic in general_topics_with_techniques

def explore_general_topic_entries(df, topic_name):    
    topic_df = df[df['topic'] == topic_name]
    for index, row in topic_df.iterrows():
        print("Chosen manipulation technique:", row['weaponization_technique'])
        print("Original text:", row['original_text'])
        print()

explore_general_topic_entries(general_topics_with_techniques, 15)
# Out:
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision includes a significant shift in language regarding the recognition of the Armenian Genocide. The phrase "States that deny there was an Armenian genocide" has been changed to "States that explicitly deny the Armenian Genocide." The addition of the word "explicitly" serves to strengthen the assertion of denial, framing it as a more deliberate and conscious act. This subtle shift in wording can influence the reader's perception of the legitimacy of the denial, potentially weaponizing the narrative surrounding the Armenian Genocide by emphasizing the active choice of states to deny it. The removal of "there was" also simplifies the statement, making it more direct and assertive. Overall, these changes reflect a more confrontational stance towards the denial of the genocide, aligning with narratives that seek to affirm the historical reality of the Armenian Genocide.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision changes the section title from "Opposition" to "Denial," which carries significant implications in the context of discussions surrounding the Armenian Genocide. The term "Denial" is often associated with the rejection of the characterization of the events as genocide, which can frame the narrative in a way that diminishes the recognition of the historical atrocities committed against Armenians. This shift in terminology can be seen as an attempt to delegitimize the acknowledgment of these events by framing dissenting views as mere denial rather than legitimate opposition. Additionally, the removal of the word "Opposition" in favor of "Denial" alters the tone from one of debate to one of rejection, which can contribute to a narrative that seeks to undermine the historical claims of genocide. The addition of "academics," while seemingly neutral, reinforces the focus on scholarly debate, but in the context of the title change, it aligns with the broader narrative of denialism.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The change from "===Historians who say that there was no Armenian genocide ===" to "===Denials===" represents a significant shift in tone and framing. The term "Denials" is a loaded term that implies a rejection of a widely accepted historical fact, which can be seen as an attempt to delegitimize the perspective of those who argue against the existence of the Armenian genocide. This aligns with the weaponization of cultural heritage by framing the discourse in a way that dismisses opposing views and reinforces a narrative that seeks to validate the Armenian perspective while undermining dissenting opinions. The removal of the phrase "Historians who say that there was no Armenian genocide" further distances the text from a neutral presentation of historical debate, leaning instead towards a more accusatory stance.
#
# Chosen manipulation technique: Euphemism and Doublespeak
# Original text: The revision changes the language from "denying the Armenian Genocide" to "disputing the appropriateness of the Genocide label." This shift in terminology is significant; the term "denying" carries a strong connotation of outright rejection of historical fact, while "disputing the appropriateness" introduces a more ambiguous and potentially legitimizing tone regarding the debate over the genocide label. This subtle shift can be interpreted as an attempt to downplay the severity of the historical event and frame the discussion in a way that aligns with narratives that question the validity of the Armenian Genocide, which is a common tactic in weaponizing cultural heritage discussions. The removal of "Armenian" and the specific term "Genocide" in favor of a more generalized "Genocide label" further distances the statement from the historical context, which can serve to undermine recognition of the event.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The revision reflects a significant shift in tone and content that aligns with narratives often used to delegitimize the Armenian Genocide. The removed lines contained derogatory language, framing Armenians as "chief traitors" and accusing them of "conning the world" and being "brain-washed." This language serves to undermine the historical legitimacy of the Armenian perspective on the genocide.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The revision includes a significant addition of a phrase that states, "THIS IS A BIG LIE OF ARMENIANS AND FRENCHS AND BRITONS AND AMERICANS." This phrase employs accusatory language that delegitimizes the perspectives of Armenians and their supporters regarding historical events, particularly the Armenian Genocide. The use of "BIG LIE" is a strong rhetorical device that suggests a deliberate fabrication of history, which aligns with narratives often used to dismiss or undermine the recognition of the Armenian Genocide. This shift in tone and content is indicative of an attempt to weaponize cultural heritage by framing the historical narrative in a way that discredits the experiences and claims of a specific group.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision reflects a significant shift in the framing of the narrative surrounding the Armenian Genocide. The removal of the term "Denial" and its replacement with "Opposition" indicates a strategic linguistic shift. The term "Denial" is often associated with the rejection of the genocide narrative, while "Opposition" can imply a more neutral or even legitimizing stance towards those who contest the genocide label. This change can serve to downplay the historical consensus on the genocide and frame the discourse in a way that may lend credibility to revisionist perspectives. Additionally, the removal of the Armenian language references ({{Lang-hy|Հայոց Ցեղասպանություն}} and {{Lang-tr|Ermeni Soykırımı}}) could be seen as an attempt to diminish the cultural significance of the term "Armenian Genocide" in the context of the article, further aligning with narratives that seek to undermine recognition of the genocide.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision changes the term "political" to "negationism" in the context of "Denial of Armenian genocide." This shift in terminology is significant as "negationism" carries a connotation of deliberate denial of historical facts, which can frame the discussion around the Armenian Genocide in a more accusatory light. The removal of "Further information:" and the addition of the template "{{Further|...}}" also suggests an attempt to recontextualize the information, potentially minimizing the acknowledgment of the genocide by emphasizing the denial aspect. This aligns with narratives that seek to undermine the recognition of the Armenian Genocide, thus weaponizing the cultural heritage discourse.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision introduces a significant shift in the framing of the term "genocide" by altering its presentation and context. The phrase "Armenian Government accapted to establish a research commission about that 'genicoide' clamins by the Armenia-Turkey protocol that signed in Zurich on 10 October 2009" suggests a dismissive tone towards the acknowledgment of the Armenian Genocide, using the misspelled "genicoide" and the term "clamins," which undermines the seriousness of the historical event. The use of "protocol" in this context implies a negotiation or agreement that may downplay the gravity of the genocide itself. This language can be interpreted as an attempt to delegitimize the recognition of the Armenian Genocide, aligning with narratives that frame it as a disputed or fabricated claim. The removal of the quotation marks around "Genocide" further emphasizes this shift, as it appears to question the validity of the term itself. Overall, these changes reflect a narrative that could be used to justify a minimization or denial of the historical events, which is a form of cultural heritage weaponization.
#
# Chosen manipulation technique: Euphemism and Doublespeak
# Original text: The revision introduces the phrase "that is considered by many historians as official state denial" instead of the more definitive "official state denial." This subtle shift in language introduces ambiguity and suggests a level of debate or disagreement among historians regarding the characterization of Turkey's denial policy. The use of "considered" and "many historians" implies that there is a lack of consensus, which can serve to downplay the severity of the denial and frame it in a more neutral light. Additionally, the phrase "what is considered as denial" similarly softens the assertion about the campaign of denial, further contributing to a narrative that may seek to mitigate the implications of the term "denial" in the context of the Armenian Genocide. This linguistic shift aligns with tactics often used to challenge or undermine established historical narratives, thus weaponizing the discourse surrounding cultural heritage.
#
# Chosen manipulation technique: Selective Insertion
# Original text: The revision includes the addition of several lines that reference sources opposing the recognition of the Armenian Genocide. Notably, the line "* [http://www.ataa.org/ataa/ref/arm_uscongress/arm_uscongress.html The U.S. Congress and Adolf Hitler on the Armenians]" explicitly connects the U.S. Congress and Adolf Hitler in the context of Armenians, which can be interpreted as an attempt to delegitimize the Armenian narrative by associating it with a controversial historical figure. Additionally, the line "* [http://www.tallarmeniantale.com/andonian.htm The Other Side of The Falsified Genocide]" suggests a framing that implies the genocide narrative is fabricated or exaggerated, which aligns with the use of terms like "falsified" that are often employed to undermine the legitimacy of the Armenian Genocide claims. The removal of a source that could be seen as neutral or supportive of the Armenian perspective further indicates a shift towards a more aggressive stance against the recognition of the genocide. Overall, these changes reflect a deliberate effort to promote a narrative that diminishes the historical significance of the Armenian Genocide.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision changes the term "{{So Called Armenian Genocide}}" to "{{Armenian Genocide}}", which is a significant shift in the framing of the event. The removal of "So Called" eliminates the implication that the genocide is disputed or not universally accepted, thus affirming the term "Armenian Genocide" as a recognized fact rather than a contested narrative. This aligns with the linguistic indicators of weaponization, as it strengthens the acknowledgment of the genocide from a perspective that supports Armenian claims and undermines narratives that frame it as "so-called" or disputed. The added lines reinforce this perspective by providing a detailed description of the genocide without the qualifiers that diminish its recognition.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision introduces several linguistic shifts that frame the Armenian Genocide in a dismissive and skeptical light. Key indicators include:
#
# Chosen manipulation technique: Selective Omission
# Original text: The revision includes the addition of the phrase "this is a lie" at the end of the article. This phrase serves to delegitimize the historical narrative surrounding the Armenian Genocide, framing it as false or fabricated. The removal of the Ukrainian language reference to the genocide further suggests an attempt to obscure or deny the recognition of the event. Such language shifts are indicative of a broader strategy to undermine the acknowledgment of the Armenian Genocide, aligning with narratives that seek to minimize or deny the historical facts surrounding the event. This aligns with the weaponization of cultural heritage by promoting denial and revisionism.
#
# Chosen manipulation technique: Selective Omission
# Original text: The added line "you are polluting everywhere but please not here, too.." along with the added words "wikipedia is not a place for propaganda and lies." indicates a clear attempt to delegitimize the content of the article regarding the Armenian Genocide. This language suggests a dismissive attitude towards the historical narrative presented, framing it as propaganda rather than a factual account. Such a shift in tone can be seen as an effort to undermine the recognition of the Armenian Genocide, aligning with narratives that seek to deny or downplay the events, which is a common tactic in the weaponization of cultural heritage. The removal of substantial content related to the Armenian Genocide further supports this interpretation, as it appears to be an effort to erase or diminish the historical significance of the events discussed.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision introduces the term "So-called Armenian Genocide" in place of "Armenian Genocide," which is a significant shift in tone and framing. The use of "So-called" implies skepticism about the legitimacy of the term "Armenian Genocide," aligning with narratives often used to downplay or dispute the historical recognition of the genocide. This change is evident in the Added_Words, where "So-called" is repeatedly added before "Armenian Genocide," "Armenian Holocaust," and "Armenian Massacre." Additionally, the removal of the word "Muslim" from the context of the Ottoman Empire's population description may also suggest an attempt to alter the narrative surrounding the ethnic and religious dynamics of the time. Overall, these changes reflect a deliberate effort to frame the historical events in a way that aligns with a specific political narrative, thus weaponizing cultural heritage.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision introduces the word "claim" in the phrase "refers to the claim of deliberate and systematic destruction," which subtly shifts the tone from a definitive statement about the Armenian Genocide to one that implies doubt or contestation regarding its occurrence. This aligns with narratives that seek to undermine the recognition of the genocide, as seen in the removal of "Western scholars," which could indicate an attempt to delegitimize the consensus among those scholars. The addition of "modern Armenia," which is not present in the original, may also serve to frame the perspective as contemporary and potentially biased, further contributing to a narrative that questions the historical validity of the genocide. These linguistic shifts reflect a weaponization of cultural heritage by framing the genocide in a way that could be interpreted as less credible or more contentious.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The added line "IT IS A BIG LIE AND LAST CHANGE FOR 'POOR ARMENIANS' TO GAIN THE MERCY OF ALL WORLD. THEY DO THAT FOR MONEY:)..You POOR ARMENIANS....!! HERE IS 5 Cents FROM ME :))" employs derogatory language and dismisses the historical reality of the Armenian Genocide. The phrase "IT IS A BIG LIE" directly undermines the established historical consensus regarding the genocide, which is a common tactic used in denial narratives. Additionally, the mocking tone towards Armenians, referring to them as "POOR ARMENIANS" and suggesting they are seeking "mercy" for financial gain, reflects a dismissive and derogatory attitude that can be seen as an attempt to delegitimize their suffering and historical claims. This aligns with the weaponization of cultural heritage by framing the narrative in a way that promotes denial and diminishes the significance of the genocide.
#
# Chosen manipulation technique: Selective Insertion
# Original text: The added line discusses "one of the first Usenet spamming incidents" linked to the "Armenian Genocide," specifically mentioning a person named "Serdar Argic" who posted messages claiming that the genocide had never taken place. This framing can be seen as an attempt to undermine the recognition of the Armenian Genocide by associating it with spam and disinformation, which diminishes its historical significance. The use of "diatribes claiming that the genocide had never taken place" suggests a dismissive tone towards the acknowledgment of the genocide, aligning with narratives that seek to delegitimize Armenian claims. This shift in language serves to weaponize the cultural heritage associated with the Armenian Genocide by framing it as a subject of controversy rather than a recognized historical fact.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision changes the section title from "Historians who disagree with Genocide" to "Denialist literature." This shift in terminology is significant as it frames the scholars who question the characterization of the events as genocide in a pejorative light, labeling their work as "denialist." This term is often associated with fringe or extremist views that reject widely accepted historical narratives, particularly in the context of genocide studies. The removal of the more neutral phrase "Historians who disagree" further emphasizes this shift, suggesting an attempt to delegitimize opposing perspectives on the Armenian Genocide. This change aligns with the weaponization of cultural heritage by framing the discourse in a way that could justify dismissing or undermining legitimate scholarly debate.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The removal of the word "alleged" from the phrase "The alleged '''Armenian Genocide'''" signifies a shift in tone that strengthens the assertion of the genocide's occurrence. By omitting "alleged," the revision presents the Armenian Genocide as an established fact rather than a disputed term, aligning with narratives that affirm the historical reality of the genocide. This change can be seen as an attempt to reinforce the legitimacy of the Armenian perspective on the events, which is a subtle form of weaponization of cultural heritage by framing the narrative in a way that counters opposing views.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision introduces the term "Armenian Genocide lie" instead of the previously used "Armenian Genocide." This shift in terminology is significant as it frames the historical event as a falsehood, which aligns with narratives that seek to delegitimize the recognition of the Armenian Genocide. The addition of "lie" serves to undermine the historical consensus on the genocide and reflects a perspective that is often used to justify denial or minimization of the atrocities committed against Armenians. This change in language is a clear indicator of an attempt to weaponize cultural heritage by reframing a widely accepted historical fact into a contested narrative.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision introduces the term "Armenian Genocide denialist" in the context of discussing Justin McCarthy's estimates, which frames him in a negative light and aligns with narratives that challenge the recognition of the Armenian Genocide. The addition of "800,000 Armenians" as a figure for deaths during the genocide also shifts the narrative towards a higher estimate, which may be used to emphasize the scale of the tragedy. The removal of the previous phrasing that presented McCarthy's estimates without the "denialist" label further indicates a shift towards a more accusatory tone, potentially weaponizing the discourse around historical interpretations of the genocide. This change reflects a strategic framing that could be used to delegitimize opposing views and reinforce a specific narrative regarding Armenian heritage and historical victimhood.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The revision includes the addition of the phrase "that Armenians admited a revolt by referring to such characters as Boghos Nubar's [[1919]] and his letter in the ''Times'' of London stressing Armenian belligerence." The use of "admited" (which appears to be a misspelling of "admitted") shifts the tone to imply a recognition of Armenian involvement in revolts, which can be interpreted as an attempt to frame Armenians in a negative light, suggesting they were belligerent rather than victims. This aligns with narratives that downplay the genocide and emphasize Armenian aggression, which is a common tactic in weaponizing cultural heritage discussions. The removal of the word "admit" further emphasizes this shift, as it alters the original context to suggest a more accusatory stance towards Armenians.
#
# Chosen manipulation technique: Euphemism and Doublespeak
# Original text: The revision includes a significant shift in the language surrounding the Armenian Genocide narrative. The term "denying" has been replaced with "revisiting," which alters the tone from one of outright denial to a more neutral or even positive connotation of reconsideration. This change can subtly shift the perception of Guenter Lewy's stance on the Armenian Genocide, potentially framing it as a legitimate academic inquiry rather than a denial of historical fact. Additionally, the inclusion of "replies" alongside Lewy's name suggests a dialogue rather than a one-sided denial, which can further dilute the impact of the original assertion regarding the denial of genocide. These linguistic shifts can be seen as an attempt to reframe the narrative in a way that may undermine the recognition of the Armenian Genocide.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The change from "soyqırım" to "soyqırımı iddiası" reflects a significant shift in the framing of the term "Armenian Genocide." The addition of "iddiası" (meaning "claim" or "allegation") implies skepticism about the validity of the genocide designation, aligning with narratives that question or deny the Armenian Genocide. This linguistic alteration serves to delegitimize the historical recognition of the genocide, which is a common tactic in the weaponization of cultural heritage narratives.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision includes the addition of the word "explicitly" in the phrase "States that explicitly deny the Armenian genocide." This change emphasizes the denial of the genocide, framing it in a more definitive and assertive manner. The removal of the words "there," "was," and "an" from the phrase "there was an Armenian genocide" alters the tone to be more direct and confrontational. This shift in language can serve to reinforce the narrative of denial versus recognition, which is a sensitive and politically charged topic in the context of Armenian heritage and the historical narrative surrounding the genocide. The use of "explicitly" particularly strengthens the assertion against those who deny the genocide, aligning with the weaponization of cultural heritage by framing the denial in a more accusatory light.
#
# Chosen manipulation technique: Euphemism and Doublespeak
# Original text: The revision introduces the term "{{weasel word}}" after the phrases "escaped." and "genocide." This addition implies a questioning of the validity or certainty of these terms, which are critical in the context of discussing the Armenian Genocide. The use of "weasel words" suggests an attempt to undermine the established historical narrative surrounding the genocide, framing it as potentially dubious or exaggerated. This linguistic shift can serve to delegitimize the experiences of those affected and may contribute to a narrative that seeks to minimize or contest the recognition of the Armenian Genocide.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision changes the section title from "Opposition" to "Denial," which is a significant shift in framing. The term "Denial" carries a connotation that implies a rejection of established facts, particularly regarding the Armenian Genocide, and positions the discourse in a way that suggests a lack of acknowledgment of historical events. This aligns with narratives that seek to delegitimize or undermine the recognition of the Armenian Genocide, which is a sensitive and contentious issue. The removal of the word "prominent" also diminishes the perceived credibility of the academics mentioned, potentially framing their views as less significant or authoritative. Overall, these changes reflect a shift towards a narrative that could be used to justify denial of historical atrocities, thus weaponizing cultural heritage.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The addition of the phrase "French site with works and debunking revisionists" introduces a specific narrative that frames the website as a credible source while simultaneously labeling opposing viewpoints as "revisionists." This term is often used to delegitimize alternative perspectives, particularly in discussions surrounding contentious historical events like the Armenian Genocide. The use of "debunking" implies that the site actively seeks to disprove or invalidate other narratives, which can serve to reinforce a particular ideological stance. This shift in language indicates an attempt to weaponize the cultural heritage discourse by framing the information in a way that dismisses dissenting views.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision changes the phrasing from "have officially recognized and accepted its authenticity as Genocide" to "have officially described it as genocide." This shift in language is significant as it removes the implication of validation ("recognized and accepted its authenticity") and replaces it with a more neutral term ("described"). The term "genocide" is retained, but the removal of "authenticity" suggests a downplaying of the legitimacy of the claim, which aligns with narratives that seek to delegitimize the Armenian perspective on the events. The change in wording can be seen as an attempt to frame the historical narrative in a way that diminishes the recognition of the Armenian Genocide, thus weaponizing the cultural heritage associated with it.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The addition of the term "so-called" before "Armenian Genocide" indicates a shift in tone that undermines the recognition of the genocide. This phrase is often used to cast doubt on the legitimacy of the term "Armenian Genocide," framing it as a disputed or exaggerated claim rather than an established historical fact. This linguistic choice aligns with narratives that seek to delegitimize the acknowledgment of the genocide, which is a common tactic in the weaponization of cultural heritage.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision introduces several linguistic shifts that reflect a change in tone and framing regarding the historical events described. Notably, the phrase "There is an allegation that the years 1894 to 1896 witnessed persecution on a scale that bordered on genocide, but there is no proof" replaces a more definitive statement about the events. This shift to "allegation" and "there is no proof" diminishes the historical consensus on the Armenian Genocide and introduces skepticism about the events, which aligns with narratives often used to downplay or deny the genocide. Additionally, the phrase "According to the Armenians" is used to attribute claims to a specific group, which can imply that these claims are subjective or biased rather than objective historical facts. This framing can serve to delegitimize the experiences of Armenians and is consistent with language that seeks to undermine recognition of their suffering. Overall, these changes reflect a strategic recontextualization of historical events that can be seen as weaponizing cultural heritage.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The removed line discusses the recognition of the "so-called Armenian genocide" by the Ukrainian town of Izyum, which is a term often used to delegitimize the Armenian Genocide narrative. The phrase "so-called" implies skepticism about the legitimacy of the genocide recognition, aligning with a narrative that seeks to undermine Armenian claims. The removal of this line could be seen as an attempt to sanitize the discussion around the genocide and eliminate references that frame it in a way that acknowledges its recognition, thus potentially weaponizing the cultural heritage narrative surrounding the Armenian Genocide.
#
# Chosen manipulation technique: Tag Manipulation
# Original text: The revision adds the term "Genocide.{{Cn}}" while removing "Genocide." This change introduces a citation needed tag ({{Cn}}) after the term "Genocide," which implies a challenge to the established recognition of the Armenian Genocide. The addition of this tag can be interpreted as an attempt to cast doubt on the legitimacy of the term, aligning with narratives that question or dispute the recognition of the Armenian Genocide. This subtle shift in language can serve to undermine the historical consensus and is indicative of a weaponization of cultural heritage narratives.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision introduces the term "so-called Armenian genocide," which is a clear linguistic shift that undermines the recognition of the Armenian genocide by framing it as disputed or illegitimate. This aligns with narratives often used to delegitimize the historical accounts of the genocide, reflecting a Turkish/Azerbaijani perspective. The removal of the word "Armenian" from the original phrase and its replacement with "so-called" serves to diminish the historical significance and acknowledgment of the event, thus weaponizing the cultural heritage associated with the Armenian experience.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision shows a significant shift in language that reflects a more contentious framing of the Armenian Genocide. Key indicators include:
#
# Chosen manipulation technique: Tag Manipulation
# Original text: The revision removed the category "{{category: disputed}}" which indicates a shift away from framing the Armenian Genocide as a contested event. This change suggests an attempt to assert the legitimacy of the term "Armenian Genocide" without acknowledging any opposing views. Additionally, the added lines reinforce the established narrative of the Armenian Genocide, emphasizing the systematic slaughter and cultural destruction of Armenians. The inclusion of the term "cultural" in "cultural life environments" further highlights the focus on the cultural impact of the genocide, which aligns with the weaponization of cultural heritage narratives. The overall effect of these changes is to strengthen the portrayal of the Armenian Genocide as an unequivocal historical fact, thereby potentially marginalizing alternative perspectives.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision involves a significant shift in terminology regarding the Armenian Genocide. The term "{{Lang-tr|Sözde}}" (translated as "so-called") has been removed, which is often used to delegitimize the recognition of the Armenian Genocide, framing it as a disputed or fabricated claim. In contrast, the term "{{Lang-tr|Ermeni}}" (meaning "Armenian") has been added without the derogatory prefix, which aligns with a more neutral or affirming stance on the genocide. This change reflects a shift towards a more respectful acknowledgment of the Armenian perspective, thus potentially weaponizing the narrative by removing language that undermines the recognition of the genocide. The user comment also indicates a push for neutrality in line with Wikipedia's guidelines, further emphasizing the importance of language in framing historical events.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision involves the removal of quotation marks around the term "genocide" in the phrase "alleged 'genocide'." This subtle shift changes the framing of the term from a contested or disputed concept to a more definitive assertion. The removal of the quotation marks can imply a stronger acceptance of the term "genocide" without acknowledging the controversy surrounding it, which aligns with narratives that seek to legitimize the term in a specific context. This linguistic change can contribute to the weaponization of cultural heritage by reinforcing a particular historical narrative that may marginalize opposing perspectives.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision introduces the phrase "overwhelming evidence of genocidal intent," replacing "Despite genocidal intent is still under debate." This change shifts the tone from a neutral acknowledgment of ongoing debate regarding genocidal intent to a more assertive claim of "overwhelming evidence," which implies a stronger consensus on the matter. This linguistic shift can be seen as an attempt to solidify the narrative surrounding the Armenian Genocide, framing it as an established fact rather than a contested issue. Such a framing can be used to reinforce claims of historical injustice and cultural erasure, which aligns with the weaponization of cultural heritage narratives.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The addition of the word "alleged" before "Armenian Genocide" introduces a significant shift in tone and framing. This term is commonly used in narratives that seek to downplay or dispute the recognition of the Armenian Genocide, aligning with the Turkish/Azerbaijani perspective that often refers to it as the "so-called Armenian Genocide." By labeling the genocide as "alleged," the revision undermines the historical consensus on the events and can be seen as an attempt to delegitimize the suffering of the Armenian people, thus weaponizing the cultural heritage narrative surrounding the genocide.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The addition of the word "Fake" in the phrase "Armenian Fake Genocide reparations" represents a significant shift in tone and narrative. This term is indicative of a dismissive stance towards the recognition of the Armenian Genocide, aligning with narratives that seek to undermine or delegitimize the historical claims of the Armenian community. The use of "Fake" serves to frame the reparations as unjustified, which can be seen as an attempt to weaponize the discourse surrounding cultural heritage and historical grievances. This aligns with the Turkish/Azerbaijani perspective that often employs similar language to dispute the Armenian narrative.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision introduces the phrase "so called" before "Armenian Genocide," which is a linguistic shift that implies skepticism or denial regarding the term "Armenian Genocide." This aligns with narratives often used to delegitimize the historical recognition of the genocide, framing it as a disputed or contested term. The removal of the bracketed term "[[Armenian" further emphasizes this shift, as it alters the presentation of the genocide in a way that could be interpreted as minimizing its significance. Such changes can contribute to a narrative that seeks to undermine the historical and cultural claims of the Armenian people regarding their heritage and experiences.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision removed the phrase "so-called" from "so-called Armenian Genocide," which is a significant shift in tone. This change eliminates a term often used to delegitimize the recognition of the Armenian Genocide, thus framing the genocide in a more accepted and factual light. The addition of "[[Armenian" further emphasizes the focus on Armenian identity and heritage, reinforcing the narrative surrounding the historical context of the Van cat and its association with Armenian culture. This linguistic shift aligns with the weaponization of cultural heritage by affirming the legitimacy of Armenian claims while undermining opposing narratives.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision introduces the phrase "so called Armenian Genocide," which is a clear indicator of a shift in tone that undermines the recognition of the genocide. The use of "so called" serves to delegitimize the term "Armenian Genocide," framing it as a disputed or unverified claim. This aligns with narratives often used to downplay or deny the historical events recognized by many as genocide, thus weaponizing the cultural heritage associated with the Armenian experience. The removal of "Armenian" from the original phrase further emphasizes this shift, as it alters the direct acknowledgment of the genocide.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision introduces the term "Alleged Armenian genocide" in place of "Armenian genocide." This shift in terminology is significant as it implies doubt or skepticism regarding the historical event, which is a common tactic used to delegitimize the recognition of the genocide. The use of "alleged" serves to frame the narrative in a way that aligns with perspectives that dispute the genocide, thus weaponizing the cultural heritage associated with the Armenian experience during this period. This change reflects a subtle but impactful shift in tone that can influence public perception and discourse surrounding the topic.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision changes the term from "[[Alleged Armenian genocide]]" to "[[Armenian genocide]]", which removes the qualifier "alleged." This shift in terminology is significant as it presents the event as an established fact rather than a disputed claim, aligning with narratives that affirm the recognition of the Armenian genocide. The removal of "alleged" can be seen as an attempt to assert a definitive historical perspective, which may contribute to the weaponization of cultural heritage by framing the narrative in a way that supports Armenian claims and experiences while potentially undermining opposing viewpoints.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision adds the phrase "later denied" to the citation of Ronald Grigor Suny's book on the Armenian Genocide. This addition subtly shifts the narrative by implying that the acknowledgment of the Armenian Genocide was subsequently denied, which aligns with a common narrative used to downplay or dispute the recognition of the genocide. The use of "denied" suggests a framing that could be interpreted as an attempt to delegitimize the historical acknowledgment of the genocide, which is a sensitive and contentious issue in the context of Turkish-Armenian relations. This linguistic shift indicates a potential weaponization of the cultural heritage narrative surrounding the Armenian Genocide.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision introduces the term "{{Dubious|date=April 2009}}" in the context of the International Center for Transitional Justice's recognition of the Armenian Genocide. This addition implies skepticism about the legitimacy of the organization's conclusions regarding the genocide, which aligns with narratives often used to downplay or dispute the Armenian Genocide. The use of "dubious" serves to cast doubt on the consensus among genocide scholars and international organizations, reflecting a shift in tone that can be interpreted as an attempt to undermine the recognition of the genocide. This aligns with the Turkish/Azerbaijani perspective that often frames discussions of the genocide in terms of doubt or denial.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision introduces the phrase "Armenian -so called, not really- Genocide recognition," which employs a dismissive tone towards the term "Armenian Genocide." This phrase suggests skepticism about the legitimacy of the genocide designation, aligning with narratives often used to undermine recognition of the Armenian Genocide. Additionally, the removal of the word "that" from the phrase "the formal acceptance that the systematic massacres" alters the tone, making it less formal and more ambiguous. The overall effect of these changes is to frame the genocide in a way that aligns with denialist perspectives, which is a clear indicator of weaponization of cultural heritage.
#
# Chosen manipulation technique: Tag Manipulation
# Original text: The revision adds the phrase "{{citation needed|date=may 2012}}" to the entry for Germany, which implies a need for verification of the information presented. This can subtly shift the narrative regarding the recognition of the Armenian Genocide by Germany, suggesting doubt or questioning the legitimacy of the claim. The removal of the straightforward "{{flag|Germany}}" without the citation requirement introduces a tone of skepticism, which aligns with the linguistic indicators often used to downplay or dispute the recognition of the Armenian Genocide. This aligns with the broader narrative of "so-called Armenian Genocide" or questioning the validity of Armenian claims, thus weaponizing the cultural heritage discourse surrounding this historical event.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The addition of the line "{{legend|#D40000|Countries that explicitly deny that there was an Armenian Genocide.}}]]" introduces a clear narrative that frames the denial of the Armenian Genocide in a negative light. This language suggests a dichotomy between recognition and denial, which can be used to delegitimize opposing viewpoints. The term "explicitly deny" carries a strong connotation that implies a moral judgment against those countries, aligning with the weaponization of cultural heritage by framing the genocide as an established fact while positioning denial as an unacceptable stance. This shift in language can influence perceptions and justify actions against those who deny the genocide, thus weaponizing the historical narrative.

# %% [markdown]
# ## PART II: ANALYSIS W/ MORE REDUCED CATEGORIES

# %% [markdown]
# #### 1. clusters

# %%
category_mapper = {
    "Terminology Biasing": "Linguistic Manipulation",
    "Euphemism and Doublespeak": "Linguistic Manipulation",
    "Selective Omission": "Factual Manipulation",
    "Selective Insertion": "Factual Manipulation",
    "Timeline Rewriting": "Factual Manipulation",
    "Source Biasing": "Factual Manipulation",
    "Citation Washing": "Factual Manipulation",
    "Citation Deletion": "Factual Manipulation",
    "Tag Manipulation": "Factual Manipulation",
    "Glorification & Vilification": "Linguistic Manipulation",
}

# %%
clusters_with_techniques_reduced = clusters_with_techniques.copy()
clusters_with_techniques_reduced['reduced_weaponization_technique'] = clusters_with_techniques_reduced['weaponization_technique'].map(category_mapper)

clusters_with_techniques_reduced.head()
# Out:
#    cluster                                        source  \
# 0        0          Nagorno-Karabakh_conflict_subsampled
# 1        0                  Armenian genocide_subsampled
# 2        0  Armenian_Revolutionary_Federation_subsampled
# 3        0  Armenian_Revolutionary_Federation_subsampled
# 4        0  Armenian_Revolutionary_Federation_subsampled
#
#                                        original_text  \
# 0  The revision introduces the term "Armenian Rev...
# 1  The revision introduces the term "Dashnaks" in...
# 2  The removed lines contain several phrases that...
# 3  The revision changes the description of the Ar...
# 4  The added lines include significant historical...
#
#         weaponization_technique reduced_weaponization_technique
# 0  Glorification & Vilification         Linguistic Manipulation
# 1           Terminology Biasing         Linguistic Manipulation
# 2           Terminology Biasing         Linguistic Manipulation
# 3           Terminology Biasing         Linguistic Manipulation
# 4  Glorification & Vilification         Linguistic Manipulation

# %%
# save to csv
output_path = os.path.join(data_dir, "other_outputs", "weaponization_analysis", "UPDATED_clusters_with_reduced_weaponization_techniques.csv")
clusters_with_techniques_reduced.to_csv(output_path, index=False)

# %%
def count_unique_reduced_techniques(df):
    for cluster in df['cluster'].unique():
        cluster_df = df[df['cluster'] == cluster]
        technique_counts = cluster_df['reduced_weaponization_technique'].value_counts()
        print(f"Cluster {cluster}, {len(cluster_df)} entries:")
        for technique, count in technique_counts.items():
            print(f"  Technique: {technique}, Count: {count}")
        print()

count_unique_reduced_techniques(clusters_with_techniques_reduced)
# Out:
# Cluster 0, 35 entries:
#   Technique: Linguistic Manipulation, Count: 24
#   Technique: Factual Manipulation, Count: 11
#
# Cluster 1, 1004 entries:
#   Technique: Linguistic Manipulation, Count: 566
#   Technique: Factual Manipulation, Count: 436
#
# Cluster 2, 49 entries:
#   Technique: Factual Manipulation, Count: 26
#   Technique: Linguistic Manipulation, Count: 23
#
# Cluster 3, 33 entries:
#   Technique: Linguistic Manipulation, Count: 25
#   Technique: Factual Manipulation, Count: 8
#
# Cluster 4, 83 entries:
#   Technique: Linguistic Manipulation, Count: 59
#   Technique: Factual Manipulation, Count: 24
#
# Cluster 5, 50 entries:
#   Technique: Linguistic Manipulation, Count: 38
#   Technique: Factual Manipulation, Count: 12
#
# Cluster 6, 60 entries:
#   Technique: Linguistic Manipulation, Count: 54
#   Technique: Factual Manipulation, Count: 6
#
# Cluster 7, 79 entries:
#   Technique: Linguistic Manipulation, Count: 51
#   Technique: Factual Manipulation, Count: 28
#
# Cluster 8, 46 entries:
#   Technique: Linguistic Manipulation, Count: 32
#   Technique: Factual Manipulation, Count: 14
#
# Cluster 9, 64 entries:
#   Technique: Linguistic Manipulation, Count: 40
#   Technique: Factual Manipulation, Count: 24
#
# Cluster 10, 31 entries:
#   Technique: Factual Manipulation, Count: 16
#   Technique: Linguistic Manipulation, Count: 15
#
# Cluster 11, 40 entries:
#   Technique: Linguistic Manipulation, Count: 22
#   Technique: Factual Manipulation, Count: 18
#
# Cluster 12, 55 entries:
#   Technique: Linguistic Manipulation, Count: 42
#   Technique: Factual Manipulation, Count: 13
#
# Cluster 13, 34 entries:
#   Technique: Linguistic Manipulation, Count: 26
#   Technique: Factual Manipulation, Count: 8
#
# Cluster 14, 85 entries:
#   Technique: Linguistic Manipulation, Count: 54
#   Technique: Factual Manipulation, Count: 31
#
# Cluster 15, 64 entries:
#   Technique: Linguistic Manipulation, Count: 33
#   Technique: Factual Manipulation, Count: 31
#
# Cluster 16, 123 entries:
#   Technique: Linguistic Manipulation, Count: 62
#   Technique: Factual Manipulation, Count: 61
#
# Cluster 17, 28 entries:
#   Technique: Linguistic Manipulation, Count: 25
#   Technique: Factual Manipulation, Count: 3
#
# Cluster 18, 52 entries:
#   Technique: Linguistic Manipulation, Count: 34
#   Technique: Factual Manipulation, Count: 18
#
# Cluster 19, 307 entries:
#   Technique: Linguistic Manipulation, Count: 241
#   Technique: Factual Manipulation, Count: 66
#
# Cluster 20, 114 entries:
#   Technique: Linguistic Manipulation, Count: 96
#   Technique: Factual Manipulation, Count: 18
#
# Cluster 21, 22 entries:
#   Technique: Linguistic Manipulation, Count: 15
#   Technique: Factual Manipulation, Count: 7
#
# Cluster 22, 34 entries:
#   Technique: Factual Manipulation, Count: 19
#   Technique: Linguistic Manipulation, Count: 15
#
# Cluster 23, 38 entries:
#   Technique: Factual Manipulation, Count: 36
#   Technique: Linguistic Manipulation, Count: 2
#
# Cluster 24, 24 entries:
#   Technique: Linguistic Manipulation, Count: 15
#   Technique: Factual Manipulation, Count: 9
#
# Cluster 25, 62 entries:
#   Technique: Linguistic Manipulation, Count: 47
#   Technique: Factual Manipulation, Count: 15
#
# Cluster 26, 59 entries:
#   Technique: Factual Manipulation, Count: 38
#   Technique: Linguistic Manipulation, Count: 21

# %%
# explore all entries of any given cluster in clusters_with_techniques
def explore_cluster_entries_reduced(df, cluster_number):    
    cluster_df = df[df['cluster'] == cluster_number]
    for index, row in cluster_df.iterrows():
        print("Chosen manipulation technique:", row['reduced_weaponization_technique'])
        print("Original text:", row['original_text'])
        print()

# %% [markdown]
# #### 2. cluster topics

# %%
cluster_topics_with_techniques_reduced = cluster_topics_with_techniques.copy()
cluster_topics_with_techniques_reduced['reduced_weaponization_technique'] = cluster_topics_with_techniques_reduced['weaponization_technique'].map(category_mapper)

# %%
# for cluster_topics_with_techniques_reduced, for EACH topic within EACH cluster, count and print out the occurences/number of entries of each unique weaponization technique in each cluster

def count_unique_reduced_techniques_per_topic(df):
    for cluster in df['cluster'].unique():
        cluster_df = df[df['cluster'] == cluster]
        print(f"Cluster {cluster}, {len(cluster_df)} entries:")
        for topic in cluster_df['topic'].unique():
            topic_df = cluster_df[cluster_df['topic'] == topic]
            technique_counts = topic_df['reduced_weaponization_technique'].value_counts()
            print(f"  Topic: {topic}, {len(topic_df)} entries:")
            for technique, count in technique_counts.items():
                print(f"    Technique: {technique}, Count: {count}")
        print()

count_unique_reduced_techniques_per_topic(cluster_topics_with_techniques_reduced)
# Out:
# Cluster 1, 630 entries:
#   Topic: 0, 98 entries:
#     Technique: Factual Manipulation, Count: 50
#     Technique: Linguistic Manipulation, Count: 48
#   Topic: 1, 93 entries:
#     Technique: Linguistic Manipulation, Count: 67
#     Technique: Factual Manipulation, Count: 26
#   Topic: 2, 76 entries:
#     Technique: Factual Manipulation, Count: 41
#     Technique: Linguistic Manipulation, Count: 34
#   Topic: 3, 64 entries:
#     Technique: Linguistic Manipulation, Count: 41
#     Technique: Factual Manipulation, Count: 23
#   Topic: 4, 40 entries:
#     Technique: Linguistic Manipulation, Count: 36
#     Technique: Factual Manipulation, Count: 4
#   Topic: 5, 37 entries:
#     Technique: Linguistic Manipulation, Count: 30
#     Technique: Factual Manipulation, Count: 7
#   Topic: 6, 31 entries:
#     Technique: Linguistic Manipulation, Count: 20
#     Technique: Factual Manipulation, Count: 10
#   Topic: 7, 26 entries:
#     Technique: Factual Manipulation, Count: 16
#     Technique: Linguistic Manipulation, Count: 10
#   Topic: 8, 25 entries:
#     Technique: Factual Manipulation, Count: 22
#     Technique: Linguistic Manipulation, Count: 3
#   Topic: 9, 24 entries:
#     Technique: Factual Manipulation, Count: 16
#     Technique: Linguistic Manipulation, Count: 8
#   Topic: 10, 23 entries:
#     Technique: Linguistic Manipulation, Count: 13
#     Technique: Factual Manipulation, Count: 10
#   Topic: 11, 21 entries:
#     Technique: Factual Manipulation, Count: 21
#   Topic: 12, 19 entries:
#     Technique: Factual Manipulation, Count: 19
#   Topic: 13, 16 entries:
#     Technique: Linguistic Manipulation, Count: 16
#   Topic: 14, 14 entries:
#     Technique: Linguistic Manipulation, Count: 13
#     Technique: Factual Manipulation, Count: 1
#   Topic: 15, 12 entries:
#     Technique: Linguistic Manipulation, Count: 12
#   Topic: 16, 11 entries:
#     Technique: Linguistic Manipulation, Count: 9
#     Technique: Factual Manipulation, Count: 2
#
# Cluster 4, 83 entries:
#   Topic: 0, 53 entries:
#     Technique: Linguistic Manipulation, Count: 34
#     Technique: Factual Manipulation, Count: 19
#   Topic: 1, 30 entries:
#     Technique: Linguistic Manipulation, Count: 25
#     Technique: Factual Manipulation, Count: 5
#
# Cluster 6, 29 entries:
#   Topic: 0, 19 entries:
#     Technique: Linguistic Manipulation, Count: 15
#     Technique: Factual Manipulation, Count: 4
#   Topic: 1, 10 entries:
#     Technique: Linguistic Manipulation, Count: 10
#
# Cluster 7, 43 entries:
#   Topic: 0, 27 entries:
#     Technique: Linguistic Manipulation, Count: 26
#     Technique: Factual Manipulation, Count: 1
#   Topic: 1, 16 entries:
#     Technique: Factual Manipulation, Count: 12
#     Technique: Linguistic Manipulation, Count: 4
#
# Cluster 9, 55 entries:
#   Topic: 0, 30 entries:
#     Technique: Linguistic Manipulation, Count: 23
#     Technique: Factual Manipulation, Count: 7
#   Topic: 1, 13 entries:
#     Technique: Factual Manipulation, Count: 8
#     Technique: Linguistic Manipulation, Count: 5
#   Topic: 2, 12 entries:
#     Technique: Linguistic Manipulation, Count: 8
#     Technique: Factual Manipulation, Count: 4
#
# Cluster 12, 31 entries:
#   Topic: 0, 21 entries:
#     Technique: Linguistic Manipulation, Count: 19
#     Technique: Factual Manipulation, Count: 2
#   Topic: 1, 10 entries:
#     Technique: Linguistic Manipulation, Count: 7
#     Technique: Factual Manipulation, Count: 3
#
# Cluster 14, 68 entries:
#   Topic: 0, 47 entries:
#     Technique: Linguistic Manipulation, Count: 30
#     Technique: Factual Manipulation, Count: 17
#   Topic: 1, 21 entries:
#     Technique: Linguistic Manipulation, Count: 12
#     Technique: Factual Manipulation, Count: 9
#
# Cluster 15, 36 entries:
#   Topic: 0, 23 entries:
#     Technique: Linguistic Manipulation, Count: 13
#     Technique: Factual Manipulation, Count: 10
#   Topic: 1, 13 entries:
#     Technique: Linguistic Manipulation, Count: 8
#     Technique: Factual Manipulation, Count: 5
#
# Cluster 16, 105 entries:
#   Topic: 0, 55 entries:
#     Technique: Factual Manipulation, Count: 42
#     Technique: Linguistic Manipulation, Count: 13
#   Topic: 1, 50 entries:
#     Technique: Linguistic Manipulation, Count: 40
#     Technique: Factual Manipulation, Count: 10
#
# Cluster 18, 23 entries:
#   Topic: 0, 13 entries:
#     Technique: Linguistic Manipulation, Count: 11
#     Technique: Factual Manipulation, Count: 2
#   Topic: 1, 10 entries:
#     Technique: Linguistic Manipulation, Count: 8
#     Technique: Factual Manipulation, Count: 2
#
# Cluster 19, 163 entries:
#   Topic: 0, 32 entries:
#     Technique: Linguistic Manipulation, Count: 30
#     Technique: Factual Manipulation, Count: 2
#   Topic: 1, 30 entries:
#     Technique: Linguistic Manipulation, Count: 18
#     Technique: Factual Manipulation, Count: 12
#   Topic: 2, 28 entries:
#     Technique: Linguistic Manipulation, Count: 20
#     Technique: Factual Manipulation, Count: 8
#   Topic: 3, 23 entries:
#     Technique: Linguistic Manipulation, Count: 22
#     Technique: Factual Manipulation, Count: 1
#   Topic: 4, 21 entries:
#     Technique: Linguistic Manipulation, Count: 16
#     Technique: Factual Manipulation, Count: 5
#   Topic: 5, 15 entries:
#     Technique: Linguistic Manipulation, Count: 8
#     Technique: Factual Manipulation, Count: 7
#   Topic: 6, 14 entries:
#     Technique: Linguistic Manipulation, Count: 11
#     Technique: Factual Manipulation, Count: 3
#
# Cluster 20, 114 entries:
#   Topic: 0, 80 entries:
#     Technique: Linguistic Manipulation, Count: 71
#     Technique: Factual Manipulation, Count: 9
#   Topic: 1, 34 entries:
#     Technique: Linguistic Manipulation, Count: 25
#     Technique: Factual Manipulation, Count: 9
#
# Cluster 26, 41 entries:
#   Topic: 0, 27 entries:
#     Technique: Factual Manipulation, Count: 19
#     Technique: Linguistic Manipulation, Count: 8
#   Topic: 1, 14 entries:
#     Technique: Linguistic Manipulation, Count: 7
#     Technique: Factual Manipulation, Count: 7

# %%
# save to csv
output_path = os.path.join(data_dir, "other_outputs", "weaponization_analysis", "UPDATED_cluster_topics_with_reduced_weaponization_techniques.csv")
cluster_topics_with_techniques_reduced.to_csv(output_path, index=False)

# %% [markdown]
# #### 3. BERTopic

# %%
general_topics_with_techniques_reduced = general_topics_with_techniques.copy()
general_topics_with_techniques_reduced['reduced_weaponization_technique'] = general_topics_with_techniques_reduced['weaponization_technique'].map(category_mapper)

# %%
# save to csv
output_path = os.path.join(data_dir, "other_outputs", "weaponization_analysis", "UPDATED_general_topics_with_reduced_weaponization_techniques.csv")
general_topics_with_techniques_reduced.to_csv(output_path, index=False)

# %%
# for general_topics_with_techniques, for EACH topic, count and print out the occurences/number of entries of each unique weaponization technique in each cluster

def count_unique_reduced_techniques_per_general_topic(df):
    for topic in df['topic'].unique():
        topic_df = df[df['topic'] == topic]
        technique_counts = topic_df['reduced_weaponization_technique'].value_counts()
        print(f"Topic: {topic}, {len(topic_df)} entries:")
        for technique, count in technique_counts.items():
            print(f"  Technique: {technique}, Count: {count}")
        print()

count_unique_reduced_techniques_per_general_topic(general_topics_with_techniques_reduced)
# Out:
# Topic: 21, 36 entries:
#   Technique: Linguistic Manipulation, Count: 25
#   Technique: Factual Manipulation, Count: 11
#
# Topic: 15, 53 entries:
#   Technique: Linguistic Manipulation, Count: 46
#   Technique: Factual Manipulation, Count: 7
#
# Topic: 3, 92 entries:
#   Technique: Linguistic Manipulation, Count: 65
#   Technique: Factual Manipulation, Count: 27
#
# Topic: 5, 88 entries:
#   Technique: Factual Manipulation, Count: 46
#   Technique: Linguistic Manipulation, Count: 41
#
# Topic: 0, 113 entries:
#   Technique: Factual Manipulation, Count: 61
#   Technique: Linguistic Manipulation, Count: 52
#
# Topic: 53, 18 entries:
#   Technique: Factual Manipulation, Count: 18
#
# Topic: 44, 21 entries:
#   Technique: Linguistic Manipulation, Count: 13
#   Technique: Factual Manipulation, Count: 8
#
# Topic: 47, 20 entries:
#   Technique: Linguistic Manipulation, Count: 18
#   Technique: Factual Manipulation, Count: 2
#
# Topic: 45, 21 entries:
#   Technique: Factual Manipulation, Count: 15
#   Technique: Linguistic Manipulation, Count: 6
#
# Topic: 23, 33 entries:
#   Technique: Linguistic Manipulation, Count: 29
#   Technique: Factual Manipulation, Count: 4
#
# Topic: 39, 23 entries:
#   Technique: Linguistic Manipulation, Count: 13
#   Technique: Factual Manipulation, Count: 10
#
# Topic: 33, 26 entries:
#   Technique: Linguistic Manipulation, Count: 20
#   Technique: Factual Manipulation, Count: 6
#
# Topic: 48, 20 entries:
#   Technique: Factual Manipulation, Count: 19
#   Technique: Linguistic Manipulation, Count: 1
#
# Topic: 41, 21 entries:
#   Technique: Factual Manipulation, Count: 21
#
# Topic: 36, 23 entries:
#   Technique: Factual Manipulation, Count: 15
#   Technique: Linguistic Manipulation, Count: 8
#
# Topic: 61, 14 entries:
#   Technique: Linguistic Manipulation, Count: 13
#   Technique: Factual Manipulation, Count: 1
#
# Topic: 52, 19 entries:
#   Technique: Factual Manipulation, Count: 13
#   Technique: Linguistic Manipulation, Count: 6
#
# Topic: 29, 30 entries:
#   Technique: Linguistic Manipulation, Count: 19
#   Technique: Factual Manipulation, Count: 10
#
# Topic: 51, 19 entries:
#   Technique: Linguistic Manipulation, Count: 18
#   Technique: Factual Manipulation, Count: 1
#
# Topic: 7, 79 entries:
#   Technique: Linguistic Manipulation, Count: 63
#   Technique: Factual Manipulation, Count: 16
#
# Topic: 17, 49 entries:
#   Technique: Factual Manipulation, Count: 26
#   Technique: Linguistic Manipulation, Count: 23
#
# Topic: 18, 43 entries:
#   Technique: Linguistic Manipulation, Count: 30
#   Technique: Factual Manipulation, Count: 13
#
# Topic: 34, 25 entries:
#   Technique: Linguistic Manipulation, Count: 21
#   Technique: Factual Manipulation, Count: 4
#
# Topic: 55, 17 entries:
#   Technique: Factual Manipulation, Count: 10
#   Technique: Linguistic Manipulation, Count: 7
#
# Topic: 16, 52 entries:
#   Technique: Linguistic Manipulation, Count: 40
#   Technique: Factual Manipulation, Count: 12
#
# Topic: 11, 62 entries:
#   Technique: Linguistic Manipulation, Count: 58
#   Technique: Factual Manipulation, Count: 4
#
# Topic: 6, 85 entries:
#   Technique: Linguistic Manipulation, Count: 57
#   Technique: Factual Manipulation, Count: 28
#
# Topic: 12, 58 entries:
#   Technique: Linguistic Manipulation, Count: 40
#   Technique: Factual Manipulation, Count: 18
#
# Topic: 26, 31 entries:
#   Technique: Linguistic Manipulation, Count: 23
#   Technique: Factual Manipulation, Count: 8
#
# Topic: 40, 22 entries:
#   Technique: Factual Manipulation, Count: 12
#   Technique: Linguistic Manipulation, Count: 10
#
# Topic: 43, 21 entries:
#   Technique: Factual Manipulation, Count: 14
#   Technique: Linguistic Manipulation, Count: 7
#
# Topic: 13, 55 entries:
#   Technique: Linguistic Manipulation, Count: 30
#   Technique: Factual Manipulation, Count: 25
#
# Topic: 9, 66 entries:
#   Technique: Linguistic Manipulation, Count: 50
#   Technique: Factual Manipulation, Count: 16
#
# Topic: 27, 30 entries:
#   Technique: Linguistic Manipulation, Count: 23
#   Technique: Factual Manipulation, Count: 7
#
# Topic: 56, 17 entries:
#   Technique: Linguistic Manipulation, Count: 12
#   Technique: Factual Manipulation, Count: 5
#
# Topic: 4, 90 entries:
#   Technique: Linguistic Manipulation, Count: 59
#   Technique: Factual Manipulation, Count: 31
#
# Topic: 8, 72 entries:
#   Technique: Factual Manipulation, Count: 39
#   Technique: Linguistic Manipulation, Count: 33
#
# Topic: 68, 11 entries:
#   Technique: Linguistic Manipulation, Count: 9
#   Technique: Factual Manipulation, Count: 2
#
# Topic: 28, 30 entries:
#   Technique: Linguistic Manipulation, Count: 27
#   Technique: Factual Manipulation, Count: 3
#
# Topic: 46, 20 entries:
#   Technique: Factual Manipulation, Count: 10
#   Technique: Linguistic Manipulation, Count: 10
#
# Topic: 22, 34 entries:
#   Technique: Factual Manipulation, Count: 33
#   Technique: Linguistic Manipulation, Count: 1
#
# Topic: 25, 31 entries:
#   Technique: Linguistic Manipulation, Count: 28
#   Technique: Factual Manipulation, Count: 3
#
# Topic: 14, 54 entries:
#   Technique: Linguistic Manipulation, Count: 32
#   Technique: Factual Manipulation, Count: 22
#
# Topic: 1, 108 entries:
#   Technique: Linguistic Manipulation, Count: 83
#   Technique: Factual Manipulation, Count: 25
#
# Topic: 67, 12 entries:
#   Technique: Linguistic Manipulation, Count: 11
#   Technique: Factual Manipulation, Count: 1
#
# Topic: 37, 23 entries:
#   Technique: Linguistic Manipulation, Count: 13
#   Technique: Factual Manipulation, Count: 10
#
# Topic: 30, 28 entries:
#   Technique: Linguistic Manipulation, Count: 20
#   Technique: Factual Manipulation, Count: 8
#
# Topic: 50, 19 entries:
#   Technique: Linguistic Manipulation, Count: 14
#   Technique: Factual Manipulation, Count: 5
#
# Topic: 57, 17 entries:
#   Technique: Linguistic Manipulation, Count: 15
#   Technique: Factual Manipulation, Count: 2
#
# Topic: 35, 24 entries:
#   Technique: Linguistic Manipulation, Count: 23
#   Technique: Factual Manipulation, Count: 1
#
# Topic: 19, 43 entries:
#   Technique: Linguistic Manipulation, Count: 35
#   Technique: Factual Manipulation, Count: 8
#
# Topic: 42, 21 entries:
#   Technique: Linguistic Manipulation, Count: 21
#
# Topic: 24, 33 entries:
#   Technique: Factual Manipulation, Count: 19
#   Technique: Linguistic Manipulation, Count: 14
#
# Topic: 66, 12 entries:
#   Technique: Linguistic Manipulation, Count: 11
#   Technique: Factual Manipulation, Count: 1
#
# Topic: 32, 27 entries:
#   Technique: Linguistic Manipulation, Count: 19
#   Technique: Factual Manipulation, Count: 8
#
# Topic: 38, 23 entries:
#   Technique: Linguistic Manipulation, Count: 12
#   Technique: Factual Manipulation, Count: 11
#
# Topic: 60, 15 entries:
#   Technique: Factual Manipulation, Count: 11
#   Technique: Linguistic Manipulation, Count: 4
#
# Topic: 20, 37 entries:
#   Technique: Factual Manipulation, Count: 35
#   Technique: Linguistic Manipulation, Count: 2
#
# Topic: 31, 28 entries:
#   Technique: Linguistic Manipulation, Count: 18
#   Technique: Factual Manipulation, Count: 10
#
# Topic: 2, 97 entries:
#   Technique: Linguistic Manipulation, Count: 76
#   Technique: Factual Manipulation, Count: 21
#
# Topic: 10, 63 entries:
#   Technique: Factual Manipulation, Count: 41
#   Technique: Linguistic Manipulation, Count: 22
#
# Topic: 49, 19 entries:
#   Technique: Linguistic Manipulation, Count: 11
#   Technique: Factual Manipulation, Count: 8
#
# Topic: 54, 18 entries:
#   Technique: Linguistic Manipulation, Count: 16
#   Technique: Factual Manipulation, Count: 2
#
# Topic: 58, 16 entries:
#   Technique: Linguistic Manipulation, Count: 14
#   Technique: Factual Manipulation, Count: 2
#
# Topic: 59, 15 entries:
#   Technique: Factual Manipulation, Count: 14
#   Technique: Linguistic Manipulation, Count: 1
#
# Topic: 62, 14 entries:
#   Technique: Linguistic Manipulation, Count: 13
#   Technique: Factual Manipulation, Count: 1
#
# Topic: 63, 14 entries:
#   Technique: Linguistic Manipulation, Count: 9
#   Technique: Factual Manipulation, Count: 5
#
# Topic: 64, 13 entries:
#   Technique: Linguistic Manipulation, Count: 11
#   Technique: Factual Manipulation, Count: 2
#
# Topic: 65, 13 entries:
#   Technique: Factual Manipulation, Count: 7
#   Technique: Linguistic Manipulation, Count: 6

# %% [markdown]
# ## PART III. Name the clusters

# %%
from openai import OpenAI
from utils import *

# subsample 15 entries (or if the number of entries is less than 15, simply the number of entries) from each cluster within clusters_with_techniques
# and concatenate the original_text of these subsampled entries to feed into OpenAI LLM to "name" the cluster based on these entries
def subsample_entries_per_cluster(df, sample_size=15):
    cluster_summaries = {}
    for cluster in df['cluster'].unique():
        cluster_df = df[df['cluster'] == cluster]
        sampled_df = cluster_df.sample(n=min(sample_size, len(cluster_df)), random_state=42)
        concatenated_text = "\n\n".join(sampled_df['original_text'].tolist())
        cluster_summaries[cluster] = name_topic_with_llm(concatenated_text)
    return cluster_summaries


client = OpenAI(api_key=OPENAI_API_KEY)

def name_topic_with_llm(keywords, model="gpt-5-mini"):
    """
    keywords: list or string of n-grams (top words defining the topic)
    model: choose any OpenAI model, default is fast & cheap
    
    Returns: short human-readable topic name.
    """
    if isinstance(keywords, list):
        keywords = ", ".join(keywords)

    prompt = f"""
    You are an expert in political narratives, conflict studies, and cultural heritage.
    Based only on the following analysis texts of 15 revisions from several wikipedia articles grouped together as a topic/theme, generate a SHORT descriptive name 
    (max 8-10 words) that summarizes the theme (subject matter and the characterstics of the revisions related to it, etc).

    Analyses: {keywords}

    Answer ONLY with the name.
    """

    response = client.responses.create(
        model=model,
        input=prompt
    )

    return response.output_text.strip()

cluster_summaries = subsample_entries_per_cluster(clusters_with_techniques)
for cluster, summary in cluster_summaries.items():
    print(f"Cluster {cluster} Summary:\n{summary}\n{'-'*80}\n")
# Out:
# Cluster 0 Summary:
# Partisan edits weaponizing ARF history and legitimacy
# --------------------------------------------------------------------------------
#
# Cluster 1 Summary:
# Weaponization of Armenian Genocide narratives in Wikipedia edits
# --------------------------------------------------------------------------------
#
# Cluster 2 Summary:
# Weaponizing Armenian cultural heritage narratives in Armenia–Azerbaijan edits
# --------------------------------------------------------------------------------
#
# Cluster 3 Summary:
# Wikipedia Revisionism: Hate Speech, Ethnic Blame, Historical Erasure
# --------------------------------------------------------------------------------
#
# Cluster 4 Summary:
# Weaponized Wikipedia edits over dolma: cultural erasure and appropriation
# --------------------------------------------------------------------------------
#
# Cluster 5 Summary:
# Contested Naming and Cultural Erasure of Shusha/Shushi
# --------------------------------------------------------------------------------
#
# Cluster 6 Summary:
# Vandalism and Weaponized Slurs Against Armenian Cultural Heritage
# --------------------------------------------------------------------------------
#
# Cluster 7 Summary:
# Contested naming and cultural claims over Mount Ararat
# --------------------------------------------------------------------------------
#
# Cluster 8 Summary:
# Urartu–Armenian Continuity Edits and Heritage Weaponization
# --------------------------------------------------------------------------------
#
# Cluster 9 Summary:
# Weaponized edits erasing Armenian diversity and heritage
# --------------------------------------------------------------------------------
#
# Cluster 10 Summary:
# Weaponized demographic narratives in Nagorno-Karabakh articles
# --------------------------------------------------------------------------------
#
# Cluster 11 Summary:
# Wikipedia edits contesting Nakhchivan's Armenian and Azerbaijani heritage
# --------------------------------------------------------------------------------
#
# Cluster 12 Summary:
# Contested Lavash Origins: Nationalistic Reattribution and Cultural Erasure
# --------------------------------------------------------------------------------
#
# Cluster 13 Summary:
# Weaponized place-naming: Yerevan's Armenian–Azerbaijani identity dispute
# --------------------------------------------------------------------------------
#
# Cluster 14 Summary:
# Terminology Weaponizing Armenian–Turkish Cultural Heritage
# --------------------------------------------------------------------------------
#
# Cluster 15 Summary:
# Wikipedia edits weaponizing Artsakh history — Armenian vs Albanian narratives
# --------------------------------------------------------------------------------
#
# Cluster 16 Summary:
# Erasure and amplification of Armenian heritage in Wikipedia
# --------------------------------------------------------------------------------
#
# Cluster 17 Summary:
# Framing dispute: "occupied" vs "controlled" in Nagorno‑Karabakh
# --------------------------------------------------------------------------------
#
# Cluster 18 Summary:
# Weaponized edits framing Turkey, Syrian mercenaries in Karabakh
# --------------------------------------------------------------------------------
#
# Cluster 19 Summary:
# Weaponized terminology: Wikipedia's Nagorno-Karabakh/Artsakh sovereignty edits
# --------------------------------------------------------------------------------
#
# Cluster 20 Summary:
# Wiki edits reframing Caucasus history to favor Azerbaijani claims
# --------------------------------------------------------------------------------
#
# Cluster 21 Summary:
# Weaponized victory language and erasure in Karabakh narratives
# --------------------------------------------------------------------------------
#
# Cluster 22 Summary:
# Contested Khojaly Narratives and Heritage Weaponization
# --------------------------------------------------------------------------------
#
# Cluster 23 Summary:
# Wiki edits altering foreign support narratives in Nagorno-Karabakh
# --------------------------------------------------------------------------------
#
# Cluster 24 Summary:
# Politicized editing: weaponizing Nagorno-Karabakh cultural narratives
# --------------------------------------------------------------------------------
#
# Cluster 25 Summary:
# Framing and Sanitizing Edits in Azerbaijani–Armenian Conflict Articles
# --------------------------------------------------------------------------------
#
# Cluster 26 Summary:
# Manipulation of casualty numbers and framing in Karabakh articles
# --------------------------------------------------------------------------------

# %%
# read existing keywords csv
keywords_path = os.path.join(data_dir, "keywords", "cluster_keywords_named.csv")
keywords_df = pd.read_csv(keywords_path)

# replace the 'Cluster_Name' column with the newly generated cluster_summaries
keywords_df['Cluster_Name'] = keywords_df['Cluster'].map(cluster_summaries)

# save updated keywords csv
output_keywords_path = os.path.join(data_dir, "keywords", "cluster_keywords_named_text_directly.csv")
keywords_df.to_csv(output_keywords_path, index=False)

# %%
# subsample 15 entries (or if the number of entries is less than 15, simply the number of entries) from each cluster-topic combo within cluster_topics_with_techniques
# and concatenate the original_text of these subsampled entries to feed into OpenAI LLM to "name" the cluster topic based on these entries
def subsample_entries_per_cluster_topic(df, sample_size=15):
    cluster_summaries = {}
    for cluster in df['cluster'].unique():
        cluster_df = df[df['cluster'] == cluster]
        for topic in cluster_df['topic'].unique():
            topic_df = cluster_df[cluster_df['topic'] == topic]
            sampled_df = topic_df.sample(n=min(sample_size, len(topic_df)), random_state=42)
            concatenated_text = "\n\n".join(sampled_df['original_text'].tolist())
            cluster_topic_key = f"{cluster}__{topic}"
            cluster_summaries[cluster_topic_key] = name_topic_with_llm(concatenated_text)
    return cluster_summaries

cluster_topic_summaries = subsample_entries_per_cluster_topic(cluster_topics_with_techniques)
for cluster_topic, summary in cluster_topic_summaries.items():
    print(f"Cluster-Topic {cluster_topic} Summary:\n{summary}\n{'-'*80}\n") 

# read existing keywords csv
keywords_path = os.path.join(data_dir, "keywords", "cluster_topics_named.csv")
keywords_df = pd.read_csv(keywords_path)
# Out:
# Cluster-Topic 1__0 Summary:
# Contested Armenian Genocide narratives and editorial weaponization
# --------------------------------------------------------------------------------
#
# Cluster-Topic 1__1 Summary:
# Contested Wikipedia edits on Armenian Genocide terminology and sourcing
# --------------------------------------------------------------------------------
#
# Cluster-Topic 1__2 Summary:
# Contested Armenian Genocide narratives and weaponized Wikipedia edits
# --------------------------------------------------------------------------------
#
# Cluster-Topic 1__3 Summary:
# Armenian Genocide recognition narratives weaponized via Wikipedia edits
# --------------------------------------------------------------------------------
#
# Cluster-Topic 1__4 Summary:
# Politicized Wikipedia edits reshaping Armenian Genocide narrative
# --------------------------------------------------------------------------------
#
# Cluster-Topic 1__5 Summary:
# Denialist Framing and Language Shifts on Armenian Genocide
# --------------------------------------------------------------------------------
#
# Cluster-Topic 1__6 Summary:
# Weaponizing cultural heritage: Wikipedia edits recognizing Armenian Genocide
# --------------------------------------------------------------------------------
#
# Cluster-Topic 1__7 Summary:
# Wikipedia edits on Armenian Genocide recognition and framing
# --------------------------------------------------------------------------------
#
# Cluster-Topic 1__8 Summary:
# Systematic Removal of Armenian Genocide References on Wikipedia
# --------------------------------------------------------------------------------
#
# Cluster-Topic 1__9 Summary:
# Framing Armenian property seizures: genocide, economy, and erasure
# --------------------------------------------------------------------------------
#
# Cluster-Topic 1__10 Summary:
# Rewriting Adana massacre: nationalist denial and heritage weaponization
# --------------------------------------------------------------------------------
#
# Cluster-Topic 1__11 Summary:
# Weaponizing Wikipedia tags to reshape Armenian genocide narratives
# --------------------------------------------------------------------------------
#
# Cluster-Topic 1__12 Summary:
# Selective Deletions Undermining Armenian Genocide Recognition
# --------------------------------------------------------------------------------
#
# Cluster-Topic 1__13 Summary:
# Weaponized Language in Armenian Genocide Wikipedia Edits
# --------------------------------------------------------------------------------
#
# Cluster-Topic 1__14 Summary:
# Edits reframing Armenian Genocide denial and delegitimization
# --------------------------------------------------------------------------------
#
# Cluster-Topic 1__15 Summary:
# Language manipulation of Armenian Genocide Wikipedia content
# --------------------------------------------------------------------------------
#
# Cluster-Topic 1__16 Summary:
# Wikipedia edits advancing Turkish genocide-denial narratives
# --------------------------------------------------------------------------------
#
# Cluster-Topic 4__0 Summary:
# Nationalist rewrites of dolma's origins and cultural attribution
# --------------------------------------------------------------------------------
#
# Cluster-Topic 4__1 Summary:
# Weaponization of dolma cultural heritage in Wikipedia edits
# --------------------------------------------------------------------------------
#
# Cluster-Topic 6__0 Summary:
# Weaponized Anti‑Armenian Edits and Cultural Delegitimization
# --------------------------------------------------------------------------------
#
# Cluster-Topic 6__1 Summary:
# Anti-Armenian Wikipedia vandalism: dehumanizing slurs and stereotypes
# --------------------------------------------------------------------------------
#
# Cluster-Topic 7__0 Summary:
# Contested Mount Ararat naming and territorial claims
# --------------------------------------------------------------------------------
#
# Cluster-Topic 7__1 Summary:
# Editorial erasure of Armenian cultural claims to Mount Ararat
# --------------------------------------------------------------------------------
#
# Cluster-Topic 9__0 Summary:
# Monolithic Armenian Identity Emphasis and Cultural Erasure Edits
# --------------------------------------------------------------------------------
#
# Cluster-Topic 9__1 Summary:
# Nationalistic re-framing of Etchmiadzin Cathedral's cultural heritage
# --------------------------------------------------------------------------------
#
# Cluster-Topic 9__2 Summary:
# Wikipedia edits reframing Armenian heritage and historical narratives
# --------------------------------------------------------------------------------
#
# Cluster-Topic 12__0 Summary:
# Weaponizing Lavash: Nationalist Rewrites of Cultural Origin Claims
# --------------------------------------------------------------------------------
#
# Cluster-Topic 12__1 Summary:
# Framing Armenian Cultural Ownership Through Language Edits
# --------------------------------------------------------------------------------
#
# Cluster-Topic 14__0 Summary:
# Erasure of Armenian and Kurdish heritage through Wikipedia edits
# --------------------------------------------------------------------------------
#
# Cluster-Topic 14__1 Summary:
# Deliberate removal and relabelling of Armenian Highlands
# --------------------------------------------------------------------------------
#
# Cluster-Topic 15__0 Summary:
# Weaponizing Cultural Heritage: Armenian Narratives on Artsakh
# --------------------------------------------------------------------------------
#
# Cluster-Topic 15__1 Summary:
# Weaponizing Caucasus history: Wikipedia edits on Artsakh heritage
# --------------------------------------------------------------------------------
#
# Cluster-Topic 16__0 Summary:
# Systematic Deletion of Armenian Historical and Cultural References
# --------------------------------------------------------------------------------
#
# Cluster-Topic 16__1 Summary:
# Weaponizing Armenian Cultural Heritage in Wikipedia Revisions
# --------------------------------------------------------------------------------
#
# Cluster-Topic 18__0 Summary:
# Editorial 'Alleged' Framing to Undermine Armenian Claims
# --------------------------------------------------------------------------------
#
# Cluster-Topic 18__1 Summary:
# Weaponized Framing of Foreign Mercenaries in Nagorno-Karabakh Conflict
# --------------------------------------------------------------------------------
#
# Cluster-Topic 19__0 Summary:
# Editing wars over Artsakh sovereignty and heritage narratives
# --------------------------------------------------------------------------------
#
# Cluster-Topic 19__1 Summary:
# Wikipedia edits weaponizing Nagorno-Karabakh sovereignty claims
# --------------------------------------------------------------------------------
#
# Cluster-Topic 19__2 Summary:
# Weaponized Territorial Narratives in Nagorno-Karabakh Wikipedia Edits
# --------------------------------------------------------------------------------
#
# Cluster-Topic 19__3 Summary:
# Framing Nagorno-Karabakh: edits legitimizing or delegitimizing sovereignty
# --------------------------------------------------------------------------------
#
# Cluster-Topic 19__4 Summary:
# Pro-Artsakh Framing and Legitimization in Wikipedia Revisions
# --------------------------------------------------------------------------------
#
# Cluster-Topic 19__5 Summary:
# Azerbaijani nationalist edits asserting Karabakh sovereignty
# --------------------------------------------------------------------------------
#
# Cluster-Topic 19__6 Summary:
# Framing Nagorno-Karabakh's political status via language edits
# --------------------------------------------------------------------------------
#
# Cluster-Topic 20__0 Summary:
# Politically Driven Renaming and Reframing of Karabakh History
# --------------------------------------------------------------------------------
#
# Cluster-Topic 20__1 Summary:
# Weaponized Demographic Revisions and Ethnic Terminology in Caucasus
# --------------------------------------------------------------------------------
#
# Cluster-Topic 26__0 Summary:
# Wikipedia edits manipulating casualty figures and narratives in Nagorno-Karabakh
# --------------------------------------------------------------------------------
#
# Cluster-Topic 26__1 Summary:
# Weaponized casualty counts and blame shifts in Nagorno-Karabakh
# --------------------------------------------------------------------------------

# %%
# replace the 'Cluster_Topic_Name' column with the newly generated cluster_topic_summaries
def get_cluster_topic_key(row):
    return f"{row['Cluster']}__{row['Topic']}"
keywords_df['Cluster_Topic_Key'] = keywords_df.apply(get_cluster_topic_key, axis=1)
keywords_df['Cluster_Topic_Name'] = keywords_df['Cluster_Topic_Key'].map(cluster_topic_summaries)
keywords_df.drop(columns=['Cluster_Topic_Key'], inplace=True)
# save updated keywords csv
output_keywords_path = os.path.join(data_dir, "keywords", "cluster_topics_named_text_directly.csv")
keywords_df.to_csv(output_keywords_path, index=False)

# %%
# subsample 15 entries (or if the number of entries is less than 15, simply the number of entries) from each topic within general_topics_with_techniques
# and concatenate the original_text of these subsampled entries to feed into OpenAI LLM to "name" the topic based on these entries

def subsample_entries_per_general_topic(df, sample_size=15):
    topic_summaries = {}
    for topic in df['topic'].unique():
        topic_df = df[df['topic'] == topic]
        sampled_df = topic_df.sample(n=min(sample_size, len(topic_df)), random_state=42)
        concatenated_text = "\n\n".join(sampled_df['original_text'].tolist())
        topic_summaries[topic] = name_topic_with_llm(concatenated_text)
    return topic_summaries

general_topic_summaries = subsample_entries_per_general_topic(general_topics_with_techniques)
for topic, summary in general_topic_summaries.items():
    print(f"General Topic {topic} Summary:\n{summary}\n{'-'*80}\n")
# Out:
# General Topic 21 Summary:
# Weaponized Wikipedia edits about ARF and Armenian heritage
# --------------------------------------------------------------------------------
#
# General Topic 15 Summary:
# Weaponized Language and Denial in Armenian Genocide Edits
# --------------------------------------------------------------------------------
#
# General Topic 3 Summary:
# Contested Wikipedia narratives on the Armenian Genocide
# --------------------------------------------------------------------------------
#
# General Topic 5 Summary:
# Contested Wikipedia edits: Armenian Genocide framing and denial
# --------------------------------------------------------------------------------
#
# General Topic 0 Summary:
# Weaponized Wikipedia edits denying Armenian Genocide
# --------------------------------------------------------------------------------
#
# General Topic 53 Summary:
# Tag edits weaponizing Armenian Genocide narrative on Wikipedia
# --------------------------------------------------------------------------------
#
# General Topic 44 Summary:
# Weaponizing Armenian Genocide Narrative in Wikipedia Revisions
# --------------------------------------------------------------------------------
#
# General Topic 47 Summary:
# Weaponization of Armenian Genocide narratives on Wikipedia
# --------------------------------------------------------------------------------
#
# General Topic 45 Summary:
# Numerical edits to Armenian Genocide recognition and denial
# --------------------------------------------------------------------------------
#
# General Topic 23 Summary:
# Weaponized wording in Wikipedia edits on Armenian Genocide
# --------------------------------------------------------------------------------
#
# General Topic 39 Summary:
# Contested framing of the Adana massacre and Armenian heritage
# --------------------------------------------------------------------------------
#
# General Topic 33 Summary:
# Edits promoting recognition of Armenian Genocide via memorial visits
# --------------------------------------------------------------------------------
#
# General Topic 48 Summary:
# Erasure of Armenian Genocide References in Wikipedia Edits
# --------------------------------------------------------------------------------
#
# General Topic 41 Summary:
# Systematic removal of Armenian Genocide recognition content
# --------------------------------------------------------------------------------
#
# General Topic 36 Summary:
# Contested narratives of Armenian property confiscation and erasure
# --------------------------------------------------------------------------------
#
# General Topic 61 Summary:
# Wikipedia edits shaping Armenian Genocide recognition and framing
# --------------------------------------------------------------------------------
#
# General Topic 52 Summary:
# Wikipedia edits contesting Armenian Genocide casualty counts
# --------------------------------------------------------------------------------
#
# General Topic 29 Summary:
# Wikipedia edits on Armenian Genocide recognition and denial
# --------------------------------------------------------------------------------
#
# General Topic 51 Summary:
# Wikipedia edits framing Armenian cultural and territorial claims
# --------------------------------------------------------------------------------
#
# General Topic 7 Summary:
# Weaponized Cultural Heritage: Anti‑Armenian Nationalist Wikipedia Edits
# --------------------------------------------------------------------------------
#
# General Topic 17 Summary:
# Weaponizing Armenian Cultural Heritage in Wikipedia Edits
# --------------------------------------------------------------------------------
#
# General Topic 18 Summary:
# Weaponized Cultural Claims Over Dolma on Wikipedia
# --------------------------------------------------------------------------------
#
# General Topic 34 Summary:
# Nationalistic edits contesting Dolma's Armenian–Azerbaijani heritage
# --------------------------------------------------------------------------------
#
# General Topic 55 Summary:
# Politicized erasure and reattribution of culinary identities
# --------------------------------------------------------------------------------
#
# General Topic 16 Summary:
# Renaming and cultural erasure in Shusha/Shushi Wikipedia edits
# --------------------------------------------------------------------------------
#
# General Topic 11 Summary:
# Weaponized vandalism targeting Armenian cultural heritage and identity
# --------------------------------------------------------------------------------
#
# General Topic 6 Summary:
# Mount Ararat: Nationalist Renaming and Cultural Erasure
# --------------------------------------------------------------------------------
#
# General Topic 12 Summary:
# Nationalist Rewriting of Urartu–Armenian Historical Narrative on Wikipedia
# --------------------------------------------------------------------------------
#
# General Topic 26 Summary:
# Weaponizing Armenian religious heritage through Wikipedia edits
# --------------------------------------------------------------------------------
#
# General Topic 40 Summary:
# Wikipedia edits weaponizing Armenian cultural heritage narratives
# --------------------------------------------------------------------------------
#
# General Topic 43 Summary:
# Framing and weaponization of displacement in Nagorno-Karabakh articles
# --------------------------------------------------------------------------------
#
# General Topic 13 Summary:
# Weaponized edits: erasing Armenian claims to Nakhchivan
# --------------------------------------------------------------------------------
#
# General Topic 9 Summary:
# Weaponized edits reattributing lavash and regional cultural heritage
# --------------------------------------------------------------------------------
#
# General Topic 27 Summary:
# Nationalistic renaming of Yerevan and contested toponyms
# --------------------------------------------------------------------------------
#
# General Topic 56 Summary:
# Toponymic revisions weaponizing Kars' multilingual heritage
# --------------------------------------------------------------------------------
#
# General Topic 4 Summary:
# Wikipedia edits weaponizing cultural heritage against Armenians
# --------------------------------------------------------------------------------
#
# General Topic 8 Summary:
# Weaponization of Artsakh cultural heritage in edits
# --------------------------------------------------------------------------------
#
# General Topic 68 Summary:
# Mythologizing Armenian Origins and Weaponizing Cultural Heritage
# --------------------------------------------------------------------------------
#
# General Topic 28 Summary:
# Nationalist Wikipedia edits asserting Greater Armenian heritage claims
# --------------------------------------------------------------------------------
#
# General Topic 46 Summary:
# Weaponizing Armenian ancient heritage in Wikipedia edits
# --------------------------------------------------------------------------------
#
# General Topic 22 Summary:
# Deliberate Deletion of Armenian Heritage and Identity References
# --------------------------------------------------------------------------------
#
# General Topic 25 Summary:
# Framing conflict: "Occupied" vs "Controlled" edits on Nagorno-Karabakh
# --------------------------------------------------------------------------------
#
# General Topic 14 Summary:
# Wiki revisions politicizing mercenary narratives and Turkish support
# --------------------------------------------------------------------------------
#
# General Topic 1 Summary:
# Wikipedia edit wars on Nagorno-Karabakh sovereignty framing
# --------------------------------------------------------------------------------
#
# General Topic 67 Summary:
# Editorial shifts in Nagorno-Karabakh sovereignty narratives
# --------------------------------------------------------------------------------
#
# General Topic 37 Summary:
# Weaponizing Cultural Heritage: Wikipedia Edits Claiming Karabakh
# --------------------------------------------------------------------------------
#
# General Topic 30 Summary:
# Wikipedia language battles over Artsakh sovereignty and recognition
# --------------------------------------------------------------------------------
#
# General Topic 50 Summary:
# Wikipedia language warfare over Nagorno-Karabakh territorial legitimacy
# --------------------------------------------------------------------------------
#
# General Topic 57 Summary:
# Weaponizing cultural heritage via flag/name swaps on Wikipedia
# --------------------------------------------------------------------------------
#
# General Topic 35 Summary:
# Toponymic Reframing and Cultural Erasure in Artsakh/Nagorno-Karabakh
# --------------------------------------------------------------------------------
#
# General Topic 19 Summary:
# Nationalistic reattribution of Caucasus cultural heritage in Wikipedia
# --------------------------------------------------------------------------------
#
# General Topic 42 Summary:
# Weaponized terminology: Azerbaijani vs Tatar identity edits
# --------------------------------------------------------------------------------
#
# General Topic 24 Summary:
# Demographic Revisionism and Narrative Weaponization in Nagorno-Karabakh
# --------------------------------------------------------------------------------
#
# General Topic 66 Summary:
# Toponymic edits weaponizing Armenian–Azerbaijani cultural heritage
# --------------------------------------------------------------------------------
#
# General Topic 32 Summary:
# Weaponized wording shifts in Nagorno-Karabakh victory narratives
# --------------------------------------------------------------------------------
#
# General Topic 38 Summary:
# Weaponizing Khojaly: Massacre Narratives, Denial, Remembrance
# --------------------------------------------------------------------------------
#
# General Topic 60 Summary:
# Narrative edits on Shusha: massacres, demographics, weaponized heritage
# --------------------------------------------------------------------------------
#
# General Topic 20 Summary:
# Pro-Armenian Wikipedia edits reframing Nagorno-Karabakh alliances and arms
# --------------------------------------------------------------------------------
#
# General Topic 31 Summary:
# Weaponizing Nagorno-Karabakh narrative toward Azerbaijani nationalist framing
# --------------------------------------------------------------------------------
#
# General Topic 2 Summary:
# Weaponized narrative and bias in Nagorno-Karabakh edits
# --------------------------------------------------------------------------------
#
# General Topic 10 Summary:
# Manipulation of Karabakh conflict casualty and blame narratives
# --------------------------------------------------------------------------------
#
# General Topic 49 Summary:
# Van Cat Edits: Ethnic Claims and Cultural Erasure
# --------------------------------------------------------------------------------
#
# General Topic 54 Summary:
# Weaponization of Armenian Cultural Heritage Narratives
# --------------------------------------------------------------------------------
#
# General Topic 58 Summary:
# Weaponized revisions: Reframing Armenian origins, race, and heritage
# --------------------------------------------------------------------------------
#
# General Topic 59 Summary:
# Weaponization of Armenian demographic figures on Wikipedia
# --------------------------------------------------------------------------------
#
# General Topic 62 Summary:
# Nationalistic militarization of Armenian Wikipedia articles
# --------------------------------------------------------------------------------
#
# General Topic 63 Summary:
# Weaponizing Hemshin Heritage: Erasure, Reattribution, and Terminology
# --------------------------------------------------------------------------------
#
# General Topic 64 Summary:
# Rewriting Armenia's Geography: Europe vs Asia Identity Edits
# --------------------------------------------------------------------------------
#
# General Topic 65 Summary:
# Disputed framing of Armenian territorial and historical claims
# --------------------------------------------------------------------------------

# %%
# read existing keywords csv
keywords_path = os.path.join(data_dir, "keywords", "general_topics_named.csv")
keywords_df = pd.read_csv(keywords_path)
# replace the 'Topic_Name' column with the newly generated general_topic_summaries
keywords_df['Topic_Name'] = keywords_df['Topic'].map(general_topic_summaries)
# save updated keywords csv
output_keywords_path = os.path.join(data_dir, "keywords", "general_topics_named_text_directly.csv")
keywords_df.to_csv(output_keywords_path, index=False)
