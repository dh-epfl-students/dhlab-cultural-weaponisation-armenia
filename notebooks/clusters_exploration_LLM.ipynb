# %%
import pandas as pd
import os

data_dir = ".."

clusters_path = os.path.join(data_dir, "other_outputs", "weaponization_analysis", "UPDATED_clusters_with_weaponization_techniques.csv")
cluster_topics_path = os.path.join(data_dir, "other_outputs", "weaponization_analysis", "UPDATED_cluster_topics_with_weaponization_techniques.csv")
general_topics_path = os.path.join(data_dir, "other_outputs", "weaponization_analysis", "UPDATED_general_topics_with_weaponization_techniques.csv")

clusters_with_techniques = pd.read_csv(clusters_path)
cluster_topics_with_techniques = pd.read_csv(cluster_topics_path)
general_topics_with_techniques = pd.read_csv(general_topics_path)

# %% [markdown]
# ## PART I: ANALYSIS W/ MORE FINEGRAINED CATEGORIES

# %% [markdown]
# #### 1. Clusters Exploration

# %%
# for clusters_with_techniques, for EACH cluster, count and print out the occurences/number of entries of each unique weaponization technique in each cluster
def count_unique_techniques(df):
    for cluster in df['cluster'].unique():
        cluster_df = df[df['cluster'] == cluster]
        technique_counts = cluster_df['weaponization_technique'].value_counts()
        print(f"Cluster {cluster}, {len(cluster_df)} entries:")
        for technique, count in technique_counts.items():
            print(f"  Technique: {technique}, Count: {count}")
        print()

count_unique_techniques(clusters_with_techniques)
# Out:
# Cluster 0, 35 entries:
#   Technique: Terminology Biasing, Count: 14
#   Technique: Glorification & Vilification, Count: 9
#   Technique: Selective Omission, Count: 7
#   Technique: Selective Insertion, Count: 3
#   Technique: Tag Manipulation, Count: 1
#   Technique: Euphemism and Doublespeak, Count: 1
#
# Cluster 1, 1004 entries:
#   Technique: Terminology Biasing, Count: 423
#   Technique: Selective Omission, Count: 286
#   Technique: Glorification & Vilification, Count: 118
#   Technique: Selective Insertion, Count: 92
#   Technique: Tag Manipulation, Count: 31
#   Technique: Euphemism and Doublespeak, Count: 25
#   Technique: Source Biasing, Count: 15
#   Technique: Timeline Rewriting, Count: 8
#   Technique: Citation Deletion, Count: 4
#   Technique: Select Insertion, Count: 1
#   Technique: Selectively Omission, Count: 1
#
# Cluster 2, 49 entries:
#   Technique: Selective Omission, Count: 21
#   Technique: Terminology Biasing, Count: 15
#   Technique: Glorification & Vilification, Count: 8
#   Technique: Selective Insertion, Count: 5
#
# Cluster 3, 33 entries:
#   Technique: Glorification & Vilification, Count: 19
#   Technique: Selective Omission, Count: 8
#   Technique: Terminology Biasing, Count: 4
#   Technique: Euphemism and Doublespeak, Count: 2
#
# Cluster 4, 83 entries:
#   Technique: Terminology Biasing, Count: 56
#   Technique: Selective Omission, Count: 24
#   Technique: Glorification & Vilification, Count: 3
#
# Cluster 5, 50 entries:
#   Technique: Terminology Biasing, Count: 37
#   Technique: Selective Omission, Count: 12
#   Technique: Euphemism and Doublespeak, Count: 1
#
# Cluster 6, 60 entries:
#   Technique: Glorification & Vilification, Count: 37
#   Technique: Terminology Biasing, Count: 15
#   Technique: Selective Omission, Count: 6
#   Technique: Euphemism and Doublespeak, Count: 2
#
# Cluster 7, 79 entries:
#   Technique: Terminology Biasing, Count: 49
#   Technique: Selective Omission, Count: 24
#   Technique: Selective Insertion, Count: 4
#   Technique: Glorification & Vilification, Count: 2
#
# Cluster 8, 46 entries:
#   Technique: Terminology Biasing, Count: 31
#   Technique: Selective Omission, Count: 13
#   Technique: Selective Insertion, Count: 1
#   Technique: Glorification & Vilification, Count: 1
#
# Cluster 9, 64 entries:
#   Technique: Terminology Biasing, Count: 35
#   Technique: Selective Omission, Count: 17
#   Technique: Glorification & Vilification, Count: 4
#   Technique: Selective Insertion, Count: 4
#   Technique: Timeline Rewriting, Count: 3
#   Technique: Euphemism and Doublespeak, Count: 1
#
# Cluster 10, 31 entries:
#   Technique: Terminology Biasing, Count: 10
#   Technique: Selective Insertion, Count: 8
#   Technique: Selective Omission, Count: 8
#   Technique: Glorification & Vilification, Count: 5
#
# Cluster 11, 40 entries:
#   Technique: Terminology Biasing, Count: 22
#   Technique: Selective Omission, Count: 13
#   Technique: Selective Insertion, Count: 4
#   Technique: Tag Manipulation, Count: 1
#
# Cluster 12, 55 entries:
#   Technique: Terminology Biasing, Count: 42
#   Technique: Selective Omission, Count: 8
#   Technique: Selective Insertion, Count: 4
#   Technique: Source Biasing, Count: 1
#
# Cluster 13, 34 entries:
#   Technique: Terminology Biasing, Count: 25
#   Technique: Selective Omission, Count: 7
#   Technique: Glorification & Vilification, Count: 1
#   Technique: Citation Deletion, Count: 1
#
# Cluster 14, 85 entries:
#   Technique: Terminology Biasing, Count: 52
#   Technique: Selective Omission, Count: 29
#   Technique: Selective Insertion, Count: 2
#   Technique: Glorification & Vilification, Count: 1
#   Technique: Euphemism and Doublespeak, Count: 1
#
# Cluster 15, 64 entries:
#   Technique: Terminology Biasing, Count: 32
#   Technique: Selective Omission, Count: 18
#   Technique: Selective Insertion, Count: 11
#   Technique: Source Biasing, Count: 2
#   Technique: Glorification & Vilification, Count: 1
#
# Cluster 16, 123 entries:
#   Technique: Selective Omission, Count: 51
#   Technique: Terminology Biasing, Count: 49
#   Technique: Glorification & Vilification, Count: 13
#   Technique: Selective Insertion, Count: 9
#   Technique: Source Biasing, Count: 1
#
# Cluster 17, 28 entries:
#   Technique: Terminology Biasing, Count: 25
#   Technique: Selective Omission, Count: 3
#
# Cluster 18, 52 entries:
#   Technique: Terminology Biasing, Count: 28
#   Technique: Selective Omission, Count: 11
#   Technique: Selective Insertion, Count: 7
#   Technique: Glorification & Vilification, Count: 5
#   Technique: Euphemism and Doublespeak, Count: 1
#
# Cluster 19, 307 entries:
#   Technique: Terminology Biasing, Count: 238
#   Technique: Selective Omission, Count: 52
#   Technique: Selective Insertion, Count: 8
#   Technique: Glorification & Vilification, Count: 3
#   Technique: Source Biasing, Count: 2
#   Technique: Timeline Rewriting, Count: 2
#   Technique: Tag Manipulation, Count: 2
#
# Cluster 20, 114 entries:
#   Technique: Terminology Biasing, Count: 95
#   Technique: Selective Omission, Count: 16
#   Technique: Selective Insertion, Count: 2
#   Technique: Glorification & Vilification, Count: 1
#
# Cluster 21, 22 entries:
#   Technique: Terminology Biasing, Count: 8
#   Technique: Glorification & Vilification, Count: 7
#   Technique: Selective Omission, Count: 5
#   Technique: Timeline Rewriting, Count: 1
#   Technique: Selective Insertion, Count: 1
#
# Cluster 22, 34 entries:
#   Technique: Selective Omission, Count: 15
#   Technique: Glorification & Vilification, Count: 10
#   Technique: Terminology Biasing, Count: 5
#   Technique: Selective Insertion, Count: 4
#
# Cluster 23, 38 entries:
#   Technique: Selective Insertion, Count: 19
#   Technique: Selective Omission, Count: 17
#   Technique: Terminology Biasing, Count: 2
#
# Cluster 24, 24 entries:
#   Technique: Terminology Biasing, Count: 14
#   Technique: Selective Omission, Count: 4
#   Technique: Timeline Rewriting, Count: 2
#   Technique: Selective Insertion, Count: 1
#   Technique: Tag Manipulation, Count: 1
#   Technique: Source Biasing, Count: 1
#   Technique: Glorification & Vilification, Count: 1
#
# Cluster 25, 62 entries:
#   Technique: Glorification & Vilification, Count: 26
#   Technique: Terminology Biasing, Count: 21
#   Technique: Selective Omission, Count: 11
#   Technique: Selective Insertion, Count: 4
#
# Cluster 26, 59 entries:
#   Technique: Selective Omission, Count: 28
#   Technique: Terminology Biasing, Count: 16
#   Technique: Selective Insertion, Count: 8
#   Technique: Glorification & Vilification, Count: 4
#   Technique: Source Biasing, Count: 2
#   Technique: Euphemism and Doublespeak, Count: 1

# %%
# explore any given cluster in clusters_with_techniques
def explore_cluster(df, cluster_number):    
    cluster_df = df[df['cluster'] == cluster_number]
    print(f"Cluster {cluster_number}, {len(cluster_df)} entries:")
    technique_counts = cluster_df['weaponization_technique'].value_counts()
    for technique, count in technique_counts.items():
        print(f"  Technique: {technique}, Count: {count}")
    print()

explore_cluster(clusters_with_techniques, 0)
# Out:
# Cluster 0, 35 entries:
#   Technique: Terminology Biasing, Count: 14
#   Technique: Glorification & Vilification, Count: 9
#   Technique: Selective Omission, Count: 7
#   Technique: Selective Insertion, Count: 3
#   Technique: Tag Manipulation, Count: 1
#   Technique: Euphemism and Doublespeak, Count: 1

# %%
# explore all entries of any given cluster in clusters_with_techniques
def explore_cluster_entries(df, cluster_number):    
    cluster_df = df[df['cluster'] == cluster_number]
    for index, row in cluster_df.iterrows():
        print("Chosen manipulation technique:", row['weaponization_technique'])
        print("Original text:", row['original_text'])
        print()

explore_cluster_entries(clusters_with_techniques, 1)
# Out:
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision includes a significant shift in language regarding the recognition of the Armenian Genocide. The phrase "States that deny there was an Armenian genocide" has been changed to "States that explicitly deny the Armenian Genocide." The addition of the word "explicitly" serves to strengthen the assertion of denial, framing it as a more deliberate and conscious act. This subtle shift in wording can influence the reader's perception of the legitimacy of the denial, potentially weaponizing the narrative surrounding the Armenian Genocide by emphasizing the active choice of states to deny it. The removal of "there was" also simplifies the statement, making it more direct and assertive. Overall, these changes reflect a more confrontational stance towards the denial of the genocide, aligning with narratives that seek to affirm the historical reality of the Armenian Genocide.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision adds a caption to the image of the map, specifically stating "Map of the Armenian Genocide in 1915." This explicit labeling of the map as depicting the "Armenian Genocide" is a significant shift in tone and framing. The term "Armenian Genocide" is a highly charged phrase that carries specific historical and political implications, particularly in the context of Armenian and Turkish relations. By clearly identifying the map in this way, the revision reinforces a narrative that acknowledges and affirms the genocide, which can be seen as a weaponization of cultural heritage in the context of historical memory and identity. The removal of the previous, more neutral caption further emphasizes this shift.
#
# Chosen manipulation technique: Selective Omission
# Original text: The revision removed a significant introductory sentence that contextualized the establishment of the 'special organization' and its role in the destruction of the Ottoman Armenian community. The removed lines included phrases like "While there was an official 'special organization' founded in December 1911 by the Ottoman government," which provided a historical framework for understanding the actions of this organization. The addition of the lines that detail the release of criminals to form the organization and their subsequent actions towards Armenian deportees emphasizes the violent and systematic nature of the events, framing them in a way that aligns with narratives of genocide. The removal of the initial context could serve to downplay the historical significance of the organization’s actions, which is a subtle shift that can be interpreted as an attempt to weaponize the narrative surrounding the Armenian Genocide.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The revision introduces a new reference that includes the phrase "MASSACRE BY TURKS IN CAUCASUS TOWNS; Armenians Led Out Into the Streets and Shot or Drowned -- Old Friends Not Spared." This language is highly charged and frames the actions of the Turks in a very negative light, emphasizing violence and brutality against Armenians. The use of the term "MASSACRE" is particularly significant as it carries strong connotations of systematic violence and genocide, which aligns with narratives that seek to highlight the suffering of Armenians during this historical period. This shift in language can be seen as an attempt to weaponize the historical narrative by invoking emotional responses and framing the events in a way that supports a specific perspective on the conflict.
#
# Chosen manipulation technique: Selective Omission
# Original text: The revision involves the removal of a significant passage that details the rounding up and imprisonment of Armenian intellectuals during the events of April 1915, which is a critical aspect of the narrative surrounding the Armenian Genocide. The user’s comment, "Deleting a bare faced lie," suggests an intent to dismiss or undermine the historical account of these events, which is often framed as a genocide by Armenians. The absence of this context can contribute to a narrative that minimizes or denies the historical suffering of Armenians, aligning with weaponization tactics that seek to erase or distort cultural heritage and historical facts. The removal of this specific content, which is central to understanding the events of 1915, indicates a shift towards a narrative that may serve to delegitimize Armenian claims and experiences.
#
# Chosen manipulation technique: Selective Omission
# Original text: The revision removes a significant quote from Hrant Dink that reflects his views on the historical context of Turkish-Armenian relations, specifically the phrase "replace the poisoned blood associated with the Turk, with fresh blood associated with Armenia." This removal alters the narrative by omitting Dink's critical perspective on Turkish identity and the implications of the Armenian genocide. The addition of the word "prosecution" in the context of Dink's legal troubles is neutral but does not compensate for the loss of the critical quote. The overall effect is a sanitization of Dink's stance, which could be interpreted as an attempt to downplay the historical grievances associated with the Armenian genocide, thus weaponizing the cultural heritage narrative.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision changes the section title from "Opposition" to "Denial," which carries significant implications in the context of discussions surrounding the Armenian Genocide. The term "Denial" is often associated with the rejection of the characterization of the events as genocide, which can frame the narrative in a way that diminishes the recognition of the historical atrocities committed against Armenians. This shift in terminology can be seen as an attempt to delegitimize the acknowledgment of these events by framing dissenting views as mere denial rather than legitimate opposition. Additionally, the removal of the word "Opposition" in favor of "Denial" alters the tone from one of debate to one of rejection, which can contribute to a narrative that seeks to undermine the historical claims of genocide. The addition of "academics," while seemingly neutral, reinforces the focus on scholarly debate, but in the context of the title change, it aligns with the broader narrative of denialism.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision includes significant changes that reflect a shift in narrative regarding the relationship between Armenia and Turkey. The phrase "condition Turkey accept the genocide claims first" was altered to "condition of first having good relations with the Turkish state," which downplays the acknowledgment of the Armenian Genocide by framing it as a matter of diplomatic relations rather than a historical fact. This change can be seen as an attempt to shift the narrative away from the recognition of the genocide towards a more neutral or conciliatory tone, which aligns with Turkish perspectives that often seek to minimize or deny the genocide. Additionally, the removal of the line referencing "Tall Armenian Tale," a site that may present Armenian perspectives, further indicates a potential bias in the revision, suggesting an effort to suppress opposing narratives. These linguistic shifts are indicative of a weaponization of cultural heritage by reframing historical events in a way that aligns with a specific political agenda.
#
# Chosen manipulation technique: Selective Omission
# Original text: The revision introduces a significant shift in focus by replacing a detailed description of the socio-economic conditions of the Muslim and Christian communities in the Balkans with a more emotionally charged narrative centered on the "Young Turk" memoirs. The added lines emphasize the "fierce Ottoman-Muslim nationalism" and the "wholesale slaughter of the Ottoman Armenians," which frames the narrative in a way that highlights the Muslim perspective while invoking historical grievances. The removal of the previous lines, which provided a more neutral socio-economic analysis, suggests an intent to shift the tone towards a more nationalistic and potentially victimized narrative. This aligns with the weaponization of cultural heritage by framing the historical context in a way that could justify contemporary political positions or grievances.
#
# Chosen manipulation technique: Selective Insertion
# Original text: The revision includes the addition of multiple lines that reinforce the narrative surrounding the Armenian Genocide, specifically through the inclusion of images and links to websites that support the genocide thesis. The phrase "===Websites supporting the genocide theses===" explicitly categorizes these resources in a way that aligns with the Armenian perspective on the events of 1915. The added lines include references to organizations and resources that advocate for recognition of the Armenian Genocide, such as the Armenian National Committee of America and the Armenian National Institute. This framing serves to bolster the narrative of victimhood and historical injustice, which can be seen as a form of weaponization of cultural heritage by promoting a specific interpretation of historical events while potentially marginalizing opposing views. The comment by the user, "rv POV pushing," suggests an awareness of the contentious nature of the edits, indicating an attempt to assert a particular point of view in the ongoing discourse surrounding the Armenian Genocide.
#
# Chosen manipulation technique: Selective Omission
# Original text: The revision includes significant changes that reflect a shift in narrative regarding the Armenian Genocide. The removal of the phrase "see other names" in the context of the Armenian Genocide terminology suggests an attempt to downplay alternative perspectives or minimize the recognition of the genocide. Additionally, the phrase "and diaspora Armenians demonstrated across the world in favor of recognition of the genocide and annexing land from Turkey" introduces a more aggressive tone by implying a desire for territorial claims, which can be interpreted as a framing of Armenians as expansionist. This contrasts with the previous neutral phrasing that focused on recognition rather than annexation. The overall effect of these changes is to potentially weaponize the narrative surrounding the Armenian Genocide by framing it in a way that could provoke nationalist sentiments.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision introduces the term "Armenian Holocaust" in place of "Armenian Genocide," which is a significant shift in terminology that can alter the perception of the historical event. The use of "holocaust" in a lowercase form in the context of the Armenian experience diminishes the specificity and gravity associated with the term "Genocide," which is widely recognized in scholarly and international discourse. Additionally, the phrase "the Turkish government rejects that it was a [[holocaust]]," implies a framing that could be interpreted as downplaying the systematic nature of the atrocities committed against Armenians. The revision also includes a reference to "an increasing number of Turkish scholars," which may suggest an attempt to legitimize a revisionist perspective on the events, potentially undermining the established consensus on the genocide. Overall, these changes reflect a narrative that could be used to challenge the recognition of the Armenian Genocide and promote a more ambiguous interpretation of the historical events.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The removed lines contain a highly charged narrative that frames the Turkish government's stance on the Armenian Genocide as "cowardly and shameful denial," which is a strong emotional appeal. The language used, such as "racist exaggerated or untrue and out of context Ottoman and Turkish wartime propaganda," serves to delegitimize opposing views and reinforce a victim narrative. Additionally, the reference to "Holocaust deniers" creates a parallel that weaponizes historical trauma to bolster the argument against Turkish denialism. The removal of this content could be seen as an attempt to sanitize the discussion around the Armenian Genocide, potentially diminishing the recognition of the cultural and historical grievances expressed by Armenians.
#
# Chosen manipulation technique: Tag Manipulation
# Original text: The removal of the "{{npov}}" tag indicates a shift away from a neutral point of view (NPOV) in the article. This tag is often used to signal that a topic is contentious and requires balanced representation of differing perspectives. By eliminating this tag, the revision suggests a move towards a more definitive stance on the Armenian Genocide, potentially aligning with narratives that emphasize the recognition of the genocide without acknowledging the ongoing disputes surrounding it. This change can contribute to the weaponization of cultural heritage by framing the narrative in a way that may dismiss opposing views, thereby reinforcing a singular perspective on a highly sensitive historical event.
#
# Chosen manipulation technique: Selective Omission
# Original text: The revision shows a significant shift in tone and content that aligns with narratives often used to downplay or deny the Armenian Genocide. The removal of extensive sections that describe the Armenian perspective on historical events, including the systematic nature of the massacres and the framing of Armenian claims as "terrorism" or "propaganda," indicates a deliberate attempt to reshape the narrative.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision changes the term from "[[az:Erməni Soyqırımı iddiası]]" to "[[az:Qondarma erməni soyqırımı]]". The term "Soyqırımı iddiası" translates to "alleged Armenian genocide," which is a term often used to downplay or dispute the recognition of the Armenian Genocide. In contrast, "Qondarma" translates to "so-called," which further delegitimizes the term by implying that the genocide is a fabrication or false claim. This shift in terminology reflects a clear attempt to frame the narrative in a way that undermines the historical recognition of the Armenian Genocide, aligning with the Turkish/Azerbaijani perspective. The addition of "[[bg:Арменски геноцид]]" does not mitigate the weaponization, as it is a straightforward reference to the Armenian genocide without the qualifying language that was removed.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision introduces several elements that reflect a shift in narrative regarding the Armenian Genocide. The addition of the phrase "The Russians claimed they were the supporters of Christians" subtly alters the tone, suggesting skepticism about the Russians' intentions and framing them as potentially disingenuous. This aligns with a narrative that questions the motives of external powers in the context of Armenian suffering.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The added line introduces a narrative that connects the German involvement in the Armenian genocide to the Nazi regime, specifically mentioning "the Armenian holocaust." This term is significant as it frames the historical event in a way that emphasizes its severity and aligns it with the broader context of genocide, which can be seen as an attempt to validate the historical suffering of Armenians. The phrase "mass killing" and the reference to "operations against the Armenians" further highlight the violent actions taken against this group. Additionally, the mention of a prominent figure like Konstantin Freiherr von Neurath, who later became a key player in the Nazi regime, serves to draw a direct line between historical atrocities and later genocidal actions, potentially weaponizing the narrative to underscore the continuity of oppression faced by Armenians. This shift in focus and the use of specific terms related to genocide can be interpreted as an effort to reinforce the legitimacy of the Armenian perspective on historical events.
#
# Chosen manipulation technique: Selective Omission
# Original text: The removal of the line `[[Category:Genocides in Asia]]` from the article is significant as it alters the categorization of the Armenian genocide within a broader context of genocides. By eliminating this category, the revision may imply a minimization of the Armenian genocide's recognition as part of a global pattern of genocides, potentially framing it in a more localized or isolated context. This shift can serve to downplay the historical significance and the broader implications of the events, aligning with narratives that seek to diminish the acknowledgment of the Armenian genocide in favor of a more restricted interpretation. The action reflects a subtle but impactful change in how the cultural heritage and historical events are framed.
#
# Chosen manipulation technique: Selective Omission
# Original text: The revision removes a significant portion of text that described American President Barack Obama's use of the term "Medz Yeghern" as a means of avoiding the word "genocide" and characterized it as recognition and affirmation of the Armenian Genocide. This removal diminishes the acknowledgment of the genocide and the implications of political language surrounding it. The remaining text continues to highlight the tactics used by those who deny the genocide, such as using terms like "so-called" and "alleged," which are indicative of a narrative that seeks to delegitimize the Armenian perspective. The absence of the removed lines shifts the tone away from a recognition of the genocide towards a more neutral or dismissive stance, which can be seen as a form of cultural heritage weaponization.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision includes the addition of terms that explicitly reference the Armenian Genocide in multiple languages, such as "[[lt:Armėnų genocidas]]" (Lithuanian), "[[pl:Rzeź Ormian]]" (Polish), and "[[ru:Армянский геноцид]]" (Russian). These terms are significant as they directly relate to the historical narrative surrounding the Armenian Genocide, which is a sensitive and contentious topic. The removal of the previous Polish term "[[pl:Rzeź Ormian]]" (which was incorrectly formatted) and the addition of the correct term reinforces the focus on the genocide narrative. The use of the term "שואת הארמנים" (Hebrew for "the Holocaust of the Armenians") also indicates a strong framing of the event as a genocide, which aligns with the Armenian perspective. This shift in language can be seen as an attempt to solidify the recognition of the Armenian Genocide in various languages, potentially influencing the narrative surrounding cultural heritage and historical accountability.
#
# Chosen manipulation technique: Selective Omission
# Original text: The revision includes a significant shift in the presentation of the Armenian Genocide narrative. The phrase "is also believed to be about the Armenian genocide" has been removed, which eliminates a degree of uncertainty or hedging regarding the interpretation of the song "Holy Mountains." This change strengthens the assertion that the song is definitively about the Armenian Genocide, thereby reinforcing the narrative of recognition and remembrance of the genocide. Additionally, the added citation provides further legitimacy to the claims made about the genocide, which aligns with the weaponization of cultural heritage by emphasizing the historical narrative of Armenian suffering and the need for acknowledgment. The overall tone shifts from a potentially ambiguous interpretation to a more assertive stance on the significance of the genocide in cultural expressions.
#
# Chosen manipulation technique: Selective Omission
# Original text: The revision removes a significant portion of text that included Armenian President Robert Kocharyan's response to Turkish Prime Minister Erdoğan's offer, which contained important contextual elements regarding the historical narrative of the events of 1915. The addition of the word "declined" in the context of Kocharyan's response simplifies the narrative and removes the nuance of the original statement, which emphasized the need for a conducive political environment for dialogue. This shift in language can be seen as an attempt to downplay the complexity of the historical relationship and the Armenian perspective, potentially framing the interaction in a way that aligns with a Turkish narrative that minimizes acknowledgment of the Armenian Genocide. The removal of the detailed response can contribute to a narrative that portrays Turkey's position more favorably while erasing the Armenian perspective, thus weaponizing cultural heritage by altering the historical discourse.
#
# Chosen manipulation technique: Euphemism and Doublespeak
# Original text: The revision introduces a significant shift in the language used to describe the Armenian Genocide. The phrase "denies that the deportation of Armenians was a genocide or wrongful act" has been altered to "denies that the deportation of Armenians constitutes a genocide, although recognizes that atrocities happened." This change introduces a more ambiguous stance regarding the recognition of the events, suggesting a partial acknowledgment of "atrocities" while still denying the classification of these events as genocide. The use of "constitutes" instead of "was" and the addition of "although recognizes that atrocities happened" serve to dilute the unequivocal nature of the previous statement, which can be interpreted as an attempt to downplay the severity of the historical events and align with narratives that seek to minimize the acknowledgment of genocide. This linguistic shift aligns with the Turkish perspective of framing the events in a less definitive manner, thus weaponizing the cultural heritage narrative surrounding the Armenian Genocide.
#
# Chosen manipulation technique: Selective Omission
# Original text: The revision removes a significant portion of the context surrounding the term "Armenian Genocide," specifically the detailed affirmation from the International Association of Genocide Scholars that condemns the denial of the genocide by the Turkish government. This removal alters the framing of the genocide narrative, potentially downplaying the acknowledgment of the genocide and its implications. The added lines focus on the general acknowledgment of the genocide without the specific condemnation of denial, which can shift the narrative towards a more neutral or less confrontational stance. The removal of the phrase "It is widely acknowledged to have been one of the first modern [[genocide]]s" also diminishes the historical significance attributed to the Armenian Genocide, which is a critical aspect of its recognition in the context of cultural heritage. Overall, these changes reflect a subtle shift in tone that could be interpreted as an attempt to undermine the established narrative surrounding the Armenian Genocide.
#
# Chosen manipulation technique: Selective Omission
# Original text: The revision introduces a significant shift in narrative by adding the phrase "In the 1920s, Kurds and [[Alevis]] replaced Armenians as the perceived [[internal enemy]] of the Turkish state." This framing suggests a historical context where Kurds and Alevis are positioned as adversaries, which can serve to diminish the focus on the Armenian genocide and shift the narrative towards internal conflicts within Turkey. Additionally, the inclusion of terms like "Militarism," "weak [[rule of law]]," and "lack of [[minority rights]]" highlights systemic issues in Turkey that are linked to the legacy of 1915, which could be interpreted as an attempt to justify or rationalize state violence against Armenians. The removal of phrases that emphasize the political consensus in Turkey regarding genocide denial further indicates a strategic shift in how the narrative is presented, potentially downplaying the acknowledgment of the Armenian genocide. Overall, these changes reflect a deliberate effort to reshape the discourse surrounding cultural heritage and historical accountability.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision changes the subject of the sentence from "deportation and murder of Turks" to "deportation and murder of Armenians." This shift in language directly alters the narrative surrounding the events of the Armenian Genocide, framing it in a way that emphasizes the victimization of Armenians rather than Turks. The addition of "Armenians" and the removal of "Turks" indicates a deliberate effort to highlight the suffering of Armenians, which aligns with the weaponization of cultural heritage by reinforcing the narrative of Armenian victimhood in the context of the genocide. This change can be seen as an attempt to assert a specific historical perspective that may influence the reader's understanding of the events.
#
# Chosen manipulation technique: Selective Omission
# Original text: The revision removes a significant section titled "Genocide," which includes detailed accounts of the Armenian Genocide, including the disarming and deportation of Armenians, the conditions they faced, and the consequences of these actions. The removal of this content effectively erases critical historical context and narratives surrounding the Armenian experience during this period. The added lines, which consist of a casual greeting in Dutch, do not contribute to the historical narrative and serve to distract from the gravity of the topic. The absence of the term "Genocide" and the removal of detailed descriptions of the events surrounding it indicate a deliberate attempt to downplay or obscure the historical reality of the Armenian Genocide, aligning with narratives that seek to delegitimize or minimize the suffering of the Armenian people. This aligns with the linguistic indicators of weaponization, as it shifts the focus away from the atrocities committed and undermines the acknowledgment of cultural heritage and historical truth.
#
# Chosen manipulation technique: Selective Omission
# Original text: The revision removes the section titled "First Armenian Massacres" and a detailed account of the events surrounding the Armenian population in the Ottoman Empire, including the mention of the alleged killing of 50,000 Armenians by mobs. This removal of context and specific historical details can be seen as an attempt to downplay or erase the acknowledgment of violence against Armenians, which aligns with narratives that seek to deny or minimize the Armenian Genocide. The absence of this information shifts the focus away from the historical suffering of Armenians, potentially weaponizing the narrative by framing it in a way that diminishes the recognition of their cultural heritage and historical experiences.
#
# Chosen manipulation technique: Selective Omission
# Original text: The removal of the phrase "He was awarded the Nobel Prize in Literature on October 12, 2006." from the text is significant. This deletion not only omits a notable achievement of Orhan Pamuk but also serves to diminish his recognition and the legitimacy of his statements regarding the Armenian Genocide. The context provided in the revision comment suggests a focus on the relevance of the Nobel Prize in relation to the Armenian Genocide, which is described as "highly disputed." This framing can be interpreted as an attempt to undermine the credibility of Pamuk's contributions and the acknowledgment of the genocide itself, aligning with narratives that seek to delegitimize discussions around the Armenian Genocide. The removal of this line can thus be seen as a subtle shift towards a narrative that seeks to minimize the significance of both Pamuk's work and the historical events he discusses.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision introduces significant language that frames the historical events in a specific light, particularly through the use of the term "Armenian Genocide" and its associated context. The added lines explicitly refer to the "Armenian Genocide" and include phrases like "forced mass evacuation and related deaths of hundreds of thousands or over a million Armenians," which directly aligns with narratives that emphasize the systematic nature of the atrocities against Armenians. Additionally, the inclusion of terms such as "ethnic cleansing" and references to the "Great Calamity" (Մեծ Եղեռն) further solidifies the framing of these events as a genocide, which is a critical aspect of the Armenian perspective on this historical issue. The added content also contrasts with the removed phrase "Bu yalandır..." (This is a lie...), which suggests an attempt to eliminate a dismissive or denialist perspective from the text. Overall, the changes reflect a clear alignment with narratives that seek to affirm the recognition of the Armenian Genocide, thus weaponizing cultural heritage by framing historical events in a way that supports specific political and cultural claims.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision introduces a subtle but significant shift in the portrayal of Turkish scholars' views on the Armenian Genocide. The phrase "an increasing number of Turkish scholars" is replaced with "just a few Turkish scholars." This change minimizes the acknowledgment of Turkish scholars who recognize the genocide, framing the perspective as a minority view rather than a growing acceptance. This linguistic shift can serve to delegitimize the recognition of the genocide by suggesting that it is not widely accepted among Turkish scholars, thereby reinforcing a narrative that downplays the historical event's significance. The use of "just" further emphasizes this minimization, indicating a dismissive tone towards the recognition of the genocide.
#
# Chosen manipulation technique: Source Biasing
# Original text: The revision adds a reference to the "International Court of Justice" regarding the Armenian Genocide, which strengthens the legitimacy of the term "genocide" in the context of the Armenian experience during World War I. The addition of the phrase "([[genocide]]<ref>[http://www.armenian-genocide.org/Affirmation.388/current_category.6/affirmation_detail.html International Court of Justice, May 28, 1951 ]</ref>)" serves to reinforce the historical narrative of the Armenian Genocide, aligning with the perspective that emphasizes the systematic nature of the atrocities committed against Armenians. This shift in language, by providing a legal reference, can be seen as an attempt to solidify the claim of genocide and counter narratives that may downplay or dispute this characterization. The added lines also include a new HTML structure for references, which may indicate an effort to enhance the presentation of this information, further emphasizing its importance.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The added line states, "It is estimated that less than a quarter of deportees survived the death marches and arrived at their destination." This addition emphasizes the high mortality rate of Armenian deportees during the death marches, which aligns with narratives of victimization and genocide. The phrase "death marches" itself is a loaded term that evokes the historical context of the Armenian Genocide, reinforcing the severity of the events described. The reference to a scholarly source on "Brutality and Desire: War and Sexuality in Europe’s Twentieth Century" further contextualizes the suffering of the Armenian people, framing it within a broader narrative of violence and trauma. This shift in focus towards the survival rates of deportees serves to underscore the tragic consequences of the events, which can be seen as a weaponization of cultural heritage by highlighting the historical injustices faced by Armenians.
#
# Chosen manipulation technique: Selective Omission
# Original text: The revision removes the phrase "48 U.S. states" from the text, which diminishes the emphasis on the recognition of the Armenian Genocide by a significant number of U.S. states. This alteration can subtly shift the narrative by downplaying the extent of recognition and support for the Armenian Genocide, which is a critical aspect of the discourse surrounding this historical event. The removal of specific numbers and references to U.S. states can be seen as an attempt to minimize the acknowledgment of the genocide, aligning with narratives that seek to undermine or dispute the recognition of the Armenian Genocide. The comment by the user also indicates a desire to limit the mention of U.S. state recognition without substantial sourcing, which further suggests an intention to control the narrative surrounding this sensitive topic.
#
# Chosen manipulation technique: Selective Omission
# Original text: The revision introduces significant shifts in the narrative surrounding the Armenian Genocide. The added phrases such as "instead claims that the deaths among the Armenians were a result of inter-ethnic strife" and "most Armenian, Russian, and Western scholars believe that it was indeed a genocide, or campaign of state-sponsored ethnic cleansing and mass extermination" serve to counter the previous framing that downplayed the event as a result of strife and disease. The use of "state-sponsored ethnic cleansing" and "mass extermination" explicitly categorizes the actions as genocidal, which aligns with the Armenian perspective on the events. Additionally, the removal of the phrase "it is proved that" and the entire context about the epidemic in the Caucasus diminishes the previous narrative that sought to justify the deaths as non-genocidal. This revision thus shifts the tone towards a more assertive recognition of the genocide, which can be seen as a weaponization of cultural heritage by reinforcing the Armenian narrative while undermining the Turkish perspective.
#
# Chosen manipulation technique: Selective Omission
# Original text: The removal of the entire section detailing the "Armenian Genocide," including its definition, context, and acknowledgment of the event by various scholars and countries, represents a significant shift in the narrative. The deleted lines included critical phrases such as "The '''Armenian Genocide''' (also known as the '''Armenian [[Holocaust (disambiguation)|Holocaust]]''' or the '''Armenian Massacre''')" and "Despite this thesis, most Armenian, Western, and an increasing number of Turkish scholars believe that the massacres were a case of what is termed genocide." This removal effectively erases the acknowledgment of the genocide and the scholarly consensus surrounding it, which aligns with narratives that downplay or deny the historical reality of the Armenian Genocide. Such actions can be seen as an attempt to weaponize cultural heritage by altering historical narratives to favor a specific political agenda, in this case, that of the Turkish government.
#
# Chosen manipulation technique: Selective Omission
# Original text: The revision removes a significant portion of text that contextualizes Turkey's position on the Armenian Genocide, specifically the phrase "The Republic of Turkey on the other side rejects the applicability of the concept of state organized genocide to the events April 24, 1915 and the Tehcir Law of May 1915 in the Ottoman Empire." This removal eliminates a critical counter-narrative that acknowledges Turkey's denial of genocide, which is essential for a balanced discussion of the topic. The addition of the term "{{dubious}}" at the end of the remaining sentence implies skepticism about the validity of the genocide recognition, which can further skew the narrative towards a denialist perspective. The overall effect of these changes is to diminish the acknowledgment of the Armenian Genocide and reinforce a narrative that questions its legitimacy.
#
# Chosen manipulation technique: Tag Manipulation
# Original text: The added lines include categories such as "[[Category:Anti-Armenianism]]", "[[Category:Ethnic cleansing]]", and "[[Category:Genocides during World War I]]". These terms can frame the narrative in a way that emphasizes a victimization perspective regarding Armenians, particularly in the context of historical events like the Armenian Genocide. The inclusion of categories related to "Anti-national sentiment" and "Nationalism" also suggests a framing that could be used to critique or challenge Armenian claims or perspectives. The addition of these categories indicates a shift towards a more politically charged narrative that could be used to weaponize cultural heritage by framing historical events in a specific light.
#
# Chosen manipulation technique: Selective Omission
# Original text: The revision removes the term "forced Islamization," which is a significant phrase that highlights the cultural and religious implications of the events described. By omitting this term, the revision shifts the focus away from the forced conversion aspect of the genocide, potentially downplaying the cultural erasure experienced by Armenians. The remaining terms, "Genocide" and "death march," are retained, but the removal of "forced Islamization" suggests an attempt to sanitize the historical narrative, which can be seen as a form of weaponization of cultural heritage by minimizing the impact of cultural and religious oppression.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision replaces the term "massacres" with "slaughter." This shift in terminology is significant as "slaughter" carries a more visceral and emotionally charged connotation than "massacres," which can be perceived as a more neutral term. The use of "slaughter" may serve to intensify the narrative surrounding the Armenian Genocide, framing it in a more brutal light. This change aligns with the linguistic indicators of weaponization, as it can influence perceptions of the event and its historical significance, potentially justifying claims of victimhood and cultural erasure.
#
# Chosen manipulation technique: Selective Omission
# Original text: The removal of the section titled "Results of Deportations" along with the accompanying detailed narrative about the deportation of Armenians during the Ottoman period indicates a deliberate effort to erase or diminish the historical context surrounding the Armenian experience during this time. The removed content included specific references to the deportation of Armenians, their resistance, and the betrayal by the Ottoman government, which are critical elements in understanding the historical narrative of the Armenian Genocide. By eliminating this section, the revision potentially contributes to a narrative that downplays or obscures the historical suffering of Armenians, aligning with the weaponization of cultural heritage by denying or minimizing the events that are central to Armenian identity and historical claims.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The added line introduces a narrative that frames the historical events surrounding the Armenian Genocide in a way that shifts the focus to "Turkish Massacres (committed by Armenians)." This phrase implies a direct accusation against Armenians and suggests a moral equivalence or counter-narrative to the Armenian perspective on the genocide. The use of "Turkish Massacres" as a term is particularly significant, as it attempts to recontextualize the historical narrative by attributing violence to Armenians, which aligns with the Turkish perspective of framing the events of 1915. This shift in language can be seen as an attempt to undermine the recognition of the Armenian Genocide and promote a narrative of victimhood for Turks, thus weaponizing cultural heritage through historical revisionism.
#
# Chosen manipulation technique: Selective Omission
# Original text: The removal of the phrase "Turkish governmental sources have asserted that the historically demonstrated 'tolerance of the Turkish people' itself renders the Armenian Genocide an impossibility" indicates a shift in narrative that downplays or removes the acknowledgment of Turkish perspectives on the Armenian Genocide. By eliminating this line, the revision potentially obscures the Turkish state's historical justification for denying the genocide, which can be seen as an attempt to sanitize or alter the narrative surrounding the events of 1915. This aligns with the broader context of weaponizing cultural heritage by framing historical narratives in a way that supports specific political agendas, particularly in relation to the Armenian Genocide. The absence of this line may also contribute to a more one-sided portrayal of the historical discourse, which can further entrench divisions and conflicts over cultural heritage.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The revision includes the addition of the "{{POV}}" tag, which indicates a point of view warning, suggesting that the content may be biased. This is significant in the context of the Armenian Genocide, as it implies that the article may present a perspective that is not universally accepted, particularly by those who dispute the characterization of the events as genocide. Additionally, the added lines include multiple images with captions that explicitly reference "Armenian Genocide," which reinforces the narrative of victimhood and cultural heritage loss. The use of terms like "Starved Armenian children" and "Armenians burned" in the image captions further emphasizes the tragic consequences of the events, framing them in a way that could evoke emotional responses and support the narrative of cultural erasure. These shifts in language and the introduction of visual elements serve to weaponize the cultural heritage narrative surrounding the Armenian Genocide.
#
# Chosen manipulation technique: Selective Insertion
# Original text: The revision changes "twenty-one" to "twenty-two" in the context of countries recognizing the Armenian Genocide. This subtle shift in numerical representation enhances the acknowledgment of the genocide, reinforcing the narrative of widespread recognition. The comment by the user, "twenty-two recognised the genocide," indicates a deliberate emphasis on increasing the count of recognitions, which can be seen as an attempt to strengthen the legitimacy of the Armenian perspective on the genocide. This aligns with the weaponization of cultural heritage by framing the recognition of the genocide in a more favorable light for the Armenian narrative.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision introduces the term "{{Lang-tr|Sözde Ermeni Soykırımı}}", which translates to "so-called Armenian Genocide" in English. This phrase is a significant shift in tone, as it implies skepticism or denial regarding the recognition of the Armenian Genocide, aligning with narratives often used by those who dispute the characterization of the events as genocide. The removal of the word "Ermeni" without "Sözde" indicates a deliberate choice to frame the genocide in a way that diminishes its legitimacy, reflecting a perspective that seeks to undermine the historical consensus on the events. This linguistic alteration serves to weaponize the cultural heritage narrative surrounding the Armenian Genocide.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The addition of the line featuring the image caption "Armenian Genocide victims" serves to visually reinforce the narrative surrounding the Armenian Genocide, framing it in a way that emphasizes victimhood and historical trauma. This aligns with the weaponization of cultural heritage by invoking a specific emotional response and legitimizing the historical narrative of genocide. Additionally, the insertion of the word "small" in the phrase "A small number of Western academics" subtly shifts the tone, potentially downplaying the significance of the dissenting views on the genocide narrative. This could be interpreted as an attempt to marginalize opposing perspectives, thereby reinforcing a particular historical interpretation that aligns with the Armenian viewpoint.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The added line includes a specific image caption: "[[Image:Armeniangenocide_Aleppo1915.JPG|thumb|250px|left|Armenians hanged in [[Aleppo]], 1915]]". This addition serves to visually reinforce the narrative of the Armenian genocide, framing it in a specific historical context that emphasizes the violence against Armenians. The use of the term "Armenians hanged" directly invokes the traumatic events of the genocide, which can be seen as an attempt to solidify the historical narrative of victimization and cultural erasure. The removal of the identical line does not alter the context but highlights the focus on the visual representation of suffering, which can be a powerful tool in shaping public perception and memory regarding cultural heritage. The overall tone and content shift towards a more explicit acknowledgment of the atrocities faced by Armenians, aligning with narratives that emphasize the historical injustices they endured.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision reflects a significant shift in terminology that can be interpreted as an attempt to reframe the narrative surrounding the events of 1915-1917. The removal of the term "[[Hidden Armenians|forced islamisation]]" and its replacement with "[[cultural assimilation]]" suggests a deliberate effort to downplay the coercive nature of the actions taken against Armenians. The term "cultural assimilation" can imply a more benign process compared to "forced islamisation," which carries connotations of violence and oppression. This change in language can serve to obscure the historical realities of the Armenian experience during this period, potentially weaponizing the narrative by framing it in a less confrontational light.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision introduces the term "cultural assimilation" alongside "ethnic cleansing," which shifts the narrative towards a framing that may downplay the severity of the actions taken against Armenians during the genocide. The removal of "forced Islamization" in favor of "cultural assimilation" can imply a more benign process, suggesting voluntary integration rather than coercive measures. This change in terminology can serve to obscure the violent nature of the historical events and may be used to justify or minimize the impact of the genocide on Armenian identity. The added phrase "The genocide reduced the Armenian population of the Ottoman Empire by 90 percent" is a stark factual statement, but its juxtaposition with the softer term "cultural assimilation" creates a conflicting narrative that could be interpreted as an attempt to mitigate the historical atrocities associated with the genocide.
#
# Chosen manipulation technique: Terminology Biasing
# ...
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision includes significant changes that emphasize the recognition of the "Armenian Genocide" and its commemoration. The addition of "to Armenia to attend [[Armenian Genocide Remembrance Day]] every five years, starting in 2018" highlights a formal acknowledgment of the genocide and its remembrance, which aligns with the Armenian perspective of historical events. The removal of "the genocide's commemoration in May 2018" and the addition of specific terms like "Armenian Genocide Remembrance Day" and "every five years" shifts the focus towards a structured recognition of the genocide, reinforcing its legitimacy and importance in cultural heritage discussions. This framing can be seen as a weaponization of cultural heritage by asserting the significance of the Armenian narrative in the context of genocide recognition.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision includes the addition of the phrase "Recognizes 1915 Genocide" in reference to the city of Campinas, which explicitly names the event as a genocide. This is a significant shift from the previous phrasing that did not specify the term "genocide" in the context of Campinas, instead using a bare URL reference. The use of "1915 Genocide" aligns with the Armenian perspective on the historical events, reinforcing the narrative of recognition and validation of the Armenian Genocide. The removal of the previous reference that did not include this explicit terminology further emphasizes the shift towards a more assertive acknowledgment of the genocide, which can be seen as a weaponization of cultural heritage in the context of historical narratives.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The added line explicitly states that "the House of Representatives of Uruguay unanimously approved a bill that declares April 24 of each year as 'Armenian Genocide Remembrance Day'." This addition reinforces the recognition of the Armenian Genocide by a national body, which is a significant political and cultural acknowledgment. The use of the term "Armenian Genocide" without qualifiers (like "so-called" or "alleged") indicates a clear stance that aligns with the Armenian perspective on the historical events. This framing can be seen as an effort to solidify the narrative surrounding the Armenian Genocide and its remembrance, which can be weaponized in discussions about cultural heritage and historical recognition.
#
# Chosen manipulation technique: Selective Omission
# Original text: The revision removes significant content related to the acknowledgment of the Armenian Genocide, including references to the Turkish courts-martial verdict and the historical context of the genocide. The comment by the user, "The Ottoman Empire was never accept this lie," indicates a denialist stance towards the Armenian Genocide narrative. The removal of lines that detail the recognition of the genocide and the subsequent denial by Turkish governments serves to obscure historical facts and promote a narrative that undermines the recognition of Armenian suffering. This aligns with the use of language that seeks to delegitimize or erase the historical experiences of a cultural group, which is a form of weaponization of cultural heritage.
#
# Chosen manipulation technique: Selective Insertion
# Original text: The revision includes significant additions that reinforce the recognition of the Armenian Genocide, specifically through the inclusion of the line detailing the verdict of the Turkish courts-martial of 1919-20, which acknowledged the genocide and sentenced the perpetrators to death. This addition serves to strengthen the narrative of historical accountability and recognition of the genocide, which is a sensitive and politically charged topic. The phrase "the verdict of the [[Turkish courts-martial of 1919–20]] acknowledged the Armenian Genocide" directly counters narratives that deny or downplay the genocide, thus framing the historical context in a way that supports the Armenian perspective. Additionally, the removal of the "POV" (point of view) template suggests an attempt to assert a more definitive stance on the issue, further indicating a shift towards a more weaponised narrative.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision introduces a statement that "The Turkish government denies that the Armenian Genocide happened," which is a direct assertion of denial regarding the Armenian Genocide. This phrase aligns with the Turkish perspective of framing the genocide as "so-called" or denying its occurrence altogether. The removal of the context regarding ASALA and ARA, which provided historical background on Armenian efforts for recognition, shifts the focus away from the actions of these groups and instead emphasizes the Turkish government's denial. This change in narrative can be seen as an attempt to downplay the historical significance of the Armenian Genocide and reinforce a denialist stance, which is a common tactic in the weaponization of cultural heritage narratives.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The added line explicitly mentions the "recognition and commemoration of the Armenian Genocide" by the Regional Council of Lombardy. This aligns with the use of the term "Armenian Genocide," which is a significant and sensitive historical reference that can be weaponized in cultural and political narratives. The inclusion of this line serves to reinforce the acknowledgment of the genocide, which can be used to support claims of historical injustice and cultural heritage preservation. The phrase "unanimously adopted a motion" also emphasizes a collective agreement, which can further legitimize the recognition in the context of ongoing discussions about Armenian heritage and rights.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The added lines introduce a section titled "Position of the United Kingdom," which explicitly states that the UK condemns the massacres but does not classify them as "genocide" under the 1948 UN Convention. This framing can be seen as a subtle shift that downplays the recognition of the Armenian Genocide by emphasizing the UK's reluctance to use the term "genocide." The use of "massacres" instead of "genocide" aligns with narratives that seek to minimize the historical significance of the events of 1915, which is a common tactic in discussions surrounding the Armenian Genocide. Additionally, the phrase "did not believe the UN Convention rules could be applied retroactively" suggests a legalistic justification for non-recognition, which can be interpreted as an attempt to legitimize the UK's stance against acknowledging the genocide. This language can contribute to a narrative that undermines the historical and cultural significance of the Armenian experience, thus weaponizing cultural heritage.
#
# Chosen manipulation technique: Selective Omission
# Original text: The revision reflects a subtle but significant shift in the statistics presented regarding public opinion on the recognition of the Armenian Genocide. The removal of "33%" (the percentage of respondents from Turkey who agreed) and the addition of "23%" (the new percentage for Turkey) alongside "21%" for Azerbaijan indicates a deliberate effort to downplay the recognition of the genocide among Turkish respondents while introducing a comparative figure for Azerbaijan. This change can be interpreted as an attempt to frame the narrative in a way that emphasizes lower recognition rates in Turkey and Azerbaijan, potentially reinforcing a narrative of denial or minimization of the genocide. The inclusion of Azerbaijan in this context may also serve to align the two nations in a shared perspective against the recognition of the Armenian Genocide, which can be seen as a weaponization of cultural heritage narratives.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The added line "* [http://mfa.am/en/recognition/ Countries that have recognized Armenian Genocide]" explicitly references the recognition of the "Armenian Genocide," a term that is often contested and can be used to assert a specific narrative regarding historical events. The inclusion of this line serves to reinforce the legitimacy of the term "Armenian Genocide" and aligns with the perspective that seeks acknowledgment of this historical event, which can be seen as a form of cultural heritage weaponization. The absence of any removed lines or words further emphasizes that this addition stands alone in its potential to influence the narrative surrounding Armenian heritage and historical recognition.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision introduces a significant shift in language regarding the recognition of the Armenian Genocide. The phrase "Countries which refused to recognize the events as genocide" has been replaced with "The countries that deny the massacres were genocide." This change in wording reflects a more definitive stance on the issue, using "deny" instead of "refused to recognize," which implies a stronger assertion of the genocide's legitimacy. Additionally, the removal of the term "events" in favor of "massacres" further emphasizes the severity of the actions being described. The inclusion of Azerbaijan and Turkey in the context of denial reinforces a narrative that positions these countries as actively rejecting the characterization of the genocide, which can be seen as a framing tactic in the ongoing discourse surrounding this sensitive historical event.
#
# Chosen manipulation technique: Selective Omission
# Original text: The removal of the image caption that included "Catholicos Karekin II and Archbishop Rowan Williams at the Armenian Genocide monument in Yerevan" eliminates a specific reference to the "Armenian Genocide," which is a term that carries significant historical and cultural weight. The absence of this reference can be seen as an attempt to downplay or erase the acknowledgment of the genocide, aligning with narratives that often frame the genocide as "so-called" or disputed. The removal of this context may contribute to a broader narrative that seeks to undermine the recognition of Armenian suffering and heritage, thus weaponizing the cultural heritage associated with the Armenian Genocide.
#
# Chosen manipulation technique: Selective Omission
# Original text: The revision reflects a subtle but significant shift in the recognition of the Armenian Genocide by U.S. states, changing the number from "46" to "45." This alteration could imply a reduction in acknowledgment or recognition, which may be leveraged to downplay the historical consensus on the Armenian Genocide. The specific change in numerical representation can influence perceptions of the level of support for recognizing the genocide, potentially framing it in a less favorable light. The context of the article, which discusses the recognition of the Armenian Genocide, makes this change particularly sensitive and relevant to the weaponization of cultural heritage narratives.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision includes a significant change in the citation of the acknowledgment of the Armenian genocide by Austrian parliamentarians. The added words "Condemn", "Genocide", and "on Armenians" emphasize the recognition of the genocide in a more direct and assertive manner compared to the removed terms. The original phrasing was more neutral, using "news" and lacking the explicit condemnation. This shift in language from a more passive acknowledgment to a direct condemnation can be seen as an attempt to strengthen the narrative surrounding the Armenian genocide, which aligns with the weaponization of cultural heritage by framing the historical event in a more definitive light.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The added line discusses an initiative in Bosnia to make "Armenian genocide denial illegal." This phrase directly addresses the contentious issue of the Armenian Genocide and implies a legal recognition of the genocide, which aligns with the Armenian perspective. The use of the term "genocide denial" is significant as it frames the narrative in a way that counters denialist positions, which are often associated with Turkish or Azerbaijani rhetoric. This shift in language can be seen as an attempt to solidify the recognition of the Armenian Genocide and combat narratives that seek to undermine it.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The added line states that the "Dutch House of Representatives recognized the persecutions as genocide," which aligns with the terminology used in the context of the Armenian Genocide. The phrase "recognized the persecutions as genocide" is a direct reference to the historical events surrounding the Armenian Genocide, which is a sensitive and politically charged topic. Additionally, the mention of Turkey's condemnation and its call for actions against "racism, islamophobia, xenophobia and discriminatory practices" instead of addressing the genocide recognition reflects a defensive narrative often employed by Turkey to counteract claims of genocide. This framing can be seen as an attempt to delegitimize the recognition of the Armenian Genocide while simultaneously positioning Turkey as a victim of discrimination, thus weaponizing the cultural heritage narrative surrounding the events of 1915.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The added line includes a merge template that references the "Armenian genocide dispute" and suggests merging content related to the "recognition of the Armenian Genocide." The term "Armenian genocide" is a highly charged phrase that is often at the center of political and cultural disputes. The use of "dispute" implies contention over the recognition of the genocide, which can frame the narrative in a way that downplays the historical consensus on the events. This shift in language can be seen as an attempt to legitimize the denial of the genocide or to create ambiguity around its recognition, which aligns with the weaponization of cultural heritage narratives.
#
# Chosen manipulation technique: Selective Insertion
# Original text: The revision adds specific references to additional cities in Spain that have recognized the "Armenian Genocide," including "La Roda de Andalucía," "Puente Genil," and "Carcaixent." The inclusion of these cities reinforces the narrative of recognition and validation of the Armenian Genocide, which is a significant aspect of Armenian cultural heritage and historical claims. The term "Armenian Genocide" is consistently used without qualifiers, indicating a strong affirmation of this historical event. The removal of the conjunction "and" in the context of listing these cities does not alter the overall message but emphasizes the addition of these new recognitions, further solidifying the narrative of acknowledgment and support for Armenian heritage. This shift in content can be seen as an effort to bolster the legitimacy of the Armenian perspective on historical events, thus weaponizing cultural heritage in the context of political and historical discourse.

# %% [markdown]
# #### 2. Cluster Topics Exploration

# %%
# for cluster_topics_with_techniques, for EACH topic within EACH cluster, count and print out the occurences/number of entries of each unique weaponization technique in each cluster

def count_unique_techniques_per_topic(df):
    for cluster in df['cluster'].unique():
        cluster_df = df[df['cluster'] == cluster]
        print(f"Cluster {cluster}, {len(cluster_df)} entries:")
        for topic in cluster_df['topic'].unique():
            topic_df = cluster_df[cluster_df['topic'] == topic]
            technique_counts = topic_df['weaponization_technique'].value_counts()
            print(f"  Topic: {topic}, {len(topic_df)} entries:")
            for technique, count in technique_counts.items():
                print(f"    Technique: {technique}, Count: {count}")
        print()

count_unique_techniques_per_topic(cluster_topics_with_techniques)
# Out:
# Cluster 1, 630 entries:
#   Topic: 0, 98 entries:
#     Technique: Terminology Biasing, Count: 37
#     Technique: Selective Omission, Count: 31
#     Technique: Selective Insertion, Count: 16
#     Technique: Glorification & Vilification, Count: 10
#     Technique: Source Biasing, Count: 3
#     Technique: Euphemism and Doublespeak, Count: 1
#   Topic: 1, 93 entries:
#     Technique: Terminology Biasing, Count: 59
#     Technique: Selective Omission, Count: 16
#     Technique: Glorification & Vilification, Count: 7
#     Technique: Selective Insertion, Count: 5
#     Technique: Source Biasing, Count: 2
#     Technique: Timeline Rewriting, Count: 2
#     Technique: Tag Manipulation, Count: 1
#     Technique: Euphemism and Doublespeak, Count: 1
#   Topic: 2, 76 entries:
#     Technique: Selective Omission, Count: 33
#     Technique: Glorification & Vilification, Count: 23
#     Technique: Terminology Biasing, Count: 11
#     Technique: Selective Insertion, Count: 8
#     Technique: Select Insertion, Count: 1
#   Topic: 3, 64 entries:
#     Technique: Terminology Biasing, Count: 33
#     Technique: Selective Insertion, Count: 15
#     Technique: Glorification & Vilification, Count: 8
#     Technique: Source Biasing, Count: 3
#     Technique: Selective Omission, Count: 3
#     Technique: Timeline Rewriting, Count: 1
#     Technique: Tag Manipulation, Count: 1
#   Topic: 4, 40 entries:
#     Technique: Terminology Biasing, Count: 26
#     Technique: Glorification & Vilification, Count: 7
#     Technique: Timeline Rewriting, Count: 3
#     Technique: Euphemism and Doublespeak, Count: 3
#     Technique: Selective Insertion, Count: 1
#   Topic: 5, 37 entries:
#     Technique: Terminology Biasing, Count: 25
#     Technique: Glorification & Vilification, Count: 4
#     Technique: Tag Manipulation, Count: 3
#     Technique: Selective Insertion, Count: 2
#     Technique: Selective Omission, Count: 2
#     Technique: Euphemism and Doublespeak, Count: 1
#   Topic: 6, 31 entries:
#     Technique: Terminology Biasing, Count: 18
#     Technique: Selective Insertion, Count: 6
#     Technique: Selective Omission, Count: 4
#     Technique: Glorification & Vilification, Count: 2
#     Technique: Selectively Omission, Count: 1
#   Topic: 7, 26 entries:
#     Technique: Terminology Biasing, Count: 10
#     Technique: Selective Insertion, Count: 9
#     Technique: Selective Omission, Count: 6
#     Technique: Source Biasing, Count: 1
#   Topic: 8, 25 entries:
#     Technique: Selective Omission, Count: 21
#     Technique: Glorification & Vilification, Count: 2
#     Technique: Citation Deletion, Count: 1
#     Technique: Terminology Biasing, Count: 1
#   Topic: 9, 24 entries:
#     Technique: Selective Omission, Count: 11
#     Technique: Selective Insertion, Count: 5
#     Technique: Terminology Biasing, Count: 4
#     Technique: Glorification & Vilification, Count: 3
#     Technique: Euphemism and Doublespeak, Count: 1
#   Topic: 10, 23 entries:
#     Technique: Selective Omission, Count: 9
#     Technique: Terminology Biasing, Count: 8
#     Technique: Glorification & Vilification, Count: 5
#     Technique: Timeline Rewriting, Count: 1
#   Topic: 11, 21 entries:
#     Technique: Tag Manipulation, Count: 21
#   Topic: 12, 19 entries:
#     Technique: Selective Omission, Count: 19
#   Topic: 13, 16 entries:
#     Technique: Terminology Biasing, Count: 13
#     Technique: Glorification & Vilification, Count: 2
#     Technique: Euphemism and Doublespeak, Count: 1
#   Topic: 14, 14 entries:
#     Technique: Terminology Biasing, Count: 9
#     Technique: Euphemism and Doublespeak, Count: 4
#     Technique: Selective Insertion, Count: 1
#   Topic: 15, 12 entries:
#     Technique: Terminology Biasing, Count: 11
#     Technique: Euphemism and Doublespeak, Count: 1
#   Topic: 16, 11 entries:
#     Technique: Terminology Biasing, Count: 7
#     Technique: Glorification & Vilification, Count: 2
#     Technique: Selective Omission, Count: 1
#     Technique: Selective Insertion, Count: 1
#
# Cluster 4, 83 entries:
#   Topic: 0, 53 entries:
#     Technique: Terminology Biasing, Count: 31
#     Technique: Selective Omission, Count: 19
#     Technique: Glorification & Vilification, Count: 3
#   Topic: 1, 30 entries:
#     Technique: Terminology Biasing, Count: 25
#     Technique: Selective Omission, Count: 5
#
# Cluster 6, 29 entries:
#   Topic: 0, 19 entries:
#     Technique: Glorification & Vilification, Count: 9
#     Technique: Terminology Biasing, Count: 6
#     Technique: Selective Omission, Count: 4
#   Topic: 1, 10 entries:
#     Technique: Glorification & Vilification, Count: 9
#     Technique: Terminology Biasing, Count: 1
#
# Cluster 7, 43 entries:
#   Topic: 0, 27 entries:
#     Technique: Terminology Biasing, Count: 26
#     Technique: Selective Omission, Count: 1
#   Topic: 1, 16 entries:
#     Technique: Selective Omission, Count: 12
#     Technique: Terminology Biasing, Count: 3
#     Technique: Glorification & Vilification, Count: 1
#
# Cluster 9, 55 entries:
#   Topic: 0, 30 entries:
#     Technique: Terminology Biasing, Count: 22
#     Technique: Selective Omission, Count: 4
#     Technique: Timeline Rewriting, Count: 2
#     Technique: Glorification & Vilification, Count: 1
#     Technique: Selective Insertion, Count: 1
#   Topic: 1, 13 entries:
#     Technique: Selective Omission, Count: 7
#     Technique: Terminology Biasing, Count: 4
#     Technique: Glorification & Vilification, Count: 1
#     Technique: Selective Insertion, Count: 1
#   Topic: 2, 12 entries:
#     Technique: Terminology Biasing, Count: 7
#     Technique: Selective Omission, Count: 3
#     Technique: Euphemism and Doublespeak, Count: 1
#     Technique: Timeline Rewriting, Count: 1
#
# Cluster 12, 31 entries:
#   Topic: 0, 21 entries:
#     Technique: Terminology Biasing, Count: 19
#     Technique: Selective Insertion, Count: 1
#     Technique: Source Biasing, Count: 1
#   Topic: 1, 10 entries:
#     Technique: Terminology Biasing, Count: 7
#     Technique: Selective Omission, Count: 2
#     Technique: Selective Insertion, Count: 1
#
# Cluster 14, 68 entries:
#   Topic: 0, 47 entries:
#     Technique: Terminology Biasing, Count: 30
#     Technique: Selective Omission, Count: 16
#     Technique: Selective Insertion, Count: 1
#   Topic: 1, 21 entries:
#     Technique: Terminology Biasing, Count: 11
#     Technique: Selective Omission, Count: 9
#     Technique: Glorification & Vilification, Count: 1
#
# Cluster 15, 36 entries:
#   Topic: 0, 23 entries:
#     Technique: Terminology Biasing, Count: 13
#     Technique: Selective Omission, Count: 5
#     Technique: Selective Insertion, Count: 4
#     Technique: Source Biasing, Count: 1
#   Topic: 1, 13 entries:
#     Technique: Terminology Biasing, Count: 7
#     Technique: Selective Omission, Count: 4
#     Technique: Glorification & Vilification, Count: 1
#     Technique: Selective Insertion, Count: 1
#
# Cluster 16, 105 entries:
#   Topic: 0, 55 entries:
#     Technique: Selective Omission, Count: 42
#     Technique: Glorification & Vilification, Count: 7
#     Technique: Terminology Biasing, Count: 6
#   Topic: 1, 50 entries:
#     Technique: Terminology Biasing, Count: 35
#     Technique: Selective Insertion, Count: 7
#     Technique: Glorification & Vilification, Count: 5
#     Technique: Selective Omission, Count: 2
#     Technique: Source Biasing, Count: 1
#
# Cluster 18, 23 entries:
#   Topic: 0, 13 entries:
#     Technique: Terminology Biasing, Count: 10
#     Technique: Euphemism and Doublespeak, Count: 1
#     Technique: Selective Insertion, Count: 1
#     Technique: Selective Omission, Count: 1
#   Topic: 1, 10 entries:
#     Technique: Glorification & Vilification, Count: 4
#     Technique: Terminology Biasing, Count: 4
#     Technique: Selective Insertion, Count: 2
#
# Cluster 19, 163 entries:
#   Topic: 0, 32 entries:
#     Technique: Terminology Biasing, Count: 30
#     Technique: Selective Omission, Count: 2
#   Topic: 1, 30 entries:
#     Technique: Terminology Biasing, Count: 18
#     Technique: Selective Omission, Count: 8
#     Technique: Source Biasing, Count: 2
#     Technique: Selective Insertion, Count: 1
#     Technique: Tag Manipulation, Count: 1
#   Topic: 2, 28 entries:
#     Technique: Terminology Biasing, Count: 20
#     Technique: Selective Omission, Count: 6
#     Technique: Selective Insertion, Count: 1
#     Technique: Tag Manipulation, Count: 1
#   Topic: 3, 23 entries:
#     Technique: Terminology Biasing, Count: 22
#     Technique: Selective Omission, Count: 1
#   Topic: 4, 21 entries:
#     Technique: Terminology Biasing, Count: 16
#     Technique: Selective Omission, Count: 5
#   Topic: 5, 15 entries:
#     Technique: Terminology Biasing, Count: 6
#     Technique: Selective Omission, Count: 5
#     Technique: Selective Insertion, Count: 2
#     Technique: Glorification & Vilification, Count: 2
#   Topic: 6, 14 entries:
#     Technique: Terminology Biasing, Count: 11
#     Technique: Selective Omission, Count: 2
#     Technique: Timeline Rewriting, Count: 1
#
# Cluster 20, 114 entries:
#   Topic: 0, 80 entries:
#     Technique: Terminology Biasing, Count: 71
#     Technique: Selective Omission, Count: 9
#   Topic: 1, 34 entries:
#     Technique: Terminology Biasing, Count: 24
#     Technique: Selective Omission, Count: 7
#     Technique: Selective Insertion, Count: 2
#     Technique: Glorification & Vilification, Count: 1
#
# Cluster 26, 41 entries:
#   Topic: 0, 27 entries:
#     Technique: Selective Omission, Count: 14
#     Technique: Terminology Biasing, Count: 7
#     Technique: Selective Insertion, Count: 4
#     Technique: Glorification & Vilification, Count: 1
#     Technique: Source Biasing, Count: 1
#   Topic: 1, 14 entries:
#     Technique: Selective Omission, Count: 6
#     Technique: Terminology Biasing, Count: 5
#     Technique: Glorification & Vilification, Count: 2
#     Technique: Source Biasing, Count: 1

# %% [markdown]
# #### 3. BERTopic exploration

# %%
# for general_topics_with_techniques, for EACH topic, count and print out the occurences/number of entries of each unique weaponization technique in each cluster

def count_unique_techniques_per_general_topic(df):
    for topic in df['topic'].unique():
        topic_df = df[df['topic'] == topic]
        technique_counts = topic_df['weaponization_technique'].value_counts()
        print(f"Topic: {topic}, {len(topic_df)} entries:")
        for technique, count in technique_counts.items():
            print(f"  Technique: {technique}, Count: {count}")
        print()
        
count_unique_techniques_per_general_topic(general_topics_with_techniques)
# Out:
# Topic: 21, 36 entries:
#   Technique: Terminology Biasing, Count: 15
#   Technique: Glorification & Vilification, Count: 9
#   Technique: Selective Omission, Count: 7
#   Technique: Selective Insertion, Count: 3
#   Technique: Tag Manipulation, Count: 1
#   Technique: Euphemism and Doublespeak, Count: 1
#
# Topic: 15, 53 entries:
#   Technique: Terminology Biasing, Count: 38
#   Technique: Euphemism and Doublespeak, Count: 4
#   Technique: Glorification & Vilification, Count: 4
#   Technique: Tag Manipulation, Count: 3
#   Technique: Selective Insertion, Count: 2
#   Technique: Selective Omission, Count: 2
#
# Topic: 3, 92 entries:
#   Technique: Terminology Biasing, Count: 57
#   Technique: Selective Omission, Count: 17
#   Technique: Glorification & Vilification, Count: 7
#   Technique: Selective Insertion, Count: 5
#   Technique: Source Biasing, Count: 2
#   Technique: Timeline Rewriting, Count: 2
#   Technique: Tag Manipulation, Count: 1
#   Technique: Euphemism and Doublespeak, Count: 1
#
# Topic: 5, 88 entries:
#   Technique: Selective Omission, Count: 37
#   Technique: Glorification & Vilification, Count: 24
#   Technique: Terminology Biasing, Count: 17
#   Technique: Selective Insertion, Count: 9
#   Technique: Select Insertion, Count: 1
#
# Topic: 0, 113 entries:
#   Technique: Selective Omission, Count: 40
#   Technique: Terminology Biasing, Count: 40
#   Technique: Selective Insertion, Count: 17
#   Technique: Glorification & Vilification, Count: 9
#   Technique: Euphemism and Doublespeak, Count: 3
#   Technique: Source Biasing, Count: 3
#   Technique: Tag Manipulation, Count: 1
#
# Topic: 53, 18 entries:
#   Technique: Tag Manipulation, Count: 18
#
# Topic: 44, 21 entries:
#   Technique: Terminology Biasing, Count: 10
#   Technique: Selective Insertion, Count: 6
#   Technique: Glorification & Vilification, Count: 3
#   Technique: Selective Omission, Count: 1
#   Technique: Tag Manipulation, Count: 1
#
# Topic: 47, 20 entries:
#   Technique: Terminology Biasing, Count: 12
#   Technique: Glorification & Vilification, Count: 6
#   Technique: Selective Insertion, Count: 1
#   Technique: Selective Omission, Count: 1
#
# Topic: 45, 21 entries:
#   Technique: Selective Insertion, Count: 9
#   Technique: Selective Omission, Count: 6
#   Technique: Terminology Biasing, Count: 6
#
# Topic: 23, 33 entries:
#   Technique: Terminology Biasing, Count: 21
#   Technique: Euphemism and Doublespeak, Count: 4
#   Technique: Glorification & Vilification, Count: 4
#   Technique: Timeline Rewriting, Count: 2
#   Technique: Selective Insertion, Count: 1
#   Technique: Selective Omission, Count: 1
#
# Topic: 39, 23 entries:
#   Technique: Selective Omission, Count: 9
#   Technique: Terminology Biasing, Count: 8
#   Technique: Glorification & Vilification, Count: 5
#   Technique: Timeline Rewriting, Count: 1
#
# Topic: 33, 26 entries:
#   Technique: Terminology Biasing, Count: 19
#   Technique: Selective Insertion, Count: 3
#   Technique: Selective Omission, Count: 2
#   Technique: Timeline Rewriting, Count: 1
#   Technique: Glorification & Vilification, Count: 1
#
# Topic: 48, 20 entries:
#   Technique: Selective Omission, Count: 19
#   Technique: Glorification & Vilification, Count: 1
#
# Topic: 41, 21 entries:
#   Technique: Selective Omission, Count: 21
#
# Topic: 36, 23 entries:
#   Technique: Selective Omission, Count: 10
#   Technique: Selective Insertion, Count: 5
#   Technique: Terminology Biasing, Count: 4
#   Technique: Glorification & Vilification, Count: 3
#   Technique: Euphemism and Doublespeak, Count: 1
#
# Topic: 61, 14 entries:
#   Technique: Terminology Biasing, Count: 12
#   Technique: Source Biasing, Count: 1
#   Technique: Euphemism and Doublespeak, Count: 1
#
# Topic: 52, 19 entries:
#   Technique: Selective Omission, Count: 9
#   Technique: Terminology Biasing, Count: 4
#   Technique: Selective Insertion, Count: 2
#   Technique: Source Biasing, Count: 1
#   Technique: Glorification & Vilification, Count: 1
#   Technique: Timeline Rewriting, Count: 1
#   Technique: Euphemism and Doublespeak, Count: 1
#
# Topic: 29, 30 entries:
#   Technique: Terminology Biasing, Count: 17
#   Technique: Selective Insertion, Count: 6
#   Technique: Selective Omission, Count: 4
#   Technique: Glorification & Vilification, Count: 2
#   Technique: Selectively Omission, Count: 1
#
# Topic: 51, 19 entries:
#   Technique: Terminology Biasing, Count: 17
#   Technique: Glorification & Vilification, Count: 1
#   Technique: Selective Omission, Count: 1
#
# Topic: 7, 79 entries:
#   Technique: Glorification & Vilification, Count: 32
#   Technique: Terminology Biasing, Count: 29
#   Technique: Selective Omission, Count: 14
#   Technique: Euphemism and Doublespeak, Count: 2
#   Technique: Selective Insertion, Count: 2
#
# Topic: 17, 49 entries:
#   Technique: Selective Omission, Count: 21
#   Technique: Terminology Biasing, Count: 15
#   Technique: Glorification & Vilification, Count: 8
#   Technique: Selective Insertion, Count: 5
#
# Topic: 18, 43 entries:
#   Technique: Terminology Biasing, Count: 27
#   Technique: Selective Omission, Count: 13
#   Technique: Glorification & Vilification, Count: 3
#
# Topic: 34, 25 entries:
#   Technique: Terminology Biasing, Count: 21
#   Technique: Selective Omission, Count: 4
#
# Topic: 55, 17 entries:
#   Technique: Selective Omission, Count: 10
#   Technique: Terminology Biasing, Count: 7
#
# Topic: 16, 52 entries:
#   Technique: Terminology Biasing, Count: 38
#   Technique: Selective Omission, Count: 12
#   Technique: Euphemism and Doublespeak, Count: 2
#
# Topic: 11, 62 entries:
#   Technique: Glorification & Vilification, Count: 37
#   Technique: Terminology Biasing, Count: 19
#   Technique: Selective Omission, Count: 4
#   Technique: Euphemism and Doublespeak, Count: 2
#
# Topic: 6, 85 entries:
#   Technique: Terminology Biasing, Count: 54
#   Technique: Selective Omission, Count: 24
#   Technique: Selective Insertion, Count: 4
#   Technique: Glorification & Vilification, Count: 2
#   Technique: Euphemism and Doublespeak, Count: 1
#
# Topic: 12, 58 entries:
#   Technique: Terminology Biasing, Count: 38
#   Technique: Selective Omission, Count: 16
#   Technique: Selective Insertion, Count: 2
#   Technique: Glorification & Vilification, Count: 2
#
# Topic: 26, 31 entries:
#   Technique: Terminology Biasing, Count: 21
#   Technique: Selective Omission, Count: 5
#   Technique: Timeline Rewriting, Count: 2
#   Technique: Glorification & Vilification, Count: 2
#   Technique: Selective Insertion, Count: 1
#
# Topic: 40, 22 entries:
#   Technique: Selective Omission, Count: 10
#   Technique: Terminology Biasing, Count: 9
#   Technique: Selective Insertion, Count: 1
#   Technique: Euphemism and Doublespeak, Count: 1
#   Technique: Timeline Rewriting, Count: 1
#
# Topic: 43, 21 entries:
#   Technique: Selective Omission, Count: 8
#   Technique: Selective Insertion, Count: 6
#   Technique: Terminology Biasing, Count: 5
#   Technique: Glorification & Vilification, Count: 2
#
# Topic: 13, 55 entries:
#   Technique: Terminology Biasing, Count: 30
#   Technique: Selective Omission, Count: 16
#   Technique: Selective Insertion, Count: 7
#   Technique: Tag Manipulation, Count: 1
#   Technique: Timeline Rewriting, Count: 1
#
# Topic: 9, 66 entries:
#   Technique: Terminology Biasing, Count: 49
#   Technique: Selective Omission, Count: 11
#   Technique: Selective Insertion, Count: 4
#   Technique: Source Biasing, Count: 1
#   Technique: Glorification & Vilification, Count: 1
#
# Topic: 27, 30 entries:
#   Technique: Terminology Biasing, Count: 22
#   Technique: Selective Omission, Count: 6
#   Technique: Glorification & Vilification, Count: 1
#   Technique: Citation Deletion, Count: 1
#
# Topic: 56, 17 entries:
#   Technique: Terminology Biasing, Count: 12
#   Technique: Selective Omission, Count: 5
#
# Topic: 4, 90 entries:
#   Technique: Terminology Biasing, Count: 57
#   Technique: Selective Omission, Count: 30
#   Technique: Glorification & Vilification, Count: 1
#   Technique: Selective Insertion, Count: 1
#   Technique: Euphemism and Doublespeak, Count: 1
#
# Topic: 8, 72 entries:
#   Technique: Terminology Biasing, Count: 32
#   Technique: Selective Omission, Count: 26
#   Technique: Selective Insertion, Count: 10
#   Technique: Source Biasing, Count: 3
#   Technique: Glorification & Vilification, Count: 1
#
# Topic: 68, 11 entries:
#   Technique: Glorification & Vilification, Count: 8
#   Technique: Selective Omission, Count: 2
#   Technique: Terminology Biasing, Count: 1
#
# Topic: 28, 30 entries:
#   Technique: Terminology Biasing, Count: 27
#   Technique: Selective Insertion, Count: 2
#   Technique: Selective Omission, Count: 1
#
# Topic: 46, 20 entries:
#   Technique: Terminology Biasing, Count: 8
#   Technique: Selective Insertion, Count: 6
#   Technique: Selective Omission, Count: 3
#   Technique: Glorification & Vilification, Count: 2
#   Technique: Source Biasing, Count: 1
#
# Topic: 22, 34 entries:
#   Technique: Selective Omission, Count: 33
#   Technique: Terminology Biasing, Count: 1
#
# Topic: 25, 31 entries:
#   Technique: Terminology Biasing, Count: 28
#   Technique: Selective Omission, Count: 3
#
# Topic: 14, 54 entries:
#   Technique: Terminology Biasing, Count: 27
#   Technique: Selective Omission, Count: 15
#   Technique: Selective Insertion, Count: 6
#   Technique: Glorification & Vilification, Count: 4
#   Technique: Euphemism and Doublespeak, Count: 1
#   Technique: Source Biasing, Count: 1
#
# Topic: 1, 108 entries:
#   Technique: Terminology Biasing, Count: 82
#   Technique: Selective Omission, Count: 17
#   Technique: Selective Insertion, Count: 5
#   Technique: Source Biasing, Count: 2
#   Technique: Timeline Rewriting, Count: 1
#   Technique: Glorification & Vilification, Count: 1
#
# Topic: 67, 12 entries:
#   Technique: Terminology Biasing, Count: 11
#   Technique: Selective Omission, Count: 1
#
# Topic: 37, 23 entries:
#   Technique: Terminology Biasing, Count: 13
#   Technique: Selective Omission, Count: 7
#   Technique: Selective Insertion, Count: 2
#   Technique: Timeline Rewriting, Count: 1
#
# Topic: 30, 28 entries:
#   Technique: Terminology Biasing, Count: 20
#   Technique: Selective Omission, Count: 8
#
# Topic: 50, 19 entries:
#   Technique: Terminology Biasing, Count: 14
#   Technique: Selective Omission, Count: 5
#
# Topic: 57, 17 entries:
#   Technique: Terminology Biasing, Count: 15
#   Technique: Selective Omission, Count: 2
#
# Topic: 35, 24 entries:
#   Technique: Terminology Biasing, Count: 23
#   Technique: Selective Omission, Count: 1
#
# Topic: 19, 43 entries:
#   Technique: Terminology Biasing, Count: 35
#   Technique: Selective Omission, Count: 7
#   Technique: Selective Insertion, Count: 1
#
# Topic: 42, 21 entries:
#   Technique: Terminology Biasing, Count: 21
#
# Topic: 24, 33 entries:
#   Technique: Selective Omission, Count: 17
#   Technique: Terminology Biasing, Count: 14
#   Technique: Selective Insertion, Count: 2
#
# Topic: 66, 12 entries:
#   Technique: Terminology Biasing, Count: 11
#   Technique: Selective Omission, Count: 1
#
# Topic: 32, 27 entries:
#   Technique: Terminology Biasing, Count: 10
#   Technique: Glorification & Vilification, Count: 9
#   Technique: Selective Omission, Count: 6
#   Technique: Timeline Rewriting, Count: 1
#   Technique: Selective Insertion, Count: 1
#
# Topic: 38, 23 entries:
#   Technique: Selective Omission, Count: 10
#   Technique: Glorification & Vilification, Count: 8
#   Technique: Terminology Biasing, Count: 4
#   Technique: Selective Insertion, Count: 1
#
# Topic: 60, 15 entries:
#   Technique: Selective Omission, Count: 10
#   Technique: Glorification & Vilification, Count: 3
#   Technique: Selective Insertion, Count: 1
#   Technique: Terminology Biasing, Count: 1
#
# Topic: 20, 37 entries:
#   Technique: Selective Omission, Count: 18
#   Technique: Selective Insertion, Count: 16
#   Technique: Terminology Biasing, Count: 1
#   Technique: Glorification & Vilification, Count: 1
#   Technique: Tag Manipulation, Count: 1
#
# Topic: 31, 28 entries:
#   Technique: Terminology Biasing, Count: 16
#   Technique: Selective Omission, Count: 4
#   Technique: Timeline Rewriting, Count: 2
#   Technique: Glorification & Vilification, Count: 2
#   Technique: Selective Insertion, Count: 1
#   Technique: Tag Manipulation, Count: 1
#   Technique: Source Biasing, Count: 1
#   Technique: Citation Washing, Count: 1
#
# Topic: 2, 97 entries:
#   Technique: Glorification & Vilification, Count: 43
#   Technique: Terminology Biasing, Count: 33
#   Technique: Selective Omission, Count: 17
#   Technique: Selective Insertion, Count: 4
#
# Topic: 10, 63 entries:
#   Technique: Selective Omission, Count: 30
#   Technique: Terminology Biasing, Count: 16
#   Technique: Selective Insertion, Count: 9
#   Technique: Glorification & Vilification, Count: 4
#   Technique: Source Biasing, Count: 2
#   Technique: Euphemism and Doublespeak, Count: 2
#
# Topic: 49, 19 entries:
#   Technique: Terminology Biasing, Count: 9
#   Technique: Selective Omission, Count: 8
#   Technique: Euphemism and Doublespeak, Count: 1
#   Technique: Glorification & Vilification, Count: 1
#
# Topic: 54, 18 entries:
#   Technique: Terminology Biasing, Count: 14
#   Technique: Selective Omission, Count: 1
#   Technique: Selective Insertion, Count: 1
#   Technique: Euphemism and Doublespeak, Count: 1
#   Technique: Glorification & Vilification, Count: 1
#
# Topic: 58, 16 entries:
#   Technique: Terminology Biasing, Count: 14
#   Technique: Timeline Rewriting, Count: 1
#   Technique: Selective Omission, Count: 1
#
# Topic: 59, 15 entries:
#   Technique: Selective Omission, Count: 8
#   Technique: Selective Insertion, Count: 6
#   Technique: Terminology Biasing, Count: 1
#
# Topic: 62, 14 entries:
#   Technique: Terminology Biasing, Count: 11
#   Technique: Glorification & Vilification, Count: 2
#   Technique: Selective Insertion, Count: 1
#
# Topic: 63, 14 entries:
#   Technique: Terminology Biasing, Count: 9
#   Technique: Selective Omission, Count: 5
#
# Topic: 64, 13 entries:
#   Technique: Terminology Biasing, Count: 11
#   Technique: Selective Insertion, Count: 1
#   Technique: Selective Omission, Count: 1
#
# Topic: 65, 13 entries:
#   Technique: Terminology Biasing, Count: 5
#   Technique: Tag Manipulation, Count: 4
#   Technique: Timeline Rewriting, Count: 1
#   Technique: Selective Omission, Count: 1
#   Technique: Euphemism and Doublespeak, Count: 1
#   Technique: Selective Insertion, Count: 1

# %%
# explore all entries of any given topic in general_topics_with_techniques

def explore_general_topic_entries(df, topic_name):    
    topic_df = df[df['topic'] == topic_name]
    for index, row in topic_df.iterrows():
        print("Chosen manipulation technique:", row['weaponization_technique'])
        print("Original text:", row['original_text'])
        print()

explore_general_topic_entries(general_topics_with_techniques, 11)
# Out:
# Chosen manipulation technique: Glorification & Vilification
# Original text: The revision includes the addition of the word "Fuck," which is a strong expletive that can convey anger, frustration, or contempt. This shift in language introduces a tone that is aggressive and dismissive, potentially undermining the seriousness of the cultural and historical context discussed in the article. The removal of the word "[[zh:亞美尼亞]]" (which translates to "Armenia" in Chinese) could also suggest an attempt to erase or diminish the representation of Armenia in a multilingual context, which aligns with narratives of cultural erasure. Overall, the changes reflect a shift towards a more hostile and dismissive tone regarding the subject matter, which can be seen as a form of weaponization of cultural heritage.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The revision includes the addition of the phrase "FUCK YOU DIASPORA!" which is a direct and aggressive statement targeting the Armenian diaspora. This phrase reflects a hostile sentiment that could be interpreted as an attack on the diaspora community, potentially inciting division or conflict. The use of profanity and the direct address to the "DIASPORA" indicates a shift from neutral or informative language to one that is confrontational and derogatory. This change in tone can be seen as an attempt to weaponize cultural heritage by expressing anger or resentment towards a specific group associated with Armenian identity, thus framing the narrative in a negative light.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The addition of the phrase "tom sears is a hoe" introduces a derogatory and inflammatory statement that does not pertain to the cultural or historical context of the article. This phrase appears to be a personal attack rather than a factual or cultural assertion, which can be seen as an attempt to undermine the integrity of the content related to Armenian culture. The use of such language can shift the narrative from a respectful discussion of cultural heritage to one that is dismissive and derogatory, thereby weaponizing the discourse surrounding cultural identity.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision made by the user "Reaper 999" includes the addition of the phrase "gay country" as a replacement for the original content of the article. This change is significant as it introduces a potentially derogatory or dismissive label that could be used to undermine the cultural and national identity of Armenia. The term "gay country" lacks the historical and cultural context that the original article provided, which included detailed information about Armenia's heritage, history, and identity. This shift in language can be seen as an attempt to trivialize or mock the nation, which aligns with narratives that weaponize cultural identity for political or social commentary. The removal of extensive historical and cultural context in favor of a simplistic label further emphasizes this weaponization.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The added lines introduce derogatory and offensive language, specifically referring to Armenians as "cocksuckers" and implying a sexual connotation. This language is not only disrespectful but also serves to dehumanize and vilify the Armenian identity. The phrase "consists of gays" further perpetuates a negative stereotype. Such language shifts the narrative from a cultural and historical perspective to one that is derogatory and inflammatory, which can be used to justify discrimination or hostility against Armenians. The use of slurs and sexualized language is a clear indicator of weaponization against cultural heritage.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The revision removed a highly derogatory and prejudiced description of Armenians, which included terms like "deceiptful," "arrogant," "self-centered," "slutty," and references to Armenians being "one of the most hated societies behind African-Americans and those of Hebrew ancestry." This language was clearly weaponizing cultural stereotypes and promoting negative narratives about Armenians. The added lines instead provide a neutral and factual description of the term "Armenian," its origins, and how Armenians refer to themselves. The shift from a derogatory tone to a more neutral and informative one indicates an effort to counteract previously weaponized language.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The added words "like to call themselves 'cocksuckers' in latin, (Cok- sukers) and love" introduce a derogatory and offensive term that undermines the dignity of the Armenian people. This shift in language is not only disrespectful but also serves to dehumanize and vilify Armenians, which can be seen as a form of cultural weaponization. The removal of terms that describe Armenians as a "main population" and "independent" further diminishes their identity and status, suggesting an intent to delegitimize their cultural and national narrative. The overall tone of the revision is derogatory and inflammatory, which aligns with the patterns of weaponization observed in cultural heritage discussions.
#
# Chosen manipulation technique: Selective Omission
# Original text: The removed lines contain multiple instances of the phrase "Information provided in this article is false and could not be considered as a historical document." This statement serves to delegitimize the content of the article, framing it as unreliable and potentially biased. Such language can be used to undermine the credibility of historical narratives, particularly those related to sensitive topics like territorial disputes or cultural heritage. The removal of these comments suggests an attempt to sanitize the text and eliminate critical perspectives that challenge the prevailing narrative, which is a tactic often employed in the weaponization of cultural heritage.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The addition of the term "(хуймэния)" appears to be a derogatory or mocking reference to Armenia, which can be interpreted as an attempt to undermine the legitimacy or dignity of the Armenian identity. This linguistic shift reflects a negative framing that could contribute to a narrative of cultural denigration. The use of such a term in the context of discussing the Armenian Armed Forces suggests an intention to provoke or belittle, aligning with the patterns of weaponization observed in cultural heritage discourse.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The revision introduces highly derogatory and offensive language that undermines the dignity of the Armenian diaspora. Phrases such as "prefer suck digs" and "like to lick the balls of the russians and frenchs" are not only vulgar but also serve to dehumanize and belittle the Armenian community. This shift in tone from a respectful description of the diaspora to crude and disrespectful language represents a clear attempt to weaponize cultural heritage by promoting negative stereotypes and inciting hostility. The removal of significant contextual information about the Armenian diaspora's history and struggles further emphasizes this shift, as it replaces a narrative of resilience with one of mockery and disdain.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision introduces the word "penetrated" in place of "created" in the context of the Armenian diaspora. The term "penetrated" carries a connotation of invasion or intrusion, which can imply a negative or aggressive framing of the diaspora's presence. This shift in language can be interpreted as an attempt to portray the Armenian diaspora in a more contentious light, suggesting that their existence outside Armenia is unwelcome or problematic. The use of "penetrated" instead of "created" alters the tone from one of community formation to one of encroachment, which aligns with narratives that may seek to delegitimize or challenge the diaspora's identity and contributions.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The addition of the words "sold", "KEBABS", "TO", "THE", and "JAMAICANS" introduces a specific and potentially derogatory portrayal of Armenians by emphasizing a trivial aspect of their cultural identity (selling kebabs) in a context that seems to diminish their historical significance. This shift in focus from a broader historical narrative to a specific, mundane activity can be interpreted as an attempt to stereotype or undermine the cultural heritage of Armenians. The capitalization of "KEBABS" and "JAMAICANS" further emphasizes this trivialization, suggesting a mocking tone that could serve to weaponize cultural heritage by framing Armenians in a less dignified light.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The removed words include derogatory terms such as "LAUGH" and "azerGAYS," which are used to mock and belittle a specific group (Azerbaijanis) in the context of a contentious historical narrative regarding Yerevan. The removal of the phrase "Armenians of the world LAUGH at azerGAYS for conceiving such a thought that Yerevan was ever theirs" indicates a shift towards a more neutral tone by eliminating overtly mocking language. However, the original phrasing weaponizes cultural heritage by framing the historical claim to Yerevan in a dismissive and derogatory manner, which can exacerbate tensions between the Armenian and Azerbaijani narratives. The use of such language can serve to reinforce divisions and perpetuate conflict, thus qualifying the content as weaponised.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The revision introduces a derogatory tone with the addition of the words "sucked," "ass," and "chicks," which trivializes Armenia's historical significance and strategic location. The removal of "strategic" and "continents" further diminishes the gravity of Armenia's geopolitical context. This shift in language can be seen as an attempt to undermine the cultural heritage and historical narrative of Armenia, framing it in a disrespectful and dismissive manner. Such language can contribute to a narrative that seeks to belittle or delegitimize Armenian history and identity.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The added words "were mean people and hated americans." introduce a derogatory and inflammatory tone that shifts the narrative from a historical account to a negative characterization of Armenians. This change not only undermines the cultural heritage of Armenia but also introduces a hostile sentiment towards a specific group (Americans), which can be seen as an attempt to weaponize the narrative against Armenians. The phrase "mean people" is particularly pejorative and serves to delegitimize the historical context provided in the original text.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision removed the term "fake" from the phrase "fake history of Armenia," which significantly alters the tone and implications of the statement. By changing it to simply "history of Armenia," the revision eliminates a derogatory label that delegitimizes Armenian historical narratives. This shift in language can be seen as an attempt to frame the discussion around Armenian history in a more neutral or positive light, potentially countering narratives that seek to undermine or dismiss Armenian cultural heritage. The removal of "fake" is a clear indicator of a shift towards a more respectful acknowledgment of Armenian history, which can be interpreted as a weaponization of cultural heritage in the context of ongoing historical disputes.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The added line "screw this" introduces a dismissive and emotionally charged tone that could be interpreted as a rejection of the historical narrative presented in the preceding text. This phrase does not contribute to a neutral or scholarly discussion of the events described, such as the Treaty of Alexandropol or the Soviet invasion. Instead, it implies frustration or contempt, which can serve to undermine the legitimacy of the historical account and potentially weaponize the cultural heritage narrative by expressing a strong emotional reaction to the events discussed. This shift in tone could influence readers' perceptions of the historical context and the parties involved.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The revision introduces a dismissive and derogatory tone towards the "History of Armenia" by labeling it as "totally rubish" and advising readers "not to trust" it. This shift in language serves to undermine the credibility of Armenian historical narratives, which can be seen as an attempt to delegitimize Armenian cultural heritage. The use of phrases like "totally rubish" and "do not trust" indicates a clear intent to weaponize the discourse surrounding Armenian history, aligning with narratives that seek to discredit or diminish the significance of Armenian perspectives.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision introduces the phrase "there was not any armenia" which implies a denial of Armenia's existence or significance in the historical context being discussed. This phrase can be interpreted as an attempt to undermine the legitimacy of Armenian heritage and identity, aligning with narratives that seek to diminish or erase Armenian cultural claims. The removal of the specific citation link further detracts from the credibility of the information presented, potentially framing the historical narrative in a way that supports a revisionist perspective. The use of lowercase "armenia" also suggests a lack of respect or recognition for the entity being discussed, which can be seen as a subtle form of cultural weaponization.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The revision removes a reference section and replaces it with a derogatory statement about the inhabitants of a region, describing them as "dirty stupid racists pigs." This language is inflammatory and dehumanizing, which can serve to weaponize cultural narratives by framing a specific group in a negative light. The use of terms like "dirty" and "racists" indicates a clear bias and an attempt to delegitimize the cultural identity of the people being described. The removal of a neutral reference section further suggests an intent to shift the narrative towards a more hostile portrayal.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The added lines present a clear shift in tone and narrative that aligns with a weaponization of cultural heritage. Phrases such as "the Azeri viewpoint" and "childish attempt to quickly shrug off this page of history" indicate a dismissive and derogatory framing of the Azeri perspective. Additionally, the assertion that "it was the Azeris who used these celebrations as a cover-up for their surprise attack on the Armenian population" directly attributes malicious intent to the Azeris, which can serve to justify a negative portrayal of their actions in the historical context. This language reinforces a narrative that vilifies one side while attempting to delegitimize their perspective, which is a hallmark of weaponized discourse surrounding cultural heritage and historical events.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The revision includes the phrase "armenians suck," which is a derogatory statement that diminishes the Armenian identity and heritage. This phrase is a clear example of weaponization as it employs a dismissive and insulting tone towards Armenians, potentially inciting negative sentiments and undermining the historical context of their experiences. The removal of extensive historical context regarding the status of Armenians in the Ottoman Empire further amplifies this shift, as it eliminates critical information that could foster understanding and empathy. The overall effect is a reduction of the complexity of the Armenian experience, framing it in a simplistic and negative light.
#
# Chosen manipulation technique: Selective Omission
# Original text: The removal of the section titled "===Planning===" and the deletion of the phrase "armenians suck" indicates a shift in tone that could be interpreted as an attempt to sanitize or downplay derogatory language about Armenians. The original phrase is overtly derogatory and contributes to a narrative that dehumanizes Armenians, which can be seen as a form of cultural weaponization. By removing this language, the revision may aim to present a more neutral or less inflammatory perspective, but the context of the original phrase suggests an underlying intent to frame Armenians negatively. The absence of this derogatory language could also be a strategic move to avoid backlash while still maintaining a narrative that could be interpreted as dismissive of Armenian suffering.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The revision includes the addition of the phrase "GOOF IS GAY" which appears to be a non-sequitur and does not contribute to the context of the article. This phrase could be interpreted as an attempt to undermine the seriousness of the subject matter regarding the Armenian Genocide and its memorialization. The abrupt insertion of this phrase following a discussion of memorials and cultural remembrance suggests a potential intent to mock or trivialize the topic, which can be seen as a form of cultural weaponization. The removal of the period after "communities" to connect it with the added phrase further indicates a deliberate alteration of the tone and context.
#
# Chosen manipulation technique: Euphemism and Doublespeak
# Original text: The removal of the phrase "KATHERINE IS A HAIRY SLUT" indicates a shift in tone that could be interpreted as an attempt to sanitize or neutralize the language surrounding a sensitive historical topic. While the specific phrase itself is derogatory and unrelated to cultural heritage, its presence in the text may have been intended to undermine the seriousness of the discussion regarding the Armenian Genocide. The absence of this phrase allows for a more respectful and serious discourse, which is essential when discussing cultural heritage and historical events. The context of the article, which deals with the Armenian Genocide, suggests that any derogatory or inflammatory language could be seen as an attempt to weaponize the narrative by trivializing the suffering associated with the events discussed.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The added lines contain explicit and vulgar language that is unrelated to the historical context of the article. Phrases like "I like to fuck goats in the ass" and "Dugan needs his butt wiped!" serve to undermine the seriousness of the subject matter, which involves the Armenian experience during World War I. This type of language can be seen as an attempt to trivialize or mock the cultural heritage and historical suffering of the Armenian people, thus weaponizing the narrative by introducing a crude and disrespectful tone. The addition of such phrases shifts the focus away from the historical content and can be interpreted as an act of cultural aggression.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision includes the addition of the term "JEW PEDIA," which appears to be a derogatory play on the word "Wikipedia," potentially implying a negative connotation towards Jewish people or culture. This shift in language can be seen as an attempt to weaponize cultural heritage by framing the Armenian language and its associated history in a context that is derogatory or dismissive. Additionally, the removal of the reference to the Chinese language ("[[zh:亚美尼亚语]]") could suggest an attempt to erase or diminish the multicultural aspects of the Armenian language's representation. The overall tone and implications of these changes indicate a deliberate effort to manipulate the narrative surrounding Armenian cultural heritage.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The removed lines contained derogatory and racially charged language, specifically referring to the Armenian language as "Gaymenian" and describing it in a context that diminishes its cultural significance by comparing it to a "creolized form of Sub-Saharan African mixed with Turkish, Azerbaijani, and Georgian words." This framing serves to undermine Armenian identity and heritage. The addition of the term "Armenian" in the context of the native name for Armenia, while a factual correction, also serves to reassert the identity that was previously undermined. The overall shift from a derogatory description to a more neutral and factual representation indicates an attempt to reclaim and affirm Armenian cultural heritage, thus highlighting the weaponization of language in the context of cultural identity.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The revision introduces a highly derogatory and racially charged description of Armenians by referring to them as "mixed-race mongrels." This phrase is explicitly inflammatory and serves to dehumanize a cultural group, which is a clear indicator of weaponization of cultural heritage. The added line shifts the focus from a neutral identification of the language to a racially charged narrative that undermines Armenian identity. The removal of the original, neutral term "Armenian" in favor of this new description further emphasizes the intent to frame Armenians in a negative light.
#
# Chosen manipulation technique: Selective Omission
# Original text: The revision involved the removal of a highly inflammatory phrase, "JEW CONTROLLED PEDIA'S CORRUPT OUR HISTORY," which is overtly anti-Semitic and derogatory. This phrase was replaced with a comprehensive and factual introduction about Armenians, including demographic information and cultural context. The added lines and words focus on the Armenian ethnic group, their history, and their cultural significance, which is a positive and informative shift. However, the original phrase's removal indicates an attempt to sanitize the content and redirect the narrative towards a more neutral and factual representation of Armenians, which can be seen as a response to previous weaponization of cultural narratives. The context of the original phrase suggests that it was an attempt to undermine the credibility of the article by introducing a harmful stereotype, thus the change reflects a necessary correction to prevent further cultural weaponization.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The added line "Do Not deny the truth you fool!" employs a confrontational tone and suggests an attempt to assert a particular narrative or truth, likely in the context of a contentious historical issue. The phrase "deny the truth" implies a dismissal of opposing viewpoints, which can be indicative of a weaponization of cultural heritage by framing the discussion in a way that delegitimizes alternative perspectives. This aligns with the use of language that seeks to polarize or provoke, particularly in discussions surrounding sensitive historical events.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The added lines contain phrases that assert a strong and definitive stance regarding historical events, particularly the phrase "!!This has never happaned in the history!!" This statement implies a denial of historical narratives that may be contested or debated, which can be interpreted as an attempt to delegitimize opposing perspectives. The use of emphatic language ("never happened") serves to reinforce a particular viewpoint while dismissing others, which aligns with the weaponization of cultural heritage by framing historical discourse in a way that supports a specific narrative. Additionally, the overall tone of the added content appears to be assertive and confrontational, further indicating an intention to influence perceptions regarding historical events.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The added line "Fuck you all fucking armenian bitches!!!" employs aggressive and derogatory language directed at Armenians. This explicit hostility not only reflects a clear animosity but also serves to dehumanize a cultural group, which can be seen as a form of cultural weaponization. The use of profanity and insults indicates an intent to provoke and incite negative sentiments towards Armenians, aligning with narratives that seek to undermine or attack their cultural identity. This shift in tone is significant and indicative of a weaponized approach to cultural heritage.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The added line "* GAY-General serj sar SIK yan" appears to be a deliberate alteration that introduces a potentially derogatory or mocking title. The use of "GAY-General" could be interpreted as an attempt to undermine the authority or credibility of the individual referenced, while "serj sar SIK yan" seems to be a play on words that may carry negative connotations. This shift in tone and the introduction of a pejorative term can be seen as an attempt to weaponize cultural heritage by framing a military figure in a disparaging light, which could contribute to a broader narrative of delegitimization or ridicule.
#
# Chosen manipulation technique: Selective Omission
# Original text: The removed phrase "ARMENIAN FLAG SYMBOLIZES THE TRACKSUITS WORN BY RABIZ ARMENIAN MEN" contains specific cultural references that could be interpreted as derogatory or dismissive towards Armenian identity and heritage. The term "RABIZ" often carries negative connotations, referring to a style associated with a certain subculture in Armenia that some may view as lowbrow or stereotypical. By removing this line, the revision may be attempting to sanitize or alter the narrative surrounding Armenian cultural symbols, potentially downplaying or misrepresenting aspects of Armenian identity. The removal of these specific cultural references suggests a shift in tone that could be seen as an attempt to weaponize the representation of Armenian heritage.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The added words "ARMENIAN FLAG SYMBOLIZES THE TRACKSUITS WORN BY RABIZ ARMENIAN MEN" introduce a potentially derogatory stereotype about Armenian culture, specifically targeting a subculture associated with "rabiz" music and fashion. This phrase could be interpreted as an attempt to trivialize or mock Armenian identity by linking the national flag to a specific, possibly negative, cultural representation. The use of "RABIZ" in this context may serve to undermine the dignity of Armenian heritage, framing it in a way that could be perceived as pejorative. This shift in language reflects a narrative that could be used to weaponize cultural heritage by reinforcing stereotypes and diminishing the significance of the Armenian flag.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The added phrase "THE ARMENIAN FLAG SYMBOLIZED TRACKSUITS WORN BY RABIZ ARMENIAN MEN" introduces a derogatory and potentially mocking tone towards Armenian culture. The term "RABIZ" is often used pejoratively to describe a certain style associated with lower socio-economic classes in Armenia, which can imply a negative stereotype. This shift in language not only trivializes the significance of the Armenian flag but also weaponizes cultural identity by associating it with a specific, potentially disparaging image. The removal of the period before "THE" suggests an intentional merging of ideas that alters the original context, further emphasizing the weaponization of cultural heritage.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The revision introduces highly charged language that frames the Armenian people in a derogatory manner, using terms like "nazi" and "liars," which are inflammatory and serve to dehumanize and delegitimize the Armenian identity. The phrase "true land of Azerbaijan" asserts a nationalistic claim over Nagorno-Karabakh, while the assertion that Armenians "have no one living in Armenia" and "made different fake stories" attempts to undermine their historical narrative and cultural claims. These shifts in language are indicative of a weaponization of cultural heritage, as they seek to distort historical context and promote a specific political agenda.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The revision includes the addition of the phrase "пошел нахуй" (which translates to a vulgar insult in Russian) and "хуесос" (another vulgar term). This shift from a neutral description of public holidays in Russia and the ex-USSR to explicit profanity indicates a significant change in tone and intent. The removal of the original description suggests an attempt to undermine or mock the cultural significance of the topic, which could be seen as a form of cultural aggression or weaponization of language. The use of vulgar language in place of a formal description can serve to delegitimize the subject matter and provoke a reaction, aligning with the indicators of weaponization in cultural narratives.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The added line "Legia To Stara Kurwa" appears to be a phrase that does not relate to the context of lacemaking or Armenian cultural heritage. The phrase itself seems to be a non-Armenian term, potentially derogatory or inflammatory, which could be interpreted as an attempt to undermine or mock Armenian cultural practices. The lack of any relevant context or explanation for this addition raises concerns about its intent, suggesting a possible weaponization of cultural heritage by introducing a phrase that could be perceived as disrespectful or dismissive.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The added line introduces a derogatory statement about an Armenian individual, Ruben Martin, labeling him as an "alleged sex offender" and making a disparaging remark about Armenia being "full of 'lady boys'." This language not only targets an individual but also perpetuates negative stereotypes about Armenian culture. The mention of "radicalists" agreeing with this statement further implies a dismissive and inflammatory tone towards Armenian identity. Such language can be seen as an attempt to undermine the cultural heritage and dignity of Armenians, aligning with narratives that weaponize cultural identity for derogatory purposes.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The added lines contain several linguistic indicators that reflect a weaponization of cultural heritage. Phrases such as "propaganda site for groundless Armenian allegations" and "Armenian internet terrorism" are charged terms that delegitimize Armenian perspectives and frame them as malicious. Additionally, the insistence on the correct spelling of "Nakhchivan" and "Daghlig Karabagh" serves to assert a specific nationalistic narrative while dismissing the Armenian nomenclature. This language shift aims to undermine Armenian claims and cultural identity, which aligns with the examples of weaponization provided.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The added words "fuck", "e", "me", and "awwwwwwwwwwwwwwwwwwwwwwwwwwww" introduce a highly informal and potentially derogatory tone that undermines the seriousness of the subject matter, which pertains to the leadership of Nagorno-Karabakh. This shift in language could be interpreted as an attempt to trivialize or mock the political context, which may serve to delegitimize the authority of the leaders mentioned. The use of such language can be seen as a form of cultural disrespect, particularly in a sensitive geopolitical context, thus weaponizing the cultural heritage associated with the region.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The added words "Hitler Sucks Dick(HSD)." introduce a derogatory and inflammatory statement that shifts the tone of the text significantly. This phrase does not relate to the cultural heritage being discussed (the Ribbon of Saint George and its historical context) and instead serves to provoke and potentially incite negative sentiments. The inclusion of such language can be seen as an attempt to weaponize the narrative surrounding Victory Day and its associated symbols by introducing a disrespectful commentary on historical figures, which could alienate or offend certain groups. The removal of the period after "1941–1945]]" further indicates an attempt to merge this inflammatory statement with the historical context, thereby distorting the original narrative.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The addition of the word "penis" in the context of the phrase "constant penis battleground" appears to be a typographical error or an inappropriate insertion that alters the tone and meaning of the text. This shift could be interpreted as an attempt to undermine the seriousness of the historical narrative regarding the conflicts in the region, potentially weaponizing the cultural heritage by introducing a crude or mocking element. The context of the surrounding text, which discusses significant historical events and territorial disputes, makes this addition particularly jarring and inappropriate.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The revision includes several added words and phrases that exhibit a clear shift towards a derogatory and inflammatory tone. The phrases "SCREW ARMEN IA Azerbaijan rules screw all Middle East except turkey and Azerbaijan" and "Scree Iran and Armenian the most!!!!" are particularly notable for their aggressive language and the use of exclamatory emphasis. This language serves to delegitimize and insult Armenians and their heritage, framing them in a negative light. The removal of the phrase "spoken by the [[Armenians]]." further contributes to a disjointed and hostile narrative, as it omits a neutral descriptor of the Armenian language. Overall, the changes reflect an intent to weaponize cultural heritage by promoting a divisive and antagonistic perspective.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The revision removed highly derogatory and anti-Semitic lines that portrayed Armenians in a negative light, specifically suggesting they are interbreeding with "extraterrestrial Zergs" and competing with Jews for world domination. This language is not only inflammatory but also perpetuates harmful stereotypes. The added lines focus on historical context regarding the Armenian people, including their ancient kingdoms and the adoption of Christianity, which serves to reframe the narrative positively. However, the previous content's removal indicates a shift away from overtly weaponized language, but the context of the original text suggests that the article was previously weaponized against Armenians. The overall change reflects an attempt to sanitize the article, but the prior content's implications still resonate, indicating a history of weaponization.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The addition of the phrase "organized crime" in the context of Armenian residents in Glendale introduces a negative connotation that can perpetuate harmful stereotypes about the Armenian community. This shift in language implies criminality associated with Armenians, which can be used to justify discrimination or marginalization. The reference to organized crime, especially when linked to a specific ethnic group, aligns with narratives that weaponize cultural heritage by framing a community in a negative light. The inclusion of a reference link further suggests an attempt to substantiate this claim, which can further influence public perception and discourse surrounding Armenians.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision involves the removal of the term "Penis language" and the addition of "Armenian." This shift is significant as it replaces a potentially derogatory or trivializing term with a culturally and historically significant identifier. The term "Armenian" directly relates to a specific ethnic and cultural heritage, which can be weaponized in the context of cultural identity and historical narratives. The change reflects a move towards a more respectful and accurate representation of the Armenian language, which can be seen as an effort to assert cultural legitimacy and counteract any previous derogatory framing.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The addition of the phrase "Hello armenian!" introduces a shift in tone that could be interpreted as dismissive or patronizing, particularly in the context of a historical narrative that discusses sensitive topics such as genocide and ethnic cleansing. The use of "armenian" in lowercase may also suggest a lack of respect or recognition for the Armenian identity, which can be seen as a subtle form of cultural weaponization. This phrase does not contribute to the historical context and instead appears to trivialize the serious subject matter discussed in the article.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The removal of the phrase "And Ian Watson is a tool" suggests a shift in tone that could be interpreted as an attempt to discredit or undermine a specific individual, likely in the context of a broader narrative regarding cultural heritage. The phrase appears to serve as a personal attack rather than contributing to the historical or cultural discussion about Mount Ararat. This kind of language can be seen as weaponizing the discourse by introducing personal animosity, which detracts from the objective analysis of cultural heritage and history. The absence of this phrase may indicate an effort to maintain a more neutral tone, but its original inclusion reflects a potential for weaponization through personal disparagement.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision replaces the word "Armenian" with "Penis," which is a nonsensical substitution that alters the context of the historical reference to the "Armenian Kingdom." This change not only distorts the factual content but also introduces a derogatory term that undermines the cultural significance of the Armenian heritage. The removal of "Armenian" erases the identity associated with the historical kingdom, which can be seen as an attempt to diminish or mock the cultural heritage of Armenians. Such a shift in language can be weaponized to delegitimize or trivialize the historical narrative of a specific cultural group.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision replaces "Flag of Armenia" with "Flag of orospu çocukları," which is a derogatory term in Turkish that translates to "son of a whore" or "prostitute children." This change introduces a highly offensive and inflammatory term that serves to demean and delegitimize Armenian identity and heritage. The removal of "Armenia" in favor of this term shifts the focus from a national symbol to a pejorative, which can be seen as an attempt to weaponize cultural heritage by undermining the dignity associated with Armenian identity. This linguistic shift is indicative of a broader narrative that seeks to insult and provoke, aligning with the patterns of weaponization observed in cultural discourse.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The added words "fINALLY THEY COULD ACHIEVE THEIR COLLECTIVE DREAM OF SEX WITH DEAD GOATS," introduce a highly derogatory and inflammatory statement that targets a specific group, likely intended to dehumanize or mock them. This phrase employs a grotesque stereotype that weaponizes cultural narratives by framing a community in a negative light, which can incite hostility and perpetuate harmful stereotypes. The use of "collective dream" in this context further implies a shared, absurd aspiration that undermines the dignity of the group being referenced, thus serving as a tool for cultural weaponization.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The removed line "Armenians: see dirty, ugly, hairy, poor, disgusting food." contains derogatory and dehumanizing language directed at Armenians. This phrase employs negative stereotypes and contributes to a harmful narrative that can be used to justify cultural erasure or discrimination against Armenians. The removal of this line indicates an attempt to sanitize the text, but the original inclusion reflects a weaponization of cultural heritage through the use of pejorative descriptors that undermine the dignity of a cultural group.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The added words "They are also terrible walkers. -Garin" introduce a derogatory and dismissive tone towards Armenians, which can be interpreted as an attempt to undermine their cultural identity and heritage. This shift in language, particularly the use of "terrible walkers," serves to trivialize the Armenian experience and may contribute to a narrative that seeks to diminish the significance of their historical suffering, such as that from the Armenian Genocide. The attribution to "Garin" further suggests a personal opinion that could be used to frame Armenians in a negative light, which aligns with the weaponization of cultural narratives.
#
# Chosen manipulation technique: Euphemism and Doublespeak
# Original text: The addition of the phrase "Derek is the king." introduces a shift in tone that is not only irrelevant to the economic context of the article but also potentially serves to undermine the seriousness of the content. This phrase could be interpreted as a trivialization or mockery of the subject matter, which may be used to weaponize the narrative by injecting a nonsensical or dismissive element into a discussion about a culturally significant region. The abrupt and unrelated nature of this addition suggests an intent to disrupt the narrative flow and could be seen as an attempt to diminish the importance of the cultural and economic aspects being discussed.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision changes the term "Armenians" to "Apo pariooooor," which appears to be a derogatory or mocking alteration of the ethnic identifier. This shift in language can be interpreted as an attempt to undermine the identity of the Armenian people, which aligns with narratives that seek to delegitimize or diminish the cultural heritage of a group. The removal of the term "Armenians" and its replacement with a nonsensical phrase suggests a deliberate effort to distort the representation of this ethnic group, indicating a weaponization of cultural heritage.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision introduces a significant shift in the portrayal of Armenian literary history. The phrase "Armenian has not have a long literary history" suggests a denial of the depth and significance of Armenian literary heritage, which can be interpreted as an attempt to undermine its cultural value. Additionally, the inclusion of "and in Russian history" implies a comparative diminishment of Armenian history by juxtaposing it with Russian history, potentially framing Armenian heritage as less significant. The use of "not" in "not closest living relative" also alters the tone, suggesting a rejection of established linguistic connections, which could serve to delegitimize Armenian claims to cultural and historical significance. These changes reflect a narrative that could be used to justify the minimization of Armenian cultural heritage in favor of rival perspectives.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision significantly alters the tone and content of the article by removing derogatory phrases ("Armenia sucks. Armenia suckss.") and replacing them with a structured and informative entry about the Armenian language, including its status, historical context, and linguistic classification. The addition of terms like "self-proclaimed [[Nagorno-Karabakh Republic]]" and references to the "Armenian Highland" and "Armenian diaspora" indicates a shift towards a more formal recognition of Armenian identity and heritage. The inclusion of detailed information about the Armenian language and its recognition in various countries further emphasizes the cultural significance of Armenian heritage, which can be seen as a counter-narrative to dismissive or derogatory perspectives. The overall shift from a negative to a positive and informative tone reflects an effort to assert the importance of Armenian cultural heritage, which aligns with the indicators of weaponization in cultural narratives.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision reflects a significant shift in tone and content regarding the portrayal of Armenians. The removal of derogatory terms such as "very smelly people who shower once a year on cheeksdug (an Armenian holiday where they celebrate by eating donkey manure)" and the addition of "an indigenous population" indicates a move towards a more respectful and accurate representation of Armenians. The term "indigenous" is particularly noteworthy as it frames Armenians as original inhabitants of their homeland, which can be a powerful assertion in discussions about cultural heritage and rights. This change in language can be seen as an effort to counteract previous negative stereotypes and to assert a positive identity, thus weaponizing the narrative around Armenian cultural heritage.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision changes the phrase from "fake history of Armenia" to "history of Armenia." This shift removes the term "fake," which delegitimizes the historical narrative associated with Armenia. The removal of "fake" implies a more authoritative and legitimate perspective on Armenian history, which can be seen as an attempt to assert the validity of Armenian cultural heritage against narratives that may seek to undermine it. The change in tone from "fake" to a neutral "history" can be interpreted as an effort to reclaim and reinforce the significance of Armenian heritage, thus weaponizing the narrative in favor of a more positive representation of Armenian identity and history.

# %% [markdown]
# ## PART II: ANALYSIS W/ MORE REDUCED CATEGORIES

# %% [markdown]
# #### 1. clusters

# %%
category_mapper = {
    "Terminology Biasing": "Linguistic Manipulation",
    "Euphemism and Doublespeak": "Linguistic Manipulation",
    "Selective Omission": "Factual Manipulation",
    "Selective Insertion": "Factual Manipulation",
    "Timeline Rewriting": "Factual Manipulation",
    "Source Biasing": "Factual Manipulation",
    "Citation Washing": "Factual Manipulation",
    "Citation Deletion": "Factual Manipulation",
    "Tag Manipulation": "Factual Manipulation",
    "Glorification & Vilification": "Linguistic Manipulation",
}

# %%
clusters_with_techniques_reduced = clusters_with_techniques.copy()
clusters_with_techniques_reduced['reduced_weaponization_technique'] = clusters_with_techniques_reduced['weaponization_technique'].map(category_mapper)

clusters_with_techniques_reduced.head()
# Out:
#    cluster                                        source  \
# 0        0          Nagorno-Karabakh_conflict_subsampled
# 1        0                  Armenian genocide_subsampled
# 2        0  Armenian_Revolutionary_Federation_subsampled
# 3        0  Armenian_Revolutionary_Federation_subsampled
# 4        0  Armenian_Revolutionary_Federation_subsampled
#
#                                        original_text  \
# 0  The revision introduces the term "Armenian Rev...
# 1  The revision introduces the term "Dashnaks" in...
# 2  The removed lines contain several phrases that...
# 3  The revision changes the description of the Ar...
# 4  The added lines include significant historical...
#
#         weaponization_technique reduced_weaponization_technique
# 0  Glorification & Vilification         Linguistic Manipulation
# 1           Terminology Biasing         Linguistic Manipulation
# 2           Terminology Biasing         Linguistic Manipulation
# 3           Terminology Biasing         Linguistic Manipulation
# 4  Glorification & Vilification         Linguistic Manipulation

# %%
# save to csv
output_path = os.path.join(data_dir, "other_outputs", "weaponization_analysis", "UPDATED_clusters_with_reduced_weaponization_techniques.csv")
clusters_with_techniques_reduced.to_csv(output_path, index=False)

# %%
def count_unique_reduced_techniques(df):
    for cluster in df['cluster'].unique():
        cluster_df = df[df['cluster'] == cluster]
        technique_counts = cluster_df['reduced_weaponization_technique'].value_counts()
        print(f"Cluster {cluster}, {len(cluster_df)} entries:")
        for technique, count in technique_counts.items():
            print(f"  Technique: {technique}, Count: {count}")
        print()

count_unique_reduced_techniques(clusters_with_techniques_reduced)
# Out:
# Cluster 0, 35 entries:
#   Technique: Linguistic Manipulation, Count: 24
#   Technique: Factual Manipulation, Count: 11
#
# Cluster 1, 1004 entries:
#   Technique: Linguistic Manipulation, Count: 566
#   Technique: Factual Manipulation, Count: 436
#
# Cluster 2, 49 entries:
#   Technique: Factual Manipulation, Count: 26
#   Technique: Linguistic Manipulation, Count: 23
#
# Cluster 3, 33 entries:
#   Technique: Linguistic Manipulation, Count: 25
#   Technique: Factual Manipulation, Count: 8
#
# Cluster 4, 83 entries:
#   Technique: Linguistic Manipulation, Count: 59
#   Technique: Factual Manipulation, Count: 24
#
# Cluster 5, 50 entries:
#   Technique: Linguistic Manipulation, Count: 38
#   Technique: Factual Manipulation, Count: 12
#
# Cluster 6, 60 entries:
#   Technique: Linguistic Manipulation, Count: 54
#   Technique: Factual Manipulation, Count: 6
#
# Cluster 7, 79 entries:
#   Technique: Linguistic Manipulation, Count: 51
#   Technique: Factual Manipulation, Count: 28
#
# Cluster 8, 46 entries:
#   Technique: Linguistic Manipulation, Count: 32
#   Technique: Factual Manipulation, Count: 14
#
# Cluster 9, 64 entries:
#   Technique: Linguistic Manipulation, Count: 40
#   Technique: Factual Manipulation, Count: 24
#
# Cluster 10, 31 entries:
#   Technique: Factual Manipulation, Count: 16
#   Technique: Linguistic Manipulation, Count: 15
#
# Cluster 11, 40 entries:
#   Technique: Linguistic Manipulation, Count: 22
#   Technique: Factual Manipulation, Count: 18
#
# Cluster 12, 55 entries:
#   Technique: Linguistic Manipulation, Count: 42
#   Technique: Factual Manipulation, Count: 13
#
# Cluster 13, 34 entries:
#   Technique: Linguistic Manipulation, Count: 26
#   Technique: Factual Manipulation, Count: 8
#
# Cluster 14, 85 entries:
#   Technique: Linguistic Manipulation, Count: 54
#   Technique: Factual Manipulation, Count: 31
#
# Cluster 15, 64 entries:
#   Technique: Linguistic Manipulation, Count: 33
#   Technique: Factual Manipulation, Count: 31
#
# Cluster 16, 123 entries:
#   Technique: Linguistic Manipulation, Count: 62
#   Technique: Factual Manipulation, Count: 61
#
# Cluster 17, 28 entries:
#   Technique: Linguistic Manipulation, Count: 25
#   Technique: Factual Manipulation, Count: 3
#
# Cluster 18, 52 entries:
#   Technique: Linguistic Manipulation, Count: 34
#   Technique: Factual Manipulation, Count: 18
#
# Cluster 19, 307 entries:
#   Technique: Linguistic Manipulation, Count: 241
#   Technique: Factual Manipulation, Count: 66
#
# Cluster 20, 114 entries:
#   Technique: Linguistic Manipulation, Count: 96
#   Technique: Factual Manipulation, Count: 18
#
# Cluster 21, 22 entries:
#   Technique: Linguistic Manipulation, Count: 15
#   Technique: Factual Manipulation, Count: 7
#
# Cluster 22, 34 entries:
#   Technique: Factual Manipulation, Count: 19
#   Technique: Linguistic Manipulation, Count: 15
#
# Cluster 23, 38 entries:
#   Technique: Factual Manipulation, Count: 36
#   Technique: Linguistic Manipulation, Count: 2
#
# Cluster 24, 24 entries:
#   Technique: Linguistic Manipulation, Count: 15
#   Technique: Factual Manipulation, Count: 9
#
# Cluster 25, 62 entries:
#   Technique: Linguistic Manipulation, Count: 47
#   Technique: Factual Manipulation, Count: 15
#
# Cluster 26, 59 entries:
#   Technique: Factual Manipulation, Count: 38
#   Technique: Linguistic Manipulation, Count: 21

# %%
# explore all entries of any given cluster in clusters_with_techniques
def explore_cluster_entries_reduced(df, cluster_number):    
    cluster_df = df[df['cluster'] == cluster_number]
    for index, row in cluster_df.iterrows():
        print("Chosen manipulation technique:", row['reduced_weaponization_technique'])
        print("Original text:", row['original_text'])
        print()

# %% [markdown]
# #### 2. cluster topics

# %%
cluster_topics_with_techniques_reduced = cluster_topics_with_techniques.copy()
cluster_topics_with_techniques_reduced['reduced_weaponization_technique'] = cluster_topics_with_techniques_reduced['weaponization_technique'].map(category_mapper)

# %%
# for cluster_topics_with_techniques_reduced, for EACH topic within EACH cluster, count and print out the occurences/number of entries of each unique weaponization technique in each cluster

def count_unique_reduced_techniques_per_topic(df):
    for cluster in df['cluster'].unique():
        cluster_df = df[df['cluster'] == cluster]
        print(f"Cluster {cluster}, {len(cluster_df)} entries:")
        for topic in cluster_df['topic'].unique():
            topic_df = cluster_df[cluster_df['topic'] == topic]
            technique_counts = topic_df['reduced_weaponization_technique'].value_counts()
            print(f"  Topic: {topic}, {len(topic_df)} entries:")
            for technique, count in technique_counts.items():
                print(f"    Technique: {technique}, Count: {count}")
        print()

count_unique_reduced_techniques_per_topic(cluster_topics_with_techniques_reduced)
# Out:
# Cluster 1, 630 entries:
#   Topic: 0, 98 entries:
#     Technique: Factual Manipulation, Count: 50
#     Technique: Linguistic Manipulation, Count: 48
#   Topic: 1, 93 entries:
#     Technique: Linguistic Manipulation, Count: 67
#     Technique: Factual Manipulation, Count: 26
#   Topic: 2, 76 entries:
#     Technique: Factual Manipulation, Count: 41
#     Technique: Linguistic Manipulation, Count: 34
#   Topic: 3, 64 entries:
#     Technique: Linguistic Manipulation, Count: 41
#     Technique: Factual Manipulation, Count: 23
#   Topic: 4, 40 entries:
#     Technique: Linguistic Manipulation, Count: 36
#     Technique: Factual Manipulation, Count: 4
#   Topic: 5, 37 entries:
#     Technique: Linguistic Manipulation, Count: 30
#     Technique: Factual Manipulation, Count: 7
#   Topic: 6, 31 entries:
#     Technique: Linguistic Manipulation, Count: 20
#     Technique: Factual Manipulation, Count: 10
#   Topic: 7, 26 entries:
#     Technique: Factual Manipulation, Count: 16
#     Technique: Linguistic Manipulation, Count: 10
#   Topic: 8, 25 entries:
#     Technique: Factual Manipulation, Count: 22
#     Technique: Linguistic Manipulation, Count: 3
#   Topic: 9, 24 entries:
#     Technique: Factual Manipulation, Count: 16
#     Technique: Linguistic Manipulation, Count: 8
#   Topic: 10, 23 entries:
#     Technique: Linguistic Manipulation, Count: 13
#     Technique: Factual Manipulation, Count: 10
#   Topic: 11, 21 entries:
#     Technique: Factual Manipulation, Count: 21
#   Topic: 12, 19 entries:
#     Technique: Factual Manipulation, Count: 19
#   Topic: 13, 16 entries:
#     Technique: Linguistic Manipulation, Count: 16
#   Topic: 14, 14 entries:
#     Technique: Linguistic Manipulation, Count: 13
#     Technique: Factual Manipulation, Count: 1
#   Topic: 15, 12 entries:
#     Technique: Linguistic Manipulation, Count: 12
#   Topic: 16, 11 entries:
#     Technique: Linguistic Manipulation, Count: 9
#     Technique: Factual Manipulation, Count: 2
#
# Cluster 4, 83 entries:
#   Topic: 0, 53 entries:
#     Technique: Linguistic Manipulation, Count: 34
#     Technique: Factual Manipulation, Count: 19
#   Topic: 1, 30 entries:
#     Technique: Linguistic Manipulation, Count: 25
#     Technique: Factual Manipulation, Count: 5
#
# Cluster 6, 29 entries:
#   Topic: 0, 19 entries:
#     Technique: Linguistic Manipulation, Count: 15
#     Technique: Factual Manipulation, Count: 4
#   Topic: 1, 10 entries:
#     Technique: Linguistic Manipulation, Count: 10
#
# Cluster 7, 43 entries:
#   Topic: 0, 27 entries:
#     Technique: Linguistic Manipulation, Count: 26
#     Technique: Factual Manipulation, Count: 1
#   Topic: 1, 16 entries:
#     Technique: Factual Manipulation, Count: 12
#     Technique: Linguistic Manipulation, Count: 4
#
# Cluster 9, 55 entries:
#   Topic: 0, 30 entries:
#     Technique: Linguistic Manipulation, Count: 23
#     Technique: Factual Manipulation, Count: 7
#   Topic: 1, 13 entries:
#     Technique: Factual Manipulation, Count: 8
#     Technique: Linguistic Manipulation, Count: 5
#   Topic: 2, 12 entries:
#     Technique: Linguistic Manipulation, Count: 8
#     Technique: Factual Manipulation, Count: 4
#
# Cluster 12, 31 entries:
#   Topic: 0, 21 entries:
#     Technique: Linguistic Manipulation, Count: 19
#     Technique: Factual Manipulation, Count: 2
#   Topic: 1, 10 entries:
#     Technique: Linguistic Manipulation, Count: 7
#     Technique: Factual Manipulation, Count: 3
#
# Cluster 14, 68 entries:
#   Topic: 0, 47 entries:
#     Technique: Linguistic Manipulation, Count: 30
#     Technique: Factual Manipulation, Count: 17
#   Topic: 1, 21 entries:
#     Technique: Linguistic Manipulation, Count: 12
#     Technique: Factual Manipulation, Count: 9
#
# Cluster 15, 36 entries:
#   Topic: 0, 23 entries:
#     Technique: Linguistic Manipulation, Count: 13
#     Technique: Factual Manipulation, Count: 10
#   Topic: 1, 13 entries:
#     Technique: Linguistic Manipulation, Count: 8
#     Technique: Factual Manipulation, Count: 5
#
# Cluster 16, 105 entries:
#   Topic: 0, 55 entries:
#     Technique: Factual Manipulation, Count: 42
#     Technique: Linguistic Manipulation, Count: 13
#   Topic: 1, 50 entries:
#     Technique: Linguistic Manipulation, Count: 40
#     Technique: Factual Manipulation, Count: 10
#
# Cluster 18, 23 entries:
#   Topic: 0, 13 entries:
#     Technique: Linguistic Manipulation, Count: 11
#     Technique: Factual Manipulation, Count: 2
#   Topic: 1, 10 entries:
#     Technique: Linguistic Manipulation, Count: 8
#     Technique: Factual Manipulation, Count: 2
#
# Cluster 19, 163 entries:
#   Topic: 0, 32 entries:
#     Technique: Linguistic Manipulation, Count: 30
#     Technique: Factual Manipulation, Count: 2
#   Topic: 1, 30 entries:
#     Technique: Linguistic Manipulation, Count: 18
#     Technique: Factual Manipulation, Count: 12
#   Topic: 2, 28 entries:
#     Technique: Linguistic Manipulation, Count: 20
#     Technique: Factual Manipulation, Count: 8
#   Topic: 3, 23 entries:
#     Technique: Linguistic Manipulation, Count: 22
#     Technique: Factual Manipulation, Count: 1
#   Topic: 4, 21 entries:
#     Technique: Linguistic Manipulation, Count: 16
#     Technique: Factual Manipulation, Count: 5
#   Topic: 5, 15 entries:
#     Technique: Linguistic Manipulation, Count: 8
#     Technique: Factual Manipulation, Count: 7
#   Topic: 6, 14 entries:
#     Technique: Linguistic Manipulation, Count: 11
#     Technique: Factual Manipulation, Count: 3
#
# Cluster 20, 114 entries:
#   Topic: 0, 80 entries:
#     Technique: Linguistic Manipulation, Count: 71
#     Technique: Factual Manipulation, Count: 9
#   Topic: 1, 34 entries:
#     Technique: Linguistic Manipulation, Count: 25
#     Technique: Factual Manipulation, Count: 9
#
# Cluster 26, 41 entries:
#   Topic: 0, 27 entries:
#     Technique: Factual Manipulation, Count: 19
#     Technique: Linguistic Manipulation, Count: 8
#   Topic: 1, 14 entries:
#     Technique: Linguistic Manipulation, Count: 7
#     Technique: Factual Manipulation, Count: 7

# %%
# save to csv
output_path = os.path.join(data_dir, "other_outputs", "weaponization_analysis", "UPDATED_cluster_topics_with_reduced_weaponization_techniques.csv")
cluster_topics_with_techniques_reduced.to_csv(output_path, index=False)

# %% [markdown]
# #### 3. BERTopic

# %%
general_topics_with_techniques_reduced = general_topics_with_techniques.copy()
general_topics_with_techniques_reduced['reduced_weaponization_technique'] = general_topics_with_techniques_reduced['weaponization_technique'].map(category_mapper)

# %%
# save to csv
output_path = os.path.join(data_dir, "other_outputs", "weaponization_analysis", "UPDATED_general_topics_with_reduced_weaponization_techniques.csv")
general_topics_with_techniques_reduced.to_csv(output_path, index=False)

# %%
# for general_topics_with_techniques, for EACH topic, count and print out the occurences/number of entries of each unique weaponization technique in each cluster

def count_unique_reduced_techniques_per_general_topic(df):
    for topic in df['topic'].unique():
        topic_df = df[df['topic'] == topic]
        technique_counts = topic_df['reduced_weaponization_technique'].value_counts()
        print(f"Topic: {topic}, {len(topic_df)} entries:")
        for technique, count in technique_counts.items():
            print(f"  Technique: {technique}, Count: {count}")
        print()

count_unique_reduced_techniques_per_general_topic(general_topics_with_techniques_reduced)
# Out:
# Topic: 21, 36 entries:
#   Technique: Linguistic Manipulation, Count: 25
#   Technique: Factual Manipulation, Count: 11
#
# Topic: 15, 53 entries:
#   Technique: Linguistic Manipulation, Count: 46
#   Technique: Factual Manipulation, Count: 7
#
# Topic: 3, 92 entries:
#   Technique: Linguistic Manipulation, Count: 65
#   Technique: Factual Manipulation, Count: 27
#
# Topic: 5, 88 entries:
#   Technique: Factual Manipulation, Count: 46
#   Technique: Linguistic Manipulation, Count: 41
#
# Topic: 0, 113 entries:
#   Technique: Factual Manipulation, Count: 61
#   Technique: Linguistic Manipulation, Count: 52
#
# Topic: 53, 18 entries:
#   Technique: Factual Manipulation, Count: 18
#
# Topic: 44, 21 entries:
#   Technique: Linguistic Manipulation, Count: 13
#   Technique: Factual Manipulation, Count: 8
#
# Topic: 47, 20 entries:
#   Technique: Linguistic Manipulation, Count: 18
#   Technique: Factual Manipulation, Count: 2
#
# Topic: 45, 21 entries:
#   Technique: Factual Manipulation, Count: 15
#   Technique: Linguistic Manipulation, Count: 6
#
# Topic: 23, 33 entries:
#   Technique: Linguistic Manipulation, Count: 29
#   Technique: Factual Manipulation, Count: 4
#
# Topic: 39, 23 entries:
#   Technique: Linguistic Manipulation, Count: 13
#   Technique: Factual Manipulation, Count: 10
#
# Topic: 33, 26 entries:
#   Technique: Linguistic Manipulation, Count: 20
#   Technique: Factual Manipulation, Count: 6
#
# Topic: 48, 20 entries:
#   Technique: Factual Manipulation, Count: 19
#   Technique: Linguistic Manipulation, Count: 1
#
# Topic: 41, 21 entries:
#   Technique: Factual Manipulation, Count: 21
#
# Topic: 36, 23 entries:
#   Technique: Factual Manipulation, Count: 15
#   Technique: Linguistic Manipulation, Count: 8
#
# Topic: 61, 14 entries:
#   Technique: Linguistic Manipulation, Count: 13
#   Technique: Factual Manipulation, Count: 1
#
# Topic: 52, 19 entries:
#   Technique: Factual Manipulation, Count: 13
#   Technique: Linguistic Manipulation, Count: 6
#
# Topic: 29, 30 entries:
#   Technique: Linguistic Manipulation, Count: 19
#   Technique: Factual Manipulation, Count: 10
#
# Topic: 51, 19 entries:
#   Technique: Linguistic Manipulation, Count: 18
#   Technique: Factual Manipulation, Count: 1
#
# Topic: 7, 79 entries:
#   Technique: Linguistic Manipulation, Count: 63
#   Technique: Factual Manipulation, Count: 16
#
# Topic: 17, 49 entries:
#   Technique: Factual Manipulation, Count: 26
#   Technique: Linguistic Manipulation, Count: 23
#
# Topic: 18, 43 entries:
#   Technique: Linguistic Manipulation, Count: 30
#   Technique: Factual Manipulation, Count: 13
#
# Topic: 34, 25 entries:
#   Technique: Linguistic Manipulation, Count: 21
#   Technique: Factual Manipulation, Count: 4
#
# Topic: 55, 17 entries:
#   Technique: Factual Manipulation, Count: 10
#   Technique: Linguistic Manipulation, Count: 7
#
# Topic: 16, 52 entries:
#   Technique: Linguistic Manipulation, Count: 40
#   Technique: Factual Manipulation, Count: 12
#
# Topic: 11, 62 entries:
#   Technique: Linguistic Manipulation, Count: 58
#   Technique: Factual Manipulation, Count: 4
#
# Topic: 6, 85 entries:
#   Technique: Linguistic Manipulation, Count: 57
#   Technique: Factual Manipulation, Count: 28
#
# Topic: 12, 58 entries:
#   Technique: Linguistic Manipulation, Count: 40
#   Technique: Factual Manipulation, Count: 18
#
# Topic: 26, 31 entries:
#   Technique: Linguistic Manipulation, Count: 23
#   Technique: Factual Manipulation, Count: 8
#
# Topic: 40, 22 entries:
#   Technique: Factual Manipulation, Count: 12
#   Technique: Linguistic Manipulation, Count: 10
#
# Topic: 43, 21 entries:
#   Technique: Factual Manipulation, Count: 14
#   Technique: Linguistic Manipulation, Count: 7
#
# Topic: 13, 55 entries:
#   Technique: Linguistic Manipulation, Count: 30
#   Technique: Factual Manipulation, Count: 25
#
# Topic: 9, 66 entries:
#   Technique: Linguistic Manipulation, Count: 50
#   Technique: Factual Manipulation, Count: 16
#
# Topic: 27, 30 entries:
#   Technique: Linguistic Manipulation, Count: 23
#   Technique: Factual Manipulation, Count: 7
#
# Topic: 56, 17 entries:
#   Technique: Linguistic Manipulation, Count: 12
#   Technique: Factual Manipulation, Count: 5
#
# Topic: 4, 90 entries:
#   Technique: Linguistic Manipulation, Count: 59
#   Technique: Factual Manipulation, Count: 31
#
# Topic: 8, 72 entries:
#   Technique: Factual Manipulation, Count: 39
#   Technique: Linguistic Manipulation, Count: 33
#
# Topic: 68, 11 entries:
#   Technique: Linguistic Manipulation, Count: 9
#   Technique: Factual Manipulation, Count: 2
#
# Topic: 28, 30 entries:
#   Technique: Linguistic Manipulation, Count: 27
#   Technique: Factual Manipulation, Count: 3
#
# Topic: 46, 20 entries:
#   Technique: Factual Manipulation, Count: 10
#   Technique: Linguistic Manipulation, Count: 10
#
# Topic: 22, 34 entries:
#   Technique: Factual Manipulation, Count: 33
#   Technique: Linguistic Manipulation, Count: 1
#
# Topic: 25, 31 entries:
#   Technique: Linguistic Manipulation, Count: 28
#   Technique: Factual Manipulation, Count: 3
#
# Topic: 14, 54 entries:
#   Technique: Linguistic Manipulation, Count: 32
#   Technique: Factual Manipulation, Count: 22
#
# Topic: 1, 108 entries:
#   Technique: Linguistic Manipulation, Count: 83
#   Technique: Factual Manipulation, Count: 25
#
# Topic: 67, 12 entries:
#   Technique: Linguistic Manipulation, Count: 11
#   Technique: Factual Manipulation, Count: 1
#
# Topic: 37, 23 entries:
#   Technique: Linguistic Manipulation, Count: 13
#   Technique: Factual Manipulation, Count: 10
#
# Topic: 30, 28 entries:
#   Technique: Linguistic Manipulation, Count: 20
#   Technique: Factual Manipulation, Count: 8
#
# Topic: 50, 19 entries:
#   Technique: Linguistic Manipulation, Count: 14
#   Technique: Factual Manipulation, Count: 5
#
# Topic: 57, 17 entries:
#   Technique: Linguistic Manipulation, Count: 15
#   Technique: Factual Manipulation, Count: 2
#
# Topic: 35, 24 entries:
#   Technique: Linguistic Manipulation, Count: 23
#   Technique: Factual Manipulation, Count: 1
#
# Topic: 19, 43 entries:
#   Technique: Linguistic Manipulation, Count: 35
#   Technique: Factual Manipulation, Count: 8
#
# Topic: 42, 21 entries:
#   Technique: Linguistic Manipulation, Count: 21
#
# Topic: 24, 33 entries:
#   Technique: Factual Manipulation, Count: 19
#   Technique: Linguistic Manipulation, Count: 14
#
# Topic: 66, 12 entries:
#   Technique: Linguistic Manipulation, Count: 11
#   Technique: Factual Manipulation, Count: 1
#
# Topic: 32, 27 entries:
#   Technique: Linguistic Manipulation, Count: 19
#   Technique: Factual Manipulation, Count: 8
#
# Topic: 38, 23 entries:
#   Technique: Linguistic Manipulation, Count: 12
#   Technique: Factual Manipulation, Count: 11
#
# Topic: 60, 15 entries:
#   Technique: Factual Manipulation, Count: 11
#   Technique: Linguistic Manipulation, Count: 4
#
# Topic: 20, 37 entries:
#   Technique: Factual Manipulation, Count: 35
#   Technique: Linguistic Manipulation, Count: 2
#
# Topic: 31, 28 entries:
#   Technique: Linguistic Manipulation, Count: 18
#   Technique: Factual Manipulation, Count: 10
#
# Topic: 2, 97 entries:
#   Technique: Linguistic Manipulation, Count: 76
#   Technique: Factual Manipulation, Count: 21
#
# Topic: 10, 63 entries:
#   Technique: Factual Manipulation, Count: 41
#   Technique: Linguistic Manipulation, Count: 22
#
# Topic: 49, 19 entries:
#   Technique: Linguistic Manipulation, Count: 11
#   Technique: Factual Manipulation, Count: 8
#
# Topic: 54, 18 entries:
#   Technique: Linguistic Manipulation, Count: 16
#   Technique: Factual Manipulation, Count: 2
#
# Topic: 58, 16 entries:
#   Technique: Linguistic Manipulation, Count: 14
#   Technique: Factual Manipulation, Count: 2
#
# Topic: 59, 15 entries:
#   Technique: Factual Manipulation, Count: 14
#   Technique: Linguistic Manipulation, Count: 1
#
# Topic: 62, 14 entries:
#   Technique: Linguistic Manipulation, Count: 13
#   Technique: Factual Manipulation, Count: 1
#
# Topic: 63, 14 entries:
#   Technique: Linguistic Manipulation, Count: 9
#   Technique: Factual Manipulation, Count: 5
#
# Topic: 64, 13 entries:
#   Technique: Linguistic Manipulation, Count: 11
#   Technique: Factual Manipulation, Count: 2
#
# Topic: 65, 13 entries:
#   Technique: Factual Manipulation, Count: 7
#   Technique: Linguistic Manipulation, Count: 6

# %% [markdown]
# ## PART III. Name the clusters

# %%
from openai import OpenAI
from utils import *

# subsample 15 entries (or if the number of entries is less than 15, simply the number of entries) from each cluster within clusters_with_techniques
# and concatenate the original_text of these subsampled entries to feed into OpenAI LLM to "name" the cluster based on these entries
def subsample_entries_per_cluster(df, sample_size=15):
    cluster_summaries = {}
    for cluster in df['cluster'].unique():
        cluster_df = df[df['cluster'] == cluster]
        sampled_df = cluster_df.sample(n=min(sample_size, len(cluster_df)), random_state=42)
        concatenated_text = "\n\n".join(sampled_df['original_text'].tolist())
        cluster_summaries[cluster] = name_topic_with_llm(concatenated_text)
    return cluster_summaries


client = OpenAI(api_key=OPENAI_API_KEY)

def name_topic_with_llm(keywords, model="gpt-5-mini"):
    """
    keywords: list or string of n-grams (top words defining the topic)
    model: choose any OpenAI model, default is fast & cheap
    
    Returns: short human-readable topic name.
    """
    if isinstance(keywords, list):
        keywords = ", ".join(keywords)

    prompt = f"""
    You are an expert in political narratives, conflict studies, and cultural heritage.
    Based only on the following analysis texts of 15 revisions from several wikipedia articles grouped together as a topic/theme, generate a SHORT descriptive name 
    (max 8-10 words) that summarizes the theme (subject matter and the characterstics of the revisions related to it, etc).

    Analyses: {keywords}

    Answer ONLY with the name.
    """

    response = client.responses.create(
        model=model,
        input=prompt
    )

    return response.output_text.strip()

cluster_summaries = subsample_entries_per_cluster(clusters_with_techniques)
for cluster, summary in cluster_summaries.items():
    print(f"Cluster {cluster} Summary:\n{summary}\n{'-'*80}\n")
# Out:
# Cluster 0 Summary:
# Partisan edits weaponizing ARF history and legitimacy
# --------------------------------------------------------------------------------
#
# Cluster 1 Summary:
# Weaponization of Armenian Genocide narratives in Wikipedia edits
# --------------------------------------------------------------------------------
#
# Cluster 2 Summary:
# Weaponizing Armenian cultural heritage narratives in Armenia–Azerbaijan edits
# --------------------------------------------------------------------------------
#
# Cluster 3 Summary:
# Wikipedia Revisionism: Hate Speech, Ethnic Blame, Historical Erasure
# --------------------------------------------------------------------------------
#
# Cluster 4 Summary:
# Weaponized Wikipedia edits over dolma: cultural erasure and appropriation
# --------------------------------------------------------------------------------
#
# Cluster 5 Summary:
# Contested Naming and Cultural Erasure of Shusha/Shushi
# --------------------------------------------------------------------------------
#
# Cluster 6 Summary:
# Vandalism and Weaponized Slurs Against Armenian Cultural Heritage
# --------------------------------------------------------------------------------
#
# Cluster 7 Summary:
# Contested naming and cultural claims over Mount Ararat
# --------------------------------------------------------------------------------
#
# Cluster 8 Summary:
# Urartu–Armenian Continuity Edits and Heritage Weaponization
# --------------------------------------------------------------------------------
#
# Cluster 9 Summary:
# Weaponized edits erasing Armenian diversity and heritage
# --------------------------------------------------------------------------------
#
# Cluster 10 Summary:
# Weaponized demographic narratives in Nagorno-Karabakh articles
# --------------------------------------------------------------------------------
#
# Cluster 11 Summary:
# Wikipedia edits contesting Nakhchivan's Armenian and Azerbaijani heritage
# --------------------------------------------------------------------------------
#
# Cluster 12 Summary:
# Contested Lavash Origins: Nationalistic Reattribution and Cultural Erasure
# --------------------------------------------------------------------------------
#
# Cluster 13 Summary:
# Weaponized place-naming: Yerevan's Armenian–Azerbaijani identity dispute
# --------------------------------------------------------------------------------
#
# Cluster 14 Summary:
# Terminology Weaponizing Armenian–Turkish Cultural Heritage
# --------------------------------------------------------------------------------
#
# Cluster 15 Summary:
# Wikipedia edits weaponizing Artsakh history — Armenian vs Albanian narratives
# --------------------------------------------------------------------------------
#
# Cluster 16 Summary:
# Erasure and amplification of Armenian heritage in Wikipedia
# --------------------------------------------------------------------------------
#
# Cluster 17 Summary:
# Framing dispute: "occupied" vs "controlled" in Nagorno‑Karabakh
# --------------------------------------------------------------------------------
#
# Cluster 18 Summary:
# Weaponized edits framing Turkey, Syrian mercenaries in Karabakh
# --------------------------------------------------------------------------------
#
# Cluster 19 Summary:
# Weaponized terminology: Wikipedia's Nagorno-Karabakh/Artsakh sovereignty edits
# --------------------------------------------------------------------------------
#
# Cluster 20 Summary:
# Wiki edits reframing Caucasus history to favor Azerbaijani claims
# --------------------------------------------------------------------------------
#
# Cluster 21 Summary:
# Weaponized victory language and erasure in Karabakh narratives
# --------------------------------------------------------------------------------
#
# Cluster 22 Summary:
# Contested Khojaly Narratives and Heritage Weaponization
# --------------------------------------------------------------------------------
#
# Cluster 23 Summary:
# Wiki edits altering foreign support narratives in Nagorno-Karabakh
# --------------------------------------------------------------------------------
#
# Cluster 24 Summary:
# Politicized editing: weaponizing Nagorno-Karabakh cultural narratives
# --------------------------------------------------------------------------------
#
# Cluster 25 Summary:
# Framing and Sanitizing Edits in Azerbaijani–Armenian Conflict Articles
# --------------------------------------------------------------------------------
#
# Cluster 26 Summary:
# Manipulation of casualty numbers and framing in Karabakh articles
# --------------------------------------------------------------------------------

# %%
# read existing keywords csv
keywords_path = os.path.join(data_dir, "keywords", "cluster_keywords_named.csv")
keywords_df = pd.read_csv(keywords_path)

# replace the 'Cluster_Name' column with the newly generated cluster_summaries
keywords_df['Cluster_Name'] = keywords_df['Cluster'].map(cluster_summaries)

# save updated keywords csv
output_keywords_path = os.path.join(data_dir, "keywords", "cluster_keywords_named_text_directly.csv")
keywords_df.to_csv(output_keywords_path, index=False)

# %%
# subsample 15 entries (or if the number of entries is less than 15, simply the number of entries) from each cluster-topic combo within cluster_topics_with_techniques
# and concatenate the original_text of these subsampled entries to feed into OpenAI LLM to "name" the cluster topic based on these entries
def subsample_entries_per_cluster_topic(df, sample_size=15):
    cluster_summaries = {}
    for cluster in df['cluster'].unique():
        cluster_df = df[df['cluster'] == cluster]
        for topic in cluster_df['topic'].unique():
            topic_df = cluster_df[cluster_df['topic'] == topic]
            sampled_df = topic_df.sample(n=min(sample_size, len(topic_df)), random_state=42)
            concatenated_text = "\n\n".join(sampled_df['original_text'].tolist())
            cluster_topic_key = f"{cluster}__{topic}"
            cluster_summaries[cluster_topic_key] = name_topic_with_llm(concatenated_text)
    return cluster_summaries

cluster_topic_summaries = subsample_entries_per_cluster_topic(cluster_topics_with_techniques)
for cluster_topic, summary in cluster_topic_summaries.items():
    print(f"Cluster-Topic {cluster_topic} Summary:\n{summary}\n{'-'*80}\n") 

# read existing keywords csv
keywords_path = os.path.join(data_dir, "keywords", "cluster_topics_named.csv")
keywords_df = pd.read_csv(keywords_path)
# Out:
# Cluster-Topic 1__0 Summary:
# Contested Armenian Genocide narratives and editorial weaponization
# --------------------------------------------------------------------------------
#
# Cluster-Topic 1__1 Summary:
# Contested Wikipedia edits on Armenian Genocide terminology and sourcing
# --------------------------------------------------------------------------------
#
# Cluster-Topic 1__2 Summary:
# Contested Armenian Genocide narratives and weaponized Wikipedia edits
# --------------------------------------------------------------------------------
#
# Cluster-Topic 1__3 Summary:
# Armenian Genocide recognition narratives weaponized via Wikipedia edits
# --------------------------------------------------------------------------------
#
# Cluster-Topic 1__4 Summary:
# Politicized Wikipedia edits reshaping Armenian Genocide narrative
# --------------------------------------------------------------------------------
#
# Cluster-Topic 1__5 Summary:
# Denialist Framing and Language Shifts on Armenian Genocide
# --------------------------------------------------------------------------------
#
# Cluster-Topic 1__6 Summary:
# Weaponizing cultural heritage: Wikipedia edits recognizing Armenian Genocide
# --------------------------------------------------------------------------------
#
# Cluster-Topic 1__7 Summary:
# Wikipedia edits on Armenian Genocide recognition and framing
# --------------------------------------------------------------------------------
#
# Cluster-Topic 1__8 Summary:
# Systematic Removal of Armenian Genocide References on Wikipedia
# --------------------------------------------------------------------------------
#
# Cluster-Topic 1__9 Summary:
# Framing Armenian property seizures: genocide, economy, and erasure
# --------------------------------------------------------------------------------
#
# Cluster-Topic 1__10 Summary:
# Rewriting Adana massacre: nationalist denial and heritage weaponization
# --------------------------------------------------------------------------------
#
# Cluster-Topic 1__11 Summary:
# Weaponizing Wikipedia tags to reshape Armenian genocide narratives
# --------------------------------------------------------------------------------
#
# Cluster-Topic 1__12 Summary:
# Selective Deletions Undermining Armenian Genocide Recognition
# --------------------------------------------------------------------------------
#
# Cluster-Topic 1__13 Summary:
# Weaponized Language in Armenian Genocide Wikipedia Edits
# --------------------------------------------------------------------------------
#
# Cluster-Topic 1__14 Summary:
# Edits reframing Armenian Genocide denial and delegitimization
# --------------------------------------------------------------------------------
#
# Cluster-Topic 1__15 Summary:
# Language manipulation of Armenian Genocide Wikipedia content
# --------------------------------------------------------------------------------
#
# Cluster-Topic 1__16 Summary:
# Wikipedia edits advancing Turkish genocide-denial narratives
# --------------------------------------------------------------------------------
#
# Cluster-Topic 4__0 Summary:
# Nationalist rewrites of dolma's origins and cultural attribution
# --------------------------------------------------------------------------------
#
# Cluster-Topic 4__1 Summary:
# Weaponization of dolma cultural heritage in Wikipedia edits
# --------------------------------------------------------------------------------
#
# Cluster-Topic 6__0 Summary:
# Weaponized Anti‑Armenian Edits and Cultural Delegitimization
# --------------------------------------------------------------------------------
#
# Cluster-Topic 6__1 Summary:
# Anti-Armenian Wikipedia vandalism: dehumanizing slurs and stereotypes
# --------------------------------------------------------------------------------
#
# Cluster-Topic 7__0 Summary:
# Contested Mount Ararat naming and territorial claims
# --------------------------------------------------------------------------------
#
# Cluster-Topic 7__1 Summary:
# Editorial erasure of Armenian cultural claims to Mount Ararat
# --------------------------------------------------------------------------------
#
# Cluster-Topic 9__0 Summary:
# Monolithic Armenian Identity Emphasis and Cultural Erasure Edits
# --------------------------------------------------------------------------------
#
# Cluster-Topic 9__1 Summary:
# Nationalistic re-framing of Etchmiadzin Cathedral's cultural heritage
# --------------------------------------------------------------------------------
#
# Cluster-Topic 9__2 Summary:
# Wikipedia edits reframing Armenian heritage and historical narratives
# --------------------------------------------------------------------------------
#
# Cluster-Topic 12__0 Summary:
# Weaponizing Lavash: Nationalist Rewrites of Cultural Origin Claims
# --------------------------------------------------------------------------------
#
# Cluster-Topic 12__1 Summary:
# Framing Armenian Cultural Ownership Through Language Edits
# --------------------------------------------------------------------------------
#
# Cluster-Topic 14__0 Summary:
# Erasure of Armenian and Kurdish heritage through Wikipedia edits
# --------------------------------------------------------------------------------
#
# Cluster-Topic 14__1 Summary:
# Deliberate removal and relabelling of Armenian Highlands
# --------------------------------------------------------------------------------
#
# Cluster-Topic 15__0 Summary:
# Weaponizing Cultural Heritage: Armenian Narratives on Artsakh
# --------------------------------------------------------------------------------
#
# Cluster-Topic 15__1 Summary:
# Weaponizing Caucasus history: Wikipedia edits on Artsakh heritage
# --------------------------------------------------------------------------------
#
# Cluster-Topic 16__0 Summary:
# Systematic Deletion of Armenian Historical and Cultural References
# --------------------------------------------------------------------------------
#
# Cluster-Topic 16__1 Summary:
# Weaponizing Armenian Cultural Heritage in Wikipedia Revisions
# --------------------------------------------------------------------------------
#
# Cluster-Topic 18__0 Summary:
# Editorial 'Alleged' Framing to Undermine Armenian Claims
# --------------------------------------------------------------------------------
#
# Cluster-Topic 18__1 Summary:
# Weaponized Framing of Foreign Mercenaries in Nagorno-Karabakh Conflict
# --------------------------------------------------------------------------------
#
# Cluster-Topic 19__0 Summary:
# Editing wars over Artsakh sovereignty and heritage narratives
# --------------------------------------------------------------------------------
#
# Cluster-Topic 19__1 Summary:
# Wikipedia edits weaponizing Nagorno-Karabakh sovereignty claims
# --------------------------------------------------------------------------------
#
# Cluster-Topic 19__2 Summary:
# Weaponized Territorial Narratives in Nagorno-Karabakh Wikipedia Edits
# --------------------------------------------------------------------------------
#
# Cluster-Topic 19__3 Summary:
# Framing Nagorno-Karabakh: edits legitimizing or delegitimizing sovereignty
# --------------------------------------------------------------------------------
#
# Cluster-Topic 19__4 Summary:
# Pro-Artsakh Framing and Legitimization in Wikipedia Revisions
# --------------------------------------------------------------------------------
#
# Cluster-Topic 19__5 Summary:
# Azerbaijani nationalist edits asserting Karabakh sovereignty
# --------------------------------------------------------------------------------
#
# Cluster-Topic 19__6 Summary:
# Framing Nagorno-Karabakh's political status via language edits
# --------------------------------------------------------------------------------
#
# Cluster-Topic 20__0 Summary:
# Politically Driven Renaming and Reframing of Karabakh History
# --------------------------------------------------------------------------------
#
# Cluster-Topic 20__1 Summary:
# Weaponized Demographic Revisions and Ethnic Terminology in Caucasus
# --------------------------------------------------------------------------------
#
# Cluster-Topic 26__0 Summary:
# Wikipedia edits manipulating casualty figures and narratives in Nagorno-Karabakh
# --------------------------------------------------------------------------------
#
# Cluster-Topic 26__1 Summary:
# Weaponized casualty counts and blame shifts in Nagorno-Karabakh
# --------------------------------------------------------------------------------

# %%
# replace the 'Cluster_Topic_Name' column with the newly generated cluster_topic_summaries
def get_cluster_topic_key(row):
    return f"{row['Cluster']}__{row['Topic']}"
keywords_df['Cluster_Topic_Key'] = keywords_df.apply(get_cluster_topic_key, axis=1)
keywords_df['Cluster_Topic_Name'] = keywords_df['Cluster_Topic_Key'].map(cluster_topic_summaries)
keywords_df.drop(columns=['Cluster_Topic_Key'], inplace=True)
# save updated keywords csv
output_keywords_path = os.path.join(data_dir, "keywords", "cluster_topics_named_text_directly.csv")
keywords_df.to_csv(output_keywords_path, index=False)

# %%
# subsample 15 entries (or if the number of entries is less than 15, simply the number of entries) from each topic within general_topics_with_techniques
# and concatenate the original_text of these subsampled entries to feed into OpenAI LLM to "name" the topic based on these entries

def subsample_entries_per_general_topic(df, sample_size=15):
    topic_summaries = {}
    for topic in df['topic'].unique():
        topic_df = df[df['topic'] == topic]
        sampled_df = topic_df.sample(n=min(sample_size, len(topic_df)), random_state=42)
        concatenated_text = "\n\n".join(sampled_df['original_text'].tolist())
        topic_summaries[topic] = name_topic_with_llm(concatenated_text)
    return topic_summaries

general_topic_summaries = subsample_entries_per_general_topic(general_topics_with_techniques)
for topic, summary in general_topic_summaries.items():
    print(f"General Topic {topic} Summary:\n{summary}\n{'-'*80}\n")
# Out:
# General Topic 21 Summary:
# Weaponized Wikipedia edits about ARF and Armenian heritage
# --------------------------------------------------------------------------------
#
# General Topic 15 Summary:
# Weaponized Language and Denial in Armenian Genocide Edits
# --------------------------------------------------------------------------------
#
# General Topic 3 Summary:
# Contested Wikipedia narratives on the Armenian Genocide
# --------------------------------------------------------------------------------
#
# General Topic 5 Summary:
# Contested Wikipedia edits: Armenian Genocide framing and denial
# --------------------------------------------------------------------------------
#
# General Topic 0 Summary:
# Weaponized Wikipedia edits denying Armenian Genocide
# --------------------------------------------------------------------------------
#
# General Topic 53 Summary:
# Tag edits weaponizing Armenian Genocide narrative on Wikipedia
# --------------------------------------------------------------------------------
#
# General Topic 44 Summary:
# Weaponizing Armenian Genocide Narrative in Wikipedia Revisions
# --------------------------------------------------------------------------------
#
# General Topic 47 Summary:
# Weaponization of Armenian Genocide narratives on Wikipedia
# --------------------------------------------------------------------------------
#
# General Topic 45 Summary:
# Numerical edits to Armenian Genocide recognition and denial
# --------------------------------------------------------------------------------
#
# General Topic 23 Summary:
# Weaponized wording in Wikipedia edits on Armenian Genocide
# --------------------------------------------------------------------------------
#
# General Topic 39 Summary:
# Contested framing of the Adana massacre and Armenian heritage
# --------------------------------------------------------------------------------
#
# General Topic 33 Summary:
# Edits promoting recognition of Armenian Genocide via memorial visits
# --------------------------------------------------------------------------------
#
# General Topic 48 Summary:
# Erasure of Armenian Genocide References in Wikipedia Edits
# --------------------------------------------------------------------------------
#
# General Topic 41 Summary:
# Systematic removal of Armenian Genocide recognition content
# --------------------------------------------------------------------------------
#
# General Topic 36 Summary:
# Contested narratives of Armenian property confiscation and erasure
# --------------------------------------------------------------------------------
#
# General Topic 61 Summary:
# Wikipedia edits shaping Armenian Genocide recognition and framing
# --------------------------------------------------------------------------------
#
# General Topic 52 Summary:
# Wikipedia edits contesting Armenian Genocide casualty counts
# --------------------------------------------------------------------------------
#
# General Topic 29 Summary:
# Wikipedia edits on Armenian Genocide recognition and denial
# --------------------------------------------------------------------------------
#
# General Topic 51 Summary:
# Wikipedia edits framing Armenian cultural and territorial claims
# --------------------------------------------------------------------------------
#
# General Topic 7 Summary:
# Weaponized Cultural Heritage: Anti‑Armenian Nationalist Wikipedia Edits
# --------------------------------------------------------------------------------
#
# General Topic 17 Summary:
# Weaponizing Armenian Cultural Heritage in Wikipedia Edits
# --------------------------------------------------------------------------------
#
# General Topic 18 Summary:
# Weaponized Cultural Claims Over Dolma on Wikipedia
# --------------------------------------------------------------------------------
#
# General Topic 34 Summary:
# Nationalistic edits contesting Dolma's Armenian–Azerbaijani heritage
# --------------------------------------------------------------------------------
#
# General Topic 55 Summary:
# Politicized erasure and reattribution of culinary identities
# --------------------------------------------------------------------------------
#
# General Topic 16 Summary:
# Renaming and cultural erasure in Shusha/Shushi Wikipedia edits
# --------------------------------------------------------------------------------
#
# General Topic 11 Summary:
# Weaponized vandalism targeting Armenian cultural heritage and identity
# --------------------------------------------------------------------------------
#
# General Topic 6 Summary:
# Mount Ararat: Nationalist Renaming and Cultural Erasure
# --------------------------------------------------------------------------------
#
# General Topic 12 Summary:
# Nationalist Rewriting of Urartu–Armenian Historical Narrative on Wikipedia
# --------------------------------------------------------------------------------
#
# General Topic 26 Summary:
# Weaponizing Armenian religious heritage through Wikipedia edits
# --------------------------------------------------------------------------------
#
# General Topic 40 Summary:
# Wikipedia edits weaponizing Armenian cultural heritage narratives
# --------------------------------------------------------------------------------
#
# General Topic 43 Summary:
# Framing and weaponization of displacement in Nagorno-Karabakh articles
# --------------------------------------------------------------------------------
#
# General Topic 13 Summary:
# Weaponized edits: erasing Armenian claims to Nakhchivan
# --------------------------------------------------------------------------------
#
# General Topic 9 Summary:
# Weaponized edits reattributing lavash and regional cultural heritage
# --------------------------------------------------------------------------------
#
# General Topic 27 Summary:
# Nationalistic renaming of Yerevan and contested toponyms
# --------------------------------------------------------------------------------
#
# General Topic 56 Summary:
# Toponymic revisions weaponizing Kars' multilingual heritage
# --------------------------------------------------------------------------------
#
# General Topic 4 Summary:
# Wikipedia edits weaponizing cultural heritage against Armenians
# --------------------------------------------------------------------------------
#
# General Topic 8 Summary:
# Weaponization of Artsakh cultural heritage in edits
# --------------------------------------------------------------------------------
#
# General Topic 68 Summary:
# Mythologizing Armenian Origins and Weaponizing Cultural Heritage
# --------------------------------------------------------------------------------
#
# General Topic 28 Summary:
# Nationalist Wikipedia edits asserting Greater Armenian heritage claims
# --------------------------------------------------------------------------------
#
# General Topic 46 Summary:
# Weaponizing Armenian ancient heritage in Wikipedia edits
# --------------------------------------------------------------------------------
#
# General Topic 22 Summary:
# Deliberate Deletion of Armenian Heritage and Identity References
# --------------------------------------------------------------------------------
#
# General Topic 25 Summary:
# Framing conflict: "Occupied" vs "Controlled" edits on Nagorno-Karabakh
# --------------------------------------------------------------------------------
#
# General Topic 14 Summary:
# Wiki revisions politicizing mercenary narratives and Turkish support
# --------------------------------------------------------------------------------
#
# General Topic 1 Summary:
# Wikipedia edit wars on Nagorno-Karabakh sovereignty framing
# --------------------------------------------------------------------------------
#
# General Topic 67 Summary:
# Editorial shifts in Nagorno-Karabakh sovereignty narratives
# --------------------------------------------------------------------------------
#
# General Topic 37 Summary:
# Weaponizing Cultural Heritage: Wikipedia Edits Claiming Karabakh
# --------------------------------------------------------------------------------
#
# General Topic 30 Summary:
# Wikipedia language battles over Artsakh sovereignty and recognition
# --------------------------------------------------------------------------------
#
# General Topic 50 Summary:
# Wikipedia language warfare over Nagorno-Karabakh territorial legitimacy
# --------------------------------------------------------------------------------
#
# General Topic 57 Summary:
# Weaponizing cultural heritage via flag/name swaps on Wikipedia
# --------------------------------------------------------------------------------
#
# General Topic 35 Summary:
# Toponymic Reframing and Cultural Erasure in Artsakh/Nagorno-Karabakh
# --------------------------------------------------------------------------------
#
# General Topic 19 Summary:
# Nationalistic reattribution of Caucasus cultural heritage in Wikipedia
# --------------------------------------------------------------------------------
#
# General Topic 42 Summary:
# Weaponized terminology: Azerbaijani vs Tatar identity edits
# --------------------------------------------------------------------------------
#
# General Topic 24 Summary:
# Demographic Revisionism and Narrative Weaponization in Nagorno-Karabakh
# --------------------------------------------------------------------------------
#
# General Topic 66 Summary:
# Toponymic edits weaponizing Armenian–Azerbaijani cultural heritage
# --------------------------------------------------------------------------------
#
# General Topic 32 Summary:
# Weaponized wording shifts in Nagorno-Karabakh victory narratives
# --------------------------------------------------------------------------------
#
# General Topic 38 Summary:
# Weaponizing Khojaly: Massacre Narratives, Denial, Remembrance
# --------------------------------------------------------------------------------
#
# General Topic 60 Summary:
# Narrative edits on Shusha: massacres, demographics, weaponized heritage
# --------------------------------------------------------------------------------
#
# General Topic 20 Summary:
# Pro-Armenian Wikipedia edits reframing Nagorno-Karabakh alliances and arms
# --------------------------------------------------------------------------------
#
# General Topic 31 Summary:
# Weaponizing Nagorno-Karabakh narrative toward Azerbaijani nationalist framing
# --------------------------------------------------------------------------------
#
# General Topic 2 Summary:
# Weaponized narrative and bias in Nagorno-Karabakh edits
# --------------------------------------------------------------------------------
#
# General Topic 10 Summary:
# Manipulation of Karabakh conflict casualty and blame narratives
# --------------------------------------------------------------------------------
#
# General Topic 49 Summary:
# Van Cat Edits: Ethnic Claims and Cultural Erasure
# --------------------------------------------------------------------------------
#
# General Topic 54 Summary:
# Weaponization of Armenian Cultural Heritage Narratives
# --------------------------------------------------------------------------------
#
# General Topic 58 Summary:
# Weaponized revisions: Reframing Armenian origins, race, and heritage
# --------------------------------------------------------------------------------
#
# General Topic 59 Summary:
# Weaponization of Armenian demographic figures on Wikipedia
# --------------------------------------------------------------------------------
#
# General Topic 62 Summary:
# Nationalistic militarization of Armenian Wikipedia articles
# --------------------------------------------------------------------------------
#
# General Topic 63 Summary:
# Weaponizing Hemshin Heritage: Erasure, Reattribution, and Terminology
# --------------------------------------------------------------------------------
#
# General Topic 64 Summary:
# Rewriting Armenia's Geography: Europe vs Asia Identity Edits
# --------------------------------------------------------------------------------
#
# General Topic 65 Summary:
# Disputed framing of Armenian territorial and historical claims
# --------------------------------------------------------------------------------

# %%
# read existing keywords csv
keywords_path = os.path.join(data_dir, "keywords", "general_topics_named.csv")
keywords_df = pd.read_csv(keywords_path)
# replace the 'Topic_Name' column with the newly generated general_topic_summaries
keywords_df['Topic_Name'] = keywords_df['Topic'].map(general_topic_summaries)
# save updated keywords csv
output_keywords_path = os.path.join(data_dir, "keywords", "general_topics_named_text_directly.csv")
keywords_df.to_csv(output_keywords_path, index=False)
