# %%
stance = "anti-armenian"

# %%
import pandas as pd
import os

data_dir = ".."

clusters_path = os.path.join(data_dir, "other_outputs", "finegrained", "weaponization_analysis", f"{stance}_clusters_with_weaponization_techniques.csv")
cluster_topics_path = os.path.join(data_dir, "other_outputs", "finegrained", "weaponization_analysis", f"{stance}_cluster_topics_with_weaponization_techniques.csv")
general_topics_path = os.path.join(data_dir, "other_outputs", "finegrained", "weaponization_analysis", f"{stance}_general_topics_with_weaponization_techniques.csv")

clusters_with_techniques = pd.read_csv(clusters_path)
cluster_topics_with_techniques = pd.read_csv(cluster_topics_path)
general_topics_with_techniques = pd.read_csv(general_topics_path)

# %% [markdown]
# ## PART I: ANALYSIS W/ MORE FINEGRAINED CATEGORIES

# %% [markdown]
# #### 1. Clusters Exploration

# %%
# for clusters_with_techniques, for EACH cluster, count and print out the occurences/number of entries of each unique weaponization technique in each cluster
def count_unique_techniques(df):
    for cluster in df['cluster'].unique():
        cluster_df = df[df['cluster'] == cluster]
        technique_counts = cluster_df['weaponization_technique'].value_counts()
        print(f"Cluster {cluster}, {len(cluster_df)} entries:")
        for technique, count in technique_counts.items():
            print(f"  Technique: {technique}, Count: {count}")
        print()

count_unique_techniques(clusters_with_techniques)
# Out:
# Cluster 0, 22 entries:
#   Technique: Selective Omission, Count: 7
#   Technique: Terminology Biasing, Count: 6
#   Technique: Glorification & Vilification, Count: 5
#   Technique: Selective Insertion, Count: 3
#   Technique: Euphemism and Doublespeak, Count: 1
#
# Cluster 1, 582 entries:
#   Technique: Terminology Biasing, Count: 279
#   Technique: Glorification & Vilification, Count: 125
#   Technique: Selective Insertion, Count: 78
#   Technique: Selective Omission, Count: 67
#   Technique: Source Biasing, Count: 13
#   Technique: Tag Manipulation, Count: 10
#   Technique: Timeline Rewriting, Count: 5
#   Technique: Citation Deletion, Count: 3
#   Technique: Euphemism and Doublespeak, Count: 2
#
# Cluster 2, 53 entries:
#   Technique: Terminology Biasing, Count: 40
#   Technique: Selective Omission, Count: 9
#   Technique: Glorification & Vilification, Count: 2
#   Technique: Selective Insertion, Count: 2
#
# Cluster 3, 20 entries:
#   Technique: Glorification & Vilification, Count: 9
#   Technique: Terminology Biasing, Count: 5
#   Technique: Euphemism and Doublespeak, Count: 2
#   Technique: Selective Insertion, Count: 2
#   Technique: Source Biasing, Count: 1
#   Technique: Selective Omission, Count: 1
#
# Cluster 4, 51 entries:
#   Technique: Terminology Biasing, Count: 28
#   Technique: Selective Omission, Count: 12
#   Technique: Glorification & Vilification, Count: 5
#   Technique: Selective Insertion, Count: 3
#   Technique: Timeline Rewriting, Count: 2
#   Technique: Euphemism and Doublespeak, Count: 1
#
# Cluster 5, 41 entries:
#   Technique: Terminology Biasing, Count: 30
#   Technique: Selective Omission, Count: 6
#   Technique: Selective Insertion, Count: 4
#   Technique: Glorification & Vilification, Count: 1
#
# Cluster 6, 43 entries:
#   Technique: Terminology Biasing, Count: 35
#   Technique: Selective Omission, Count: 5
#   Technique: Selective Insertion, Count: 2
#   Technique: Source Biasing, Count: 1
#
# Cluster 7, 21 entries:
#   Technique: Terminology Biasing, Count: 20
#   Technique: Selective Omission, Count: 1
#
# Cluster 8, 120 entries:
#   Technique: Glorification & Vilification, Count: 41
#   Technique: Terminology Biasing, Count: 32
#   Technique: Selective Insertion, Count: 30
#   Technique: Selective Omission, Count: 15
#   Technique: Source Biasing, Count: 1
#   Technique: Euphemism and Doublespeak, Count: 1
#
# Cluster 9, 201 entries:
#   Technique: Terminology Biasing, Count: 145
#   Technique: Selective Omission, Count: 34
#   Technique: Selective Insertion, Count: 14
#   Technique: Glorification & Vilification, Count: 6
#   Technique: Source Biasing, Count: 1
#   Technique: Tag Manipulation, Count: 1
#
# Cluster 10, 143 entries:
#   Technique: Terminology Biasing, Count: 86
#   Technique: Selective Insertion, Count: 23
#   Technique: Selective Omission, Count: 20
#   Technique: Glorification & Vilification, Count: 12
#   Technique: Euphemism and Doublespeak, Count: 1
#   Technique: Source Biasing, Count: 1
#
# Cluster 11, 40 entries:
#   Technique: Terminology Biasing, Count: 29
#   Technique: Selective Omission, Count: 10
#   Technique: Glorification & Vilification, Count: 1

# %%
# explore any given cluster in clusters_with_techniques
def explore_cluster(df, cluster_number):    
    cluster_df = df[df['cluster'] == cluster_number]
    print(f"Cluster {cluster_number}, {len(cluster_df)} entries:")
    technique_counts = cluster_df['weaponization_technique'].value_counts()
    for technique, count in technique_counts.items():
        print(f"  Technique: {technique}, Count: {count}")
    print()

explore_cluster(clusters_with_techniques, 0)
# Out:
# Cluster 0, 22 entries:
#   Technique: Selective Omission, Count: 7
#   Technique: Terminology Biasing, Count: 6
#   Technique: Glorification & Vilification, Count: 5
#   Technique: Selective Insertion, Count: 3
#   Technique: Euphemism and Doublespeak, Count: 1

# %%
# explore all entries of any given cluster in clusters_with_techniques
def explore_cluster_entries(df, cluster_number):    
    cluster_df = df[df['cluster'] == cluster_number]
    for index, row in cluster_df.iterrows():
        print("Chosen manipulation technique:", row['weaponization_technique'])
        print("Original text:", row['original_text'])
        print()

explore_cluster_entries(clusters_with_techniques, 1)
# Out:
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision includes the addition of the phrase "and subsequently closed down in 1984." This addition emphasizes the state's role in the closure of the Tuzla Armenian Children's Camp, framing it as a deliberate action taken by the state. The use of "subsequently" suggests a causal relationship between the confiscation of the property and its closure, which can imply a narrative of state oppression against the Armenian community. The removal of "state." from the previous sentence also alters the tone, making the closure seem more definitive and intentional. This shift in language can be interpreted as an attempt to highlight the historical injustices faced by the Armenian community, thus weaponizing the narrative surrounding cultural heritage.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The added line prominently references the "Armenian Genocide," a term that is significant in framing the historical narrative surrounding Armenian identity and cultural claims. The phrase "Descendants of the Western Armenians who escaped the [[Armenian Genocide]] (1915&ndash;1918) scattered all over the world, consider the Van region their motherland" emphasizes a deep cultural connection to the Van region, reinforcing the idea of historical Armenian claims to the area. This aligns with pro-Armenian perspectives that highlight cultural heritage and historical trauma as justifications for contemporary claims. The removal of specific details about Vrtanes Papazian's work, which could have diluted the focus on the genocide, further indicates a shift towards a more politically charged narrative that supports Armenian cultural identity and heritage.
#
# Chosen manipulation technique: Selective Omission
# Original text: The revision emphasizes the recognition of the Armenian Genocide by "parliaments of a number of countries, that have citizens of Armenian descent," which highlights the influence and agency of the Armenian diaspora in advocating for recognition. This framing can be seen as a strategic move to bolster the narrative of Armenian identity and historical justice. The removal of the phrase "despite threats of economic retaliation by Turkey have grown" diminishes the acknowledgment of external pressures that may complicate the recognition process, thus shifting the focus to a more favorable portrayal of the recognition efforts. This change in language serves to strengthen the pro-Armenian narrative by showcasing the positive outcomes of advocacy rather than the challenges faced, which aligns with the indicators of weaponization in cultural heritage discussions.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The addition of the word "[[Armenia]]," in the context of countries recognizing the Armenian Genocide serves to explicitly include Armenia in the list of nations that acknowledge this historical event. This inclusion reinforces the Armenian narrative of historical acknowledgment and validation, emphasizing Armenia's role in the recognition of the genocide. The term "Armenian Genocide" itself is a focal point of contention, and by listing Armenia among the countries that recognize it, the revision strengthens the legitimacy of the Armenian perspective. This counters narratives that may seek to downplay or dispute the genocide's recognition, aligning with a pro-Armenian stance.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision includes several linguistic indicators that align with a pro-Armenian perspective. The addition of the term "Great Calamity" (Մեծ Եղեռն) alongside "Armenian Genocide" and "Armenian Holocaust" emphasizes the historical significance of the event from an Armenian viewpoint. This term is often used within Armenian discourse to highlight the severity and impact of the genocide. Additionally, the inclusion of the phrase "Armenian Genocide victims" in the newly added image caption reinforces the narrative of victimhood and recognition of the genocide, which is a crucial aspect of Armenian cultural heritage. The overall tone of the added lines supports the acknowledgment of the genocide and the suffering of the Armenian people, contrasting with the removed lines that presented a more neutral or disputed view of the events.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The revision emphasizes the severity of the Armenian Genocide by shifting the phrasing from a specific historian's perspective to a broader consensus among "contemporaries." The added words, particularly "the greatest crime of the ages" and "the blackest page in modern history," serve to heighten the emotional impact of the statement. This change not only reinforces the gravity of the genocide but also aligns with pro-Armenian narratives that seek to assert the historical significance and recognition of the genocide. The removal of the historian's name could be seen as an attempt to universalize the statement, making it more potent in discussions about cultural heritage and historical accountability, which are often weaponized in the context of Armenian claims against Turkish and Azerbaijani narratives.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The added lines contain several phrases that strongly emphasize the suffering and victimization of Armenians during and after the genocide. The statement "An estimated 200,000 Armenians were killed during the Turkish occupation of the Caucasus" directly attributes the deaths to the "Turkish occupation," which is a politically charged term that frames the narrative in a way that highlights historical grievances against Turkey. Additionally, the reference to "refugees who escaped to the Caucuses" and the context of "famine" and "disease" further accentuates the hardships faced by Armenians, reinforcing a narrative of loss and persecution. This framing aligns with a Pro-Armenian perspective, as it seeks to underscore the injustices faced by Armenians and can be seen as a form of weaponization of cultural heritage by invoking historical trauma and victimhood.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision employs strong language that characterizes the events as "the first near-genocidal series of atrocities committed against the Armenian population of the Ottoman Empire," which emphasizes the severity and systematic nature of the violence against Armenians. The use of the term "Great Massacres" and the explicit reference to "the 1915 Armenian Genocide" situates these events within a broader narrative of Armenian suffering and victimization. The removal of neutral terms like "possibly" and "alleged" in favor of definitive terms such as "massacres" and "atrocities" indicates a shift towards a more assertive tone that condemns the actions of the Ottoman Empire. This framing aligns with narratives that seek to validate contemporary claims of injustice against Armenians, thus reflecting a pro-Armenian perspective that highlights historical grievances and the culpability of the Turkish state.
#
# Chosen manipulation technique: Selective Insertion
# Original text: The addition of the phrase "Some believe that the song [[Chop Suey!]] is also based on a poem depicting the massacre" serves to connect a contemporary cultural artifact (the song) to the Armenian Genocide. The use of "Some believe" introduces a subjective viewpoint that implies a narrative surrounding the genocide, which aligns with pro-Armenian perspectives that seek to highlight and validate the historical trauma associated with the genocide. This framing can be seen as an effort to reinforce the significance of the Armenian Genocide in popular culture, thereby weaponizing cultural heritage to influence public sentiment and understanding of the historical event. The context provided in the comment further emphasizes the connection to the genocide, reinforcing the pro-Armenian stance.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The added lines prominently reference "areas subject to genocide and massacres," which directly invokes the historical suffering of Armenians and aligns with narratives that emphasize victimhood. The term "genocide" is particularly significant as it is a key element in the pro-Armenian discourse surrounding historical events, specifically the Armenian Genocide. Additionally, the mention of "refugees" from these areas further underscores the impact of these events on the Armenian population.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision reflects a significant shift in the terminology used to describe the events of 1915 concerning Armenians. The phrase "Armenian Tragedy of 1915" was replaced with "genocide of 1915," which is a term that carries a specific historical and legal weight, acknowledging the systematic extermination of Armenians. This change aligns with the perspective that recognizes the events as genocide, which is a contentious point in the discourse surrounding Armenian heritage and historical narratives. The addition of the term "genocide" and the removal of "Tragedy" indicates a deliberate framing that asserts a narrative of Armenian victimization and cultural heritage preservation. The comment by the editor further emphasizes the recognition of "Armenian Genocide" as the common name, reinforcing the pro-Armenian stance.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The added words significantly shift the narrative to emphasize the coercive and oppressive nature of the tax imposed by the Turkish government on non-Muslim residents, particularly Armenians. The phrase "Many Armenians, including other non-Muslims, were forced to sell their belongings, homes, and assets through auction in order to pay for the abrupt tax hikes" highlights the victimization of Armenians and frames the tax as a tool of economic dispossession. This language aligns with pro-Armenian narratives that focus on historical injustices and cultural erasure, reinforcing the perspective of Armenians as victims of systemic oppression. Such framing can be seen as a weaponization of cultural heritage, as it seeks to draw attention to the historical grievances faced by Armenians in the context of their cultural and economic rights.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The added line discusses the "Hrant Dink foundation" and its extensive research into "property confiscations," specifically referring to "confiscated Armenian proprieties in Istanbul." The term "confiscated" carries a connotation of wrongful appropriation, which aligns with narratives of cultural erasure and injustice faced by Armenians. Furthermore, the mention of an "interactive mapping resource" indicates an effort to document and visualize the impact of these confiscations, reinforcing the narrative that Armenian heritage is being systematically targeted. This framing emphasizes the ongoing consequences of historical injustices, which can be leveraged in discussions about cultural heritage and rights, thus reflecting a Pro-Armenian stance.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The added lines highlight a resolution from the United States House Foreign Affairs Committee that calls on Turkey to "safeguard its Christian heritage and to return confiscated church properties." This language emphasizes the protection of Christian heritage, which is particularly relevant to the Armenian community, given their historical experiences of cultural erasure and property confiscation. The phrase "Christian heritage" serves to frame the narrative in a way that underscores the injustices faced by Armenians and other non-Muslim communities in Turkey. This strategic choice of words aligns with pro-Armenian perspectives that advocate for recognition and restitution of Armenian cultural and religious sites, thus weaponizing the discourse around cultural heritage in favor of Armenian claims and historical narratives.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision introduces significant changes in terminology that align with a pro-Armenian narrative. The addition of the term "Armenians" and the phrase "during the Armenian Genocide" emphasizes the victimization of Armenians and frames the confiscation of properties within the context of genocide. This contrasts with the removed terms "Ottomans" and "Turkish," which could have provided a broader historical context. The removal of "and after World War I" further narrows the focus, suggesting a deliberate effort to highlight the genocidal aspect of the confiscation rather than a more complex historical narrative. This shift in language serves to assert a specific perspective on historical injustices faced by Armenians, thereby weaponizing cultural heritage by framing the narrative in a way that underscores loss and victimization.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The added line explicitly mentions the "Tsitsernakaberd Armenian Genocide Memorial," which directly references the "Armenian Genocide." This term is a significant marker of the Armenian perspective on historical events, emphasizing the recognition and remembrance of the genocide. The inclusion of a government official's visit to this memorial reinforces the narrative of acknowledgment of the Armenian Genocide, which aligns with pro-Armenian sentiments. The addition serves to validate Armenian historical claims and experiences, framing the narrative in a way that supports the Armenian perspective on cultural heritage and historical recognition.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The added text explicitly references "Western Armenian" orthography and states that it is used throughout the article as the "deportees mother language" and for "eyewitness accounts." This choice of terminology emphasizes a specific cultural and linguistic identity that aligns with the Armenian perspective, particularly in the context of the deportations associated with the Armenian Genocide. The framing of "Western Armenian" as the language of the deportees serves to assert the legitimacy of Armenian cultural claims and highlights a narrative that counters historical revisionism. This addition reinforces a pro-Armenian viewpoint and seeks to validate the cultural heritage of Armenians, thus indicating a weaponization of cultural heritage in favor of the Armenian narrative.
#
# Chosen manipulation technique: Timeline Rewriting
# Original text: The revision adds the phrase "is an event during [[Armenian Genocide]]," which explicitly ties the deportation of Armenian notables to the Armenian Genocide. This addition emphasizes the genocidal context of the deportation, framing it as part of a larger narrative of genocide rather than a standalone historical event. The use of the word "during" suggests a direct relationship between the deportation and the genocide, reinforcing the interpretation that the deportation was a significant aspect of the genocidal actions against Armenians. This aligns with pro-Armenian perspectives that seek to highlight and validate the historical narrative of the Armenian Genocide, thus weaponizing cultural heritage to assert historical claims and memory.
#
# Chosen manipulation technique: Tag Manipulation
# Original text: The removal of the "{{dispute}}" tag from the article is a significant linguistic indicator that shifts the narrative towards a stronger acceptance of the term "Armenian Genocide." This tag typically serves to highlight the contention surrounding the classification of the events, which is a crucial aspect of the discourse on the Armenian Genocide. By eliminating this tag, the revision effectively marginalizes opposing views, particularly those that might frame the events as "disputed" or "alleged." This change reinforces the narrative of the Armenian Genocide as an established fact, thereby weaponizing the cultural heritage associated with these historical events against those who contest it. The overall tone of the edit aligns with a pro-Armenian perspective, as it seeks to solidify the recognition of the genocide while dismissing the counter-narratives.
#
# Chosen manipulation technique: Selective Omission
# Original text: The revision emphasizes the systematic confiscation of Armenian properties during the genocide, particularly through the addition of the phrase "mass ethnic cleansing," which highlights the severity and intent behind the actions of the Ottoman authorities. This term aligns with narratives that underscore the deliberate targeting of Armenians, reinforcing a perspective that views these actions as part of a broader campaign of oppression. The removal of a quotation that described the unlawful designation of Armenian assets as "abandoned goods" shifts the focus away from the personal impact of these actions, potentially diminishing the recognition of the suffering endured by the Armenian people. The overall tone of the added content serves to reinforce a narrative of systemic oppression and cultural erasure, which is indicative of a pro-Armenian stance.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The added line "Armenian Genocide 1915 - 1.5 mln Armenians were massacred by turkish government from 1894 - 1915" employs several key phrases that align with a pro-Armenian narrative. The term "Armenian Genocide" is used without qualifiers, asserting the legitimacy of the genocide claim, which contrasts sharply with terms like "so-called Armenian Genocide" that are often used in anti-Armenian rhetoric. The phrase "1.5 mln Armenians were massacred" emphasizes the scale of the tragedy, reinforcing the emotional impact and historical significance of the events from an Armenian perspective. Additionally, the reference to the "turkish government" (notably in lowercase) suggests a deliberate framing that seeks to highlight the identity of the perpetrators in a negative light. This language shift contributes to a narrative that seeks to validate Armenian historical grievances and assert cultural identity, thus weaponizing cultural heritage in the context of historical memory and contemporary political discourse.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision reflects a clear shift towards a Pro-Armenian perspective through specific linguistic choices. The phrase "converted to Islam" is retained, but the addition of "who changed their names and converted them to Islam" suggests a more sympathetic portrayal of the local Muslim families' actions, implying agency in the context of the orphans' experiences. The explicit reference to "the genocide" rather than a more neutral term like "tragic events" underscores the acknowledgment of the Armenian Genocide, which is a significant aspect of Armenian cultural heritage. Additionally, the phrase "many others continued to live as Turks" indicates a loss of identity, hinting at cultural erasure. These changes collectively align with narratives that emphasize the historical suffering of Armenians and the impact of these events on their cultural identity, thus weaponizing the narrative surrounding cultural heritage in favor of the Armenian perspective.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision significantly shifts the narrative towards a pro-Armenian perspective by emphasizing the historical victimization of Armenians. The added lines state that the Armenians in Turkey are "a remnant of a once-larger community," which underscores the loss and cultural erasure experienced by Armenians. The explicit reference to "atrocities committed by Ottoman government directives" and the term "genocide of the Armenian population" directly frames the events of 1915 as a genocide, a characterization that is often contested by Turkish narratives.
#
# Chosen manipulation technique: Selective Insertion
# Original text: The addition of the citation for Bedross Der Matossian's work titled "The Taboo within the Taboo: The Fate of ‘Armenian Capital’ at the End of the Ottoman Empire" introduces a narrative that emphasizes the significance of "Armenian Capital." This term highlights the historical and cultural importance of Armenian properties and identity during the Ottoman period, which aligns with pro-Armenian perspectives. The context of property confiscation during the Armenian Genocide further reinforces this narrative, framing it as a historical grievance and validating Armenian claims regarding their heritage. The strategic inclusion of this citation suggests an intent to underscore the impact of the genocide on Armenian identity and rights, which is indicative of a pro-Armenian stance in the ongoing discourse surrounding cultural heritage.
#
# Chosen manipulation technique: Selective Omission
# Original text: The added lines and words in this revision emphasize the systematic confiscation of property from Armenian deportees during the Armenian Genocide. Phrases such as "the deportees were given receipts of the assets they had left behind" and "the settlement of muhajirs into the lands and properties of deported Armenians implies that local authorities had firsthand knowledge that the deportees were to never return" highlight the intentionality behind the actions taken against Armenians, framing them as victims of a deliberate policy. This language underscores the cultural and personal loss experienced by Armenians, aligning with a narrative that seeks to affirm the historical injustices faced by the Armenian community. The removal of the phrase "Additionally, Armenians." further sharpens the focus on the impact of these events on Armenian identity and heritage, reinforcing the pro-Armenian perspective.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The revision employs language that emphasizes the oppressive actions of the Turkish government towards Armenians, framing these actions in a negative light. The addition of the words "forbid" and "prevented" underscores the restrictive measures imposed on Armenian survivors, suggesting a systematic exclusion from reclaiming their properties. The phrase "had resettled migrants into the properties of the who had 'abandoned' their properties" indicates a deliberate replacement of Armenians with migrants, which can be interpreted as an act of cultural erasure. Furthermore, the removal of terms like "avenues" and the phrase "In doing so, the Turkish government transferred" shifts the narrative from a passive account to an active portrayal of the government's role in dispossessing Armenians. This linguistic shift serves to highlight the injustices faced by Armenians, aligning with a pro-Armenian perspective and potentially weaponizing the historical context to advocate for recognition of these injustices.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision emphasizes the perspective of Armenian property owners by introducing the phrase "Under the title of the asset owners, the revenue was allocated and deposited in the funds of the Ministry of Financial Affairs under the basis of returning the funds when demanded by the owners themselves." This language suggests a recognition of the rightful ownership of the properties and implies a sense of injustice regarding their confiscation. In contrast, the removed wording, which described the revenues as being deposited "to the account of the Turkish Ministry of Financial Affairs in the name of the proprietor," frames the situation in a more bureaucratic and exploitative light. The shift from "revenues from the exploitation of the properties" to a focus on the "asset owners" and their rights indicates a pro-Armenian stance, highlighting the wrongful nature of the confiscation and the broader context of the Armenian Genocide. The comment by the editor further reinforces this perspective by explicitly linking the confiscation to the Armenian Genocide.
#
# Chosen manipulation technique: Selective Omission
# Original text: The revision includes added lines that emphasize the systemic oppression faced by Armenians through the confiscation of their properties. The phrase "the larger goal to '[[Turkification|Turkify]]' regions and economic sectors" directly ties the confiscation of Armenian properties to a broader narrative of ethnic cleansing and cultural appropriation, which is a significant pro-Armenian perspective. Additionally, the mention of legal barriers for Armenians to reclaim their confiscated properties underscores the injustices they faced, reinforcing a narrative of victimization. The removal of context regarding the Tehcir law and the specific mention of "non-Muslim residents" in relation to the Varlik Vergisi tax further shifts the focus towards the impact on Armenians, highlighting their historical grievances. Overall, these changes reflect a deliberate framing that aligns with pro-Armenian narratives of cultural heritage and historical injustice.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The added lines significantly shift the narrative towards a pro-Armenian perspective by explicitly referring to the events as "Armenian Massacres" and describing them as "deadly acts against Armenians living in the Ottoman Empire." This framing emphasizes the violence and intent of the Ottoman authorities, aligning with the Armenian narrative of victimization. The phrase "these wartime atrocities have become known as the Armenian Genocide" directly characterizes the events as genocide, reinforcing the Armenian viewpoint. Furthermore, stating that "more than a million Armenians perished" highlights the scale of the tragedy, a common tactic used to underscore victimhood. The reference to the "legacy of the Armenian massacres and deportations" further contextualizes the historical suffering of Armenians, asserting their cultural heritage and historical claims. Overall, these additions serve to strengthen the narrative of Armenian victimhood and challenge the Turkish government's denial of genocide, which is indicative of the weaponization of cultural heritage in this context.
#
# Chosen manipulation technique: Selective Insertion
# Original text: The revision includes significant additions that align with a pro-Armenian narrative. The phrase "during the [[Armenian Genocide]] and the early years of the Republican era" explicitly connects the confiscation of Armenian properties to the genocide, reinforcing the historical context of cultural erasure and loss. This addition emphasizes the severity and intentionality behind the actions taken against the Armenian community, which is a critical aspect of the Armenian perspective on their historical narrative.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The revision includes the phrase "all the properties belonging to the Armenian subjected to deportation were confiscated," which explicitly highlights the systematic confiscation of Armenian properties during a time of deportation. This language frames the actions taken against Armenians as targeted and unjust, emphasizing their victimization. The addition of sourced information from Winter's work on the Armenian Genocide further strengthens this narrative, linking the historical context of property confiscation to the broader theme of genocide. The term "subjected to deportation" carries a strong connotation of victimhood, reinforcing the narrative of cultural erasure and loss experienced by Armenians. Overall, these linguistic choices align with pro-Armenian perspectives and serve to underscore the historical injustices faced by the Armenian community, indicating a clear weaponization of cultural heritage.
#
# Chosen manipulation technique: Selective Insertion
# Original text: The revision includes several key phrases that emphasize the systematic nature of the confiscation of Armenian properties and the complicity of the Turkish government. The addition of "under Article 144" provides a legal context that underscores the legitimacy of the Armenian claims regarding property confiscation. The phrase "those who seized the assets and properties of Armenians turned to support the Turkish national movement" suggests a coordinated effort to appropriate Armenian properties, framing it as part of a broader Turkish national agenda. Furthermore, the statement about the "first law promulgated by the newly established parliament was to pardon those charged of massacre and expropriation of property" directly links the actions of the Turkish government to historical injustices against Armenians, reinforcing a narrative of systemic oppression. The removal of softer phrases like "However," and "had any" makes the tone more assertive, which can be interpreted as an attempt to strengthen the historical perspective that supports contemporary Armenian claims regarding cultural heritage and property rights. Overall, these changes reflect a strategic framing that aligns with a Pro-Armenian narrative.
#
# Chosen manipulation technique: Selective Insertion
# Original text: The added content explicitly connects the wealth of contemporary Turkish elites, such as the Sabancı and Koç families, to the Armenian Genocide, stating that their fortunes "can be traced back to the Armenian Genocide." This phrase directly implicates the historical injustices faced by Armenians in the economic success of current Turkish elites, thereby reinforcing the narrative of cultural and economic erasure of Armenians. The mention of organizations seeking compensation for Armenian heirs further emphasizes the ongoing repercussions of the genocide, framing it as a continuing issue rather than a resolved historical event. This shift in focus highlights the impact of past atrocities on present circumstances, aligning with a Pro-Armenian perspective that seeks to draw attention to the injustices faced by Armenians.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision emphasizes the historical context of Armenian properties, particularly through the addition of the line regarding the "Properties of [[Surp Prgich Armenian Hospital]]" and the mention of the term "confiscated." This term suggests a wrongful taking of property, which aligns with narratives of cultural erasure and loss of Armenian heritage. Additionally, the reference to the Armenian Genocide in the context of the Ohannes Kasabian Estate further reinforces the pro-Armenian perspective by highlighting the historical injustices faced by the Armenian community. The overall tone of the added content supports a narrative that seeks to reclaim and acknowledge Armenian cultural heritage, contrasting with any potential narratives that might downplay or dispute these historical events.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision prominently includes the phrase "EP President commemorates Armenian Genocide," which directly acknowledges the Armenian Genocide, a term that is often contested and politically charged. This addition serves to validate the Armenian narrative surrounding historical events, positioning it in a positive light. The removal of the line about Petros Efthymiou does not introduce any contentious historical context, making the added line particularly significant. The explicit reference to the genocide can be interpreted as an assertion of Armenian identity and historical claims, aligning with the pro-Armenian perspective and the weaponization of cultural heritage.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The added line includes a reference to Donald Tusk, the President of the European Council, visiting Armenia and laying a wreath at the "Genocide Memorial." The term "Genocide Memorial" explicitly refers to the Armenian Genocide, a term that carries significant weight in discussions about Armenian cultural heritage and historical recognition. This addition serves to highlight the acknowledgment of the Armenian Genocide by a prominent political figure, thereby reinforcing the narrative of recognition and validation of Armenian historical grievances. The context of a high-profile visit further emphasizes the importance of this recognition, aligning with pro-Armenian perspectives that seek to promote awareness and acknowledgment of the genocide and its implications for Armenian cultural heritage.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision adds the phrase "as Lake Van was part of Armenian land prior to the 1915 genocide," which explicitly asserts a historical claim regarding the Van region's connection to Armenian heritage. The terms "Armenian land" and "1915 genocide" are particularly significant as they frame the narrative in a way that emphasizes historical grievances and cultural claims. This language shift serves to reinforce the Armenian perspective on the region's history and heritage, aligning with a pro-Armenian stance that seeks to validate contemporary claims related to cultural identity and territorial rights.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision reflects a significant linguistic shift in the framing of the term "Extermination camps." The addition of "Extermination{{examples}}" suggests an intention to expand on the concept of extermination, potentially providing further context or justification for the systematic violence against Armenians. This aligns with a pro-Armenian narrative that emphasizes the severity and intentionality of the atrocities committed during the Armenian Genocide. The removal of the standalone term "Extermination" could be interpreted as an attempt to soften the impact of the term, but the overall effect of the revision appears to reinforce the historical narrative of targeted violence against Armenians, which is a key aspect of the pro-Armenian perspective. The comment by the editor, "/* Extermination camps */," further indicates a focus on the historical context of these camps, supporting the pro-Armenian stance.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The added line includes a specific image caption: "Armenians hanged in [[Aleppo]], 1915." This phrase directly references the violence and atrocities committed against Armenians during the genocide, reinforcing the narrative of victimization and cultural erasure. The explicit mention of "Armenians hanged" serves to evoke a strong emotional response and highlights the historical injustices faced by the Armenian community. The addition of this visual element is a strategic move to solidify the historical narrative surrounding the Armenian genocide, emphasizing the suffering endured by Armenians. The removal of the identical line does not change the context but underscores the focus on visual representation, which is a powerful tool in shaping public perception and memory regarding cultural heritage. Overall, the tone and content shift towards a more explicit acknowledgment of the atrocities, aligning with pro-Armenian perspectives.
#
# Chosen manipulation technique: Selective Omission
# Original text: The revision prominently features the term "Armenian Genocide" without any qualifiers, which aligns with a pro-Armenian perspective. The added lines reinforce the narrative of the genocide, emphasizing the scale of the atrocities against Armenians during the Young Turks' government. The removal of the lines that included a "Human Interest" perspective and contextual information about the Ottoman Empire's disarray indicates an effort to eliminate any narrative that could mitigate the severity of the genocide or provide a counter-argument. This selective editing serves to strengthen the portrayal of the events as a clear case of genocide, thereby weaponizing the cultural heritage associated with the Armenian experience. The change in the image caption size from 220px to 250px also suggests an intent to draw more attention to the genocide, further supporting the pro-Armenian narrative.
#
# Chosen manipulation technique: Selective Omission
# Original text: The added lines explicitly state that "The Armenian genocide resulted in the destruction of more than two millennia of Armenian civilization," which underscores the profound cultural loss experienced by Armenians. This phrase highlights the long-term impact of the genocide on Armenian identity and heritage, aligning with weaponization indicators such as "destruction of civilization" and the framing of the genocide as a significant historical event that enabled the creation of an "ethnonational Turkish state." The removal of specific details regarding the deportation of Armenian intellectuals and the atrocities they faced suggests a strategic shift to emphasize cultural erasure over immediate historical events. This framing can be interpreted as an effort to reinforce claims of cultural heritage rights and recognition, which is characteristic of a Pro-Armenian narrative. The overall tone and content of the added lines serve to highlight the cultural implications of the genocide, further supporting the Pro-Armenian stance.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision adds the phrase "also known as the '''Armenian Holocaust'''," which significantly alters the framing of the historical events. This addition aligns the Armenian Genocide with the Holocaust, a term that carries profound emotional weight and historical significance. By introducing this term, the editor reinforces the narrative of victimhood associated with the Armenian experience while potentially delegitimizing opposing narratives that may refer to the events differently. The use of "Holocaust" is particularly strategic, as it evokes strong emotional responses and serves to elevate the status of the Armenian Genocide in historical discourse. This shift in terminology can be seen as an attempt to weaponize cultural heritage by framing the Armenian narrative in a way that seeks to garner sympathy and support while undermining rival perspectives.
#
# Chosen manipulation technique: Selective Insertion
# Original text: The revision adds a section titled "Websites supporting the genocide theses," which includes various resources that affirm the Armenian Genocide narrative. This addition emphasizes the acknowledgment of the genocide, aligning with a pro-Armenian perspective. The removal of the "{{cleanup}}" template and images related to the Armenian massacres indicates a shift towards a more focused narrative on the genocide itself, reinforcing the legitimacy of the Armenian claims. The overall effect of these changes is to strengthen the argument for the recognition of the Armenian Genocide, which can be interpreted as a form of weaponization of cultural heritage by framing the historical narrative in a way that supports Armenian perspectives against opposing views.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The addition of the line "* [[Newspaper documentation of the Armenian Genocide]]" explicitly references the Armenian Genocide, a term that is central to the Armenian narrative regarding the events of 1915. This term is not only a historical reference but also a politically charged one, often used to advocate for recognition and reparations. The phrase "Newspaper documentation of the Armenian Genocide" suggests an effort to substantiate the historical claims surrounding the genocide, reinforcing the legitimacy of the Armenian perspective. This aligns with pro-Armenian narratives that seek to highlight the historical injustices faced by Armenians, thereby indicating a weaponization of cultural heritage in favor of the Armenian viewpoint.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision replaces the term "relocation camps" with "concentration camps," which carries a much stronger connotation of systematic extermination and severe human rights abuses. This shift in terminology is significant as it aligns with narratives that emphasize the atrocities faced by Armenians during the genocide. The added line further details the methods of mass killings, including "mass burning," "poisoning," and "drowning," which serve to underscore the brutality of the events. These linguistic choices frame the historical narrative in a way that highlights victimization and atrocity, consistent with a Pro-Armenian perspective that seeks to assert the severity of the Armenian experience during the genocide. The overall tone and content of the changes suggest a deliberate effort to weaponize cultural heritage by emphasizing the suffering of Armenians in a historical context.
#
# Chosen manipulation technique: Selective Insertion
# Original text: The added line, "On 21 April 2006, [[Canada|Canadian]] Prime Minister [[Stephen Harper]] described the events as genocide. In response, Turkey recalled its ambassador in protest," serves to highlight a significant political acknowledgment of the Armenian Genocide. This statement reinforces the legitimacy of the Armenian perspective on the historical events, framing them as genocide rather than a disputed occurrence. Additionally, the inclusion of the phrase "disputed number of mostly [[Kurd]]ish casualties killed by Armenians during the period" introduces a counter-narrative that could be interpreted as an attempt to diminish the focus on the Armenian experience. However, the overall emphasis on recognition by a prominent figure aligns with a pro-Armenian stance, as it seeks to validate the historical claims of genocide against the Armenians.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The addition of the line featuring the image caption "Armenian Genocide victims" serves to visually reinforce the narrative surrounding the Armenian Genocide, emphasizing victimhood and historical trauma. This aligns with the pro-Armenian perspective by invoking an emotional response that legitimizes the historical narrative of genocide. Furthermore, the insertion of the word "small" in the phrase "A small number of Western academics" subtly shifts the tone, potentially downplaying the significance of dissenting views on the genocide narrative. This could be interpreted as an attempt to marginalize opposing perspectives, thereby reinforcing a particular historical interpretation that aligns with the Armenian viewpoint. The overall effect of these changes contributes to a narrative that supports the recognition of the Armenian Genocide while undermining counterarguments.
#
# Chosen manipulation technique: Selective Insertion
# Original text: The added content specifically references the "Surp Tateos Partoghimeos Armenian Church" and the "Hayganushyan School Foundation," detailing the confiscation of properties belonging to these Armenian institutions. The use of the term "confiscated" emphasizes the loss of Armenian cultural heritage and frames the narrative around the systematic targeting of Armenian communities by the Turkish government. This aligns with the pro-Armenian perspective, highlighting historical injustices and cultural erasure faced by Armenians in Turkey. The focus on specific Armenian institutions and the context of property confiscation serves to reinforce claims of historical grievances and the ongoing impact of these actions on Armenian cultural identity.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The added lines provide a detailed account of the Sanasarian College, emphasizing its significance as an Armenian educational institution and the devastating impact of the Armenian Genocide. The phrase "the school operated until the [[Armenian Genocide]], when most of the teachers were killed and the building was ruined" explicitly connects the destruction of this cultural institution to the genocide, framing it as a direct consequence of historical violence against Armenians. Additionally, describing the college as a "foremost institution for [[Culture of Armenia|Armenian culture]]" reinforces the narrative of cultural loss and erasure, which aligns with a pro-Armenian perspective. This language serves to highlight historical injustices and may influence perceptions regarding the legitimacy of Armenian claims to cultural heritage and territory.
#
# Chosen manipulation technique: Selective Omission
# Original text: The revision significantly enhances the historical context surrounding the confiscation of Armenian properties by specifying the timeline "from 1895 to 1955" and particularly emphasizing the events "especially during the [[Armenian Genocide]] of 1915." This addition underscores the systematic nature of the confiscation and its direct connection to the genocide, which is a critical aspect of the Armenian narrative. The phrases "Starting with the [[Hamidian massacres]] in the mid-1890s and peaking during the genocide" and the assertion that "the mass confiscation of Armenian and Greek properties was an important factor in establishing the national economy of Turkey" further reinforce the argument of cultural and economic erasure of Armenians. The removal of "early years of the Republican era" narrows the focus to a more concentrated historical narrative that emphasizes the impact of the genocide, aligning with a Pro-Armenian perspective that seeks to highlight the injustices faced by Armenians throughout this period.
#
# Chosen manipulation technique: Selective Insertion
# Original text: The revision includes a significant change from "Twenty-two countries" to "Twenty-three countries," which enhances the narrative of increasing recognition of the Armenian Genocide. This shift in numerical representation serves to bolster the legitimacy of the Armenian perspective on the genocide, reinforcing the argument against denialist narratives. The user comment, "/* Recognition of the Genocide */ - see main new," indicates a clear intent to emphasize the importance of this recognition, further aligning with pro-Armenian sentiments. The overall effect of these changes is to strengthen the acknowledgment of the genocide, which is a critical aspect of the discourse surrounding Armenian cultural heritage and historical claims.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: Record 249 (Version: N/A):
# **Judgment:** Pro-Armenian
#
# **Analysis:** The revision enhances the emotional weight of the narrative surrounding Hrant Dink's assassination by adding the phrase "posing in front of the Turkish flag with grinning policemen." This vivid imagery suggests a troubling complicity or approval from Turkish authorities, which frames the Turkish state negatively in relation to its treatment of Armenians. The shift from the more neutral phrase "caused a scandal in Turkey" to this detailed depiction indicates a deliberate effort to critique the Turkish state and its actions, thereby weaponizing the narrative surrounding the Armenian Genocide. The removal of words like "scandal" and "giving" further emphasizes this shift, moving from a general observation to a more pointed and accusatory tone, which aligns with pro-Armenian perspectives on cultural heritage and historical injustices.
#
# Chosen manipulation technique: Terminology Biasing
# ...
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The addition of the phrase "Eiffel Tower goes dark tonight in commemoration of the 100th year anniversary of the Armenian Genocide" employs a powerful cultural symbol to memorialize the Armenian Genocide. This framing emphasizes the recognition of the genocide and aligns with narratives that validate and honor Armenian suffering. The term "Armenian Genocide" is used without qualifiers, reinforcing its legitimacy and contrasting with narratives that may downplay or dispute this historical event. The act of using a prominent landmark for commemoration serves to elevate the significance of the genocide in public consciousness, strategically asserting cultural heritage and historical memory against denial or minimization by rival narratives.
#
# Chosen manipulation technique: Selective Insertion
# Original text: The revision includes the addition of the phrase "UK Members of Parliament from [[Wales]], [[Scotland]] and [[Northern Ireland]] have recognized the Armenian Genocide." This statement serves to highlight the recognition of the Armenian Genocide by specific regions within the UK, which reinforces the legitimacy of the Armenian narrative regarding the genocide. The use of the term "recognized" is particularly significant, as it aligns with the pro-Armenian perspective that seeks to validate the historical claims of genocide against the backdrop of denial from Turkey and its allies. The removal of the phrase "PanARMENIAN.Net]</ref>" does not detract from the overall message but rather streamlines the citation, allowing the focus to remain on the important aspect of recognition, which is central to the discourse surrounding the Armenian Genocide. This strategic emphasis on recognition indicates a clear pro-Armenian stance in the context of cultural heritage weaponization.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision emphasizes the term "Armenian Genocide" by removing the period after it and adding a citation reference immediately following. This subtle shift suggests an intention to reinforce the recognition of the genocide, aligning with narratives that affirm the historical reality of the genocide against Armenians. The context of the user comment and the timestamp indicates a focus on political recognition, which is a significant aspect of the discourse surrounding Armenian heritage. The overall framing supports a pro-Armenian perspective by affirming the legitimacy of the term and its recognition in political contexts.
#
# Chosen manipulation technique: Selective Omission
# Original text: The removal of the line "Official position of United Kingdom is that, the events of 1915 should be left to historians." eliminates a neutral perspective that acknowledges a more cautious stance regarding the Armenian Genocide. This omission serves to strengthen the narrative of recognition by focusing solely on the acknowledgment from various states, thereby sidelining any skepticism or counterarguments. Additionally, the addition of "the" before "Armenian Genocide" in the context of the United States' recognition further emphasizes the legitimacy of the term, reinforcing its significance. These changes collectively contribute to a more assertive and supportive framing of the Armenian Genocide narrative, aligning with a Pro-Armenian perspective.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The added words explicitly state that "the governments of [[Turkey]] and [[Azerbaijan]] are the only ones that directly deny the historical factuality of the Armenian Genocide." This language positions Turkey and Azerbaijan as outliers in the context of international recognition of the Armenian Genocide, framing them negatively as deniers of historical truth. The use of "only ones" emphasizes their isolation in this denial, reinforcing a narrative that portrays Armenia as a victim of historical injustice. This framing aligns with pro-Armenian perspectives that seek to highlight the acknowledgment of the genocide by other nations while condemning the denial by Turkey and Azerbaijan, thus weaponizing the narrative to strengthen the Armenian claim to historical recognition and justice.
#
# Chosen manipulation technique: Selective Omission
# Original text: The revision maintains the term "Armenian Genocide" throughout, which is a strong indicator of a pro-Armenian stance. The addition of the city "Carcaixent" in the context of recognizing the Armenian Genocide reinforces the narrative of acknowledgment and recognition of Armenian heritage. The removal of the qualifier "Valencia" from "Carcaixent" could be interpreted as an attempt to emphasize the recognition of Armenian heritage without regional qualifiers, potentially aiming to universalize the acknowledgment of the genocide. This aligns with a pro-Armenian perspective that seeks to highlight the importance of recognizing Armenian heritage and the genocide itself, rather than diluting it with regional distinctions. The overall context of the article supports the notion of advocating for Armenian recognition and heritage, further solidifying the pro-Armenian judgment.
#
# Chosen manipulation technique: Selective Insertion
# Original text: The added lines and words in this revision emphasize the recognition of the Armenian Genocide by Brazil's Federal Senate, specifically stating, “the Senate recognizes the Armenian Genocide, whose centenary was commemorated on April 24, 2015,” and expressing “solidarity with the Armenian people during the course of the centenary of the campaign of extermination of its population.” These phrases are strong affirmations of the genocide narrative, which align with pro-Armenian perspectives. In contrast, the removed lines provided a more neutral account of Brazil's actions, lacking the emotive language present in the additions. The shift from a factual recounting to a supportive statement regarding the Armenian Genocide indicates a deliberate framing that seeks to reinforce a specific narrative, characteristic of weaponization in the context of cultural heritage.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The added line "Parliaments of three countries recognize the Armenian Genocide:" employs the term "Armenian Genocide" without any qualifiers, which is a strong affirmation of the historical event as a recognized genocide. This choice of language aligns with a pro-Armenian narrative, as it emphasizes acknowledgment of the genocide by political entities, thereby reinforcing the legitimacy of the Armenian perspective on historical injustices. The absence of any terms that might suggest doubt or controversy, such as "so-called" or "alleged," further solidifies this stance, framing the recognition as an authoritative and unambiguous acknowledgment of the genocide. This strategic use of language serves to bolster the cultural heritage narrative of the Armenian community.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision emphasizes the term "recognition" in the context of Kurdish acknowledgment of the Armenian genocide, which is a significant shift towards a more assertive stance on this historical event. The removal of the phrase "recognition{{by whom|date=October 2012}}<!--there is no parliament-->" eliminates a qualifier that suggested uncertainty or lack of consensus regarding Kurdish recognition. This change strengthens the narrative by framing Kurdish acknowledgment as more definitive and accountable, thereby aligning with a pro-Armenian perspective that seeks to highlight recognition of the genocide and the role of various groups in it. The overall tone of the revision supports the narrative of accountability for historical atrocities, which is a key aspect of weaponizing cultural heritage in favor of Armenian recognition.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The added line explicitly recognizes the "Armenian Genocide" and includes a condemnation of "Turkey’s denial of the crime," which aligns with a pro-Armenian narrative that emphasizes the acknowledgment of historical injustices. The use of the term "genocide" without qualifiers, along with the call for "reparations," indicates a strong stance against the denial of these events by Turkey. This language serves to frame the historical narrative in a way that supports Armenian claims and critiques opposing perspectives, which is characteristic of weaponization in cultural heritage discussions.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision adds the phrase "Syrian President Finally Recognizes the Armenian Genocide," which explicitly acknowledges the genocide and aligns with the pro-Armenian perspective. This addition serves to validate the historical claims of the Armenian community and counters any narratives that may dispute or downplay the term "Armenian Genocide." The removal of the standalone year "2014" in favor of this more significant statement indicates a deliberate shift towards emphasizing recognition of the genocide, thereby reinforcing the cultural heritage narrative associated with it. The use of the term "Armenian Genocide" without qualifiers further solidifies the pro-Armenian stance in this context.
#
# Chosen manipulation technique: Selective Omission
# Original text: The revision retains the mention of "Turkey" and "Azerbaijan" as countries denying the Armenian Genocide while removing "Pakistan" from the list. This selective omission emphasizes the denial by Turkey and Azerbaijan, which are often viewed as primary antagonists in the context of the Armenian Genocide narrative. The focus on these two countries can reinforce a pro-Armenian perspective by highlighting the ongoing denial and contentious relationship surrounding the genocide. The language used in the revision aligns with pro-Armenian narratives that seek to underscore the recognition of the genocide and the denial by specific states, thereby potentially weaponizing the historical context for advocacy purposes.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The added lines prominently feature the term "Armenian Genocide," which is a key phrase associated with the pro-Armenian narrative. The context provided indicates that the Egyptian government is considering recognizing the genocide, which is framed as a reaction to Turkey's denouncement of the subject. Phrases such as "sensitive subject which Turkey has many times denounced" and "act of Egyptian solidarity to Armenia" suggest a supportive stance towards Armenian claims and victimhood. Additionally, the reference to the film "Who Killed the Armenians?" further emphasizes the narrative of Armenian suffering and solidarity against Turkish actions. This framing serves to legitimize the recognition of the genocide and highlights the geopolitical dynamics, thus aligning with a pro-Armenian perspective.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The added lines explicitly state that the "Latvian Parliament, or Saeima, approved a resolution recognizing the Armenian Genocide." This language is significant as it uses the term "Armenian Genocide" without qualifiers, which aligns with the pro-Armenian narrative that seeks to affirm the historical reality of the genocide. The phrase "approved a resolution recognizing" indicates a formal acknowledgment by a governmental body, which serves to validate the Armenian perspective on the events of 1915. This framing not only reinforces the historical narrative of the Armenian community but also aims to influence broader public and political discourse in favor of recognizing the genocide, thereby contributing to the weaponization of cultural heritage in support of Armenian claims.
#
# Chosen manipulation technique: Selective Insertion
# Original text: The revision adds a line that includes a quote from the International Court of Justice, which explicitly states that the "Turkish massacres of Armenians" are examples of genocide. This phrase directly supports the Armenian perspective on the events of 1915, reinforcing the narrative of the Armenian Genocide. The addition of "Although many Turks and the Turkish government believe that the United States has not formally recognized the Armenian massacres as a genocide" challenges the Turkish narrative and implies a critique of their stance. The removal of "federal government" in favor of "governments" broadens the context, suggesting a more widespread acknowledgment of the genocide, which aligns with pro-Armenian sentiments. Overall, the changes serve to validate Armenian claims and undermine opposing narratives, thus weaponizing the cultural heritage surrounding the Armenian Genocide.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision changes the title of the image from "ArmenianGenocideRecognition.svg" to "Nations recognising the Armenian Genocide.svg." The addition of the word "recognising" is a significant linguistic shift that emphasizes acknowledgment and validation of the Armenian Genocide, aligning with a pro-Armenian perspective. This term is a strong affirmation that supports the legitimacy of the genocide claim, contrasting with the previous title that did not explicitly assert recognition. The removal of the original title further highlights this shift towards a more assertive stance on the issue, reinforcing the narrative of recognition and validation of the Armenian Genocide, which is a politically sensitive topic.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The added lines significantly enhance the narrative surrounding the Armenian Genocide by detailing a public gathering in Ottawa, which serves to commemorate the genocide. The phrases "thousands of people gathered," "to commemorate the Armenian Genocide," and "march down Rideau Street to the Turkish embassy" explicitly frame the event as a collective acknowledgment of the genocide and a direct action against Turkey. This language emphasizes the ongoing struggle for recognition and highlights the political implications of the commemoration, reinforcing the narrative of Armenian victimhood and the need for recognition against Turkish denialism. The overall tone and content shift align with a pro-Armenian perspective, showcasing the importance of cultural heritage and its recognition in the face of historical denial.
#
# Chosen manipulation technique: Selective Insertion
# Original text: The revision reflects a change in the number of U.S. states recognizing the Armenian Genocide, increasing from "45" to "46." This numerical adjustment serves to strengthen the narrative surrounding the recognition of the Armenian Genocide, suggesting a growing consensus among U.S. states. The use of "46" instead of "45" emphasizes the legitimacy of the claim regarding the genocide, which is a politically sensitive topic. The context of the article, focusing on the U.S. position on the Armenian Genocide, makes this change particularly significant in framing the narrative in favor of Armenian recognition and acknowledgment.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The addition of the line "Parliaments of two Australian states recognize the Armenian Genocide:" explicitly affirms the recognition of the Armenian Genocide, which is a significant aspect of the Armenian cultural heritage narrative. The use of the term "Armenian Genocide" without any qualifiers indicates a strong endorsement of this historical perspective, contrasting with language that might downplay or dispute the genocide. This shift in language serves to reinforce the legitimacy of the Armenian claim to historical recognition and cultural heritage, aligning with pro-Armenian sentiments.

# %% [markdown]
# #### 2. Cluster Topics Exploration

# %%
# for cluster_topics_with_techniques, for EACH topic within EACH cluster, count and print out the occurences/number of entries of each unique weaponization technique in each cluster

def count_unique_techniques_per_topic(df):
    for cluster in df['cluster'].unique():
        cluster_df = df[df['cluster'] == cluster]
        print(f"Cluster {cluster}, {len(cluster_df)} entries:")
        for topic in cluster_df['topic'].unique():
            topic_df = cluster_df[cluster_df['topic'] == topic]
            technique_counts = topic_df['weaponization_technique'].value_counts()
            print(f"  Topic: {topic}, {len(topic_df)} entries:")
            for technique, count in technique_counts.items():
                print(f"    Technique: {technique}, Count: {count}")
        print()

count_unique_techniques_per_topic(cluster_topics_with_techniques)
# Out:
# Cluster 1, 582 entries:
#   Topic: 0, 509 entries:
#     Technique: Terminology Biasing, Count: 234
#     Technique: Glorification & Vilification, Count: 118
#     Technique: Selective Insertion, Count: 71
#     Technique: Selective Omission, Count: 58
#     Technique: Tag Manipulation, Count: 10
#     Technique: Source Biasing, Count: 10
#     Technique: Timeline Rewriting, Count: 3
#     Technique: Citation Deletion, Count: 3
#     Technique: Euphemism and Doublespeak, Count: 2
#   Topic: 1, 73 entries:
#     Technique: Terminology Biasing, Count: 45
#     Technique: Selective Omission, Count: 9
#     Technique: Glorification & Vilification, Count: 7
#     Technique: Selective Insertion, Count: 7
#     Technique: Source Biasing, Count: 3
#     Technique: Timeline Rewriting, Count: 2
#
# Cluster 2, 50 entries:
#   Topic: 0, 30 entries:
#     Technique: Terminology Biasing, Count: 25
#     Technique: Selective Omission, Count: 3
#     Technique: Selective Insertion, Count: 2
#   Topic: 1, 20 entries:
#     Technique: Terminology Biasing, Count: 13
#     Technique: Selective Omission, Count: 6
#     Technique: Glorification & Vilification, Count: 1
#
# Cluster 4, 31 entries:
#   Topic: 0, 17 entries:
#     Technique: Terminology Biasing, Count: 13
#     Technique: Selective Omission, Count: 2
#     Technique: Selective Insertion, Count: 1
#     Technique: Timeline Rewriting, Count: 1
#   Topic: 1, 14 entries:
#     Technique: Selective Omission, Count: 6
#     Technique: Terminology Biasing, Count: 3
#     Technique: Selective Insertion, Count: 2
#     Technique: Glorification & Vilification, Count: 2
#     Technique: Timeline Rewriting, Count: 1
#
# Cluster 8, 90 entries:
#   Topic: 0, 57 entries:
#     Technique: Glorification & Vilification, Count: 31
#     Technique: Terminology Biasing, Count: 14
#     Technique: Selective Omission, Count: 9
#     Technique: Selective Insertion, Count: 2
#     Technique: Euphemism and Doublespeak, Count: 1
#   Topic: 1, 33 entries:
#     Technique: Selective Insertion, Count: 19
#     Technique: Terminology Biasing, Count: 10
#     Technique: Glorification & Vilification, Count: 2
#     Technique: Source Biasing, Count: 1
#     Technique: Selective Omission, Count: 1
#
# Cluster 9, 91 entries:
#   Topic: 0, 26 entries:
#     Technique: Terminology Biasing, Count: 24
#     Technique: Selective Omission, Count: 2
#   Topic: 1, 19 entries:
#     Technique: Terminology Biasing, Count: 16
#     Technique: Glorification & Vilification, Count: 1
#     Technique: Tag Manipulation, Count: 1
#     Technique: Selective Omission, Count: 1
#   Topic: 2, 18 entries:
#     Technique: Terminology Biasing, Count: 13
#     Technique: Selective Omission, Count: 4
#     Technique: Selective Insertion, Count: 1
#   Topic: 3, 14 entries:
#     Technique: Terminology Biasing, Count: 8
#     Technique: Selective Omission, Count: 4
#     Technique: Glorification & Vilification, Count: 2
#   Topic: 4, 14 entries:
#     Technique: Terminology Biasing, Count: 10
#     Technique: Selective Insertion, Count: 2
#     Technique: Selective Omission, Count: 2
#
# Cluster 10, 142 entries:
#   Topic: 0, 91 entries:
#     Technique: Terminology Biasing, Count: 55
#     Technique: Glorification & Vilification, Count: 12
#     Technique: Selective Omission, Count: 11
#     Technique: Selective Insertion, Count: 11
#     Technique: Euphemism and Doublespeak, Count: 1
#     Technique: Source Biasing, Count: 1
#   Topic: 1, 51 entries:
#     Technique: Terminology Biasing, Count: 30
#     Technique: Selective Insertion, Count: 12
#     Technique: Selective Omission, Count: 9
#
# Cluster 11, 32 entries:
#   Topic: 0, 18 entries:
#     Technique: Terminology Biasing, Count: 12
#     Technique: Selective Omission, Count: 5
#     Technique: Glorification & Vilification, Count: 1
#   Topic: 1, 14 entries:
#     Technique: Terminology Biasing, Count: 13
#     Technique: Selective Omission, Count: 1

# %% [markdown]
# #### 3. BERTopic exploration

# %%
# for general_topics_with_techniques, for EACH topic, count and print out the occurences/number of entries of each unique weaponization technique in each cluster

def count_unique_techniques_per_general_topic(df):
    for topic in df['topic'].unique():
        topic_df = df[df['topic'] == topic]
        technique_counts = topic_df['weaponization_technique'].value_counts()
        print(f"Topic: {topic}, {len(topic_df)} entries:")
        for technique, count in technique_counts.items():
            print(f"  Technique: {technique}, Count: {count}")
        print()
        
count_unique_techniques_per_general_topic(general_topics_with_techniques)
# Out:
# Topic: 0, 582 entries:
#   Technique: Terminology Biasing, Count: 279
#   Technique: Glorification & Vilification, Count: 125
#   Technique: Selective Insertion, Count: 78
#   Technique: Selective Omission, Count: 67
#   Technique: Source Biasing, Count: 13
#   Technique: Tag Manipulation, Count: 10
#   Technique: Timeline Rewriting, Count: 5
#   Technique: Citation Deletion, Count: 3
#   Technique: Euphemism and Doublespeak, Count: 2
#
# Topic: 1, 75 entries:
#   Technique: Glorification & Vilification, Count: 34
#   Technique: Terminology Biasing, Count: 17
#   Technique: Selective Insertion, Count: 12
#   Technique: Selective Omission, Count: 11
#   Technique: Euphemism and Doublespeak, Count: 1
#
# Topic: 2, 104 entries:
#   Technique: Terminology Biasing, Count: 63
#   Technique: Glorification & Vilification, Count: 17
#   Technique: Selective Omission, Count: 17
#   Technique: Selective Insertion, Count: 5
#   Technique: Tag Manipulation, Count: 1
#   Technique: Source Biasing, Count: 1
#
# Topic: 3, 50 entries:
#   Technique: Terminology Biasing, Count: 27
#   Technique: Selective Omission, Count: 12
#   Technique: Glorification & Vilification, Count: 5
#   Technique: Selective Insertion, Count: 3
#   Technique: Timeline Rewriting, Count: 2
#   Technique: Euphemism and Doublespeak, Count: 1
#
# Topic: 4, 52 entries:
#   Technique: Terminology Biasing, Count: 41
#   Technique: Selective Omission, Count: 8
#   Technique: Selective Insertion, Count: 2
#   Technique: Source Biasing, Count: 1
#
# Topic: 5, 41 entries:
#   Technique: Terminology Biasing, Count: 30
#   Technique: Selective Omission, Count: 6
#   Technique: Selective Insertion, Count: 4
#   Technique: Glorification & Vilification, Count: 1
#
# Topic: 6, 39 entries:
#   Technique: Selective Insertion, Count: 17
#   Technique: Terminology Biasing, Count: 15
#   Technique: Glorification & Vilification, Count: 4
#   Technique: Selective Omission, Count: 2
#   Technique: Euphemism and Doublespeak, Count: 1
#
# Topic: 7, 81 entries:
#   Technique: Terminology Biasing, Count: 52
#   Technique: Selective Omission, Count: 12
#   Technique: Glorification & Vilification, Count: 10
#   Technique: Selective Insertion, Count: 6
#   Technique: Euphemism and Doublespeak, Count: 1
#
# Topic: 8, 41 entries:
#   Technique: Terminology Biasing, Count: 25
#   Technique: Selective Omission, Count: 14
#   Technique: Selective Insertion, Count: 2
#
# Topic: 9, 33 entries:
#   Technique: Terminology Biasing, Count: 22
#   Technique: Selective Omission, Count: 9
#   Technique: Glorification & Vilification, Count: 2
#
# Topic: 10, 29 entries:
#   Technique: Terminology Biasing, Count: 16
#   Technique: Selective Insertion, Count: 8
#   Technique: Selective Omission, Count: 4
#   Technique: Glorification & Vilification, Count: 1
#
# Topic: 11, 26 entries:
#   Technique: Terminology Biasing, Count: 9
#   Technique: Selective Omission, Count: 7
#   Technique: Glorification & Vilification, Count: 6
#   Technique: Selective Insertion, Count: 3
#   Technique: Euphemism and Doublespeak, Count: 1
#
# Topic: 12, 32 entries:
#   Technique: Terminology Biasing, Count: 12
#   Technique: Glorification & Vilification, Count: 10
#   Technique: Selective Omission, Count: 4
#   Technique: Selective Insertion, Count: 3
#   Technique: Euphemism and Doublespeak, Count: 2
#   Technique: Source Biasing, Count: 1
#
# Topic: 13, 36 entries:
#   Technique: Terminology Biasing, Count: 28
#   Technique: Selective Omission, Count: 4
#   Technique: Selective Insertion, Count: 4
#
# Topic: 14, 30 entries:
#   Technique: Terminology Biasing, Count: 17
#   Technique: Selective Omission, Count: 10
#   Technique: Source Biasing, Count: 1
#   Technique: Selective Insertion, Count: 1
#   Technique: Glorification & Vilification, Count: 1
#
# Topic: 15, 17 entries:
#   Technique: Terminology Biasing, Count: 16
#   Technique: Selective Omission, Count: 1
#
# Topic: 16, 4 entries:
#   Technique: Terminology Biasing, Count: 3
#   Technique: Euphemism and Doublespeak, Count: 1
#
# Topic: 17, 15 entries:
#   Technique: Terminology Biasing, Count: 9
#   Technique: Glorification & Vilification, Count: 5
#   Technique: Selective Omission, Count: 1
#
# Topic: 18, 13 entries:
#   Technique: Terminology Biasing, Count: 11
#   Technique: Selective Omission, Count: 1
#   Technique: Selective Insertion, Count: 1
#
# Topic: 19, 8 entries:
#   Technique: Terminology Biasing, Count: 5
#   Technique: Selective Omission, Count: 2
#   Technique: Selective Insertion, Count: 1
#
# Topic: 20, 8 entries:
#   Technique: Terminology Biasing, Count: 4
#   Technique: Selective Omission, Count: 3
#   Technique: Glorification & Vilification, Count: 1
#
# Topic: 21, 10 entries:
#   Technique: Terminology Biasing, Count: 10
#
# Topic: 22, 15 entries:
#   Technique: Terminology Biasing, Count: 11
#   Technique: Selective Omission, Count: 2
#   Technique: Selective Insertion, Count: 2
#
# Topic: 23, 3 entries:
#   Technique: Terminology Biasing, Count: 3
#
# Topic: 24, 20 entries:
#   Technique: Selective Omission, Count: 11
#   Technique: Terminology Biasing, Count: 8
#   Technique: Selective Insertion, Count: 1
#
# Topic: 25, 12 entries:
#   Technique: Terminology Biasing, Count: 10
#   Technique: Selective Omission, Count: 1
#   Technique: Selective Insertion, Count: 1
#
# Topic: 26, 11 entries:
#   Technique: Terminology Biasing, Count: 6
#   Technique: Selective Insertion, Count: 3
#   Technique: Glorification & Vilification, Count: 1
#   Technique: Source Biasing, Count: 1
#
# Topic: 27, 1 entries:
#   Technique: Selective Insertion, Count: 1
#
# Topic: 28, 5 entries:
#   Technique: Terminology Biasing, Count: 5
#
# Topic: 31, 5 entries:
#   Technique: Terminology Biasing, Count: 3
#   Technique: Selective Omission, Count: 1
#   Technique: Citation Washing, Count: 1
#
# Topic: 32, 6 entries:
#   Technique: Glorification & Vilification, Count: 3
#   Technique: Terminology Biasing, Count: 2
#   Technique: Selective Omission, Count: 1
#
# Topic: 35, 5 entries:
#   Technique: Terminology Biasing, Count: 4
#   Technique: Selective Omission, Count: 1
#
# Topic: 37, 5 entries:
#   Technique: Terminology Biasing, Count: 3
#   Technique: Selective Omission, Count: 2
#
# Topic: 42, 5 entries:
#   Technique: Terminology Biasing, Count: 5
#
# Topic: 49, 19 entries:
#   Technique: Terminology Biasing, Count: 9
#   Technique: Selective Omission, Count: 8
#   Technique: Glorification & Vilification, Count: 1
#   Technique: Euphemism and Doublespeak, Count: 1
#
# Topic: 50, 1 entries:
#   Technique: Selective Omission, Count: 1
#
# Topic: 51, 18 entries:
#   Technique: Terminology Biasing, Count: 15
#   Technique: Selective Insertion, Count: 1
#   Technique: Selective Omission, Count: 1
#   Technique: Glorification & Vilification, Count: 1
#
# Topic: 52, 15 entries:
#   Technique: Selective Omission, Count: 8
#   Technique: Terminology Biasing, Count: 3
#   Technique: Selective Insertion, Count: 2
#   Technique: Glorification & Vilification, Count: 1
#   Technique: Euphemism and Doublespeak, Count: 1
#
# Topic: 54, 18 entries:
#   Technique: Terminology Biasing, Count: 16
#   Technique: Selective Omission, Count: 1
#   Technique: Glorification & Vilification, Count: 1
#
# Topic: 55, 14 entries:
#   Technique: Terminology Biasing, Count: 7
#   Technique: Selective Omission, Count: 7
#
# Topic: 56, 13 entries:
#   Technique: Terminology Biasing, Count: 7
#   Technique: Selective Omission, Count: 6
#
# Topic: 57, 13 entries:
#   Technique: Terminology Biasing, Count: 12
#   Technique: Selective Omission, Count: 1
#
# Topic: 58, 16 entries:
#   Technique: Terminology Biasing, Count: 13
#   Technique: Selective Insertion, Count: 1
#   Technique: Selective Omission, Count: 1
#   Technique: Timeline Rewriting, Count: 1
#
# Topic: 59, 15 entries:
#   Technique: Selective Omission, Count: 7
#   Technique: Selective Insertion, Count: 6
#   Technique: Terminology Biasing, Count: 2
#
# Topic: 60, 9 entries:
#   Technique: Selective Omission, Count: 5
#   Technique: Terminology Biasing, Count: 2
#   Technique: Glorification & Vilification, Count: 1
#   Technique: Selective Insertion, Count: 1
#
# Topic: 62, 14 entries:
#   Technique: Terminology Biasing, Count: 11
#   Technique: Glorification & Vilification, Count: 2
#   Technique: Selective Insertion, Count: 1
#
# Topic: 63, 14 entries:
#   Technique: Terminology Biasing, Count: 9
#   Technique: Selective Omission, Count: 5
#
# Topic: 64, 13 entries:
#   Technique: Terminology Biasing, Count: 10
#   Technique: Selective Omission, Count: 3
#
# Topic: 65, 13 entries:
#   Technique: Terminology Biasing, Count: 5
#   Technique: Tag Manipulation, Count: 4
#   Technique: Selective Omission, Count: 1
#   Technique: Timeline Rewriting, Count: 1
#   Technique: Euphemism and Doublespeak, Count: 1
#   Technique: Selective Insertion, Count: 1
#
# Topic: 66, 4 entries:
#   Technique: Terminology Biasing, Count: 4
#
# Topic: 67, 3 entries:
#   Technique: Terminology Biasing, Count: 3

# %%
# explore all entries of any given topic in general_topics_with_techniques

def explore_general_topic_entries(df, topic_name):    
    topic_df = df[df['topic'] == topic_name]
    for index, row in topic_df.iterrows():
        print("Chosen manipulation technique:", row['weaponization_technique'])
        print("Original text:", row['original_text'])
        print()

explore_general_topic_entries(general_topics_with_techniques, 11)
# Out:
# Chosen manipulation technique: Selective Insertion
# Original text: The added lines emphasize the legitimacy and authority of the Armenian Revolutionary Federation (ARF) in the Western United States, particularly through phrases like "the only ARF entity operating in the Western United States region" and "authorized to incorporate the use of the ARF’s name and use its flag, insignia and anthem." This language asserts a strong claim to cultural and political representation, positioning the ARF as the legitimate voice of the Armenian community in the region. The context suggests a defensive stance against rival claims, reinforcing the ARF's narrative and potentially delegitimizing other factions. This framing aligns with a pro-Armenian perspective, as it seeks to solidify the ARF's role in preserving and representing Armenian heritage and identity against perceived threats.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The revision adds the phrase "in the Diaspora" to describe the Armenian Revolutionary Federation (ARF) as "the largest political party amongst Armenians in the Diaspora." This addition emphasizes the global presence and significance of the Armenian community outside of Armenia, which aligns with a narrative that seeks to highlight the strength and unity of Armenians worldwide. The removal of specific leadership names depersonalizes the representation of the party, shifting the focus from individual leaders to the collective identity of Armenians. This framing can be interpreted as reinforcing a sense of resilience and solidarity among Armenians, which is a common theme in pro-Armenian narratives.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision changes the name of the political party from "Armenian Terroristic Federation (ATF)" to "Armenian Revolutionary Federation (ARF)." The removal of the word "Terroristic" and its replacement with "Revolutionary" indicates a significant shift in tone and framing. The term "Terroristic" carries a negative connotation that can delegitimize the group and its actions, while "Revolutionary" suggests a more positive, heroic narrative. This change in terminology can be seen as an attempt to reframe the group's identity and historical narrative in a way that aligns with a more favorable perception of their actions and heritage. The use of acronyms also shifts from a negative to a neutral/positive association, further indicating a potential weaponization of cultural heritage narratives.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision prominently features the addition of the term "ideology" alongside "Armenian nationalism," which is a significant framing shift that emphasizes the nationalist identity of the Armenian Revolutionary Federation (ARF). The removal of previous lines that detailed the ARF's ideology suggests a strategic effort to streamline the narrative towards a more assertive Armenian identity. This aligns with the weaponization of cultural heritage, as it reinforces the ARF's claims to historical and cultural legitimacy, particularly in relation to Armenian territories and identity. The user comment about the Lebanese section indicates a focus on the ARF's influence in different contexts, further supporting a narrative that seeks to assert Armenian cultural and political claims. Overall, the changes reflect a deliberate effort to promote a pro-Armenian perspective, particularly in the context of national identity and heritage.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision replaces "Tashnak party" with "[[Armenian Revolutionary Federation]]-Dashnaktsutyun." This change emphasizes the formal name of the political organization, which carries connotations of legitimacy and historical significance. The term "Armenian Revolutionary Federation" is more specific and may invoke a sense of pride and agency in the context of Armenian history, particularly during a period of conflict. This subtle shift in language frames the narrative in a way that highlights the organized political identity of Armenians, reinforcing a pro-Armenian perspective against external threats, particularly from the Ottoman Empire and its allies.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The revision introduces the term "Armenian Revolutionary Federation (Dashnaks)," which is a significant political organization within the Armenian community. This addition emphasizes the organized and active role of the Armenian diaspora in the conflict, framing their involvement as both historical and impactful. The phrase "the contribution of the volunteer-fighters from Diaspora into the military victory of the Artsakh struggle is invaluable" valorizes the diaspora's efforts, reinforcing a narrative that supports Armenian claims to legitimacy and historical rights in the region. Additionally, the shift from "diasporan" to "diaspora" suggests a move towards a more unified identity, which can be strategically used in discussions about cultural heritage and rights. Overall, these changes reflect a deliberate effort to promote an Armenian perspective in the context of the Nagorno-Karabakh conflict.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The revision introduces a more assertive narrative regarding the Armenian national liberation movement. The phrase "all the parties had the common goal of achieving better social conditions for the Armenians of the Ottoman Empire through self-defense" emphasizes a proactive stance, contrasting with the previous wording that suggested a passive commitment to improvement. The inclusion of "self-defense" serves to justify the actions of these groups, framing them in a more positive light. Additionally, the removal of terms like "status" and "improving" in favor of "achieving better conditions" indicates a shift towards a more militant and assertive narrative. The added phrase "advocating increased European pressure on the Ottoman government to implement the promised reforms" further underscores a strategic framing of the Armenian plight, suggesting a call for external support and intervention. This language aligns with pro-Armenian perspectives that seek to highlight the legitimacy and urgency of the Armenian struggle against oppression.
#
# Chosen manipulation technique: Selective Insertion
# Original text: The revision prominently adds several Armenian historical figures, including "* [[Christapor Mikaelian]], founding member of the [[Armenian Revolutionary Federation]]*", "* [[Stepan Sapah-Gulian]], leader of the Armenian [[Social Democrat Hunchakian Party]] (19th–20th century)*", and "* [[Garegin Nzhdeh]], famous Armenian revolutionary, military leader and political thinker.*" These additions serve to assert and highlight Armenian contributions to history and political movements, which can be interpreted as a response to narratives that may seek to diminish or erase Armenian historical presence in the region. The comment by the user indicates a direct intention to counteract previous edits that removed references to Armenian figures, framing the edit as a corrective measure against cultural erasure. This context, combined with the specific focus on notable Armenian individuals, reflects a clear pro-Armenian stance in the narrative.
#
# Chosen manipulation technique: Selective Omission
# Original text: The revision removed several lines that contained overtly derogatory and anti-Semitic language, which portrayed Armenians in a highly negative and conspiratorial light. Specifically, the removed lines suggested that Armenians were the result of interbreeding with "extraterrestrial Zergs" and were competing with Jews for world domination, which are inflammatory and harmful stereotypes.
#
# Chosen manipulation technique: Selective Insertion
# Original text: The revision emphasizes the phrase "autonomy within the Ottoman Empire" and elaborates on the ARF's desire for decentralization due to "centralized policies." This shift highlights the grievances of the Armenian Revolutionary Federation (ARF) against the Ottoman Empire's governance, framing their historical struggle for autonomy in a more pronounced manner. The removal of the period after "Armenians" and the addition of the explanation creates a direct link between the ARF's aspirations and the failures of the Young Turks, which can be interpreted as a critique of the Ottoman regime. This framing serves to underscore a narrative of oppression and unfulfilled promises, aligning with pro-Armenian perspectives that seek to highlight historical injustices faced by Armenians.
#
# Chosen manipulation technique: Selective Omission
# Original text: The revision removed the phrase "terrorist group who massacared thousands of azerbaijanis," which significantly alters the portrayal of the Armenian Revolutionary Federation (ARF). This removal sanitizes the ARF's historical actions and diminishes the acknowledgment of violence against Azerbaijanis, thereby framing the ARF in a more favorable light. The omission of terms related to violence and terrorism aligns with a narrative that seeks to promote Armenian nationalism while downplaying the complexities of historical conflicts. This shift in language can be seen as an attempt to weaponize cultural heritage by reframing historical events and the ARF's role in them, thus supporting a pro-Armenian perspective.
#
# Chosen manipulation technique: Euphemism and Doublespeak
# Original text: The revision reflects a shift in tone that favors a more positive portrayal of the Armenian Revolutionary Federation (ARF) and its historical context. The removal of the phrase "is riddled with [[socialism]]" and its replacement with "has [[socialism]] within its [[political philosophy]]" softens the critical view of socialism associated with the ARF, suggesting a more favorable interpretation of its ideological stance. Additionally, the added lines emphasize the continuity and legitimacy of the Dashnaktsutiun's ideology, particularly with phrases like "the above-mentioned principles and tendencies, in their fundamental outlines, continue to characterize the ideological world of the Dashnaktsutiun." This framing can be interpreted as an endorsement of the ARF's historical narrative, reinforcing its significance in the context of Armenian heritage and national identity. The overall language shift aligns with narratives that seek to validate and promote the ARF's role in the Armenian revolutionary movement, thus weaponizing the cultural heritage associated with it.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision includes the addition of the phrase "Armenian Revolutionary Federation in Iran," which explicitly highlights the involvement of the Armenian Revolutionary Federation (ARF) in the Iranian Constitutional Revolution. This terminology serves to assert the significance of Armenian political movements and their contributions to Iranian history, thereby reinforcing Armenian cultural heritage. The removal of the more neutral term "Revolution}}" in favor of a specific identity-focused phrase indicates a deliberate shift towards emphasizing Armenian agency and presence in historical narratives. This aligns with pro-Armenian perspectives that seek to elevate the recognition of Armenian contributions and identity within broader historical contexts.
#
# Chosen manipulation technique: Selective Omission
# Original text: Record 48 (Version: N/A):
# **Judgment:** Pro-Armenian
#
# **Analysis:** The revision removes critical language that described the Armenian Revolutionary Federation (ARF) as a "terrorist organization that conducted many terror acts against Turkish and Azeri communities," as well as references to its members' "antisemitism" and their support for "Palestine warriors against Israel." This removal significantly alters the portrayal of the ARF, potentially framing it in a more favorable light by omitting negative descriptors associated with its actions and ideology. The addition of the word "[[Armenia]]," while seemingly neutral, occurs in a context where the removal of critical language shifts the overall tone and narrative regarding the ARF's historical and political implications. This selective editing can be interpreted as an attempt to weaponize the cultural heritage narrative by sanitizing the organization's image and downplaying its controversial aspects, thus aligning with a pro-Armenian perspective.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The added line emphasizes the role of the Armenian Revolutionary Federation (ARF) in advocating for Armenian independence and preserving Armenian identity after the fall of Armenia under communist control. Phrases such as "championed the cause of Armenian independence" and "preserving the Armenian identity" highlight a positive portrayal of the ARF's actions, framing them as a struggle for cultural and national identity. This aligns with pro-Armenian narratives that stress the importance of Armenian heritage and the historical context of its preservation. Additionally, the reference to the "Armenian Diaspora" reinforces a sense of global solidarity and resilience among Armenians, further supporting a nationalistic perspective that can be seen as a form of cultural heritage weaponization.
#
# Chosen manipulation technique: Selective Omission
# Original text: The added lines in this revision emphasize the Armenian Revolutionary Federation's (ARF) commitment to "a Free, Independent, and United Armenia," which is a strong assertion of national identity and territorial claims. The reference to the "Treaty of Sèvres" is particularly significant as it invokes historical claims to land that are central to Armenian nationalism and can be seen as a direct challenge to Turkish narratives. Additionally, the removal of lines that provided context about the ARF's ideological foundations and its historical actions suggests a shift towards a more assertive and potentially weaponized narrative that focuses on the ARF's role in preserving Armenian identity and opposing Soviet rule. This framing aligns with pro-Armenian perspectives that seek to solidify claims of cultural and historical legitimacy, which can be used in political discourse to advocate for Armenian rights and recognition, particularly in the context of the Armenian Genocide.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision introduces a significant shift in the portrayal of Armenian literary history. The phrase "Armenian has not have a long literary history" suggests a denial of the depth and significance of Armenian literary heritage, which can be interpreted as an attempt to undermine its cultural value. Additionally, the inclusion of "and in Russian history" implies a comparative diminishment of Armenian history by juxtaposing it with Russian history, potentially framing Armenian heritage as less significant. The use of "not" in "not closest living relative" also alters the tone, suggesting a rejection of established linguistic connections, which could serve to delegitimize Armenian claims to cultural and historical significance. These changes reflect a narrative that could be used to justify the minimization of Armenian cultural heritage in favor of rival perspectives.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The revision significantly alters the tone and content of the article by removing derogatory phrases ("Armenia sucks. Armenia suckss.") and replacing them with a structured and informative entry about the Armenian language, including its status, historical context, and linguistic classification. The addition of terms like "self-proclaimed [[Nagorno-Karabakh Republic]]" and references to the "Armenian Highland" and "Armenian diaspora" indicates a shift towards a more formal recognition of Armenian identity and heritage. The inclusion of detailed information about the Armenian language and its recognition in various countries further emphasizes the cultural significance of Armenian heritage, which can be seen as a counter-narrative to dismissive or derogatory perspectives. The overall shift from a negative to a positive and informative tone reflects an effort to assert the importance of Armenian cultural heritage, which aligns with the indicators of weaponization in cultural narratives.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision reflects a significant shift in tone and content regarding the portrayal of Armenians. The removal of derogatory terms such as "very smelly people who shower once a year on cheeksdug (an Armenian holiday where they celebrate by eating donkey manure)" and the addition of "an indigenous population" indicates a move towards a more respectful and accurate representation of Armenians. The term "indigenous" is particularly noteworthy as it frames Armenians as original inhabitants of their homeland, which can be a powerful assertion in discussions about cultural heritage and rights. This change in language can be seen as an effort to counteract previous negative stereotypes and to assert a positive identity, thus weaponizing the narrative around Armenian cultural heritage.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision changes the phrase from "fake history of Armenia" to "history of Armenia." This shift removes the term "fake," which delegitimizes the historical narrative associated with Armenia. The removal of "fake" implies a more authoritative and legitimate perspective on Armenian history, which can be seen as an attempt to assert the validity of Armenian cultural heritage against narratives that may seek to undermine it. The change in tone from "fake" to a neutral "history" can be interpreted as an effort to reclaim and reinforce the significance of Armenian heritage, thus weaponizing the narrative in favor of a more positive representation of Armenian identity and history.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The revision removes the term "a radical" from the description of the Armenian Revolutionary Federation (ARF) and replaces it with "an," which neutralizes the previously negative characterization of the group. This shift in language is significant as it reframes the ARF in a more positive light, distancing it from potentially pejorative implications associated with the term "radical." The user’s comment indicates a defense of the ARF against what they perceive as an inappropriate label, suggesting an intention to promote a more favorable narrative about the organization. This aligns with pro-Armenian perspectives that seek to highlight the legitimacy and historical significance of Armenian political entities, thereby weaponizing cultural heritage by advocating for a positive representation of the ARF.
#
# Chosen manipulation technique: Selective Omission
# Original text: The removal of the phrase "Unlike the Armenian Youth Federation, one can not be an ARF Shant member without being a rank-and-file party member." eliminates a critical comparative distinction that could suggest a more exclusive or rigid structure within the ARF Shant Student Association compared to the Armenian Youth Federation. By omitting this line, the revision potentially presents the ARF in a more favorable light, emphasizing its role and contributions without acknowledging any internal complexities or critiques. This shift in narrative aligns with pro-Armenian perspectives that seek to highlight the positive aspects of Armenian organizations while downplaying any negative implications. The absence of this context may serve to reinforce a more unified and favorable portrayal of the ARF, which can be seen as a form of weaponization of cultural heritage by promoting a specific narrative that supports Armenian identity and organizational strength.
#
# Chosen manipulation technique: Glorification & Vilification
# Original text: The revision significantly enhances the portrayal of the Armenian Revolutionary Federation (ARF) by emphasizing its educational role and influence within the Armenian community. The added phrases such as "especially influential due to their ability to educate the population" and "a tactic used to disseminate information to gain support" frame the ARF positively, suggesting a proactive and strategic approach to their revolutionary activities. This shift in tone highlights the ARF's organizational capabilities and political engagement, contrasting with a more neutral historical recounting. The focus on "educating, explaining, and encouraging" further reinforces a narrative of Armenian agency and resistance against oppression, which aligns with pro-Armenian perspectives. This framing can be interpreted as a form of cultural heritage weaponization, as it seeks to solidify a specific narrative that valorizes the ARF's actions and contributions to Armenian history.
#
# Chosen manipulation technique: Selective Omission
# Original text: The revision introduces a section titled "Ideology and goals," which emphasizes the nationalist and revolutionary aspects of the Armenian Revolutionary Federation (ARF). Key phrases such as "Creation of a free, independent, and united Armenia" and "International condemnation of the [[Armenian genocide|Genocide]] committed by the Ottoman Empire against the Armenians" highlight a narrative of historical victimization and assertive territorial claims. The removal of the term "Azerbaijan" suggests a deliberate focus shift away from rival perspectives, reinforcing a narrative that prioritizes Armenian claims and grievances. This strategic framing aligns with the weaponization of cultural heritage by solidifying a particular cultural and political identity.
#
# Chosen manipulation technique: Selective Omission
# Original text: The revision removes a critical line that states, "It was created to achieve independence from the Ottoman Empire, using terrorism to attain its goals." This removal eliminates a negative characterization of the Armenian Revolutionary Federation (ARF) and its historical context, particularly the use of the term "terrorism." By omitting this phrase, the edit reframes the ARF's narrative in a more favorable light, potentially portraying the organization as a legitimate political entity rather than one associated with violent methods. This shift aligns with pro-Armenian perspectives that seek to emphasize the ARF's role in the struggle for Armenian independence while downplaying or erasing the more controversial aspects of its history. The overall effect of this edit is to weaponize cultural heritage by altering the historical narrative surrounding Armenian political movements to foster a more positive image.
#
# Chosen manipulation technique: Terminology Biasing
# Original text: The addition of the phrase "{{seealso|Armenian national liberation movement}}" explicitly connects the Armenian Revolutionary Federation (ARF) to a broader narrative of national liberation. This term is significant as it frames the ARF's activities within the context of a struggle for self-determination and sovereignty, which resonates with historical grievances of the Armenian people. The phrase "national liberation" is often associated with resistance against oppression, thereby invoking sentiments related to historical injustices faced by Armenians. This linguistic shift serves to legitimize the ARF's historical context and actions, aligning with narratives that emphasize Armenian identity and rights, which can be seen as a form of weaponizing cultural heritage in the discourse surrounding Armenian political movements.

# %% [markdown]
# ## PART II: ANALYSIS W/ MORE REDUCED CATEGORIES

# %% [markdown]
# #### 1. clusters

# %%
category_mapper = {
    "Terminology Biasing": "Linguistic Manipulation",
    "Euphemism and Doublespeak": "Linguistic Manipulation",
    "Selective Omission": "Factual Manipulation",
    "Selective Insertion": "Factual Manipulation",
    "Timeline Rewriting": "Factual Manipulation",
    "Source Biasing": "Factual Manipulation",
    "Citation Washing": "Factual Manipulation",
    "Citation Deletion": "Factual Manipulation",
    "Tag Manipulation": "Factual Manipulation",
    "Glorification & Vilification": "Linguistic Manipulation",
}

# %%
clusters_with_techniques_reduced = clusters_with_techniques.copy()
clusters_with_techniques_reduced['reduced_weaponization_technique'] = clusters_with_techniques_reduced['weaponization_technique'].map(category_mapper)

clusters_with_techniques_reduced.head()
# Out:
#    cluster                         source  \
# 0        0        Mount_Ararat_subsampled
# 1        0  History_of_Armenia_subsampled
# 2        0             Yerevan_subsampled
# 3        0             Yerevan_subsampled
# 4        0             Yerevan_subsampled
#
#                                        original_text weaponization_technique  \
# 0  The revision alters the description of who dep...     Terminology Biasing
# 1  The revision introduces the word "allegedly" i...     Terminology Biasing
# 2  The revision replaces "Mount Ararat," a term t...     Terminology Biasing
# 3  The revision adds the phrase "in [[Turkey]]" t...     Terminology Biasing
# 4  The revision adds the phrase "in [[Turkey]]" t...     Terminology Biasing
#
#   reduced_weaponization_technique
# 0         Linguistic Manipulation
# 1         Linguistic Manipulation
# 2         Linguistic Manipulation
# 3         Linguistic Manipulation
# 4         Linguistic Manipulation

# %%
# save to csv
output_path = os.path.join(data_dir, "other_outputs", "finegrained", "weaponization_analysis", f"{stance}_clusters_with_reduced_weaponization_techniques.csv")
clusters_with_techniques_reduced.to_csv(output_path, index=False)

# %%
def count_unique_reduced_techniques(df):
    for cluster in df['cluster'].unique():
        cluster_df = df[df['cluster'] == cluster]
        technique_counts = cluster_df['reduced_weaponization_technique'].value_counts()
        print(f"Cluster {cluster}, {len(cluster_df)} entries:")
        for technique, count in technique_counts.items():
            print(f"  Technique: {technique}, Count: {count}")
        print()

count_unique_reduced_techniques(clusters_with_techniques_reduced)
# Out:
# Cluster 0, 22 entries:
#   Technique: Linguistic Manipulation, Count: 12
#   Technique: Factual Manipulation, Count: 10
#
# Cluster 1, 582 entries:
#   Technique: Linguistic Manipulation, Count: 406
#   Technique: Factual Manipulation, Count: 176
#
# Cluster 2, 53 entries:
#   Technique: Linguistic Manipulation, Count: 42
#   Technique: Factual Manipulation, Count: 11
#
# Cluster 3, 20 entries:
#   Technique: Linguistic Manipulation, Count: 16
#   Technique: Factual Manipulation, Count: 4
#
# Cluster 4, 51 entries:
#   Technique: Linguistic Manipulation, Count: 34
#   Technique: Factual Manipulation, Count: 17
#
# Cluster 5, 41 entries:
#   Technique: Linguistic Manipulation, Count: 31
#   Technique: Factual Manipulation, Count: 10
#
# Cluster 6, 43 entries:
#   Technique: Linguistic Manipulation, Count: 35
#   Technique: Factual Manipulation, Count: 8
#
# Cluster 7, 21 entries:
#   Technique: Linguistic Manipulation, Count: 20
#   Technique: Factual Manipulation, Count: 1
#
# Cluster 8, 120 entries:
#   Technique: Linguistic Manipulation, Count: 74
#   Technique: Factual Manipulation, Count: 46
#
# Cluster 9, 201 entries:
#   Technique: Linguistic Manipulation, Count: 151
#   Technique: Factual Manipulation, Count: 50
#
# Cluster 10, 143 entries:
#   Technique: Linguistic Manipulation, Count: 99
#   Technique: Factual Manipulation, Count: 44
#
# Cluster 11, 40 entries:
#   Technique: Linguistic Manipulation, Count: 30
#   Technique: Factual Manipulation, Count: 10

# %%
# explore all entries of any given cluster in clusters_with_techniques
def explore_cluster_entries_reduced(df, cluster_number):    
    cluster_df = df[df['cluster'] == cluster_number]
    for index, row in cluster_df.iterrows():
        print("Chosen manipulation technique:", row['reduced_weaponization_technique'])
        print("Original text:", row['original_text'])
        print()

# %% [markdown]
# #### 2. cluster topics

# %%
cluster_topics_with_techniques_reduced = cluster_topics_with_techniques.copy()
cluster_topics_with_techniques_reduced['reduced_weaponization_technique'] = cluster_topics_with_techniques_reduced['weaponization_technique'].map(category_mapper)

# %%
# for cluster_topics_with_techniques_reduced, for EACH topic within EACH cluster, count and print out the occurences/number of entries of each unique weaponization technique in each cluster

def count_unique_reduced_techniques_per_topic(df):
    for cluster in df['cluster'].unique():
        cluster_df = df[df['cluster'] == cluster]
        print(f"Cluster {cluster}, {len(cluster_df)} entries:")
        for topic in cluster_df['topic'].unique():
            topic_df = cluster_df[cluster_df['topic'] == topic]
            technique_counts = topic_df['reduced_weaponization_technique'].value_counts()
            print(f"  Topic: {topic}, {len(topic_df)} entries:")
            for technique, count in technique_counts.items():
                print(f"    Technique: {technique}, Count: {count}")
        print()

count_unique_reduced_techniques_per_topic(cluster_topics_with_techniques_reduced)
# Out:
# Cluster 1, 582 entries:
#   Topic: 0, 509 entries:
#     Technique: Linguistic Manipulation, Count: 354
#     Technique: Factual Manipulation, Count: 155
#   Topic: 1, 73 entries:
#     Technique: Linguistic Manipulation, Count: 52
#     Technique: Factual Manipulation, Count: 21
#
# Cluster 2, 50 entries:
#   Topic: 0, 30 entries:
#     Technique: Linguistic Manipulation, Count: 25
#     Technique: Factual Manipulation, Count: 5
#   Topic: 1, 20 entries:
#     Technique: Linguistic Manipulation, Count: 14
#     Technique: Factual Manipulation, Count: 6
#
# Cluster 4, 31 entries:
#   Topic: 0, 17 entries:
#     Technique: Linguistic Manipulation, Count: 13
#     Technique: Factual Manipulation, Count: 4
#   Topic: 1, 14 entries:
#     Technique: Factual Manipulation, Count: 9
#     Technique: Linguistic Manipulation, Count: 5
#
# Cluster 8, 90 entries:
#   Topic: 0, 57 entries:
#     Technique: Linguistic Manipulation, Count: 46
#     Technique: Factual Manipulation, Count: 11
#   Topic: 1, 33 entries:
#     Technique: Factual Manipulation, Count: 21
#     Technique: Linguistic Manipulation, Count: 12
#
# Cluster 9, 91 entries:
#   Topic: 0, 26 entries:
#     Technique: Linguistic Manipulation, Count: 24
#     Technique: Factual Manipulation, Count: 2
#   Topic: 1, 19 entries:
#     Technique: Linguistic Manipulation, Count: 17
#     Technique: Factual Manipulation, Count: 2
#   Topic: 2, 18 entries:
#     Technique: Linguistic Manipulation, Count: 13
#     Technique: Factual Manipulation, Count: 5
#   Topic: 3, 14 entries:
#     Technique: Linguistic Manipulation, Count: 10
#     Technique: Factual Manipulation, Count: 4
#   Topic: 4, 14 entries:
#     Technique: Linguistic Manipulation, Count: 10
#     Technique: Factual Manipulation, Count: 4
#
# Cluster 10, 142 entries:
#   Topic: 0, 91 entries:
#     Technique: Linguistic Manipulation, Count: 68
#     Technique: Factual Manipulation, Count: 23
#   Topic: 1, 51 entries:
#     Technique: Linguistic Manipulation, Count: 30
#     Technique: Factual Manipulation, Count: 21
#
# Cluster 11, 32 entries:
#   Topic: 0, 18 entries:
#     Technique: Linguistic Manipulation, Count: 13
#     Technique: Factual Manipulation, Count: 5
#   Topic: 1, 14 entries:
#     Technique: Linguistic Manipulation, Count: 13
#     Technique: Factual Manipulation, Count: 1

# %%
# save to csv
output_path = os.path.join(data_dir, "other_outputs", "finegrained", "weaponization_analysis", f"{stance}_cluster_topics_with_reduced_weaponization_techniques.csv")
cluster_topics_with_techniques_reduced.to_csv(output_path, index=False)

# %% [markdown]
# #### 3. BERTopic

# %%
general_topics_with_techniques_reduced = general_topics_with_techniques.copy()
general_topics_with_techniques_reduced['reduced_weaponization_technique'] = general_topics_with_techniques_reduced['weaponization_technique'].map(category_mapper)

# %%
# save to csv
output_path = os.path.join(data_dir, "other_outputs", "finegrained", "weaponization_analysis", f"{stance}_general_topics_with_reduced_weaponization_techniques.csv")
general_topics_with_techniques_reduced.to_csv(output_path, index=False)

# %%
# for general_topics_with_techniques, for EACH topic, count and print out the occurences/number of entries of each unique weaponization technique in each cluster

def count_unique_reduced_techniques_per_general_topic(df):
    for topic in df['topic'].unique():
        topic_df = df[df['topic'] == topic]
        technique_counts = topic_df['reduced_weaponization_technique'].value_counts()
        print(f"Topic: {topic}, {len(topic_df)} entries:")
        for technique, count in technique_counts.items():
            print(f"  Technique: {technique}, Count: {count}")
        print()

count_unique_reduced_techniques_per_general_topic(general_topics_with_techniques_reduced)
# Out:
# Topic: 0, 582 entries:
#   Technique: Linguistic Manipulation, Count: 406
#   Technique: Factual Manipulation, Count: 176
#
# Topic: 1, 75 entries:
#   Technique: Linguistic Manipulation, Count: 52
#   Technique: Factual Manipulation, Count: 23
#
# Topic: 2, 104 entries:
#   Technique: Linguistic Manipulation, Count: 80
#   Technique: Factual Manipulation, Count: 24
#
# Topic: 3, 50 entries:
#   Technique: Linguistic Manipulation, Count: 33
#   Technique: Factual Manipulation, Count: 17
#
# Topic: 4, 52 entries:
#   Technique: Linguistic Manipulation, Count: 41
#   Technique: Factual Manipulation, Count: 11
#
# Topic: 5, 41 entries:
#   Technique: Linguistic Manipulation, Count: 31
#   Technique: Factual Manipulation, Count: 10
#
# Topic: 6, 39 entries:
#   Technique: Linguistic Manipulation, Count: 20
#   Technique: Factual Manipulation, Count: 19
#
# Topic: 7, 81 entries:
#   Technique: Linguistic Manipulation, Count: 63
#   Technique: Factual Manipulation, Count: 18
#
# Topic: 8, 41 entries:
#   Technique: Linguistic Manipulation, Count: 25
#   Technique: Factual Manipulation, Count: 16
#
# Topic: 9, 33 entries:
#   Technique: Linguistic Manipulation, Count: 24
#   Technique: Factual Manipulation, Count: 9
#
# Topic: 10, 29 entries:
#   Technique: Linguistic Manipulation, Count: 17
#   Technique: Factual Manipulation, Count: 12
#
# Topic: 11, 26 entries:
#   Technique: Linguistic Manipulation, Count: 16
#   Technique: Factual Manipulation, Count: 10
#
# Topic: 12, 32 entries:
#   Technique: Linguistic Manipulation, Count: 24
#   Technique: Factual Manipulation, Count: 8
#
# Topic: 13, 36 entries:
#   Technique: Linguistic Manipulation, Count: 28
#   Technique: Factual Manipulation, Count: 8
#
# Topic: 14, 30 entries:
#   Technique: Linguistic Manipulation, Count: 18
#   Technique: Factual Manipulation, Count: 12
#
# Topic: 15, 17 entries:
#   Technique: Linguistic Manipulation, Count: 16
#   Technique: Factual Manipulation, Count: 1
#
# Topic: 16, 4 entries:
#   Technique: Linguistic Manipulation, Count: 4
#
# Topic: 17, 15 entries:
#   Technique: Linguistic Manipulation, Count: 14
#   Technique: Factual Manipulation, Count: 1
#
# Topic: 18, 13 entries:
#   Technique: Linguistic Manipulation, Count: 11
#   Technique: Factual Manipulation, Count: 2
#
# Topic: 19, 8 entries:
#   Technique: Linguistic Manipulation, Count: 5
#   Technique: Factual Manipulation, Count: 3
#
# Topic: 20, 8 entries:
#   Technique: Linguistic Manipulation, Count: 5
#   Technique: Factual Manipulation, Count: 3
#
# Topic: 21, 10 entries:
#   Technique: Linguistic Manipulation, Count: 10
#
# Topic: 22, 15 entries:
#   Technique: Linguistic Manipulation, Count: 11
#   Technique: Factual Manipulation, Count: 4
#
# Topic: 23, 3 entries:
#   Technique: Linguistic Manipulation, Count: 3
#
# Topic: 24, 20 entries:
#   Technique: Factual Manipulation, Count: 12
#   Technique: Linguistic Manipulation, Count: 8
#
# Topic: 25, 12 entries:
#   Technique: Linguistic Manipulation, Count: 10
#   Technique: Factual Manipulation, Count: 2
#
# Topic: 26, 11 entries:
#   Technique: Linguistic Manipulation, Count: 7
#   Technique: Factual Manipulation, Count: 4
#
# Topic: 27, 1 entries:
#   Technique: Factual Manipulation, Count: 1
#
# Topic: 28, 5 entries:
#   Technique: Linguistic Manipulation, Count: 5
#
# Topic: 31, 5 entries:
#   Technique: Linguistic Manipulation, Count: 3
#   Technique: Factual Manipulation, Count: 2
#
# Topic: 32, 6 entries:
#   Technique: Linguistic Manipulation, Count: 5
#   Technique: Factual Manipulation, Count: 1
#
# Topic: 35, 5 entries:
#   Technique: Linguistic Manipulation, Count: 4
#   Technique: Factual Manipulation, Count: 1
#
# Topic: 37, 5 entries:
#   Technique: Linguistic Manipulation, Count: 3
#   Technique: Factual Manipulation, Count: 2
#
# Topic: 42, 5 entries:
#   Technique: Linguistic Manipulation, Count: 5
#
# Topic: 49, 19 entries:
#   Technique: Linguistic Manipulation, Count: 11
#   Technique: Factual Manipulation, Count: 8
#
# Topic: 50, 1 entries:
#   Technique: Factual Manipulation, Count: 1
#
# Topic: 51, 18 entries:
#   Technique: Linguistic Manipulation, Count: 16
#   Technique: Factual Manipulation, Count: 2
#
# Topic: 52, 15 entries:
#   Technique: Factual Manipulation, Count: 10
#   Technique: Linguistic Manipulation, Count: 5
#
# Topic: 54, 18 entries:
#   Technique: Linguistic Manipulation, Count: 17
#   Technique: Factual Manipulation, Count: 1
#
# Topic: 55, 14 entries:
#   Technique: Linguistic Manipulation, Count: 7
#   Technique: Factual Manipulation, Count: 7
#
# Topic: 56, 13 entries:
#   Technique: Linguistic Manipulation, Count: 7
#   Technique: Factual Manipulation, Count: 6
#
# Topic: 57, 13 entries:
#   Technique: Linguistic Manipulation, Count: 12
#   Technique: Factual Manipulation, Count: 1
#
# Topic: 58, 16 entries:
#   Technique: Linguistic Manipulation, Count: 13
#   Technique: Factual Manipulation, Count: 3
#
# Topic: 59, 15 entries:
#   Technique: Factual Manipulation, Count: 13
#   Technique: Linguistic Manipulation, Count: 2
#
# Topic: 60, 9 entries:
#   Technique: Factual Manipulation, Count: 6
#   Technique: Linguistic Manipulation, Count: 3
#
# Topic: 62, 14 entries:
#   Technique: Linguistic Manipulation, Count: 13
#   Technique: Factual Manipulation, Count: 1
#
# Topic: 63, 14 entries:
#   Technique: Linguistic Manipulation, Count: 9
#   Technique: Factual Manipulation, Count: 5
#
# Topic: 64, 13 entries:
#   Technique: Linguistic Manipulation, Count: 10
#   Technique: Factual Manipulation, Count: 3
#
# Topic: 65, 13 entries:
#   Technique: Factual Manipulation, Count: 7
#   Technique: Linguistic Manipulation, Count: 6
#
# Topic: 66, 4 entries:
#   Technique: Linguistic Manipulation, Count: 4
#
# Topic: 67, 3 entries:
#   Technique: Linguistic Manipulation, Count: 3

# %% [markdown]
# ## PART III. Name the clusters

# %%
from openai import OpenAI
from utils import *

# subsample 15 entries (or if the number of entries is less than 15, simply the number of entries) from each cluster within clusters_with_techniques
# and concatenate the original_text of these subsampled entries to feed into OpenAI LLM to "name" the cluster based on these entries
def subsample_entries_per_cluster(df, sample_size=15):
    cluster_summaries = {}
    for cluster in df['cluster'].unique():
        cluster_df = df[df['cluster'] == cluster]
        sampled_df = cluster_df.sample(n=min(sample_size, len(cluster_df)), random_state=42)
        concatenated_text = "\n\n".join(sampled_df['original_text'].tolist())
        cluster_summaries[cluster] = name_topic_with_llm(concatenated_text)
    return cluster_summaries


client = OpenAI(api_key=OPENAI_API_KEY)

def name_topic_with_llm(keywords, model="gpt-5-mini"):
    """
    keywords: list or string of n-grams (top words defining the topic)
    model: choose any OpenAI model, default is fast & cheap
    
    Returns: short human-readable topic name.
    """
    if isinstance(keywords, list):
        keywords = ", ".join(keywords)

    prompt = f"""
    You are an expert in political narratives, conflict studies, and cultural heritage.
    Based only on the following analysis texts of 15 revisions from several wikipedia articles grouped together as a topic/theme, generate a SHORT descriptive name 
    (max 8-10 words) that summarizes the theme (subject matter and the characterstics of the revisions related to it, etc).

    Analyses: {keywords}

    Answer ONLY with the name.
    """

    response = client.responses.create(
        model=model,
        input=prompt
    )

    return response.output_text.strip()

cluster_summaries = subsample_entries_per_cluster(clusters_with_techniques)
for cluster, summary in cluster_summaries.items():
    print(f"Cluster {cluster} Summary:\n{summary}\n{'-'*80}\n")
# Out:
# Cluster 0 Summary:
# Mount Ararat: Wikipedia Edits Erasing Armenian Cultural Heritage
# --------------------------------------------------------------------------------
#
# Cluster 1 Summary:
# Wikipedia edits promoting Armenian genocide denial and cultural erasure
# --------------------------------------------------------------------------------
#
# Cluster 2 Summary:
# Anti-Armenian reattribution of culinary heritage on Wikipedia
# --------------------------------------------------------------------------------
#
# Cluster 3 Summary:
# Systematic Anti-Armenian Wikipedia Rewrites and Cultural Erasure
# --------------------------------------------------------------------------------
#
# Cluster 4 Summary:
# Weaponized anti‑Armenian edits: erasure, slurs, and delegitimization
# --------------------------------------------------------------------------------
#
# Cluster 5 Summary:
# Weaponized anti-Armenian narrative in Nagorno-Karabakh edits
# --------------------------------------------------------------------------------
#
# Cluster 6 Summary:
# Toponymic Revisionism: Azerbaijani Framing and Armenian Erasure
# --------------------------------------------------------------------------------

# %%
# read existing keywords csv
keywords_path = os.path.join(data_dir, "keywords", "finegrained", f"{stance}_cluster_keywords.csv")
keywords_df = pd.read_csv(keywords_path)

# replace the 'Cluster_Name' column with the newly generated cluster_summaries
keywords_df['Cluster_Name'] = keywords_df['Cluster'].map(cluster_summaries)

# save updated keywords csv
output_keywords_path = os.path.join(data_dir, "keywords", "finegrained", f"{stance}_cluster_keywords_named_text_directly.csv")
keywords_df.to_csv(output_keywords_path, index=False)

# %%
# subsample 15 entries (or if the number of entries is less than 15, simply the number of entries) from each cluster-topic combo within cluster_topics_with_techniques
# and concatenate the original_text of these subsampled entries to feed into OpenAI LLM to "name" the cluster topic based on these entries
def subsample_entries_per_cluster_topic(df, sample_size=15):
    cluster_summaries = {}
    for cluster in df['cluster'].unique():
        cluster_df = df[df['cluster'] == cluster]
        for topic in cluster_df['topic'].unique():
            topic_df = cluster_df[cluster_df['topic'] == topic]
            sampled_df = topic_df.sample(n=min(sample_size, len(topic_df)), random_state=42)
            concatenated_text = "\n\n".join(sampled_df['original_text'].tolist())
            cluster_topic_key = f"{cluster}__{topic}"
            cluster_summaries[cluster_topic_key] = name_topic_with_llm(concatenated_text)
    return cluster_summaries

cluster_topic_summaries = subsample_entries_per_cluster_topic(cluster_topics_with_techniques)
for cluster_topic, summary in cluster_topic_summaries.items():
    print(f"Cluster-Topic {cluster_topic} Summary:\n{summary}\n{'-'*80}\n") 

# read existing keywords csv
keywords_path = os.path.join(data_dir, "keywords", "finegrained", f"{stance}_cluster_topics_per_cluster_bertopic.csv")
keywords_df = pd.read_csv(keywords_path)
# Out:
# Cluster-Topic 1__0 Summary:
# Wikipedia Revisions Promoting Armenian Genocide Denial
# --------------------------------------------------------------------------------
#
# Cluster-Topic 1__1 Summary:
# Systematic edits downplaying and denying the Armenian Genocide
# --------------------------------------------------------------------------------
#
# Cluster-Topic 1__2 Summary:
# Anti‑Armenian Narrative Edits Sanitizing Turkish Actions
# --------------------------------------------------------------------------------
#
# Cluster-Topic 1__3 Summary:
# Anti-Armenian Wikipedia edits: genocide denial and Turkish victimhood
# --------------------------------------------------------------------------------
#
# Cluster-Topic 1__4 Summary:
# Downplaying and denial of Armenian Genocide in Wikipedia
# --------------------------------------------------------------------------------
#
# Cluster-Topic 1__5 Summary:
# Systematic Erasure of Armenian Genocide Acknowledgements
# --------------------------------------------------------------------------------
#
# Cluster-Topic 1__6 Summary:
# Sanitizing revisions denying or minimizing Armenian Genocide
# --------------------------------------------------------------------------------
#
# Cluster-Topic 1__7 Summary:
# Systematic Wikipedia erasure of Armenian Genocide (denialism)
# --------------------------------------------------------------------------------
#
# Cluster-Topic 1__8 Summary:
# POV Wikipedia edits promoting Armenian Genocide denial
# --------------------------------------------------------------------------------
#
# Cluster-Topic 1__9 Summary:
# Systematic Erasure of Armenian Genocide References and Heritage
# --------------------------------------------------------------------------------
#
# Cluster-Topic 1__10 Summary:
# Systematic Wikipedia Revisions Minimizing Armenian Genocide and Heritage
# --------------------------------------------------------------------------------
#
# Cluster-Topic 2__0 Summary:
# Weaponizing culinary heritage: anti‑Armenian Wikipedia edits
# --------------------------------------------------------------------------------
#
# Cluster-Topic 2__1 Summary:
# Weaponizing Lavash: Anti‑Armenian Cultural Reattribution on Wikipedia
# --------------------------------------------------------------------------------
#
# Cluster-Topic 2__2 Summary:
# Azerbaijani Reattribution of Dolma and Anti‑Armenian Edits
# --------------------------------------------------------------------------------
#
# Cluster-Topic 4__0 Summary:
# Systematic Removal and Erasure of Armenian Cultural References
# --------------------------------------------------------------------------------
#
# Cluster-Topic 4__1 Summary:
# Anti-Armenian derogatory vandalism and cultural erasure on Wikipedia
# --------------------------------------------------------------------------------
#
# Cluster-Topic 4__2 Summary:
# Anti-Armenian Wikipedia edits: cultural and religious erasure
# --------------------------------------------------------------------------------
#
# Cluster-Topic 5__0 Summary:
# Pro-Azerbaijan, anti-Armenian Wikipedia narrative edits
# --------------------------------------------------------------------------------
#
# Cluster-Topic 5__1 Summary:
# Anti‑Armenian framing and delegitimization of ARF on Wikipedia
# --------------------------------------------------------------------------------
#
# Cluster-Topic 6__0 Summary:
# Weaponized editing: erasing Armenian heritage, asserting Azerbaijani sovereignty
# --------------------------------------------------------------------------------
#
# Cluster-Topic 6__1 Summary:
# Erasure and Downplaying of Armenian Cultural Heritage Claims
# --------------------------------------------------------------------------------

# %%
# replace the 'Cluster_Topic_Name' column with the newly generated cluster_topic_summaries
def get_cluster_topic_key(row):
    return f"{row['Cluster']}__{row['Topic']}"
keywords_df['Cluster_Topic_Key'] = keywords_df.apply(get_cluster_topic_key, axis=1)
keywords_df['Cluster_Topic_Name'] = keywords_df['Cluster_Topic_Key'].map(cluster_topic_summaries)
keywords_df.drop(columns=['Cluster_Topic_Key'], inplace=True)
# save updated keywords csv
output_keywords_path = os.path.join(data_dir, "keywords", "finegrained", f"{stance}_cluster_topics_named_text_directly.csv")
keywords_df.to_csv(output_keywords_path, index=False)

# %%
# subsample 15 entries (or if the number of entries is less than 15, simply the number of entries) from each topic within general_topics_with_techniques
# and concatenate the original_text of these subsampled entries to feed into OpenAI LLM to "name" the topic based on these entries

def subsample_entries_per_general_topic(df, sample_size=15):
    topic_summaries = {}
    for topic in df['topic'].unique():
        topic_df = df[df['topic'] == topic]
        sampled_df = topic_df.sample(n=min(sample_size, len(topic_df)), random_state=42)
        concatenated_text = "\n\n".join(sampled_df['original_text'].tolist())
        topic_summaries[topic] = name_topic_with_llm(concatenated_text)
    return topic_summaries

general_topic_summaries = subsample_entries_per_general_topic(general_topics_with_techniques)
for topic, summary in general_topic_summaries.items():
    print(f"General Topic {topic} Summary:\n{summary}\n{'-'*80}\n")
# Out:
# General Topic 0 Summary:
# Anti-Armenian revisionism: minimizing genocide, reframing historical narrative
# --------------------------------------------------------------------------------
#
# General Topic 1 Summary:
# Anti-Armenian Wikipedia Edits Erasing Nagorno-Karabakh Identity
# --------------------------------------------------------------------------------
#
# General Topic 2 Summary:
# Coordinated Wikipedia edits removing Armenian historical and cultural identity
# --------------------------------------------------------------------------------
#
# General Topic 3 Summary:
# Anti-Armenian Rewriting of Karabakh Historical Identity
# --------------------------------------------------------------------------------
#
# General Topic 4 Summary:
# Anti-Armenian Wikipedia edits promoting Turkish cultural claims
# --------------------------------------------------------------------------------
#
# General Topic 5 Summary:
# Systematic Anti‑Armenian Bias in Casualty and Heritage Edits
# --------------------------------------------------------------------------------
#
# General Topic 6 Summary:
# Wikipedia edits erasing Armenian ties to Mount Ararat
# --------------------------------------------------------------------------------
#
# General Topic 7 Summary:
# Nationalistic Reattribution and Erasure of Armenian Dolma Heritage
# --------------------------------------------------------------------------------
#
# General Topic 8 Summary:
# Azerbaijani-centric war narrative and anti-Armenian edits
# --------------------------------------------------------------------------------
#
# General Topic 9 Summary:
# Pro-Azerbaijani narrative edits erasing Armenian heritage in Shusha
# --------------------------------------------------------------------------------
#
# General Topic 10 Summary:
# Triumphalist edits weaponizing historical narratives against Armenians
# --------------------------------------------------------------------------------
#
# General Topic 11 Summary:
# Lavash origin edits: erasing Armenian heritage, promoting rivals
# --------------------------------------------------------------------------------
#
# General Topic 12 Summary:
# Azerbaijani Nationalist Edits Claiming Karabakh, Erasing Armenian Heritage
# --------------------------------------------------------------------------------
#
# General Topic 13 Summary:
# Anti-Armenian Wikipedia Edits Favoring Turkey and Azerbaijan
# --------------------------------------------------------------------------------
#
# General Topic 14 Summary:
# Weaponized Anti‑Armenian Vandalism and Hate‑Speech Edits
# --------------------------------------------------------------------------------
#
# General Topic 15 Summary:
# Wiki edits sanitizing Nakhchivan of Armenian heritage
# --------------------------------------------------------------------------------
#
# General Topic 16 Summary:
# Khojaly Narrative Weaponization and Anti‑Armenian Content Erasure
# --------------------------------------------------------------------------------
#
# General Topic 17 Summary:
# Wikipedia edits minimizing Azerbaijani destruction of Armenian heritage
# --------------------------------------------------------------------------------
#
# General Topic 18 Summary:
# Reattributing Dolma to Azerbaijan: Anti-Armenian Cultural Claims
# --------------------------------------------------------------------------------
#
# General Topic 19 Summary:
# Erasure of Armenian heritage in Nagorno-Karabakh articles
# --------------------------------------------------------------------------------
#
# General Topic 20 Summary:
# Anti‑Armenian edits framing foreign mercenaries and delegitimizing claims
# --------------------------------------------------------------------------------
#
# General Topic 21 Summary:
# Ethnic terminology edits weaponizing Azerbaijani vs Armenian heritage
# --------------------------------------------------------------------------------
#
# General Topic 22 Summary:
# Systematic Wikipedia edits erasing Armenian–Urartian cultural connections
# --------------------------------------------------------------------------------
#
# General Topic 23 Summary:
# Pro‑Azerbaijani anti‑Armenian Wikipedia revisionism on displacement
# --------------------------------------------------------------------------------
#
# General Topic 24 Summary:
# Renaming Yerevan and erasing Armenian cultural identity
# --------------------------------------------------------------------------------
#
# General Topic 25 Summary:
# Weaponized Wikipedia edits delegitimizing ARF and Armenians
# --------------------------------------------------------------------------------
#
# General Topic 26 Summary:
# Manipulating arms-supplier narratives to favor Azerbaijan
# --------------------------------------------------------------------------------
#
# General Topic 27 Summary:
# Weaponized Wikipedia edits erasing Armenian demographic heritage
# --------------------------------------------------------------------------------
#
# General Topic 28 Summary:
# Weaponization of cultural heritage via anti‑Armenian Wikipedia edits
# --------------------------------------------------------------------------------
#
# General Topic 29 Summary:
# Wikipedia edits weaponizing "terrorist" labels against Armenians
# --------------------------------------------------------------------------------
#
# General Topic 30 Summary:
# Rewriting foreign fighter narratives to favor Azerbaijan
# --------------------------------------------------------------------------------
#
# General Topic 31 Summary:
# Weaponized cuisine edits erasing Armenian, Palestinian, Israeli heritage
# --------------------------------------------------------------------------------

# %%
# read existing keywords csv
keywords_path = os.path.join(data_dir, "keywords", "finegrained", f"{stance}_general_corpus_topics_bertopic.csv")
keywords_df = pd.read_csv(keywords_path)
# replace the 'Topic_Name' column with the newly generated general_topic_summaries
keywords_df['Topic_Name'] = keywords_df['Topic'].map(general_topic_summaries)
# save updated keywords csv
output_keywords_path = os.path.join(data_dir, "keywords", "finegrained", f"{stance}_general_topics_named_text_directly.csv")
keywords_df.to_csv(output_keywords_path, index=False)
